# %%
#!pip -q install openai

# %%
import json
import os
import pandas as pd
import re
import time

# import local library
from GPTCall import ask_chatgpt
from SaveExcel_v2 import update_sheet_preserving_format, update_list_sheets_preserving_format

# %%
# read the current path, set to mypath
mypath = os.getcwd()
myfile = r"CMG_Processing_MSDManual.xlsx"
process_knowledge_filename = r"CMG_Prompts.xlsx"

# Use os.path.join to create the full paths
process_knowledge_file_fullpath = os.path.join(mypath, process_knowledge_filename.lstrip('/'))
myexcelfile = os.path.join(mypath, myfile.lstrip('/'))

# %%
myexcelfile
# Out:
# 'c:\\Users\\PC\\NIT6001\\CMG_prog_v3\\CMG_Processing_MSDManual.xlsx'

# %%
process_knowledge_file_fullpath
# Out:
# 'c:\\Users\\PC\\NIT6001\\CMG_prog_v3\\CMG_Prompts.xlsx'

# %%
def cmg_process_1(row_start=0, row_end=0):
    print ("main function started \n--------------------")
    # call the function to read the excel file paragraphs and articles
    df_paragraphs = pd.read_excel(myexcelfile, sheet_name='paragraphs')
    df_articles = pd.read_excel(myexcelfile, sheet_name='articles')

    # set the start and end row to process
    df_paragraphs, df_articles=group_paragraphs(df_paragraphs,  df_articles, row_start, row_end)

    data_sheets = [('paragraphs', df_paragraphs), ('articles', df_articles)]
    update_list_sheets_preserving_format(myexcelfile, data_sheets)


def check_excelfile_info(myexcelfile):
    # Use 'with' to ensure the Excel file is closed after checking
    with pd.ExcelFile(myexcelfile) as xls:
        # Iterate through all sheets
        for sheet_name in xls.sheet_names:
            # Read each sheet
            df = pd.read_excel(xls, sheet_name)

            # Print the sheet name and its columns
            print(f"Sheet name: {sheet_name}")
            print("Columns:", df.columns.tolist())

    # The file is automatically closed when exiting the 'with' block

def generate_prompt(step, prompt_path=process_knowledge_file_fullpath):
    # Map step numbers to knowledge areas
    step_mapping = {
        1: "step1_group_paragraphs",
        2: "step2_extract_events",
        3: "step3_convert_sentence_to_cognitive_map_graph"
    }
    
    # Check if the input step is valid
    if step not in step_mapping:
        return "Error: Invalid step input. Please enter 1, 2, or 3."
    
    # Retrieve the corresponding knowledge area
    knowledge_area = step_mapping[step]
    
    # Read the prompts from the excel file, sheet name: knowledge, column: knowledge_area
    df = pd.read_excel(prompt_path, sheet_name="knowledge", engine='openpyxl')
    
    # Filter based on the knowledge_area
    filtered_df = df[df['knowledge_area'] == knowledge_area]
    
    if filtered_df.empty:
        return f"Could not read the knowledge on {knowledge_area}.\n"
    
    myprompt = '\n'.join(filtered_df['knowledge'].astype(str))
    
    # Customize the message based on the step
    if step == 1:
        return myprompt + "\n Here is the article content:"
    elif step == 2:
        return myprompt + "\n Here is the paragraph:"
    elif step == 3:
        return myprompt + "\n Here is the sentence:"

def group_paragraphs(df_paragraphs, df_articles, row_start, row_end):
    print("\n group_paragraphs function \n --------------------------------------")
    
    # Generate the prompt for grouping paragraphs (step 1)
    myprompt = generate_prompt(1)
    print(myprompt)

    # Adjust row_end if it's 0 (process until the last row)
    if row_end == 0 or row_end > df_articles.index[-1]:   
        row_end = df_articles.index[-1]
    
    # Ensure row_start is within bounds
    if row_start < 0:
        row_start = 0
    
    # Ensure row_end is not before row_start
    if row_end < row_start:
        row_end = row_start
    
    # Loop through the articles from row_start to row_end
    for index in range(row_start, row_end + 1):
        if index > df_articles.index[-1]:  # Ensure index is within DataFrame bounds
            break  # Exit the loop if index exceeds the DataFrame row count

        # Access the current row
        row = df_articles.iloc[index]
        article_id = row['Article ID']
        fulltext = str(row['Full text'])
        processed_flag = row['processed']
        
        # Check if the article has already been processed and the fulltext is valid
        if processed_flag != 'Yes' and fulltext and fulltext.lower() != 'nan':
            # Call the GPT model with the prompt and full text
            response_text = ask_chatgpt(myprompt, fulltext)
            print("-------response_text-----------------------")
            print(response_text)

            # Parse the response and update df_paragraphs and df_articles
            df_paragraphs, article_label, article_metadata, article_keypoint = parse_paragraphs_json_v2(response_text, article_id, df_paragraphs)
            print("article_metadata: ", article_metadata) # 666
            # Mark the article as processed and store relevant data
            df_articles.loc[index, 'processed'] = 'Yes'
            df_articles.loc[index, 'article labels'] = ', '.join(article_label) if article_label else None
            df_articles.loc[index, 'article metadata'] = json.dumps(article_metadata)
            df_articles.loc[index, 'article keypoint'] = ', '.join(article_keypoint) if article_keypoint else None
            df_articles.loc[index, 'json str'] = response_text

    return df_paragraphs, df_articles


def parse_paragraphs_json_v2(response_text, article_id, df_paragraphs):
    # Load the response text as JSON
    try:
        response_json = response_text.replace("```json", "").replace("```", "") # Remove code block markdown
        response_json = json.loads(response_json)
    except json.JSONDecodeError:
        print("Error decoding JSON")
        return df_paragraphs, [], [], []
    
    # Extract relevant parts from the JSON
    article_label = response_json.get("article_label", [])
    article_metadata = response_json.get("article_metadata", [])
    print("article_metadata: ", article_metadata) # 666
    article_keypoint = response_json.get("article_keypoint", [])
    paragraphs = response_json.get("paragraphs", [])

    # Get the last ID from the DataFrame or start from 0 if empty
    last_id = df_paragraphs['ID'].max() if not df_paragraphs.empty else 0
    
    # Prepare a list to hold new rows for batch concatenation
    new_rows = []

    # Process each paragraph
    for paragraph in paragraphs:
        if isinstance(paragraph, dict):
            # Extract label and paragraph text from the dictionary
            label = paragraph.get("label", [])
            new_paragraph = paragraph.get("new_paragraph", "")
        else:
            # Handle unexpected data formats
            label = ["Unexpected data format error"]
            new_paragraph = str(paragraph)

        # Increment the ID and prepare a new row for the DataFrame
        last_id += 1
        new_row = {
            'ID': last_id,
            'Article ID': article_id,
            'paragraph labels': ', '.join(label),  # Convert label list to comma-separated string
            'Paragraph text': new_paragraph,
        }
        new_rows.append(new_row)
    
    # Concatenate the new rows to the existing DataFrame in a single operation
    if new_rows:
        df_paragraphs = pd.concat([df_paragraphs, pd.DataFrame(new_rows)], ignore_index=True)

    # Return the updated DataFrame, article labels, metadata, and key points
    return df_paragraphs, article_label, article_metadata, article_keypoint

# %%
cmg_process_1(0, 0)
# Out:
# main function started
# --------------------
#
#  group_paragraphs function
#  --------------------------------------
# Let's work this out in a step by step way to be sure we have the right answer.
# <instruction>
# Coherently split/breakdown this document into meaningful paragraphs. Keep metadata into a separated part.
# A document have a list of labels that: summarize the key areas covered in the article.
# Each paragraph can have a few labels. Labels represent the category and key info of the article.
# A document has Key points. Keep Key points into a separated part.
# </instruction>
# <format>
# Paragraphs should maintain natural language form.
# All labels are in a list.
# Labels should have full meaning, because each paragraph will be processed independently. For example, clinic observation is not a good label; 'Acute kidney injury clinic observation' is a clear label.
# Give json as the output, in this structure {"article_label": [***,***], "article_metadata": {metadata of the article}, "article_keypoint": [key points of the article], "paragraphs": [{"label": [***,***], "new_paragraph": ***},{"label": [***,***], "new_paragraph": ***},...]}
# </format>
# <constraint>
# Do not use pronouns.
# If the content is too long or for whatever reasSon, make sure the json is completed. For example, if your output is limited to 8192 characters, and the content has more than that, make sure the output json is properly closed.  You can add into the label that the content has not been completed because of the character limits.
# Answer only the json, do not provide other content. My program will parse your returned json.
# Use the same language as the article content.
# </constraint>
# <reminder>
# Adhere to {format}, {constraint} when performing {instruction}
# </reminder>
#  Here is the article content:
# {'id': 'chatcmpl-A9cTf3AQJqTQ8Hvl91XMr96SdATb6', 'object': 'chat.completion', 'created': 1726856223, 'model': 'gpt-4o-2024-08-06', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '```json\n{\n    "article_label": ["Ulcerative Colitis", "Inflammatory Bowel Disease", "Colon Cancer Risk", "Medical Treatment", "Surgical Treatment", "Diagnosis", "Symptoms", "Prognosis"],\n    "article_metadata": {\n        "authors": ["Aaron E. Walfish, MD", "Rafael Antonio Ching Companioni, MD"],\n        "affiliations": ["Mount Sinai Medical Center", "HCA Florida Gulf Coast Hospital"],\n        "review_date": "Nov 2023"\n    },\n    "article_keypoint": [\n        "Ulcerative colitis begins in the rectum and may extend proximally in a contiguous fashion without intervening patches of normal bowel.",\n        "Symptoms are intermittent episodes of abdominal cramping and bloody diarrhea.",\n        "Complications include fulminant colitis, which may lead to perforation; long-term, the risk of colon cancer is increased.",\n        "Treat mild disease with 5-ASA by rectum and, for proximal disease, by mouth.",\n        "Treat extensive disease with high-dose corticosteroids, immunomodulator therapy, biologics, tofacitinib, upadacitinib, or ozanimod.",\n        "Treat fulminant disease with high-dose IV corticosteroids or cyclosporine and antibiotics or infliximab; colectomy may be required.",\n        "About one third of patients with extensive ulcerative colitis ultimately require surgery."\n    ],\n    "paragraphs": [\n        {\n            "label": ["Ulcerative Colitis Overview", "Chronic Inflammatory Disease", "Colon Cancer Risk"],\n            "new_paragraph": "Ulcerative colitis is a chronic inflammatory and ulcerative disease arising in the colonic mucosa, characterized most often by bloody diarrhea. Extraintestinal symptoms, particularly arthritis, may occur. Long-term risk of colon cancer is elevated compared to unaffected people. Diagnosis is by colonoscopy. Treatment is with 5-aminosalicylic acid, corticosteroids, immunomodulators, biologics, antibiotics, and occasionally surgery."\n        },\n        {\n            "label": ["Pathophysiology", "Ulcerative Colitis", "Rectum Involvement"],\n            "new_paragraph": "Ulcerative colitis usually begins in the rectum. It may remain localized to the rectum (ulcerative proctitis) or extend proximally, sometimes involving the entire colon. Rarely, it involves most of the large bowel at once."\n        },\n        {\n            "label": ["Pathophysiology", "Ulcerative Colitis", "Mucosal Inflammation"],\n            "new_paragraph": "The inflammation caused by ulcerative colitis affects the mucosa and submucosa, and there is a sharp border between normal and affected tissue. Only in severe disease is the muscularis involved. Early in the disease, the mucous membrane is erythematous, finely granular, and friable, with loss of the normal vascular pattern and often with scattered hemorrhagic areas. Large mucosal ulcers with copious purulent exudate characterize severe disease. Islands of relatively normal or hyperplastic inflammatory mucosa (pseudopolyps) project above areas of ulcerated mucosa. Fistulas and abscesses do not occur."\n        },\n        {\n            "label": ["Symptoms", "Ulcerative Colitis", "Bloody Diarrhea"],\n            "new_paragraph": "Patients typically have attacks of bloody diarrhea of varied intensity and duration interspersed with asymptomatic intervals. Usually, an attack begins insidiously, with increased urgency to defecate, mild lower abdominal cramps, and blood and mucus in the stools. Some cases develop after an infection (e.g., amebiasis, bacillary dysentery)."\n        },\n        {\n            "label": ["Symptoms", "Ulcerative Colitis", "Systemic Symptoms"],\n            "new_paragraph": "Systemic symptoms and signs, more common with extensive ulcerative colitis, include malaise, fever, anemia, anorexia, and weight loss. Extraintestina ...
# -------response_text-----------------------
# ```json
# {
#     "article_label": ["Ulcerative Colitis", "Inflammatory Bowel Disease", "Colon Cancer Risk", "Medical Treatment", "Surgical Treatment", "Diagnosis", "Symptoms", "Prognosis"],
#     "article_metadata": {
#         "authors": ["Aaron E. Walfish, MD", "Rafael Antonio Ching Companioni, MD"],
#         "affiliations": ["Mount Sinai Medical Center", "HCA Florida Gulf Coast Hospital"],
#         "review_date": "Nov 2023"
#     },
#     "article_keypoint": [
#         "Ulcerative colitis begins in the rectum and may extend proximally in a contiguous fashion without intervening patches of normal bowel.",
#         "Symptoms are intermittent episodes of abdominal cramping and bloody diarrhea.",
#         "Complications include fulminant colitis, which may lead to perforation; long-term, the risk of colon cancer is increased.",
#         "Treat mild disease with 5-ASA by rectum and, for proximal disease, by mouth.",
#         "Treat extensive disease with high-dose corticosteroids, immunomodulator therapy, biologics, tofacitinib, upadacitinib, or ozanimod.",
#         "Treat fulminant disease with high-dose IV corticosteroids or cyclosporine and antibiotics or infliximab; colectomy may be required.",
#         "About one third of patients with extensive ulcerative colitis ultimately require surgery."
#     ],
#     "paragraphs": [
#         {
#             "label": ["Ulcerative Colitis Overview", "Chronic Inflammatory Disease", "Colon Cancer Risk"],
#             "new_paragraph": "Ulcerative colitis is a chronic inflammatory and ulcerative disease arising in the colonic mucosa, characterized most often by bloody diarrhea. Extraintestinal symptoms, particularly arthritis, may occur. Long-term risk of colon cancer is elevated compared to unaffected people. Diagnosis is by colonoscopy. Treatment is with 5-aminosalicylic acid, corticosteroids, immunomodulators, biologics, antibiotics, and occasionally surgery."
#         },
#         {
#             "label": ["Pathophysiology", "Ulcerative Colitis", "Rectum Involvement"],
#             "new_paragraph": "Ulcerative colitis usually begins in the rectum. It may remain localized to the rectum (ulcerative proctitis) or extend proximally, sometimes involving the entire colon. Rarely, it involves most of the large bowel at once."
#         },
#         {
#             "label": ["Pathophysiology", "Ulcerative Colitis", "Mucosal Inflammation"],
#             "new_paragraph": "The inflammation caused by ulcerative colitis affects the mucosa and submucosa, and there is a sharp border between normal and affected tissue. Only in severe disease is the muscularis involved. Early in the disease, the mucous membrane is erythematous, finely granular, and friable, with loss of the normal vascular pattern and often with scattered hemorrhagic areas. Large mucosal ulcers with copious purulent exudate characterize severe disease. Islands of relatively normal or hyperplastic inflammatory mucosa (pseudopolyps) project above areas of ulcerated mucosa. Fistulas and abscesses do not occur."
#         },
#         {
#             "label": ["Symptoms", "Ulcerative Colitis", "Bloody Diarrhea"],
#             "new_paragraph": "Patients typically have attacks of bloody diarrhea of varied intensity and duration interspersed with asymptomatic intervals. Usually, an attack begins insidiously, with increased urgency to defecate, mild lower abdominal cramps, and blood and mucus in the stools. Some cases develop after an infection (e.g., amebiasis, bacillary dysentery)."
#         },
#         {
#             "label": ["Symptoms", "Ulcerative Colitis", "Systemic Symptoms"],
#             "new_paragraph": "Systemic symptoms and signs, more common with extensive ulcerative colitis, include malaise, fever, anemia, anorexia, and weight loss. Extraintestinal manifestations of inflammatory bowel disease (IBD), particularly joint and skin complications, are most common when systemic symptoms are present."
#         },
#         {
#             "label": ["Diagnosis", "Ulcerative Colitis", "Colonoscopy"],
#             "new_paragraph": "Diagnosis of ulcerative colitis is suggested by typical symptoms and signs, particularly when accompanied by extraintestinal manifestations or a history of previous similar attacks. Ulcerative colitis should be distinguished from Crohn disease but more importantly from other causes of acute colitis (e.g., infection; in older patients, ischemia)."
#         },
#         {
#             "label": ["Diagnosis", "Ulcerative Colitis", "Laboratory Tests"],
#             "new_paragraph": "Laboratory tests should be done to screen for anemia, hypoalbuminemia, and electrolyte abnormalities. Liver tests should be done; elevated alkaline phosphatase and gamma-glutamyl transpeptidase levels suggest possible primary sclerosing cholangitis. Perinuclear antineutrophil cytoplasmic antibodies are relatively specific for ulcerative colitis."
#         },
#         {
#             "label": ["Treatment", "Ulcerative Colitis", "Dietary Management"],
#             "new_paragraph": "Avoiding raw fruits and vegetables limits trauma to the inflamed colonic mucosa and may lessen symptoms. A milk-free diet may help but need not be continued if no benefit is noted. Loperamide is indicated for relatively mild diarrhea; higher oral doses may be required for more intense diarrhea."
#         },
#         {
#             "label": ["Treatment", "Ulcerative Colitis", "Mild Disease"],
#             "new_paragraph": "Patients with mild to moderate ulcerative proctitis or proctosigmoiditis that does not extend proximally beyond the sigmoid colon are treated with 5-ASA (mesalamine) by enema once a day or twice a day depending on severity. Suppositories are effective for more distal disease and are usually preferred by patients."
#         },
#         {
#             "label": ["Treatment", "Ulcerative Colitis", "Severe Disease"],
#             "new_paragraph": "Patients with > 10 bloody bowel movements per day, tachycardia, high fever, or severe abdominal pain require hospitalization to receive biologic agent and/or high-dose IV corticosteroids. IV fluids and blood transfusion are given as needed for dehydration and anemia. The patient must be observed closely for the development of toxic colitis."
#         },
#         {
#             "label": ["Treatment", "Ulcerative Colitis", "Fulminant Colitis"],
#             "new_paragraph": "If fulminant or toxic colitis is suspected, the patient should stop all antidiarrheal medications, take nothing by mouth, and have inserted a long intestinal tube attached to intermittent suction. Aggressive IV fluid and electrolyte therapy with sodium chloride, potassium chloride, and blood as needed should be administered."
#         },
#         {
#             "label": ["Surgical Treatment", "Ulcerative Colitis", "Proctocolectomy"],
#             "new_paragraph": "Nearly one third of patients with extensive ulcerative colitis ultimately require surgery. Total proctocolectomy is curative: Life expectancy is restored to normal, and the risk of colon cancer is significantly decreased. However, some studies report up to 25% of patients subsequently develop inflammation in the small bowel mucosa consistent with Crohn disease."
#         },
#         {
#             "label": ["Prognosis", "Ulcerative Colitis", "Chronic Disease"],
#             "new_paragraph": "Usually, ulcerative colitis is chronic with repeated exacerbations and remissions. In some patients, an initial attack becomes fulminant with massive hemorrhage, perforation, or sepsis and toxemia. Complete recovery after a single attack occurs in a few patients."
#         },
#         {
#             "label": ["Prognosis", "Ulcerative Colitis", "Colon Cancer Risk"],
#             "new_paragraph": "The risk of colon cancer is proportional to the duration of disease and amount of colon affected but not necessarily to the clinical severity of the attacks. Some studies suggest that sustained microscopic inflammation is a risk factor, and that use of 5-aminosalicylic acid (5-ASA) to control inflammation is protective."
#         }
#     ]
# }
# ```
# article_metadata:  {'authors': ['Aaron E. Walfish, MD', 'Rafael Antonio Ching Companioni, MD'], 'affiliations': ['Mount Sinai Medical Center', 'HCA Florida Gulf Coast Hospital'], 'review_date': 'Nov 2023'}
# article_metadata:  {'authors': ['Aaron E. Walfish, MD', 'Rafael Antonio Ching Companioni, MD'], 'affiliations': ['Mount Sinai Medical Center', 'HCA Florida Gulf Coast Hospital'], 'review_date': 'Nov 2023'}
# {'id': 'chatcmpl-A9cU9U98UKsW5VC0iYlT4dlO1M8Jq', 'object': 'chat.completion', 'created': 1726856253, 'model': 'gpt-4o-2024-08-06', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '```json\n{\n    "article_label": [\n        "Crohn Disease Overview",\n        "Inflammatory Bowel Disease",\n        "Gastrointestinal Disorders"\n    ],\n    "article_metadata": {\n        "authors": [\n            "Aaron E. Walfish, MD",\n            "Rafael Antonio Ching Companioni, MD"\n        ],\n        "affiliations": [\n            "Mount Sinai Medical Center",\n            "HCA Florida Gulf Coast Hospital"\n        ],\n        "review_date": "Nov 2023"\n    },\n    "article_keypoint": [\n        "Crohn disease typically affects the ileum and/or colon but spares the rectum.",\n        "Intermittent areas of diseased bowel are sharply demarcated from adjacent normal bowel.",\n        "Symptoms primarily involve episodic diarrhea and abdominal pain.",\n        "Complications include abdominal abscesses and enterocutaneous fistulas.",\n        "Treat mild disease with 5-aminosalicylic acid and/or antibiotics.",\n        "Treat moderate to severe disease with corticosteroids and sometimes immunomodulators or biologics.",\n        "About 70% of patients ultimately require an operation."\n    ],\n    "paragraphs": [\n        {\n            "label": [\n                "Crohn Disease Overview",\n                "Symptoms and Diagnosis",\n                "Treatment Options"\n            ],\n            "new_paragraph": "Crohn disease is a chronic transmural inflammatory bowel disease that usually affects the distal ileum and colon but may occur in any part of the gastrointestinal tract. Symptoms include diarrhea and abdominal pain. Abscesses, internal and external fistulas, and bowel obstruction may arise. Extraintestinal symptoms, particularly arthritis, may occur. Diagnosis is by colonoscopy and imaging studies. Treatment is with 5-aminosalicylic acid, corticosteroids, immunomodulators, anticytokines, antibiotics, and often surgery."\n        },\n        {\n            "label": [\n                "Pathophysiology of Crohn Disease",\n                "Gastrointestinal Tract Inflammation",\n                "Bowel Obstruction"\n            ],\n            "new_paragraph": "Crohn disease begins with crypt inflammation and abscesses, which progress to tiny focal aphthoid ulcers. These mucosal lesions may develop into deep longitudinal and transverse ulcers with intervening mucosal edema, creating a characteristic cobblestoned appearance to the bowel. Transmural spread of inflammation leads to lymphedema and thickening of the bowel wall and mesentery. Mesenteric fat typically extends onto the serosal surface of the bowel. Mesenteric lymph nodes often enlarge. Extensive inflammation may result in hypertrophy of the muscularis mucosae, fibrosis, and stricture formation, which can lead to bowel obstruction."\n        },\n        {\n            "label": [\n                "Complications of Crohn Disease",\n                "Fistulas and Abscesses",\n                "Granulomas"\n            ],\n            "new_paragraph": "Abscesses are common, and fistulas often penetrate into adjoining structures, including other loops of bowel, the bladder, or psoas muscle. Fistulas may even extend to the skin of the anterior abdomen or flanks. Independently of intra-abdominal disease activity, perianal fistulas and abscesses occur in 25 to 33% of cases; these complications are frequently the most troublesome aspects of Crohn disease. Noncaseating granulomas can occur in lymph nodes, peritoneum, the liver, and all layers of the bowel wall. Although pathognomonic when present, granulomas are not detected in about half of patients with Crohn disease."\n        },\n        {\n            "label": [\n                "Symptoms and Signs of Crohn Disease",\n                "Initial Manifestations",\n                "Perianal Disease"\n            ],\n       ...
# -------response_text-----------------------
# ```json
# {
#     "article_label": [
#         "Crohn Disease Overview",
#         "Inflammatory Bowel Disease",
#         "Gastrointestinal Disorders"
#     ],
#     "article_metadata": {
#         "authors": [
#             "Aaron E. Walfish, MD",
#             "Rafael Antonio Ching Companioni, MD"
#         ],
#         "affiliations": [
#             "Mount Sinai Medical Center",
#             "HCA Florida Gulf Coast Hospital"
#         ],
#         "review_date": "Nov 2023"
#     },
#     "article_keypoint": [
#         "Crohn disease typically affects the ileum and/or colon but spares the rectum.",
#         "Intermittent areas of diseased bowel are sharply demarcated from adjacent normal bowel.",
#         "Symptoms primarily involve episodic diarrhea and abdominal pain.",
#         "Complications include abdominal abscesses and enterocutaneous fistulas.",
#         "Treat mild disease with 5-aminosalicylic acid and/or antibiotics.",
#         "Treat moderate to severe disease with corticosteroids and sometimes immunomodulators or biologics.",
#         "About 70% of patients ultimately require an operation."
#     ],
#     "paragraphs": [
#         {
#             "label": [
#                 "Crohn Disease Overview",
#                 "Symptoms and Diagnosis",
#                 "Treatment Options"
#             ],
#             "new_paragraph": "Crohn disease is a chronic transmural inflammatory bowel disease that usually affects the distal ileum and colon but may occur in any part of the gastrointestinal tract. Symptoms include diarrhea and abdominal pain. Abscesses, internal and external fistulas, and bowel obstruction may arise. Extraintestinal symptoms, particularly arthritis, may occur. Diagnosis is by colonoscopy and imaging studies. Treatment is with 5-aminosalicylic acid, corticosteroids, immunomodulators, anticytokines, antibiotics, and often surgery."
#         },
#         {
#             "label": [
#                 "Pathophysiology of Crohn Disease",
#                 "Gastrointestinal Tract Inflammation",
#                 "Bowel Obstruction"
#             ],
#             "new_paragraph": "Crohn disease begins with crypt inflammation and abscesses, which progress to tiny focal aphthoid ulcers. These mucosal lesions may develop into deep longitudinal and transverse ulcers with intervening mucosal edema, creating a characteristic cobblestoned appearance to the bowel. Transmural spread of inflammation leads to lymphedema and thickening of the bowel wall and mesentery. Mesenteric fat typically extends onto the serosal surface of the bowel. Mesenteric lymph nodes often enlarge. Extensive inflammation may result in hypertrophy of the muscularis mucosae, fibrosis, and stricture formation, which can lead to bowel obstruction."
#         },
#         {
#             "label": [
#                 "Complications of Crohn Disease",
#                 "Fistulas and Abscesses",
#                 "Granulomas"
#             ],
#             "new_paragraph": "Abscesses are common, and fistulas often penetrate into adjoining structures, including other loops of bowel, the bladder, or psoas muscle. Fistulas may even extend to the skin of the anterior abdomen or flanks. Independently of intra-abdominal disease activity, perianal fistulas and abscesses occur in 25 to 33% of cases; these complications are frequently the most troublesome aspects of Crohn disease. Noncaseating granulomas can occur in lymph nodes, peritoneum, the liver, and all layers of the bowel wall. Although pathognomonic when present, granulomas are not detected in about half of patients with Crohn disease."
#         },
#         {
#             "label": [
#                 "Symptoms and Signs of Crohn Disease",
#                 "Initial Manifestations",
#                 "Perianal Disease"
#             ],
#             "new_paragraph": "The most common initial manifestations of Crohn disease are chronic diarrhea with abdominal pain, fever, anorexia, and weight loss. The abdomen is tender, and a mass or fullness may be palpable. Gross rectal bleeding is unusual except in isolated colonic disease, which may manifest similarly to ulcerative colitis. Some patients present with an acute abdomen that simulates acute appendicitis or intestinal obstruction. About 33% of patients have perianal disease (especially fissures and fistulas), which is sometimes the most prominent or even initial complaint."
#         },
#         {
#             "label": [
#                 "Diagnosis of Crohn Disease",
#                 "Imaging Studies",
#                 "Differential Diagnosis"
#             ],
#             "new_paragraph": "Crohn disease should be suspected in a patient with inflammatory or obstructive symptoms or in a patient without prominent GI symptoms but with perianal fistulas or abscesses or with otherwise unexplained arthritis, erythema nodosum, fever, anemia, or (in a child) stunted growth. A family history of Crohn disease also increases the index of suspicion. Similar symptoms and signs may be caused by other GI disorders, particularly ulcerative colitis. Differentiation from ulcerative colitis may be an issue in the 20% of cases in which Crohn disease is confined to the colon."
#         },
#         {
#             "label": [
#                 "Treatment of Crohn Disease",
#                 "Symptom Relief",
#                 "Medication and Surgery"
#             ],
#             "new_paragraph": "Cramps and diarrhea may be relieved by oral administration of loperamide 2 to 4 mg or antispasmodic drugs up to 4 times a day. Such symptomatic treatment is safe, except in cases of severe, acute Crohn colitis, which may progress to toxic colitis as in ulcerative colitis. Hydrophilic mucilloids sometimes help prevent anal irritation by increasing stool firmness. Dietary roughage is to be avoided in stricturing disease or active colonic inflammation. Routine health maintenance measures should be emphasized."
#         },
#         {
#             "label": [
#                 "Prognosis for Crohn Disease",
#                 "Disease Management",
#                 "Quality of Life"
#             ],
#             "new_paragraph": "Established Crohn disease is rarely cured but is characterized by intermittent exacerbations and remissions. Some patients have severe disease with frequent, debilitating periods of pain. However, with judicious medical therapy and, where appropriate, surgical therapy, most patients function well and adapt successfully. Disease-related mortality is very low. GI cancer, including cancer of the colon and small bowel, is the leading cause of excess Crohn disease-related mortality. Thromboembolic complications also may cause death."
#         }
#     ]
# }
# ```
# article_metadata:  {'authors': ['Aaron E. Walfish, MD', 'Rafael Antonio Ching Companioni, MD'], 'affiliations': ['Mount Sinai Medical Center', 'HCA Florida Gulf Coast Hospital'], 'review_date': 'Nov 2023'}
# article_metadata:  {'authors': ['Aaron E. Walfish, MD', 'Rafael Antonio Ching Companioni, MD'], 'affiliations': ['Mount Sinai Medical Center', 'HCA Florida Gulf Coast Hospital'], 'review_date': 'Nov 2023'}
# {'id': 'chatcmpl-A9cUYYvEKyeS5dKGotAC7wtfYO8Ej', 'object': 'chat.completion', 'created': 1726856278, 'model': 'gpt-4o-2024-08-06', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '```json\n{\n    "article_label": [\n        "Gastrointestinal bleeding overview",\n        "Etiology of GI bleeding",\n        "Evaluation of GI bleeding",\n        "Treatment of GI bleeding",\n        "Geriatrics and GI bleeding"\n    ],\n    "article_metadata": {\n        "author": "Parswa Ansari, MD",\n        "institution": "Hofstra Northwell-Lenox Hill Hospital, New York",\n        "review_date": "May 2023"\n    },\n    "article_keypoint": [\n        "Rectal bleeding may result from upper or lower GI bleeding.",\n        "Orthostatic changes in vital signs are unreliable markers for serious bleeding.",\n        "Hematemesis, hematochezia, or melena should be considered an emergency and managed in an intensive care unit or other monitored setting.",\n        "IV fluid resuscitation should begin immediately and may require transfusion with blood products.",\n        "About 80% of patients stop bleeding spontaneously; various endoscopic techniques are usually the first choice for the remainder."\n    ],\n    "paragraphs": [\n        {\n            "label": [\n                "Gastrointestinal bleeding overview",\n                "Symptoms of GI bleeding"\n            ],\n            "new_paragraph": "Gastrointestinal (GI) bleeding can originate anywhere from the mouth to the anus and can be overt or occult. The manifestations depend on the location and rate of bleeding. Hematemesis is vomiting of red blood and indicates upper GI bleeding, usually from a peptic ulcer, vascular lesion, or varix. Coffee-ground emesis is vomiting of dark brown, granular material that resembles coffee grounds. It results from upper GI bleeding that has slowed or stopped, with conversion of red hemoglobin to brown hematin by gastric acid."\n        },\n        {\n            "label": [\n                "Symptoms of GI bleeding",\n                "Upper and lower GI bleeding"\n            ],\n            "new_paragraph": "Hematochezia is the passage of gross blood from the rectum and usually indicates lower GI bleeding but may result from vigorous upper GI bleeding with rapid transit of blood through the intestines. Melena is black, tarry stool and typically indicates upper GI bleeding, but bleeding from a source in the small bowel or right colon may also be the cause. About 100 to 200 mL of blood in the upper GI tract is required to cause melena, which may persist for several days after bleeding has ceased. Black stool that does not contain occult blood may result from ingestion of iron, bismuth, or various foods and should not be mistaken for melena."\n        },\n        {\n            "label": [\n                "Symptoms of GI bleeding",\n                "Acute and chronic GI bleeding"\n            ],\n            "new_paragraph": "Chronic occult bleeding can occur from anywhere in the GI tract and is detectable by chemical testing of a stool specimen. Acute, severe bleeding also can occur from anywhere in the GI tract. Patients may present with signs of shock. Patients with underlying ischemic heart disease may develop angina or myocardial infarction because of coronary hypoperfusion. GI bleeding in patients with underlying liver disease may precipitate portosystemic encephalopathy or hepatorenal syndrome (kidney failure secondary to liver failure)."\n        },\n        {\n            "label": [\n                "Etiology of GI bleeding",\n                "Upper and lower GI bleeding"\n            ],\n            "new_paragraph": "There are many possible causes of GI bleeding, which are divided into upper GI (above the ligament of Treitz), lower GI, and small bowel. Bleeding of any cause is more likely, and potentially more severe, in patients with chronic liver disease, in those with hereditary coagulation disorders, or in those taking certain ...
# -------response_text-----------------------
# ```json
# {
#     "article_label": [
#         "Gastrointestinal bleeding overview",
#         "Etiology of GI bleeding",
#         "Evaluation of GI bleeding",
#         "Treatment of GI bleeding",
#         "Geriatrics and GI bleeding"
#     ],
#     "article_metadata": {
#         "author": "Parswa Ansari, MD",
#         "institution": "Hofstra Northwell-Lenox Hill Hospital, New York",
#         "review_date": "May 2023"
#     },
#     "article_keypoint": [
#         "Rectal bleeding may result from upper or lower GI bleeding.",
#         "Orthostatic changes in vital signs are unreliable markers for serious bleeding.",
#         "Hematemesis, hematochezia, or melena should be considered an emergency and managed in an intensive care unit or other monitored setting.",
#         "IV fluid resuscitation should begin immediately and may require transfusion with blood products.",
#         "About 80% of patients stop bleeding spontaneously; various endoscopic techniques are usually the first choice for the remainder."
#     ],
#     "paragraphs": [
#         {
#             "label": [
#                 "Gastrointestinal bleeding overview",
#                 "Symptoms of GI bleeding"
#             ],
#             "new_paragraph": "Gastrointestinal (GI) bleeding can originate anywhere from the mouth to the anus and can be overt or occult. The manifestations depend on the location and rate of bleeding. Hematemesis is vomiting of red blood and indicates upper GI bleeding, usually from a peptic ulcer, vascular lesion, or varix. Coffee-ground emesis is vomiting of dark brown, granular material that resembles coffee grounds. It results from upper GI bleeding that has slowed or stopped, with conversion of red hemoglobin to brown hematin by gastric acid."
#         },
#         {
#             "label": [
#                 "Symptoms of GI bleeding",
#                 "Upper and lower GI bleeding"
#             ],
#             "new_paragraph": "Hematochezia is the passage of gross blood from the rectum and usually indicates lower GI bleeding but may result from vigorous upper GI bleeding with rapid transit of blood through the intestines. Melena is black, tarry stool and typically indicates upper GI bleeding, but bleeding from a source in the small bowel or right colon may also be the cause. About 100 to 200 mL of blood in the upper GI tract is required to cause melena, which may persist for several days after bleeding has ceased. Black stool that does not contain occult blood may result from ingestion of iron, bismuth, or various foods and should not be mistaken for melena."
#         },
#         {
#             "label": [
#                 "Symptoms of GI bleeding",
#                 "Acute and chronic GI bleeding"
#             ],
#             "new_paragraph": "Chronic occult bleeding can occur from anywhere in the GI tract and is detectable by chemical testing of a stool specimen. Acute, severe bleeding also can occur from anywhere in the GI tract. Patients may present with signs of shock. Patients with underlying ischemic heart disease may develop angina or myocardial infarction because of coronary hypoperfusion. GI bleeding in patients with underlying liver disease may precipitate portosystemic encephalopathy or hepatorenal syndrome (kidney failure secondary to liver failure)."
#         },
#         {
#             "label": [
#                 "Etiology of GI bleeding",
#                 "Upper and lower GI bleeding"
#             ],
#             "new_paragraph": "There are many possible causes of GI bleeding, which are divided into upper GI (above the ligament of Treitz), lower GI, and small bowel. Bleeding of any cause is more likely, and potentially more severe, in patients with chronic liver disease, in those with hereditary coagulation disorders, or in those taking certain medications. Medications associated with GI bleeding include anticoagulants, those affecting platelet function, and those affecting mucosal defenses."
#         },
#         {
#             "label": [
#                 "Common causes of GI bleeding",
#                 "Upper GI bleeding causes"
#             ],
#             "new_paragraph": "Common causes of upper GI bleeding include duodenal ulcer, gastric or duodenal erosions, varices, gastric ulcer, Mallory-Weiss tear, erosive esophagitis, angioma, arteriovenous malformations, gastrointestinal stromal tumors, and hemobilia."
#         },
#         {
#             "label": [
#                 "Common causes of GI bleeding",
#                 "Lower GI bleeding causes"
#             ],
#             "new_paragraph": "Common causes of lower GI bleeding include anal fissures, angiodysplasia, colitis, colonic carcinoma, colonic polyps, diverticular disease, inflammatory bowel disease, and internal hemorrhoids."
#         },
#         {
#             "label": [
#                 "Common causes of GI bleeding",
#                 "Small bowel lesions"
#             ],
#             "new_paragraph": "Small-bowel lesions, which are rare, can include angiomas, arteriovenous malformations, Meckel diverticulum, and tumors."
#         },
#         {
#             "label": [
#                 "Evaluation of GI bleeding",
#                 "Initial stabilization"
#             ],
#             "new_paragraph": "In acutely ill patients, stabilization with airway management, IV fluids, or transfusions is essential before and during diagnostic evaluation."
#         },
#         {
#             "label": [
#                 "Evaluation of GI bleeding",
#                 "History taking"
#             ],
#             "new_paragraph": "History of present illness should attempt to ascertain quantity and frequency of blood passage. Patients with hematemesis should be asked whether blood was passed with initial vomiting or only after an initial nonbloody emesis. Patients with rectal bleeding should be asked whether pure blood was passed; whether it was mixed with stool, pus, or mucus; or whether blood simply coated the stool or toilet paper."
#         },
#         {
#             "label": [
#                 "Evaluation of GI bleeding",
#                 "Physical examination"
#             ],
#             "new_paragraph": "General examination is focused on vital signs and other indicators of shock or hypovolemia and anemia. Orthostatic changes in pulse or blood pressure often develop after acute loss of blood. External stigmata of bleeding disorders are sought, as are signs of chronic liver disease and portal hypertension. A digital rectal examination is necessary to search for stool color, masses, and fissures."
#         },
#         {
#             "label": [
#                 "Evaluation of GI bleeding",
#                 "Red flags"
#             ],
#             "new_paragraph": "Several findings suggest hypovolemia or hemorrhagic shock, including syncope, hypotension, pallor, diaphoresis, tachycardia, and oliguria."
#         },
#         {
#             "label": [
#                 "Evaluation of GI bleeding",
#                 "Interpretation of findings"
#             ],
#             "new_paragraph": "The history and physical examination suggest a source of bleeding in about 50% of patients, but findings are rarely diagnostic, and confirmatory testing is required. Epigastric abdominal discomfort relieved by food or antacids suggests peptic ulcer disease. Weight loss and anorexia suggest a GI cancer. A history of cirrhosis or chronic hepatitis suggests esophageal varices."
#         },
#         {
#             "label": [
#                 "Evaluation of GI bleeding",
#                 "Testing"
#             ],
#             "new_paragraph": "Several tests are done to help confirm the suspected diagnosis: Complete blood count, coagulation profile, and often other laboratory studies. Nasogastric tube for all but those with minimal rectal bleeding. Upper endoscopy for suspected upper GI bleeding. Colonoscopy for lower GI bleeding. Sometimes angiography for upper and lower GI bleeding."
#         },
#         {
#             "label": [
#                 "Treatment of GI bleeding",
#                 "General treatment"
#             ],
#             "new_paragraph": "Secure airway if needed. IV fluid resuscitation. Blood transfusion if needed. Sometimes medications. In some, endoscopic or angiographic hemostasis. Hematemesis, hematochezia, or melena should be considered an emergency. Admission to an intensive care unit or other monitored setting, with consultation by both a gastroenterologist and a surgeon, is recommended for all patients with severe GI bleeding."
#         },
#         {
#             "label": [
#                 "Treatment of GI bleeding",
#                 "Airway management"
#             ],
#             "new_paragraph": "A major cause of morbidity and mortality in patients with active upper GI bleeding is aspiration of blood with subsequent respiratory compromise. To prevent these problems, endotracheal intubation should be considered in patients who have inadequate gag reflexes or are obtunded or unconscious."
#         },
#         {
#             "label": [
#                 "Treatment of GI bleeding",
#                 "Fluid resuscitation and transfusion"
#             ],
#             "new_paragraph": "Intravenous access should be obtained immediately. IV fluids are initiated immediately, as for any patient with hypovolemia or hemorrhagic shock. Patients requiring further resuscitation should receive transfusion with packed RBCs. Platelet count should be monitored closely; platelet transfusion may be required with severe bleeding."
#         },
#         {
#             "label": [
#                 "Treatment of GI bleeding",
#                 "Medications"
#             ],
#             "new_paragraph": "An IV proton pump inhibitor may be started in cases of possible upper GI bleeding and should be used if a gastroduodenal ulcer is confirmed as the source of bleeding. Octreotide is used in patients with suspected variceal bleeding."
#         },
#         {
#             "label": [
#                 "Treatment of GI bleeding",
#                 "Hemostasis"
#             ],
#             "new_paragraph": "GI bleeding stops spontaneously in about 80% of patients. The remaining patients require some type of intervention. Specific therapy depends on the bleeding site. Early intervention to control bleeding is important to minimize mortality, particularly in older adults."
#         },
#         {
#             "label": [
#                 "Geriatrics and GI bleeding",
#                 "Common causes in older adults"
#             ],
#             "new_paragraph": "In older adults, hemorrhoids and colorectal cancer are the most common causes of minor bleeding. Peptic ulcer, diverticular disease, and angiodysplasia are the most common causes of major bleeding. Variceal bleeding is less common than in younger patients."
#         },
#         {
#             "label": [
#                 "Geriatrics and GI bleeding",
#                 "Management in older adults"
#             ],
#             "new_paragraph": "Massive GI bleeding is tolerated poorly by older adults. Diagnosis must be made quickly, and treatment must be started sooner than in younger patients, who can better tolerate repeated episodes of bleeding."
#         }
#     ]
# }
# ```
# article_metadata:  {'author': 'Parswa Ansari, MD', 'institution': 'Hofstra Northwell-Lenox Hill Hospital, New York', 'review_date': 'May 2023'}
# article_metadata:  {'author': 'Parswa Ansari, MD', 'institution': 'Hofstra Northwell-Lenox Hill Hospital, New York', 'review_date': 'May 2023'}
# {'id': 'chatcmpl-A9cVDAr1dGLadx8OPQb6JPyw5QP1d', 'object': 'chat.completion', 'created': 1726856319, 'model': 'gpt-4o-2024-08-06', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '```json\n{\n    "article_label": ["Gastric acid analysis", "Medical procedure", "Gastric disorders", "Diagnostic test"],\n    "article_metadata": {\n        "author": "Jonathan Gotfried, MD",\n        "affiliation": "Lewis Katz School of Medicine at Temple University",\n        "reviewed_revised": "Mar 2023"\n    },\n    "article_keypoint": [\n        "Gastric acid analysis is rarely performed in current practice.",\n        "The test measures gastric acid output in basal and stimulated states.",\n        "It is useful for patients with recurrent ulcers after vagotomy and elevated serum gastrin levels.",\n        "The test can indicate conditions like Zollinger-Ellison syndrome, pernicious anemia, and atrophic gastritis.",\n        "Gastric analysis involves nasogastric tube insertion and collection of gastric juice.",\n        "Complications from the procedure are very rare."\n    ],\n    "paragraphs": [\n        {\n            "label": ["Gastric acid analysis", "Medical procedure", "Recurrent ulcer", "Vagotomy"],\n            "new_paragraph": "Gastric acid analysis is rarely done in current practice. When conducted, samples of stomach contents obtained via nasogastric tube are used to measure gastric acid output in a basal and stimulated state. This information may be useful in a patient who develops a recurrent ulcer after surgical vagotomy for peptic ulcer disease. In this case, a positive acid response to stimulation (sham feeding) indicates an incomplete vagotomy."\n        },\n        {\n            "label": ["Gastric acid analysis", "Elevated serum gastrin", "Zollinger-Ellison syndrome", "Hypochlorhydria"],\n            "new_paragraph": "The test also is used to evaluate a patient with elevated serum gastrin levels. Hyperchlorhydria in the presence of elevated gastrin usually indicates Zollinger-Ellison syndrome. Hypochlorhydria in the presence of elevated gastrin indicates impairment of acid output, such as occurs in pernicious anemia, atrophic gastritis, and Ménétrier disease and after inhibition of gastric acid secretion by potent antisecretory medications."\n        },\n        {\n            "label": ["Gastric acid analysis", "Medical procedure", "Nasogastric tube", "Basal acid output"],\n            "new_paragraph": "To do gastric analysis, a nasogastric tube is inserted and the gastric contents are aspirated and discarded. Gastric juice is then collected for 1 hour, divided into four 15-minute samples. These samples represent basal acid output."\n        },\n        {\n            "label": ["Gastric acid analysis", "Esophageal pH-monitoring", "Medical procedure"],\n            "new_paragraph": "Gastric analysis can also be done during catheter-based esophageal pH-monitoring."\n        },\n        {\n            "label": ["Gastric acid analysis", "Medical procedure", "Complications"],\n            "new_paragraph": "Complications of gastric analysis are very rare."\n        }\n    ]\n}\n```', 'refusal': None}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 659, 'completion_tokens': 630, 'total_tokens': 1289, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'system_fingerprint': 'fp_7568d46099'}
# -------response_text-----------------------
# ```json
# {
#     "article_label": ["Gastric acid analysis", "Medical procedure", "Gastric disorders", "Diagnostic test"],
#     "article_metadata": {
#         "author": "Jonathan Gotfried, MD",
#         "affiliation": "Lewis Katz School of Medicine at Temple University",
#         "reviewed_revised": "Mar 2023"
#     },
#     "article_keypoint": [
#         "Gastric acid analysis is rarely performed in current practice.",
#         "The test measures gastric acid output in basal and stimulated states.",
#         "It is useful for patients with recurrent ulcers after vagotomy and elevated serum gastrin levels.",
#         "The test can indicate conditions like Zollinger-Ellison syndrome, pernicious anemia, and atrophic gastritis.",
#         "Gastric analysis involves nasogastric tube insertion and collection of gastric juice.",
#         "Complications from the procedure are very rare."
#     ],
#     "paragraphs": [
#         {
#             "label": ["Gastric acid analysis", "Medical procedure", "Recurrent ulcer", "Vagotomy"],
#             "new_paragraph": "Gastric acid analysis is rarely done in current practice. When conducted, samples of stomach contents obtained via nasogastric tube are used to measure gastric acid output in a basal and stimulated state. This information may be useful in a patient who develops a recurrent ulcer after surgical vagotomy for peptic ulcer disease. In this case, a positive acid response to stimulation (sham feeding) indicates an incomplete vagotomy."
#         },
#         {
#             "label": ["Gastric acid analysis", "Elevated serum gastrin", "Zollinger-Ellison syndrome", "Hypochlorhydria"],
#             "new_paragraph": "The test also is used to evaluate a patient with elevated serum gastrin levels. Hyperchlorhydria in the presence of elevated gastrin usually indicates Zollinger-Ellison syndrome. Hypochlorhydria in the presence of elevated gastrin indicates impairment of acid output, such as occurs in pernicious anemia, atrophic gastritis, and Ménétrier disease and after inhibition of gastric acid secretion by potent antisecretory medications."
#         },
#         {
#             "label": ["Gastric acid analysis", "Medical procedure", "Nasogastric tube", "Basal acid output"],
#             "new_paragraph": "To do gastric analysis, a nasogastric tube is inserted and the gastric contents are aspirated and discarded. Gastric juice is then collected for 1 hour, divided into four 15-minute samples. These samples represent basal acid output."
#         },
#         {
#             "label": ["Gastric acid analysis", "Esophageal pH-monitoring", "Medical procedure"],
#             "new_paragraph": "Gastric analysis can also be done during catheter-based esophageal pH-monitoring."
#         },
#         {
#             "label": ["Gastric acid analysis", "Medical procedure", "Complications"],
#             "new_paragraph": "Complications of gastric analysis are very rare."
#         }
#     ]
# }
# ```
# article_metadata:  {'author': 'Jonathan Gotfried, MD', 'affiliation': 'Lewis Katz School of Medicine at Temple University', 'reviewed_revised': 'Mar 2023'}
# article_metadata:  {'author': 'Jonathan Gotfried, MD', 'affiliation': 'Lewis Katz School of Medicine at Temple University', 'reviewed_revised': 'Mar 2023'}
# ...
# -------response_text-----------------------
# ```json
# {
#     "article_label": ["Peutz-Jeghers Syndrome", "Genetic Disorder", "Cancer Risk", "Diagnosis", "Surveillance"],
#     "article_metadata": {
#         "author": "Anthony Villano, MD, Fox Chase Cancer Center",
#         "review_date": "Oct 2023",
#         "patient_education": "VIEW PATIENT EDUCATION",
#         "topic_resources": {
#             "3D Models": 0,
#             "Audios": 0,
#             "Calculators": 0,
#             "Images": 2,
#             "Tables": 0,
#             "Videos": 0
#         }
#     },
#     "article_keypoint": [
#         "Peutz-Jeghers syndrome is an autosomal dominant disease with multiple hamartomatous polyps and distinctive pigmented skin lesions.",
#         "The syndrome is caused by a germline mutation of the STK11/LKB1 tumor suppressor gene.",
#         "Patients have an increased risk of both GI and non-GI cancers.",
#         "Diagnosis is suggested by clinical evaluation and genetic testing for STK11 mutations.",
#         "GI cancer surveillance includes colonoscopy, upper endoscopy, and video capsule endoscopy starting at age 8.",
#         "Surveillance for other cancers includes breast, ovarian, endometrial, cervical, pancreatic, and testicular cancer.",
#         "First-degree relatives should be evaluated for skin lesions of Peutz-Jeghers syndrome."
#     ],
#     "paragraphs": [
#         {
#             "label": ["Peutz-Jeghers Syndrome", "Genetic Disorder", "Cancer Risk"],
#             "new_paragraph": "Peutz-Jeghers syndrome is an autosomal dominant disease with multiple hamartomatous polyps in the stomach, small bowel, and colon along with distinctive pigmented skin lesions. Most (66 to 94%) cases appear to be caused by a germline mutation of the STK11/LKB1 (serine/threonine kinase 11) tumor suppressor gene. Patients are at a significantly increased risk of gastrointestinal (GI) and non-GI cancers. GI cancers include those of the pancreas, stomach, small intestine, and colon. Non-GI cancers include those of the breast, lung, uterus, ovaries, and testes."
#         },
#         {
#             "label": ["Peutz-Jeghers Syndrome", "Skin Lesions", "Clinical Features"],
#             "new_paragraph": "The skin lesions are melanotic macules of the skin and mucous membranes, especially of the perioral region, lips and gums, hands, and feet. All but the buccal lesions tend to fade by puberty. Polyps may bleed and often cause obstruction or intussusception."
#         },
#         {
#             "label": ["Peutz-Jeghers Syndrome", "Diagnosis", "Genetic Testing"],
#             "new_paragraph": "Diagnosis of Peutz-Jeghers syndrome is suggested by the clinical picture. Patients with perioral or buccal pigmentation and/or ≥ 2 GI hamartomatous polyps or a family history of Peutz-Jeghers syndrome should be evaluated for this syndrome including testing for STK11 mutations (see also the American College of Gastroenterology's 2015 clinical guidelines about genetic testing and management of hereditary GI cancer syndromes)."
#         },
#         {
#             "label": ["Peutz-Jeghers Syndrome", "GI Cancer Surveillance", "Cancer Risk"],
#             "new_paragraph": "GI cancer surveillance of patients with Peutz-Jeghers syndrome includes colonoscopy, upper endoscopy, and video capsule endoscopy beginning at age 8, with the timing of subsequent surveillance determined by the findings. Colonic polyps > 1 cm typically are removed."
#         },
#         {
#             "label": ["Peutz-Jeghers Syndrome", "Cancer Surveillance", "Non-GI Cancer Risk"],
#             "new_paragraph": "Surveillance for breast, ovarian, endometrial, and cervical cancer should include breast self-examination starting at age 18 and then should include annual pelvic examination, pelvic or transvaginal ultrasound, Papanicolaou (Pap) test, and breast MRI and/or mammogram starting at age 25. Surveillance for pancreatic cancer should begin at age 30 and includes magnetic resonance cholangiopancreatography (MRCP) or endoscopic ultrasonography. Surveillance of the testes (for Sertoli cell tumor) by testicular examination should be done annually from birth to adolescence; ultrasonography should be done if abnormalities are palpated or if feminization occurs."
#         },
#         {
#             "label": ["Peutz-Jeghers Syndrome", "Cancer Risk", "Lung Cancer"],
#             "new_paragraph": "Although patients with Peutz-Jeghers syndrome are at increased risk of lung cancer, no specific screening is recommended but should be considered if patients smoke."
#         },
#         {
#             "label": ["Peutz-Jeghers Syndrome", "Family Screening", "Skin Lesions"],
#             "new_paragraph": "First-degree relatives should be evaluated for skin lesions of Peutz-Jeghers syndrome."
#         },
#         {
#             "label": ["Peutz-Jeghers Syndrome", "Additional Resources"],
#             "new_paragraph": "The following English-language resource may be useful. Please note that THE MANUAL is not responsible for the content of this resource. American Gastroenterological Association: Guidelines for genetic testing and management of hereditary gastrointestinal cancer syndromes (2015)."
#         }
#     ]
# }
# ```
# article_metadata:  {'author': 'Anthony Villano, MD, Fox Chase Cancer Center', 'review_date': 'Oct 2023', 'patient_education': 'VIEW PATIENT EDUCATION', 'topic_resources': {'3D Models': 0, 'Audios': 0, 'Calculators': 0, 'Images': 2, 'Tables': 0, 'Videos': 0}}
# article_metadata:  {'author': 'Anthony Villano, MD, Fox Chase Cancer Center', 'review_date': 'Oct 2023', 'patient_education': 'VIEW PATIENT EDUCATION', 'topic_resources': {'3D Models': 0, 'Audios': 0, 'Calculators': 0, 'Images': 2, 'Tables': 0, 'Videos': 0}}
# {'id': 'chatcmpl-A9cZjFKI42cr0HibrnXXsq615u9jn', 'object': 'chat.completion', 'created': 1726856599, 'model': 'gpt-4o-2024-08-06', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '```json\n{\n  "article_label": ["Anorectal Fistula", "Symptoms", "Diagnosis", "Treatment", "Medical Information"],\n  "article_metadata": {\n    "author": "Parswa Ansari, MD",\n    "institution": "Hofstra Northwell-Lenox Hill Hospital, New York",\n    "review_date": "Jan 2023"\n  },\n  "article_keypoint": [\n    "Anorectal fistula is a tubelike tract with openings in the anal canal and perianal skin.",\n    "Symptoms include discharge and sometimes pain.",\n    "Diagnosis involves examination and possibly anoscopy, sigmoidoscopy, or colonoscopy.",\n    "Treatment often requires surgery, with various procedures available.",\n    "Fistulas can arise spontaneously or from perirectal abscess drainage."\n  ],\n  "paragraphs": [\n    {\n      "label": ["Anorectal Fistula", "Symptoms", "Diagnosis", "Treatment"],\n      "new_paragraph": "An anorectal fistula is a tubelike tract with one opening in the anal canal and the other usually in the perianal skin. Symptoms are discharge and sometimes pain. Diagnosis is by examination and sometimes anoscopy, sigmoidoscopy, or colonoscopy. Treatment often requires surgery."\n    },\n    {\n      "label": ["Anorectal Fistula", "Causes"],\n      "new_paragraph": "Fistulas arise spontaneously or occur secondary to drainage of a perirectal abscess. Most fistulas originate in the anorectal crypts. Other causes include Crohn disease, tuberculosis, diverticulitis, cancer, and trauma. Fistulas in infants are congenital and are more common among boys. Rectovaginal fistulas may be secondary to Crohn disease, obstetric injuries, radiation therapy, or cancer."\n    },\n    {\n      "label": ["Anorectal Fistula", "Symptoms"],\n      "new_paragraph": "A history of recurrent anorectal abscess followed by intermittent or constant discharge is usual. Discharge material is purulent, serosanguineous, or both. Pain may be present if there is infection. On inspection, one or more secondary openings can be seen. A cordlike tract can often be palpated. A probe inserted into the tract can determine the depth and direction and often the primary opening."\n    },\n    {\n      "label": ["Anorectal Fistula", "Diagnosis"],\n      "new_paragraph": "Diagnosis of anorectal fistula is by examination. Anoscopy or sigmoidoscopy may be used to visualize the internal opening of the fistula. Colonoscopy should follow if there is suspicion of Crohn disease. Hidradenitis suppurativa, pilonidal sinus, dermal suppurative sinuses, and urethroperineal fistulas must be differentiated from cryptogenic fistulas."\n    },\n    {\n      "label": ["Anorectal Fistula", "Treatment"],\n      "new_paragraph": "Various surgical procedures are available for the treatment of anorectal fistula. Medical treatment is considered if the fistula is caused by Crohn disease. Previously, the only effective treatment was fistulotomy or fistulectomy. Currently, alternative treatments include advancement flaps, biologic plugs, and fibrin glue instillations. The LIFT procedure is an alternative more likely to preserve continence. If diarrhea or Crohn disease is present, fistulotomy is inadvisable."\n    },\n    {\n      "label": ["Anorectal Fistula", "Treatment", "Crohn Disease"],\n      "new_paragraph": "For patients with Crohn disease, metronidazole, other appropriate antibiotics, and suppressive therapies can be given. Infliximab is effective in closing anal fistulas caused by Crohn disease."\n    },\n    {\n      "label": ["Anorectal Fistula", "Additional Resources"],\n      "new_paragraph": "The following English-language resource may be useful: American Society of Colon and Rectal Surgeons: Clinical practice guideline for the management of anorectal abscess, fistula-in-ano, and rectovaginal fistula (2016)."\n    }\n  ]\n}\n```', 'refusal': None}, 'logprobs': N ...
# -------response_text-----------------------
# ```json
# {
#   "article_label": ["Anorectal Fistula", "Symptoms", "Diagnosis", "Treatment", "Medical Information"],
#   "article_metadata": {
#     "author": "Parswa Ansari, MD",
#     "institution": "Hofstra Northwell-Lenox Hill Hospital, New York",
#     "review_date": "Jan 2023"
#   },
#   "article_keypoint": [
#     "Anorectal fistula is a tubelike tract with openings in the anal canal and perianal skin.",
#     "Symptoms include discharge and sometimes pain.",
#     "Diagnosis involves examination and possibly anoscopy, sigmoidoscopy, or colonoscopy.",
#     "Treatment often requires surgery, with various procedures available.",
#     "Fistulas can arise spontaneously or from perirectal abscess drainage."
#   ],
#   "paragraphs": [
#     {
#       "label": ["Anorectal Fistula", "Symptoms", "Diagnosis", "Treatment"],
#       "new_paragraph": "An anorectal fistula is a tubelike tract with one opening in the anal canal and the other usually in the perianal skin. Symptoms are discharge and sometimes pain. Diagnosis is by examination and sometimes anoscopy, sigmoidoscopy, or colonoscopy. Treatment often requires surgery."
#     },
#     {
#       "label": ["Anorectal Fistula", "Causes"],
#       "new_paragraph": "Fistulas arise spontaneously or occur secondary to drainage of a perirectal abscess. Most fistulas originate in the anorectal crypts. Other causes include Crohn disease, tuberculosis, diverticulitis, cancer, and trauma. Fistulas in infants are congenital and are more common among boys. Rectovaginal fistulas may be secondary to Crohn disease, obstetric injuries, radiation therapy, or cancer."
#     },
#     {
#       "label": ["Anorectal Fistula", "Symptoms"],
#       "new_paragraph": "A history of recurrent anorectal abscess followed by intermittent or constant discharge is usual. Discharge material is purulent, serosanguineous, or both. Pain may be present if there is infection. On inspection, one or more secondary openings can be seen. A cordlike tract can often be palpated. A probe inserted into the tract can determine the depth and direction and often the primary opening."
#     },
#     {
#       "label": ["Anorectal Fistula", "Diagnosis"],
#       "new_paragraph": "Diagnosis of anorectal fistula is by examination. Anoscopy or sigmoidoscopy may be used to visualize the internal opening of the fistula. Colonoscopy should follow if there is suspicion of Crohn disease. Hidradenitis suppurativa, pilonidal sinus, dermal suppurative sinuses, and urethroperineal fistulas must be differentiated from cryptogenic fistulas."
#     },
#     {
#       "label": ["Anorectal Fistula", "Treatment"],
#       "new_paragraph": "Various surgical procedures are available for the treatment of anorectal fistula. Medical treatment is considered if the fistula is caused by Crohn disease. Previously, the only effective treatment was fistulotomy or fistulectomy. Currently, alternative treatments include advancement flaps, biologic plugs, and fibrin glue instillations. The LIFT procedure is an alternative more likely to preserve continence. If diarrhea or Crohn disease is present, fistulotomy is inadvisable."
#     },
#     {
#       "label": ["Anorectal Fistula", "Treatment", "Crohn Disease"],
#       "new_paragraph": "For patients with Crohn disease, metronidazole, other appropriate antibiotics, and suppressive therapies can be given. Infliximab is effective in closing anal fistulas caused by Crohn disease."
#     },
#     {
#       "label": ["Anorectal Fistula", "Additional Resources"],
#       "new_paragraph": "The following English-language resource may be useful: American Society of Colon and Rectal Surgeons: Clinical practice guideline for the management of anorectal abscess, fistula-in-ano, and rectovaginal fistula (2016)."
#     }
#   ]
# }
# ```
# article_metadata:  {'author': 'Parswa Ansari, MD', 'institution': 'Hofstra Northwell-Lenox Hill Hospital, New York', 'review_date': 'Jan 2023'}
# article_metadata:  {'author': 'Parswa Ansari, MD', 'institution': 'Hofstra Northwell-Lenox Hill Hospital, New York', 'review_date': 'Jan 2023'}

# %%
def cmg_process_2(row_start=0, row_end=0):
    print ("main function started \n--------------------")
    time_started=time.time()

    df_paragraphs = pd.read_excel(myexcelfile, sheet_name='paragraphs')
    df_sentences = pd.read_excel(myexcelfile, sheet_name='sentences')

    df_paragraphs, df_sentences=extract_events(df_paragraphs,  df_sentences, row_start, row_end)

    update_sheet_preserving_format(myexcelfile, 'paragraphs', df_paragraphs)
    update_sheet_preserving_format(myexcelfile, 'sentences', df_sentences)

    time_finished=time.time()
    timeused=time_finished-time_started
    print("Time used=", round(timeused,2)) # 


def extract_events(df_paragraphs, df_sentences,row_start, row_end):
    print("\n extract_events function \n --------------------------------------")
    myprompt=generate_prompt(2)
    print(myprompt)

    # Adjust row_end if it's 0 (process until the last row)
    if row_end == 0 or row_end > df_paragraphs.index[-1]:   
        row_end = df_paragraphs.index[-1]
    
    # Ensure row_start is within bounds
    if row_start < 0:
        row_start = 0
    
    # Ensure row_end is not before row_start
    if row_end < row_start:
        row_end = row_start
    
    # Loop through the articles from row_start to row_end
    for index in range(row_start, row_end + 1):
        if index > df_paragraphs.index[-1]:  # Ensure index is within DataFrame bounds
            break  # Exit the loop if index exceeds the DataFrame row count

        # Access the current row
        row = df_paragraphs.iloc[index]
        # get article id
        article_id = row['Article ID']
        mycontent = row['Paragraph text']
        # events_text = row['Convert paragraph to events']
        processedflag=row['processed']

        # Proceed if 'Paragraph text' is not empty and processed is not 'Yes'
        if processedflag!='Yes' and pd.notna(mycontent)  and mycontent.strip():
            response_text = ask_chatgpt(myprompt, mycontent)
            print("-------response_text-----------------------")
            print(response_text)
            # clean the response_text to remove the markdown

            # Update the DataFrame with the response
            df_paragraphs.at[index, 'Convert paragraph to events'] = response_text
            df_sentences=extract_events_from_paragraph(response_text,index, df_sentences, article_id)
            df_paragraphs.at[index,'processed']='Yes'

    return df_paragraphs,df_sentences


def extract_events_from_paragraph(response_text, index, df_sentences, article_id):
    """
    Function to extract events from JSON-like text and add them to a DataFrame.

    :param response_text: JSON-like event data as a string.
    :param index: Index of the paragraph (used to set paragraph ID).
    :param df_sentences: DataFrame to store the events extracted from paragraphs.
    :return: Updated df_sentences DataFrame with new events.
    """
    print("\nExtracting events from paragraph index =", index, "\n-------------------------------------")

    # If df_sentences is not empty, continue IDs from the last used ID
    if not df_sentences.empty:
        sentence_id = df_sentences['Event ID'].max() + 1
    else:
        sentence_id = 1  # If df_sentences is empty, start IDs from 1

    # Initialize a list to hold new rows
    new_rows = []

    # Extract all JSON-like blocks from the response_text
    json_blocks = re.findall(r'\{[^}]*\}', response_text)

    # Parse each JSON block and append it to the DataFrame
    for block in json_blocks:
        try:
            event_data = json.loads(block)

            # Create a new row with event data
            new_row = {col: '' for col in df_sentences.columns}
            new_row.update({
                'Event ID': sentence_id,
                'Article ID': article_id,
                'Paragraph ID': index + 1,  # Use index+1 for paragraph ID
                'Head labels': ', '.join(event_data.get('head_label', [])),
                'Relation label': event_data.get('relation_label', ''),
                'Tail labels': ', '.join(event_data.get('tail_label', [])),
                'Head text': event_data.get('head_text', ''),
                'Relation text': event_data.get('relation_text', ''),
                'Tail text': event_data.get('tail_text', ''),
                'Sentence text': f"{event_data.get('head_text', '')} {event_data.get('relation_text', '')} {event_data.get('tail_text', '')}"
            })

            new_rows.append(new_row)
            sentence_id += 1

        except json.JSONDecodeError:
            print("Error decoding JSON block:", block)

    # Append new rows to df_sentences DataFrame
    if new_rows:
        df_sentences = pd.concat([df_sentences, pd.DataFrame(new_rows)], ignore_index=True)

    return df_sentences

# %%
cmg_process_2(33, 0)
# Out:
# main function started
# --------------------
#
#  extract_events function
#  --------------------------------------
# Let's work this out in a step by step way to be sure we have the right answer.
# <instruction>Identify causal relationships between medical concepts such as conditions, treatments, risk factors, and symptoms. Each concept and relation may have multiple labels.</instruction>
#
# <format>
# {
#   "head_label": [<list_of_head_labels>],
#   "relation_label": "<causal_relation>",
#   "tail_label": [<list_of_tail_labels>],
#   "head_text": "<head_plaintext>",
#   "relation_text": "<relation_plaintext>",
#   "tail_text": "<tail_plaintext>"
# }
# </format>
#
# <constraint>
# - "head_label" and "tail_label" should contain lists of relevant labels, such as condition, treatment, risk factor, symptom, etc.
# - "relation_label" should be one of: IMPLIES, CAUSES, NEGATES, AND, OR, THRESHOLD.
# - Use plain text for "head_text", "relation_text", and "tail_text".
# </constraint>
#
# <reminder>Ensure that the relationships accurately reflect medical logic and that multiple labels can be used for both entities and relations.</reminder>
#  Here is the paragraph:
# {'id': 'chatcmpl-A9cat7XyXqu8Rq8afnZ015LXGDJFy', 'object': 'chat.completion', 'created': 1726856671, 'model': 'gpt-4o-2024-08-06', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n  "head_label": ["condition"],\n  "relation_label": "CAUSES",\n  "tail_label": ["symptom"],\n  "head_text": "Ulcerative colitis",\n  "relation_text": "characterized most often by",\n  "tail_text": "bloody diarrhea"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "CAUSES",\n  "tail_label": ["symptom"],\n  "head_text": "Ulcerative colitis",\n  "relation_text": "may cause",\n  "tail_text": "extraintestinal symptoms, particularly arthritis"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "IMPLIES",\n  "tail_label": ["risk factor"],\n  "head_text": "Ulcerative colitis",\n  "relation_text": "elevates long-term risk of",\n  "tail_text": "colon cancer"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "DIAGNOSED BY",\n  "tail_label": ["procedure"],\n  "head_text": "Ulcerative colitis",\n  "relation_text": "diagnosis is by",\n  "tail_text": "colonoscopy"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "TREATED WITH",\n  "tail_label": ["treatment"],\n  "head_text": "Ulcerative colitis",\n  "relation_text": "treatment is with",\n  "tail_text": "5-aminosalicylic acid"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "TREATED WITH",\n  "tail_label": ["treatment"],\n  "head_text": "Ulcerative colitis",\n  "relation_text": "treatment is with",\n  "tail_text": "corticosteroids"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "TREATED WITH",\n  "tail_label": ["treatment"],\n  "head_text": "Ulcerative colitis",\n  "relation_text": "treatment is with",\n  "tail_text": "immunomodulators"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "TREATED WITH",\n  "tail_label": ["treatment"],\n  "head_text": "Ulcerative colitis",\n  "relation_text": "treatment is with",\n  "tail_text": "biologics"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "TREATED WITH",\n  "tail_label": ["treatment"],\n  "head_text": "Ulcerative colitis",\n  "relation_text": "treatment is with",\n  "tail_text": "antibiotics"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "TREATED WITH",\n  "tail_label": ["treatment"],\n  "head_text": "Ulcerative colitis",\n  "relation_text": "treatment is occasionally with",\n  "tail_text": "surgery"\n}', 'refusal': None}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 336, 'completion_tokens': 629, 'total_tokens': 965, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'system_fingerprint': 'fp_5050236cbd'}
# -------response_text-----------------------
# {
#   "head_label": ["condition"],
#   "relation_label": "CAUSES",
#   "tail_label": ["symptom"],
#   "head_text": "Ulcerative colitis",
#   "relation_text": "characterized most often by",
#   "tail_text": "bloody diarrhea"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "CAUSES",
#   "tail_label": ["symptom"],
#   "head_text": "Ulcerative colitis",
#   "relation_text": "may cause",
#   "tail_text": "extraintestinal symptoms, particularly arthritis"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["risk factor"],
#   "head_text": "Ulcerative colitis",
#   "relation_text": "elevates long-term risk of",
#   "tail_text": "colon cancer"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "DIAGNOSED BY",
#   "tail_label": ["procedure"],
#   "head_text": "Ulcerative colitis",
#   "relation_text": "diagnosis is by",
#   "tail_text": "colonoscopy"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "TREATED WITH",
#   "tail_label": ["treatment"],
#   "head_text": "Ulcerative colitis",
#   "relation_text": "treatment is with",
#   "tail_text": "5-aminosalicylic acid"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "TREATED WITH",
#   "tail_label": ["treatment"],
#   "head_text": "Ulcerative colitis",
#   "relation_text": "treatment is with",
#   "tail_text": "corticosteroids"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "TREATED WITH",
#   "tail_label": ["treatment"],
#   "head_text": "Ulcerative colitis",
#   "relation_text": "treatment is with",
#   "tail_text": "immunomodulators"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "TREATED WITH",
#   "tail_label": ["treatment"],
#   "head_text": "Ulcerative colitis",
#   "relation_text": "treatment is with",
#   "tail_text": "biologics"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "TREATED WITH",
#   "tail_label": ["treatment"],
#   "head_text": "Ulcerative colitis",
#   "relation_text": "treatment is with",
#   "tail_text": "antibiotics"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "TREATED WITH",
#   "tail_label": ["treatment"],
#   "head_text": "Ulcerative colitis",
#   "relation_text": "treatment is occasionally with",
#   "tail_text": "surgery"
# }
#
# Extracting events from paragraph index = 33
# -------------------------------------
# {'id': 'chatcmpl-A9cb2OFa5QgB8vwa2Ru3G4MYtc708', 'object': 'chat.completion', 'created': 1726856680, 'model': 'gpt-4o-2024-08-06', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n  "head_label": ["condition"], \n  "relation_label": "IMPLIES", \n  "tail_label": ["condition"],\n  "head_text": "Ulcerative colitis", \n  "relation_text": "usually begins in", \n  "tail_text": "the rectum"\n}\n\n{\n  "head_label": ["condition"], \n  "relation_label": "OR", \n  "tail_label": ["condition"],\n  "head_text": "Ulcerative colitis", \n  "relation_text": "may remain localized to", \n  "tail_text": "the rectum (ulcerative proctitis)"\n}\n\n{\n  "head_label": ["condition"], \n  "relation_label": "OR", \n  "tail_label": ["condition"],\n  "head_text": "Ulcerative colitis", \n  "relation_text": "extend proximally, sometimes involving", \n  "tail_text": "the entire colon"\n}\n\n{\n  "head_label": ["condition"], \n  "relation_label": "RARELY", \n  "tail_label": ["condition"],\n  "head_text": "Ulcerative colitis", \n  "relation_text": "involves", \n  "tail_text": "most of the large bowel at once"\n}', 'refusal': None}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 303, 'completion_tokens': 267, 'total_tokens': 570, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'system_fingerprint': 'fp_5050236cbd'}
# -------response_text-----------------------
# {
#   "head_label": ["condition"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["condition"],
#   "head_text": "Ulcerative colitis",
#   "relation_text": "usually begins in",
#   "tail_text": "the rectum"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "OR",
#   "tail_label": ["condition"],
#   "head_text": "Ulcerative colitis",
#   "relation_text": "may remain localized to",
#   "tail_text": "the rectum (ulcerative proctitis)"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "OR",
#   "tail_label": ["condition"],
#   "head_text": "Ulcerative colitis",
#   "relation_text": "extend proximally, sometimes involving",
#   "tail_text": "the entire colon"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "RARELY",
#   "tail_label": ["condition"],
#   "head_text": "Ulcerative colitis",
#   "relation_text": "involves",
#   "tail_text": "most of the large bowel at once"
# }
#
# Extracting events from paragraph index = 34
# -------------------------------------
# {'id': 'chatcmpl-A9cb69fs8Jzd8lKWMtktkyPjTcsxB', 'object': 'chat.completion', 'created': 1726856684, 'model': 'gpt-4o-2024-08-06', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n  "head_label": ["condition"],\n  "relation_label": "CAUSES",\n  "tail_label": ["symptom"],\n  "head_text": "ulcerative colitis",\n  "relation_text": "causes",\n  "tail_text": "inflammation affecting the mucosa and submucosa"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "IMPLIES",\n  "tail_label": ["symptom"],\n  "head_text": "severe ulcerative colitis",\n  "relation_text": "implies",\n  "tail_text": "muscularis involvement"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "CAUSES",\n  "tail_label": ["symptom"],\n  "head_text": "early ulcerative colitis",\n  "relation_text": "causes",\n  "tail_text": "erythematous, finely granular, and friable mucous membrane"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "CAUSES",\n  "tail_label": ["symptom"],\n  "head_text": "early ulcerative colitis",\n  "relation_text": "causes",\n  "tail_text": "loss of normal vascular pattern and scattered hemorrhagic areas"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "CAUSES",\n  "tail_label": ["symptom"],\n  "head_text": "severe ulcerative colitis",\n  "relation_text": "causes",\n  "tail_text": "large mucosal ulcers with copious purulent exudate"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "CAUSES",\n  "tail_label": ["symptom"],\n  "head_text": "ulcerative colitis",\n  "relation_text": "causes",\n  "tail_text": "pseudopolyps projecting above areas of ulcerated mucosa"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "NEGATES",\n  "tail_label": ["symptom"],\n  "head_text": "ulcerative colitis",\n  "relation_text": "does not cause",\n  "tail_text": "fistulas and abscesses"\n}', 'refusal': None}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 380, 'completion_tokens': 467, 'total_tokens': 847, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'system_fingerprint': 'fp_5050236cbd'}
# -------response_text-----------------------
# {
#   "head_label": ["condition"],
#   "relation_label": "CAUSES",
#   "tail_label": ["symptom"],
#   "head_text": "ulcerative colitis",
#   "relation_text": "causes",
#   "tail_text": "inflammation affecting the mucosa and submucosa"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["symptom"],
#   "head_text": "severe ulcerative colitis",
#   "relation_text": "implies",
#   "tail_text": "muscularis involvement"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "CAUSES",
#   "tail_label": ["symptom"],
#   "head_text": "early ulcerative colitis",
#   "relation_text": "causes",
#   "tail_text": "erythematous, finely granular, and friable mucous membrane"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "CAUSES",
#   "tail_label": ["symptom"],
#   "head_text": "early ulcerative colitis",
#   "relation_text": "causes",
#   "tail_text": "loss of normal vascular pattern and scattered hemorrhagic areas"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "CAUSES",
#   "tail_label": ["symptom"],
#   "head_text": "severe ulcerative colitis",
#   "relation_text": "causes",
#   "tail_text": "large mucosal ulcers with copious purulent exudate"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "CAUSES",
#   "tail_label": ["symptom"],
#   "head_text": "ulcerative colitis",
#   "relation_text": "causes",
#   "tail_text": "pseudopolyps projecting above areas of ulcerated mucosa"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "NEGATES",
#   "tail_label": ["symptom"],
#   "head_text": "ulcerative colitis",
#   "relation_text": "does not cause",
#   "tail_text": "fistulas and abscesses"
# }
#
# Extracting events from paragraph index = 35
# -------------------------------------
# {'id': 'chatcmpl-A9cbDR3cZKfD8263tk1aRm2S0bRZc', 'object': 'chat.completion', 'created': 1726856691, 'model': 'gpt-4o-2024-08-06', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n  "head_label": ["condition", "symptom"], \n  "relation_label": "IMPLIES", \n  "tail_label": ["symptom"],\n  "head_text": "attack of bloody diarrhea", \n  "relation_text": "implies", \n  "tail_text": "increased urgency to defecate, mild lower abdominal cramps, and blood and mucus in the stools"\n}\n\n{\n  "head_label": ["condition"], \n  "relation_label": "CAUSES", \n  "tail_label": ["condition"],\n  "head_text": "infection", \n  "relation_text": "causes", \n  "tail_text": "attack of bloody diarrhea"\n}\n\n{\n  "head_label": ["condition"], \n  "relation_label": "OR", \n  "tail_label": ["condition"],\n  "head_text": "infection", \n  "relation_text": "or", \n  "tail_text": "amebiasis, bacillary dysentery"\n}', 'refusal': None}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 321, 'completion_tokens': 205, 'total_tokens': 526, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'system_fingerprint': 'fp_5050236cbd'}
# -------response_text-----------------------
# {
#   "head_label": ["condition", "symptom"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["symptom"],
#   "head_text": "attack of bloody diarrhea",
#   "relation_text": "implies",
#   "tail_text": "increased urgency to defecate, mild lower abdominal cramps, and blood and mucus in the stools"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "CAUSES",
#   "tail_label": ["condition"],
#   "head_text": "infection",
#   "relation_text": "causes",
#   "tail_text": "attack of bloody diarrhea"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "OR",
#   "tail_label": ["condition"],
#   "head_text": "infection",
#   "relation_text": "or",
#   "tail_text": "amebiasis, bacillary dysentery"
# }
#
# Extracting events from paragraph index = 36
# -------------------------------------
# {'id': 'chatcmpl-A9cbG2UOW1DZmRjcQMYcf9cPDocCT', 'object': 'chat.completion', 'created': 1726856694, 'model': 'gpt-4o-2024-08-06', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n  "head_label": ["condition", "symptom"],\n  "relation_label": "IMPLIES",\n  "tail_label": ["condition", "symptom"],\n  "head_text": "extensive ulcerative colitis",\n  "relation_text": "more common with",\n  "tail_text": "systemic symptoms and signs"\n}\n\n{\n  "head_label": ["symptom"],\n  "relation_label": "CAUSES",\n  "tail_label": ["symptom"],\n  "head_text": "systemic symptoms and signs",\n  "relation_text": "include",\n  "tail_text": "malaise, fever, anemia, anorexia, and weight loss"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "CAUSES",\n  "tail_label": ["condition"],\n  "head_text": "inflammatory bowel disease (IBD)",\n  "relation_text": "Extraintestinal manifestations of",\n  "tail_text": "joint and skin complications"\n}\n\n{\n  "head_label": ["symptom"],\n  "relation_label": "IMPLIES",\n  "tail_label": ["condition"],\n  "head_text": "systemic symptoms",\n  "relation_text": "are most common when",\n  "tail_text": "extraintestinal manifestations of IBD"\n}', 'refusal': None}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 306, 'completion_tokens': 267, 'total_tokens': 573, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'system_fingerprint': 'fp_143bb8492c'}
# -------response_text-----------------------
# {
#   "head_label": ["condition", "symptom"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["condition", "symptom"],
#   "head_text": "extensive ulcerative colitis",
#   "relation_text": "more common with",
#   "tail_text": "systemic symptoms and signs"
# }
#
# {
#   "head_label": ["symptom"],
#   "relation_label": "CAUSES",
#   "tail_label": ["symptom"],
#   "head_text": "systemic symptoms and signs",
#   "relation_text": "include",
#   "tail_text": "malaise, fever, anemia, anorexia, and weight loss"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "CAUSES",
#   "tail_label": ["condition"],
#   "head_text": "inflammatory bowel disease (IBD)",
#   "relation_text": "Extraintestinal manifestations of",
#   "tail_text": "joint and skin complications"
# }
#
# {
#   "head_label": ["symptom"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["condition"],
#   "head_text": "systemic symptoms",
#   "relation_text": "are most common when",
#   "tail_text": "extraintestinal manifestations of IBD"
# }
#
# Extracting events from paragraph index = 37
# -------------------------------------
# {'id': 'chatcmpl-A9cbLn906pYoLIhMdcgjsoOHhkoew', 'object': 'chat.completion', 'created': 1726856699, 'model': 'gpt-4o-2024-08-06', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n  "head_label": ["condition", "symptom"],\n  "relation_label": "IMPLIES",\n  "tail_label": ["condition"],\n  "head_text": "typical symptoms and signs",\n  "relation_text": "suggests",\n  "tail_text": "ulcerative colitis"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "AND",\n  "tail_label": ["condition"],\n  "head_text": "ulcerative colitis",\n  "relation_text": "accompanied by",\n  "tail_text": "extraintestinal manifestations"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "OR",\n  "tail_label": ["condition"],\n  "head_text": "ulcerative colitis",\n  "relation_text": "distinguished from",\n  "tail_text": "Crohn disease"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "OR",\n  "tail_label": ["condition"],\n  "head_text": "ulcerative colitis",\n  "relation_text": "distinguished from",\n  "tail_text": "other causes of acute colitis"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "CAUSES",\n  "tail_label": ["condition"],\n  "head_text": "infection",\n  "relation_text": "causes",\n  "tail_text": "acute colitis"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "CAUSES",\n  "tail_label": ["condition"],\n  "head_text": "ischemia",\n  "relation_text": "causes",\n  "tail_text": "acute colitis"\n}', 'refusal': None}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 315, 'completion_tokens': 352, 'total_tokens': 667, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'system_fingerprint': 'fp_8080548e81'}
# -------response_text-----------------------
# {
#   "head_label": ["condition", "symptom"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["condition"],
#   "head_text": "typical symptoms and signs",
#   "relation_text": "suggests",
#   "tail_text": "ulcerative colitis"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "AND",
#   "tail_label": ["condition"],
#   "head_text": "ulcerative colitis",
#   "relation_text": "accompanied by",
#   "tail_text": "extraintestinal manifestations"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "OR",
#   "tail_label": ["condition"],
#   "head_text": "ulcerative colitis",
#   "relation_text": "distinguished from",
#   "tail_text": "Crohn disease"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "OR",
#   "tail_label": ["condition"],
#   "head_text": "ulcerative colitis",
#   "relation_text": "distinguished from",
#   "tail_text": "other causes of acute colitis"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "CAUSES",
#   "tail_label": ["condition"],
#   "head_text": "infection",
#   "relation_text": "causes",
#   "tail_text": "acute colitis"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "CAUSES",
#   "tail_label": ["condition"],
#   "head_text": "ischemia",
#   "relation_text": "causes",
#   "tail_text": "acute colitis"
# }
#
# Extracting events from paragraph index = 38
# -------------------------------------
# {'id': 'chatcmpl-A9cbQb4xQy9OfOi9ic8KeEblOfe5Q', 'object': 'chat.completion', 'created': 1726856704, 'model': 'gpt-4o-2024-08-06', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n  "head_label": ["condition", "symptom"],\n  "relation_label": "IMPLIES",\n  "tail_label": ["condition"],\n  "head_text": "elevated alkaline phosphatase and gamma-glutamyl transpeptidase levels",\n  "relation_text": "suggest possible",\n  "tail_text": "primary sclerosing cholangitis"\n}\n\n{\n  "head_label": ["test", "biomarker"],\n  "relation_label": "SPECIFIC_FOR",\n  "tail_label": ["condition"],\n  "head_text": "perinuclear antineutrophil cytoplasmic antibodies",\n  "relation_text": "are relatively specific for",\n  "tail_text": "ulcerative colitis"\n}', 'refusal': None}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 325, 'completion_tokens': 156, 'total_tokens': 481, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'system_fingerprint': 'fp_143bb8492c'}
# -------response_text-----------------------
# {
#   "head_label": ["condition", "symptom"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["condition"],
#   "head_text": "elevated alkaline phosphatase and gamma-glutamyl transpeptidase levels",
#   "relation_text": "suggest possible",
#   "tail_text": "primary sclerosing cholangitis"
# }
#
# {
#   "head_label": ["test", "biomarker"],
#   "relation_label": "SPECIFIC_FOR",
#   "tail_label": ["condition"],
#   "head_text": "perinuclear antineutrophil cytoplasmic antibodies",
#   "relation_text": "are relatively specific for",
#   "tail_text": "ulcerative colitis"
# }
#
# Extracting events from paragraph index = 39
# -------------------------------------
# {'id': 'chatcmpl-A9cbTmIhc9Hp2BoZeNQvBG4iQHsEF', 'object': 'chat.completion', 'created': 1726856707, 'model': 'gpt-4o-2024-08-06', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n  "head_label": ["treatment", "dietary modification"], \n  "relation_label": "IMPLIES", \n  "tail_label": ["symptom", "condition"], \n  "head_text": "Avoiding raw fruits and vegetables", \n  "relation_text": "limits", \n  "tail_text": "trauma to the inflamed colonic mucosa and may lessen symptoms"\n}\n\n{\n  "head_label": ["treatment", "dietary modification"], \n  "relation_label": "IMPLIES", \n  "tail_label": ["symptom"], \n  "head_text": "A milk-free diet", \n  "relation_text": "may help", \n  "tail_text": "lessen symptoms"\n}\n\n{\n  "head_label": ["treatment", "medication"], \n  "relation_label": "IMPLIES", \n  "tail_label": ["symptom"], \n  "head_text": "Loperamide", \n  "relation_text": "is indicated for", \n  "tail_text": "relatively mild diarrhea"\n}\n\n{\n  "head_label": ["treatment", "medication"], \n  "relation_label": "THRESHOLD", \n  "tail_label": ["symptom"], \n  "head_text": "higher oral doses of Loperamide", \n  "relation_text": "may be required for", \n  "tail_text": "more intense diarrhea"\n}', 'refusal': None}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 310, 'completion_tokens': 299, 'total_tokens': 609, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'system_fingerprint': 'fp_5050236cbd'}
# -------response_text-----------------------
# {
#   "head_label": ["treatment", "dietary modification"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["symptom", "condition"],
#   "head_text": "Avoiding raw fruits and vegetables",
#   "relation_text": "limits",
#   "tail_text": "trauma to the inflamed colonic mucosa and may lessen symptoms"
# }
#
# {
#   "head_label": ["treatment", "dietary modification"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["symptom"],
#   "head_text": "A milk-free diet",
#   "relation_text": "may help",
#   "tail_text": "lessen symptoms"
# }
#
# {
#   "head_label": ["treatment", "medication"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["symptom"],
#   "head_text": "Loperamide",
#   "relation_text": "is indicated for",
#   "tail_text": "relatively mild diarrhea"
# }
#
# {
#   "head_label": ["treatment", "medication"],
#   "relation_label": "THRESHOLD",
#   "tail_label": ["symptom"],
#   "head_text": "higher oral doses of Loperamide",
#   "relation_text": "may be required for",
#   "tail_text": "more intense diarrhea"
# }
#
# Extracting events from paragraph index = 40
# -------------------------------------
# {'id': 'chatcmpl-A9cbXzR8ZUKKIs2vlkl7cKF7hd7VB', 'object': 'chat.completion', 'created': 1726856711, 'model': 'gpt-4o-2024-08-06', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n  "head_label": ["condition"],\n  "relation_label": "TREATED_BY",\n  "tail_label": ["treatment"],\n  "head_text": "mild to moderate ulcerative proctitis or proctosigmoiditis",\n  "relation_text": "are treated with",\n  "tail_text": "5-ASA (mesalamine) by enema"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "TREATED_BY",\n  "tail_label": ["treatment"],\n  "head_text": "more distal disease",\n  "relation_text": "are treated with",\n  "tail_text": "suppositories"\n}\n\n{\n  "head_label": ["treatment"],\n  "relation_label": "PREFERRED_BY",\n  "tail_label": ["patient preference"],\n  "head_text": "suppositories",\n  "relation_text": "are usually preferred by",\n  "tail_text": "patients"\n}', 'refusal': None}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 320, 'completion_tokens': 198, 'total_tokens': 518, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'system_fingerprint': 'fp_8080548e81'}
# -------response_text-----------------------
# {
#   "head_label": ["condition"],
#   "relation_label": "TREATED_BY",
#   "tail_label": ["treatment"],
#   "head_text": "mild to moderate ulcerative proctitis or proctosigmoiditis",
#   "relation_text": "are treated with",
#   "tail_text": "5-ASA (mesalamine) by enema"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "TREATED_BY",
#   "tail_label": ["treatment"],
#   "head_text": "more distal disease",
#   "relation_text": "are treated with",
#   "tail_text": "suppositories"
# }
#
# {
#   "head_label": ["treatment"],
#   "relation_label": "PREFERRED_BY",
#   "tail_label": ["patient preference"],
#   "head_text": "suppositories",
#   "relation_text": "are usually preferred by",
#   "tail_text": "patients"
# }
#
# Extracting events from paragraph index = 41
# -------------------------------------
# {'id': 'chatcmpl-A9cbb4adYRRMJCyQVPA7VPm0oPd8a', 'object': 'chat.completion', 'created': 1726856715, 'model': 'gpt-4o-2024-08-06', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n  "head_label": ["symptom"],\n  "relation_label": "IMPLIES",\n  "tail_label": ["treatment"],\n  "head_text": "> 10 bloody bowel movements per day",\n  "relation_text": "require",\n  "tail_text": "hospitalization to receive biologic agent and/or high-dose IV corticosteroids"\n}\n\n{\n  "head_label": ["symptom"],\n  "relation_label": "IMPLIES",\n  "tail_label": ["treatment"],\n  "head_text": "tachycardia",\n  "relation_text": "require",\n  "tail_text": "hospitalization to receive biologic agent and/or high-dose IV corticosteroids"\n}\n\n{\n  "head_label": ["symptom"],\n  "relation_label": "IMPLIES",\n  "tail_label": ["treatment"],\n  "head_text": "high fever",\n  "relation_text": "require",\n  "tail_text": "hospitalization to receive biologic agent and/or high-dose IV corticosteroids"\n}\n\n{\n  "head_label": ["symptom"],\n  "relation_label": "IMPLIES",\n  "tail_label": ["treatment"],\n  "head_text": "severe abdominal pain",\n  "relation_text": "require",\n  "tail_text": "hospitalization to receive biologic agent and/or high-dose IV corticosteroids"\n}\n\n{\n  "head_label": ["symptom"],\n  "relation_label": "IMPLIES",\n  "tail_label": ["treatment"],\n  "head_text": "dehydration",\n  "relation_text": "require",\n  "tail_text": "IV fluids"\n}\n\n{\n  "head_label": ["symptom"],\n  "relation_label": "IMPLIES",\n  "tail_label": ["treatment"],\n  "head_text": "anemia",\n  "relation_text": "require",\n  "tail_text": "blood transfusion"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "THRESHOLD",\n  "tail_label": ["condition"],\n  "head_text": "development of toxic colitis",\n  "relation_text": "must be observed closely for",\n  "tail_text": "hospitalization"\n}', 'refusal': None}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 318, 'completion_tokens': 456, 'total_tokens': 774, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'system_fingerprint': 'fp_143bb8492c'}
# -------response_text-----------------------
# {
#   "head_label": ["symptom"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["treatment"],
#   "head_text": "> 10 bloody bowel movements per day",
#   "relation_text": "require",
#   "tail_text": "hospitalization to receive biologic agent and/or high-dose IV corticosteroids"
# }
#
# {
#   "head_label": ["symptom"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["treatment"],
#   "head_text": "tachycardia",
#   "relation_text": "require",
#   "tail_text": "hospitalization to receive biologic agent and/or high-dose IV corticosteroids"
# }
#
# {
#   "head_label": ["symptom"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["treatment"],
#   "head_text": "high fever",
#   "relation_text": "require",
#   "tail_text": "hospitalization to receive biologic agent and/or high-dose IV corticosteroids"
# }
#
# {
#   "head_label": ["symptom"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["treatment"],
#   "head_text": "severe abdominal pain",
#   "relation_text": "require",
#   "tail_text": "hospitalization to receive biologic agent and/or high-dose IV corticosteroids"
# }
#
# {
#   "head_label": ["symptom"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["treatment"],
#   "head_text": "dehydration",
#   "relation_text": "require",
#   "tail_text": "IV fluids"
# }
#
# {
#   "head_label": ["symptom"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["treatment"],
#   "head_text": "anemia",
#   "relation_text": "require",
#   "tail_text": "blood transfusion"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "THRESHOLD",
#   "tail_label": ["condition"],
#   "head_text": "development of toxic colitis",
#   "relation_text": "must be observed closely for",
#   "tail_text": "hospitalization"
# }
#
# Extracting events from paragraph index = 42
# -------------------------------------
# {'id': 'chatcmpl-A9cbhBSMLkqikG7Mrn3xTgIMkuuFj', 'object': 'chat.completion', 'created': 1726856721, 'model': 'gpt-4o-2024-08-06', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n  "head_label": ["condition", "symptom"], \n  "relation_label": "IMPLIES", \n  "tail_label": ["treatment"], \n  "head_text": "fulminant or toxic colitis", \n  "relation_text": "is suspected, the patient should", \n  "tail_text": "stop all antidiarrheal medications"\n}\n\n{\n  "head_label": ["condition", "symptom"], \n  "relation_label": "IMPLIES", \n  "tail_label": ["treatment"], \n  "head_text": "fulminant or toxic colitis", \n  "relation_text": "is suspected, the patient should", \n  "tail_text": "take nothing by mouth"\n}\n\n{\n  "head_label": ["condition", "symptom"], \n  "relation_label": "IMPLIES", \n  "tail_label": ["treatment"], \n  "head_text": "fulminant or toxic colitis", \n  "relation_text": "is suspected, the patient should", \n  "tail_text": "have inserted a long intestinal tube attached to intermittent suction"\n}\n\n{\n  "head_label": ["condition", "symptom"], \n  "relation_label": "IMPLIES", \n  "tail_label": ["treatment"], \n  "head_text": "fulminant or toxic colitis", \n  "relation_text": "is suspected, the patient should", \n  "tail_text": "receive aggressive IV fluid and electrolyte therapy with sodium chloride, potassium chloride, and blood as needed"\n}', 'refusal': None}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 312, 'completion_tokens': 327, 'total_tokens': 639, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'system_fingerprint': 'fp_5050236cbd'}
# -------response_text-----------------------
# {
#   "head_label": ["condition", "symptom"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["treatment"],
#   "head_text": "fulminant or toxic colitis",
#   "relation_text": "is suspected, the patient should",
#   "tail_text": "stop all antidiarrheal medications"
# }
#
# {
#   "head_label": ["condition", "symptom"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["treatment"],
#   "head_text": "fulminant or toxic colitis",
#   "relation_text": "is suspected, the patient should",
#   "tail_text": "take nothing by mouth"
# }
#
# {
#   "head_label": ["condition", "symptom"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["treatment"],
#   "head_text": "fulminant or toxic colitis",
#   "relation_text": "is suspected, the patient should",
#   "tail_text": "have inserted a long intestinal tube attached to intermittent suction"
# }
#
# {
#   "head_label": ["condition", "symptom"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["treatment"],
#   "head_text": "fulminant or toxic colitis",
#   "relation_text": "is suspected, the patient should",
#   "tail_text": "receive aggressive IV fluid and electrolyte therapy with sodium chloride, potassium chloride, and blood as needed"
# }
#
# Extracting events from paragraph index = 43
# -------------------------------------
# {'id': 'chatcmpl-A9cbmk5bp5DL8eM1NWcqPTywixS22', 'object': 'chat.completion', 'created': 1726856726, 'model': 'gpt-4o-2024-08-06', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n  "head_label": ["condition", "risk factor"],\n  "relation_label": "IMPLIES",\n  "tail_label": ["treatment"],\n  "head_text": "extensive ulcerative colitis",\n  "relation_text": "ultimately require",\n  "tail_text": "surgery"\n}\n\n{\n  "head_label": ["treatment"],\n  "relation_label": "CAUSES",\n  "tail_label": ["outcome"],\n  "head_text": "Total proctocolectomy",\n  "relation_text": "is",\n  "tail_text": "curative"\n}\n\n{\n  "head_label": ["treatment"],\n  "relation_label": "IMPLIES",\n  "tail_label": ["outcome"],\n  "head_text": "Total proctocolectomy",\n  "relation_text": "restores",\n  "tail_text": "Life expectancy to normal"\n}\n\n{\n  "head_label": ["treatment"],\n  "relation_label": "IMPLIES",\n  "tail_label": ["risk factor"],\n  "head_text": "Total proctocolectomy",\n  "relation_text": "decreases",\n  "tail_text": "risk of colon cancer"\n}\n\n{\n  "head_label": ["treatment"],\n  "relation_label": "CAUSES",\n  "tail_label": ["condition"],\n  "head_text": "Total proctocolectomy",\n  "relation_text": "develop",\n  "tail_text": "inflammation in the small bowel mucosa consistent with Crohn disease"\n}', 'refusal': None}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 320, 'completion_tokens': 319, 'total_tokens': 639, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'system_fingerprint': 'fp_143bb8492c'}
# -------response_text-----------------------
# {
#   "head_label": ["condition", "risk factor"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["treatment"],
#   "head_text": "extensive ulcerative colitis",
#   "relation_text": "ultimately require",
#   "tail_text": "surgery"
# }
#
# {
#   "head_label": ["treatment"],
#   "relation_label": "CAUSES",
#   "tail_label": ["outcome"],
#   "head_text": "Total proctocolectomy",
#   "relation_text": "is",
#   "tail_text": "curative"
# }
#
# {
#   "head_label": ["treatment"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["outcome"],
#   "head_text": "Total proctocolectomy",
#   "relation_text": "restores",
#   "tail_text": "Life expectancy to normal"
# }
#
# {
#   "head_label": ["treatment"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["risk factor"],
#   "head_text": "Total proctocolectomy",
#   "relation_text": "decreases",
#   "tail_text": "risk of colon cancer"
# }
#
# {
#   "head_label": ["treatment"],
#   "relation_label": "CAUSES",
#   "tail_label": ["condition"],
#   "head_text": "Total proctocolectomy",
#   "relation_text": "develop",
#   "tail_text": "inflammation in the small bowel mucosa consistent with Crohn disease"
# }
#
# Extracting events from paragraph index = 44
# -------------------------------------
# {'id': 'chatcmpl-A9cbrHBr4tGBcfFoHnGBs5fQoqIa3', 'object': 'chat.completion', 'created': 1726856731, 'model': 'gpt-4o-2024-08-06', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n  "head_label": ["condition"],\n  "relation_label": "IMPLIES",\n  "tail_label": ["symptom"],\n  "head_text": "ulcerative colitis",\n  "relation_text": "is chronic with",\n  "tail_text": "repeated exacerbations and remissions"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "CAUSES",\n  "tail_label": ["condition", "symptom"],\n  "head_text": "an initial attack of ulcerative colitis",\n  "relation_text": "becomes fulminant with",\n  "tail_text": "massive hemorrhage, perforation, or sepsis and toxemia"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "OR",\n  "tail_label": ["symptom"],\n  "head_text": "massive hemorrhage",\n  "relation_text": "or",\n  "tail_text": "perforation, sepsis and toxemia"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "IMPLIES",\n  "tail_label": ["outcome"],\n  "head_text": "ulcerative colitis",\n  "relation_text": "can lead to",\n  "tail_text": "complete recovery after a single attack in a few patients"\n}', 'refusal': None}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 305, 'completion_tokens': 275, 'total_tokens': 580, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'system_fingerprint': 'fp_5050236cbd'}
# -------response_text-----------------------
# {
#   "head_label": ["condition"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["symptom"],
#   "head_text": "ulcerative colitis",
#   "relation_text": "is chronic with",
#   "tail_text": "repeated exacerbations and remissions"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "CAUSES",
#   "tail_label": ["condition", "symptom"],
#   "head_text": "an initial attack of ulcerative colitis",
#   "relation_text": "becomes fulminant with",
#   "tail_text": "massive hemorrhage, perforation, or sepsis and toxemia"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "OR",
#   "tail_label": ["symptom"],
#   "head_text": "massive hemorrhage",
#   "relation_text": "or",
#   "tail_text": "perforation, sepsis and toxemia"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["outcome"],
#   "head_text": "ulcerative colitis",
#   "relation_text": "can lead to",
#   "tail_text": "complete recovery after a single attack in a few patients"
# }
#
# Extracting events from paragraph index = 45
# -------------------------------------
# {'id': 'chatcmpl-A9cbwGp8VzOjMcpnLFjBUw9hud7gZ', 'object': 'chat.completion', 'created': 1726856736, 'model': 'gpt-4o-2024-08-06', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n  "head_label": ["risk factor", "condition"],\n  "relation_label": "IMPLIES",\n  "tail_label": ["condition"],\n  "head_text": "duration of disease and amount of colon affected",\n  "relation_text": "is proportional to",\n  "tail_text": "risk of colon cancer"\n}\n\n{\n  "head_label": ["risk factor"],\n  "relation_label": "NEGATES",\n  "tail_label": ["risk factor"],\n  "head_text": "clinical severity of the attacks",\n  "relation_text": "not necessarily proportional to",\n  "tail_text": "risk of colon cancer"\n}\n\n{\n  "head_label": ["risk factor"],\n  "relation_label": "CAUSES",\n  "tail_label": ["condition"],\n  "head_text": "sustained microscopic inflammation",\n  "relation_text": "is a risk factor for",\n  "tail_text": "colon cancer"\n}\n\n{\n  "head_label": ["treatment"],\n  "relation_label": "NEGATES",\n  "tail_label": ["risk factor"],\n  "head_text": "use of 5-aminosalicylic acid (5-ASA)",\n  "relation_text": "is protective against",\n  "tail_text": "risk of colon cancer"\n}', 'refusal': None}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 313, 'completion_tokens': 263, 'total_tokens': 576, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'system_fingerprint': 'fp_5050236cbd'}
# -------response_text-----------------------
# {
#   "head_label": ["risk factor", "condition"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["condition"],
#   "head_text": "duration of disease and amount of colon affected",
#   "relation_text": "is proportional to",
#   "tail_text": "risk of colon cancer"
# }
#
# {
#   "head_label": ["risk factor"],
#   "relation_label": "NEGATES",
#   "tail_label": ["risk factor"],
#   "head_text": "clinical severity of the attacks",
#   "relation_text": "not necessarily proportional to",
#   "tail_text": "risk of colon cancer"
# }
#
# {
#   "head_label": ["risk factor"],
#   "relation_label": "CAUSES",
#   "tail_label": ["condition"],
#   "head_text": "sustained microscopic inflammation",
#   "relation_text": "is a risk factor for",
#   "tail_text": "colon cancer"
# }
#
# {
#   "head_label": ["treatment"],
#   "relation_label": "NEGATES",
#   "tail_label": ["risk factor"],
#   "head_text": "use of 5-aminosalicylic acid (5-ASA)",
#   "relation_text": "is protective against",
#   "tail_text": "risk of colon cancer"
# }
#
# Extracting events from paragraph index = 46
# -------------------------------------
# {'id': 'chatcmpl-A9cc1Ab0IzeFAYAo1mGiXZn1EObFF', 'object': 'chat.completion', 'created': 1726856741, 'model': 'gpt-4o-2024-08-06', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n  "head_label": ["condition"],\n  "relation_label": "CAUSES",\n  "tail_label": ["symptom"],\n  "head_text": "Crohn disease",\n  "relation_text": "causes",\n  "tail_text": "diarrhea and abdominal pain"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "CAUSES",\n  "tail_label": ["complication"],\n  "head_text": "Crohn disease",\n  "relation_text": "may cause",\n  "tail_text": "abscesses, internal and external fistulas, and bowel obstruction"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "CAUSES",\n  "tail_label": ["symptom"],\n  "head_text": "Crohn disease",\n  "relation_text": "may cause",\n  "tail_text": "extraintestinal symptoms, particularly arthritis"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "DIAGNOSED_BY",\n  "tail_label": ["diagnostic procedure"],\n  "head_text": "Crohn disease",\n  "relation_text": "is diagnosed by",\n  "tail_text": "colonoscopy and imaging studies"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "TREATED_WITH",\n  "tail_label": ["treatment"],\n  "head_text": "Crohn disease",\n  "relation_text": "is treated with",\n  "tail_text": "5-aminosalicylic acid, corticosteroids, immunomodulators, anticytokines, antibiotics, and often surgery"\n}', 'refusal': None}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 354, 'completion_tokens': 333, 'total_tokens': 687, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'system_fingerprint': 'fp_143bb8492c'}
# -------response_text-----------------------
# {
#   "head_label": ["condition"],
#   "relation_label": "CAUSES",
#   "tail_label": ["symptom"],
#   "head_text": "Crohn disease",
#   "relation_text": "causes",
#   "tail_text": "diarrhea and abdominal pain"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "CAUSES",
#   "tail_label": ["complication"],
#   "head_text": "Crohn disease",
#   "relation_text": "may cause",
#   "tail_text": "abscesses, internal and external fistulas, and bowel obstruction"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "CAUSES",
#   "tail_label": ["symptom"],
#   "head_text": "Crohn disease",
#   "relation_text": "may cause",
#   "tail_text": "extraintestinal symptoms, particularly arthritis"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "DIAGNOSED_BY",
#   "tail_label": ["diagnostic procedure"],
#   "head_text": "Crohn disease",
#   "relation_text": "is diagnosed by",
#   "tail_text": "colonoscopy and imaging studies"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "TREATED_WITH",
#   "tail_label": ["treatment"],
#   "head_text": "Crohn disease",
#   "relation_text": "is treated with",
#   "tail_text": "5-aminosalicylic acid, corticosteroids, immunomodulators, anticytokines, antibiotics, and often surgery"
# }
#
# Extracting events from paragraph index = 47
# -------------------------------------
# {'id': 'chatcmpl-A9cc5KbadI09EeQuZgwu5GgacZqX1', 'object': 'chat.completion', 'created': 1726856745, 'model': 'gpt-4o-2024-08-06', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n  "head_label": ["condition", "symptom"],\n  "relation_label": "CAUSES",\n  "tail_label": ["condition", "symptom"],\n  "head_text": "Crohn disease",\n  "relation_text": "begins with",\n  "tail_text": "crypt inflammation and abscesses"\n}\n\n{\n  "head_label": ["symptom"],\n  "relation_label": "PROGRESSES TO",\n  "tail_label": ["symptom"],\n  "head_text": "crypt inflammation and abscesses",\n  "relation_text": "progress to",\n  "tail_text": "tiny focal aphthoid ulcers"\n}\n\n{\n  "head_label": ["symptom"],\n  "relation_label": "MAY DEVELOP INTO",\n  "tail_label": ["symptom"],\n  "head_text": "tiny focal aphthoid ulcers",\n  "relation_text": "may develop into",\n  "tail_text": "deep longitudinal and transverse ulcers with intervening mucosal edema"\n}\n\n{\n  "head_label": ["symptom"],\n  "relation_label": "CAUSES",\n  "tail_label": ["condition"],\n  "head_text": "deep longitudinal and transverse ulcers with intervening mucosal edema",\n  "relation_text": "creating",\n  "tail_text": "cobblestoned appearance to the bowel"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "LEADS TO",\n  "tail_label": ["symptom"],\n  "head_text": "Transmural spread of inflammation",\n  "relation_text": "leads to",\n  "tail_text": "lymphedema and thickening of the bowel wall and mesentery"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "RESULTS IN",\n  "tail_label": ["condition"],\n  "head_text": "Extensive inflammation",\n  "relation_text": "may result in",\n  "tail_text": "hypertrophy of the muscularis mucosae, fibrosis, and stricture formation"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "CAN LEAD TO",\n  "tail_label": ["condition"],\n  "head_text": "stricture formation",\n  "relation_text": "can lead to",\n  "tail_text": "bowel obstruction"\n}', 'refusal': None}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 381, 'completion_tokens': 480, 'total_tokens': 861, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'system_fingerprint': 'fp_5050236cbd'}
# -------response_text-----------------------
# {
#   "head_label": ["condition", "symptom"],
#   "relation_label": "CAUSES",
#   "tail_label": ["condition", "symptom"],
#   "head_text": "Crohn disease",
#   "relation_text": "begins with",
#   "tail_text": "crypt inflammation and abscesses"
# }
#
# {
#   "head_label": ["symptom"],
#   "relation_label": "PROGRESSES TO",
#   "tail_label": ["symptom"],
#   "head_text": "crypt inflammation and abscesses",
#   "relation_text": "progress to",
#   "tail_text": "tiny focal aphthoid ulcers"
# }
#
# {
#   "head_label": ["symptom"],
#   "relation_label": "MAY DEVELOP INTO",
#   "tail_label": ["symptom"],
#   "head_text": "tiny focal aphthoid ulcers",
#   "relation_text": "may develop into",
#   "tail_text": "deep longitudinal and transverse ulcers with intervening mucosal edema"
# }
#
# {
#   "head_label": ["symptom"],
#   "relation_label": "CAUSES",
#   "tail_label": ["condition"],
#   "head_text": "deep longitudinal and transverse ulcers with intervening mucosal edema",
#   "relation_text": "creating",
#   "tail_text": "cobblestoned appearance to the bowel"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "LEADS TO",
#   "tail_label": ["symptom"],
#   "head_text": "Transmural spread of inflammation",
#   "relation_text": "leads to",
#   "tail_text": "lymphedema and thickening of the bowel wall and mesentery"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "RESULTS IN",
#   "tail_label": ["condition"],
#   "head_text": "Extensive inflammation",
#   "relation_text": "may result in",
#   "tail_text": "hypertrophy of the muscularis mucosae, fibrosis, and stricture formation"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "CAN LEAD TO",
#   "tail_label": ["condition"],
#   "head_text": "stricture formation",
#   "relation_text": "can lead to",
#   "tail_text": "bowel obstruction"
# }
#
# Extracting events from paragraph index = 48
# -------------------------------------
# ...
# -------response_text-----------------------
# {
#   "head_label": ["condition", "risk factor"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["symptom"],
#   "head_text": "history of recurrent anorectal abscess",
#   "relation_text": "is usual followed by",
#   "tail_text": "intermittent or constant discharge"
# }
#
# {
#   "head_label": ["symptom"],
#   "relation_label": "OR",
#   "tail_label": ["symptom"],
#   "head_text": "discharge material is purulent",
#   "relation_text": "or",
#   "tail_text": "serosanguineous"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "CAUSES",
#   "tail_label": ["symptom"],
#   "head_text": "infection",
#   "relation_text": "may cause",
#   "tail_text": "pain"
# }
#
# {
#   "head_label": ["symptom"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["sign"],
#   "head_text": "pain",
#   "relation_text": "may be present if there is",
#   "tail_text": "infection"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["sign"],
#   "head_text": "anorectal abscess",
#   "relation_text": "on inspection, can be seen as",
#   "tail_text": "one or more secondary openings"
# }
#
# {
#   "head_label": ["sign"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["sign"],
#   "head_text": "cordlike tract",
#   "relation_text": "can often be palpated",
#   "tail_text": "indicating a tract"
# }
#
# {
#   "head_label": ["procedure"],
#   "relation_label": "DETERMINES",
#   "tail_label": ["sign"],
#   "head_text": "probe inserted into the tract",
#   "relation_text": "can determine",
#   "tail_text": "depth and direction and often the primary opening"
# }
#
# Extracting events from paragraph index = 223
# -------------------------------------
# {'id': 'chatcmpl-A9cpQVOQBHGcS8fWx9KLdaZeb06hw', 'object': 'chat.completion', 'created': 1726857572, 'model': 'gpt-4o-2024-08-06', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n  "head_label": ["condition", "diagnostic procedure"],\n  "relation_label": "IMPLIES",\n  "tail_label": ["condition"],\n  "head_text": "Diagnosis of anorectal fistula by examination",\n  "relation_text": "implies",\n  "tail_text": "anorectal fistula"\n}\n\n{\n  "head_label": ["diagnostic procedure"],\n  "relation_label": "CAUSES",\n  "tail_label": ["symptom"],\n  "head_text": "Anoscopy or sigmoidoscopy",\n  "relation_text": "may be used to visualize",\n  "tail_text": "internal opening of the fistula"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "THRESHOLD",\n  "tail_label": ["diagnostic procedure"],\n  "head_text": "suspicion of Crohn disease",\n  "relation_text": "should follow",\n  "tail_text": "colonoscopy"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "OR",\n  "tail_label": ["condition"],\n  "head_text": "Hidradenitis suppurativa, pilonidal sinus, dermal suppurative sinuses, and urethroperineal fistulas",\n  "relation_text": "must be differentiated from",\n  "tail_text": "cryptogenic fistulas"\n}', 'refusal': None}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 333, 'completion_tokens': 286, 'total_tokens': 619, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'system_fingerprint': 'fp_143bb8492c'}
# -------response_text-----------------------
# {
#   "head_label": ["condition", "diagnostic procedure"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["condition"],
#   "head_text": "Diagnosis of anorectal fistula by examination",
#   "relation_text": "implies",
#   "tail_text": "anorectal fistula"
# }
#
# {
#   "head_label": ["diagnostic procedure"],
#   "relation_label": "CAUSES",
#   "tail_label": ["symptom"],
#   "head_text": "Anoscopy or sigmoidoscopy",
#   "relation_text": "may be used to visualize",
#   "tail_text": "internal opening of the fistula"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "THRESHOLD",
#   "tail_label": ["diagnostic procedure"],
#   "head_text": "suspicion of Crohn disease",
#   "relation_text": "should follow",
#   "tail_text": "colonoscopy"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "OR",
#   "tail_label": ["condition"],
#   "head_text": "Hidradenitis suppurativa, pilonidal sinus, dermal suppurative sinuses, and urethroperineal fistulas",
#   "relation_text": "must be differentiated from",
#   "tail_text": "cryptogenic fistulas"
# }
#
# Extracting events from paragraph index = 224
# -------------------------------------
# {'id': 'chatcmpl-A9cpUiegDyBjhR762ukurgNlCfMUi', 'object': 'chat.completion', 'created': 1726857576, 'model': 'gpt-4o-2024-08-06', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n  "head_label": ["condition", "risk factor"],\n  "relation_label": "CAUSES",\n  "tail_label": ["condition"],\n  "head_text": "Crohn disease",\n  "relation_text": "causes",\n  "tail_text": "anorectal fistula"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "IMPLIES",\n  "tail_label": ["treatment"],\n  "head_text": "anorectal fistula",\n  "relation_text": "implies",\n  "tail_text": "surgical procedures"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "NEGATES",\n  "tail_label": ["treatment"],\n  "head_text": "diarrhea",\n  "relation_text": "negates",\n  "tail_text": "fistulotomy"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "NEGATES",\n  "tail_label": ["treatment"],\n  "head_text": "Crohn disease",\n  "relation_text": "negates",\n  "tail_text": "fistulotomy"\n}\n\n{\n  "head_label": ["treatment"],\n  "relation_label": "OR",\n  "tail_label": ["treatment"],\n  "head_text": "fistulotomy",\n  "relation_text": "or",\n  "tail_text": "fistulectomy"\n}\n\n{\n  "head_label": ["treatment"],\n  "relation_label": "OR",\n  "tail_label": ["treatment"],\n  "head_text": "advancement flaps",\n  "relation_text": "or",\n  "tail_text": "biologic plugs"\n}\n\n{\n  "head_label": ["treatment"],\n  "relation_label": "OR",\n  "tail_label": ["treatment"],\n  "head_text": "advancement flaps",\n  "relation_text": "or",\n  "tail_text": "fibrin glue instillations"\n}\n\n{\n  "head_label": ["treatment"],\n  "relation_label": "OR",\n  "tail_label": ["treatment"],\n  "head_text": "biologic plugs",\n  "relation_text": "or",\n  "tail_text": "fibrin glue instillations"\n}\n\n{\n  "head_label": ["treatment"],\n  "relation_label": "IMPLIES",\n  "tail_label": ["outcome"],\n  "head_text": "LIFT procedure",\n  "relation_text": "implies",\n  "tail_text": "preservation of continence"\n}', 'refusal': None}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 348, 'completion_tokens': 535, 'total_tokens': 883, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'system_fingerprint': 'fp_143bb8492c'}
# -------response_text-----------------------
# {
#   "head_label": ["condition", "risk factor"],
#   "relation_label": "CAUSES",
#   "tail_label": ["condition"],
#   "head_text": "Crohn disease",
#   "relation_text": "causes",
#   "tail_text": "anorectal fistula"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["treatment"],
#   "head_text": "anorectal fistula",
#   "relation_text": "implies",
#   "tail_text": "surgical procedures"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "NEGATES",
#   "tail_label": ["treatment"],
#   "head_text": "diarrhea",
#   "relation_text": "negates",
#   "tail_text": "fistulotomy"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "NEGATES",
#   "tail_label": ["treatment"],
#   "head_text": "Crohn disease",
#   "relation_text": "negates",
#   "tail_text": "fistulotomy"
# }
#
# {
#   "head_label": ["treatment"],
#   "relation_label": "OR",
#   "tail_label": ["treatment"],
#   "head_text": "fistulotomy",
#   "relation_text": "or",
#   "tail_text": "fistulectomy"
# }
#
# {
#   "head_label": ["treatment"],
#   "relation_label": "OR",
#   "tail_label": ["treatment"],
#   "head_text": "advancement flaps",
#   "relation_text": "or",
#   "tail_text": "biologic plugs"
# }
#
# {
#   "head_label": ["treatment"],
#   "relation_label": "OR",
#   "tail_label": ["treatment"],
#   "head_text": "advancement flaps",
#   "relation_text": "or",
#   "tail_text": "fibrin glue instillations"
# }
#
# {
#   "head_label": ["treatment"],
#   "relation_label": "OR",
#   "tail_label": ["treatment"],
#   "head_text": "biologic plugs",
#   "relation_text": "or",
#   "tail_text": "fibrin glue instillations"
# }
#
# {
#   "head_label": ["treatment"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["outcome"],
#   "head_text": "LIFT procedure",
#   "relation_text": "implies",
#   "tail_text": "preservation of continence"
# }
#
# Extracting events from paragraph index = 225
# -------------------------------------
# {'id': 'chatcmpl-A9cpdEjWKMwavK2EVBHwP65ufRypr', 'object': 'chat.completion', 'created': 1726857585, 'model': 'gpt-4o-2024-08-06', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n  "head_label": ["condition"],\n  "relation_label": "CAUSES",\n  "tail_label": ["symptom"],\n  "head_text": "Crohn disease",\n  "relation_text": "causes",\n  "tail_text": "anal fistulas"\n}\n\n{\n  "head_label": ["treatment"],\n  "relation_label": "IMPLIES",\n  "tail_label": ["condition"],\n  "head_text": "metronidazole",\n  "relation_text": "can be given for",\n  "tail_text": "Crohn disease"\n}\n\n{\n  "head_label": ["treatment"],\n  "relation_label": "IMPLIES",\n  "tail_label": ["condition"],\n  "head_text": "other appropriate antibiotics",\n  "relation_text": "can be given for",\n  "tail_text": "Crohn disease"\n}\n\n{\n  "head_label": ["treatment"],\n  "relation_label": "IMPLIES",\n  "tail_label": ["condition"],\n  "head_text": "suppressive therapies",\n  "relation_text": "can be given for",\n  "tail_text": "Crohn disease"\n}\n\n{\n  "head_label": ["treatment"],\n  "relation_label": "EFFECTIVE FOR",\n  "tail_label": ["symptom"],\n  "head_text": "Infliximab",\n  "relation_text": "is effective in closing",\n  "tail_text": "anal fistulas"\n}', 'refusal': None}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 292, 'completion_tokens': 302, 'total_tokens': 594, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'system_fingerprint': 'fp_143bb8492c'}
# -------response_text-----------------------
# {
#   "head_label": ["condition"],
#   "relation_label": "CAUSES",
#   "tail_label": ["symptom"],
#   "head_text": "Crohn disease",
#   "relation_text": "causes",
#   "tail_text": "anal fistulas"
# }
#
# {
#   "head_label": ["treatment"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["condition"],
#   "head_text": "metronidazole",
#   "relation_text": "can be given for",
#   "tail_text": "Crohn disease"
# }
#
# {
#   "head_label": ["treatment"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["condition"],
#   "head_text": "other appropriate antibiotics",
#   "relation_text": "can be given for",
#   "tail_text": "Crohn disease"
# }
#
# {
#   "head_label": ["treatment"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["condition"],
#   "head_text": "suppressive therapies",
#   "relation_text": "can be given for",
#   "tail_text": "Crohn disease"
# }
#
# {
#   "head_label": ["treatment"],
#   "relation_label": "EFFECTIVE FOR",
#   "tail_label": ["symptom"],
#   "head_text": "Infliximab",
#   "relation_text": "is effective in closing",
#   "tail_text": "anal fistulas"
# }
#
# Extracting events from paragraph index = 226
# -------------------------------------
# {'id': 'chatcmpl-A9cpigNQCkhG60Lcc2OIMdiS8exTw', 'object': 'chat.completion', 'created': 1726857590, 'model': 'gpt-4o-2024-08-06', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '{\n  "head_label": ["condition"],\n  "relation_label": "AND",\n  "tail_label": ["condition"],\n  "head_text": "anorectal abscess",\n  "relation_text": "and",\n  "tail_text": "fistula-in-ano"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "AND",\n  "tail_label": ["condition"],\n  "head_text": "fistula-in-ano",\n  "relation_text": "and",\n  "tail_text": "rectovaginal fistula"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "AND",\n  "tail_label": ["condition"],\n  "head_text": "anorectal abscess",\n  "relation_text": "and",\n  "tail_text": "rectovaginal fistula"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "IMPLIES",\n  "tail_label": ["treatment"],\n  "head_text": "anorectal abscess",\n  "relation_text": "implies",\n  "tail_text": "management"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "IMPLIES",\n  "tail_label": ["treatment"],\n  "head_text": "fistula-in-ano",\n  "relation_text": "implies",\n  "tail_text": "management"\n}\n\n{\n  "head_label": ["condition"],\n  "relation_label": "IMPLIES",\n  "tail_label": ["treatment"],\n  "head_text": "rectovaginal fistula",\n  "relation_text": "implies",\n  "tail_text": "management"\n}', 'refusal': None}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 298, 'completion_tokens': 354, 'total_tokens': 652, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'system_fingerprint': 'fp_143bb8492c'}
# -------response_text-----------------------
# {
#   "head_label": ["condition"],
#   "relation_label": "AND",
#   "tail_label": ["condition"],
#   "head_text": "anorectal abscess",
#   "relation_text": "and",
#   "tail_text": "fistula-in-ano"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "AND",
#   "tail_label": ["condition"],
#   "head_text": "fistula-in-ano",
#   "relation_text": "and",
#   "tail_text": "rectovaginal fistula"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "AND",
#   "tail_label": ["condition"],
#   "head_text": "anorectal abscess",
#   "relation_text": "and",
#   "tail_text": "rectovaginal fistula"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["treatment"],
#   "head_text": "anorectal abscess",
#   "relation_text": "implies",
#   "tail_text": "management"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["treatment"],
#   "head_text": "fistula-in-ano",
#   "relation_text": "implies",
#   "tail_text": "management"
# }
#
# {
#   "head_label": ["condition"],
#   "relation_label": "IMPLIES",
#   "tail_label": ["treatment"],
#   "head_text": "rectovaginal fistula",
#   "relation_text": "implies",
#   "tail_text": "management"
# }
#
# Extracting events from paragraph index = 227
# -------------------------------------
# Time used= 928.84
