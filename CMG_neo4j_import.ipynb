# %%
import pandas as pd
from openai import OpenAI
# import graph database driver
from neo4j import GraphDatabase
# import the OpenAI ChatOpenAI class
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-4o",
    api_key="sk-proj-pjGUyMNiHPDiH7CLYv4rT3BlbkFJQpZiY1U0sYAqOATygpnJ",
    temperature=0.0,
    max_tokens=None
    )


df = pd.read_csv('CMG_EDA_1.csv')
# Return empty string if the value is NaN, apply to columns 'Head text', 'Relation text' and 'Tail text'
df['Head text'] = df['Head text'].apply(lambda x: '' if pd.isnull(x) else x)
df['Relation text'] = df['Relation text'].apply(lambda x: '' if pd.isnull(x) else x)
df['Tail text'] = df['Tail text'].apply(lambda x: '' if pd.isnull(x) else x)

# embedding = client.embeddings.create()

client = OpenAI(api_key="sk-proj-pjGUyMNiHPDiH7CLYv4rT3BlbkFJQpZiY1U0sYAqOATygpnJ")
# connect to the Neo4j database
uri = "bolt://localhost:54621"
driver = GraphDatabase.driver(uri, auth=("neo4j", "saiyan94"))

# Generate embeddings for each row in the dataframe, using text-embedding-3-small, on column 'Head text', 'Relation text' and 'Tail text'
def generate_embeddings(df):
    embeddings = []
    for i in range(len(df)):
        head_text = df['Head text'][i]
        relation_text = df['Relation text'][i]
        tail_text = df['Tail text'][i]
        # embed and store the embeddings in separated lists
        head_embedding = client.embeddings.create(input=head_text, model="text-embedding-3-small")
        relation_embedding = client.embeddings.create(input=relation_text, model="text-embedding-3-small")
        tail_embedding = client.embeddings.create(input=tail_text, model="text-embedding-3-small")
        embeddings.append([head_embedding, relation_embedding, tail_embedding])
    return embeddings

# update the dataframe with the embeddings
def update_df(df, embeddings):
    df['Head embedding'] = [embedding[0] for embedding in embeddings]
    df['Relation embedding'] = [embedding[1] for embedding in embeddings]
    df['Tail embedding'] = [embedding[2] for embedding in embeddings]
    return df

# function to generate embeddings for a certain number of rows
def generate_embeddings_batch(df, start, end=None):
    # end = -1 means the end of the dataframe
    if end == -1:
        end = len(df)
    embeddings = []
    for i in range(start, end):
        head_text = df['Head text'][i]
        relation_text = df['Relation text'][i]
        tail_text = df['Tail text'][i]
        # embed and store the embeddings in separated lists
        head = client.embeddings.create(input=[head_text], model="text-embedding-3-small")
        head_embedding = [r.embedding for r in head.data]
        relation = client.embeddings.create(input=[relation_text], model="text-embedding-3-small")
        relation_embedding = [r.embedding for r in relation.data]
        if tail_text.strip():
            tail = client.embeddings.create(input=[tail_text], model="text-embedding-3-small")
            tail_embedding = [r.embedding for r in tail.data]
        else:
            tail_embedding = []
        embeddings.append([head_embedding, relation_embedding, tail_embedding])
    return embeddings

# %%
# Re-write the embeddings fucntion to update embedding to neo4j head, relation and tail nodes
def get_openai_embedding(text):
    # embed and store the embeddings in separated lists
    response = client.embeddings.create(input=text, model="text-embedding-3-small")
    return response.data[0].embedding

# Write function to access Neo4j graph, match nodes that have "text" property and embed the text into a new property "embedding"
def update_neo4j_embeddings():
    with driver.session() as session:
        query_node_property = """
        MATCH (n)
        WHERE n.text IS NOT NULL
        RETURN n.article_id AS article_id, n.paragraph_id AS paragraph_id, n.event_id AS event_id, n.text AS text_property
        """
        result = session.run(query_node_property)
        for record in result:
            text = record['text_property']
            embedding = get_openai_embedding(text)
            query_update_embedding = """
            MATCH (n)
            WHERE n.text = $text
            SET n.embedding = $embedding
            """
            session.run(query_update_embedding, text=text, embedding=embedding)

def update_relation_neo4j_embeddings():
    with driver.session() as session:
        query_relation_property = """
        MATCH ()-[r]->()
        WHERE r.text IS NOT NULL
        RETURN r.article_id AS article_id, r.paragraph_id AS paragraph_id, r.event_id AS event_id, r.text AS text_property
        """
        result = session.run(query_relation_property)
        for record in result:
            text = record['text_property']
            embedding = get_openai_embedding(text)
            query_update_embedding = """
            MATCH ()-[r]->()
            WHERE r.text = $text
            SET r.embedding = $embedding
            """
            session.run(query_update_embedding, text=text, embedding=embedding)

# %%
# test get_openai_embedding
text = 'hello world'
embedding = get_openai_embedding(text)

# %%
update_relation_neo4j_embeddings()

# %%
update_neo4j_embeddings()

# %%
# check df head, relation and tail text if there is any NaN value
print(df['Head text'].isnull().sum())
print(df['Relation text'].isnull().sum())
print(df['Tail text'].isnull().sum())

# print the df Head, Relation, Tail for checking
print(df['Head text'])
print(df['Relation text'])
print(df['Tail text'])
# check number of items in the Head column, Relation column and Tail column
print(len(df['Head text']))
print(len(df['Relation text']))
print(len(df['Tail text']))
# Out:
# 0
# 0
# 0
# 0      Flexible endoscopes equipped with video cameras
# 1                     specialized, longer enteroscopes
# 2                                            endoscopy
# 3                                            endoscopy
# 4                                            endoscopy
#                             ...
# 993                                     fistula-in-ano
# 994                                  anorectal abscess
# 995                                  anorectal abscess
# 996                                     fistula-in-ano
# 997                               rectovaginal fistula
# Name: Head text, Length: 998, dtype: object
# 0        can be used to view
# 1      can be used to assess
# 2                can combine
# 3                      gives
# 4            often outweighs
#                ...
# 993                      and
# 994                      and
# 995                  implies
# 996                  implies
# 997                  implies
# Name: Relation text, Length: 998, dtype: object
# 0      the upper gastrointestinal tract from pharynx ...
# 1              the deeper parts of the jejunum and ileum
# 2                 diagnosis and therapy in one procedure
# 3      a significant advantage over studies that prov...
# 4                      higher cost and need for sedation
#                              ...
# 993                                 rectovaginal fistula
# 994                                 rectovaginal fistula
# 995                                           management
# 996                                           management
# 997                                           management
# Name: Tail text, Length: 998, dtype: object
# 998
# 998
# 998

# %%
# embeddings = generate_embeddings(df)
# Test generate embeddings batch with 1 row
embeddings = generate_embeddings_batch(df, 0, 1)
print(embeddings)
# Out:
# [[[[0.023966971784830093, 0.011609974317252636, 0.0076818810775876045, -0.00022041054035071284, -0.05518006160855293, 0.0023935844656080008, -0.023904720321297646, -0.00251341937109828, 0.0343630351126194, -0.020804576575756073, 0.04581737890839577, -0.07171415537595749, 0.016471846029162407, -0.033192697912454605, 0.023705514147877693, -0.05049872025847435, -0.01980854570865631, -0.005829887930303812, -0.006309227552264929, 0.05981159955263138, 0.03491085022687912, -0.007451549172401428, -0.007327045779675245, -0.05503065511584282, -0.001314292661845684, -0.042729686945676804, -0.032943692058324814, 0.05453264340758324, 0.019173577427864075, 0.0067792292684316635, 0.032171767204999924, -0.03550846874713898, -0.03329230099916458, -0.0067543284967541695, -0.08067842572927475, 0.05234137549996376, 0.0028153411112725735, 0.0034487538505345583, -0.026021283119916916, 0.025672672316432, 0.0508224293589592, 0.005941941402852535, 0.018638210371136665, -0.00992917362600565, 0.008360426872968674, -0.02380511723458767, -0.04701261594891548, 0.042704787105321884, 0.01873781345784664, -0.017667081207036972, 0.030254410579800606, 0.018638210371136665, 0.008572082966566086, -0.015388662926852703, -0.035807278007268906, -0.05846695974469185, -0.03812304884195328, 0.004214451648294926, -0.02435293234884739, 0.02221146784722805, 0.005185581278055906, -0.054034627974033356, 0.05861636623740196, 0.024776246398687363, -0.010894077830016613, -0.00991672370582819, -0.028660763055086136, 0.05483144894242287, 0.0034114026930183172, 0.010035001672804356, 0.03705231472849846, 0.0369776114821434, -0.05707251653075218, 0.006511546205729246, 0.028162747621536255, -0.014467335306107998, -0.0026348105166107416, -0.008540957234799862, -0.013670511543750763, -0.016808005049824715, 0.017131716012954712, 0.04392492398619652, -0.05821795389056206, 0.010894077830016613, -0.012101763859391212, 0.015239258296787739, 0.011398318223655224, -0.04863116517663002, -0.022871337831020355, 0.02061782032251358, -0.008951819501817226, 0.0026799431070685387, 0.023145247250795364, 0.0008684136555530131, 0.021613851189613342, 0.03125043958425522, -0.03311799839138985, -0.06593718379735947, 0.030304212123155594, 0.041385047137737274, 0.036130987107753754, 0.017330922186374664, -0.009698841720819473, -0.05891517177224159, 0.054084427654743195, 0.009854471310973167, 0.007295919582247734, 0.009985200129449368, 0.020804576575756073, 0.022124316543340683, 0.0630984976887703, -0.039741598069667816, -0.021277690306305885, -0.018862318247556686, 0.026245390996336937, -0.0005555980023927987, -0.0179658904671669, -0.05002560466527939, 0.01720641739666462, -0.0385463610291481, -0.03787403926253319, 0.041609153151512146, -0.012120439670979977, -0.059911202639341354, -0.012506401166319847, 0.0030596796423196793, -0.041409946978092194, 0.0030814677011221647, 0.0033522634766995907, -0.05522986128926277, 0.011522822082042694, -0.044298432767391205, 0.021003782749176025, -0.00992294866591692, -0.006387042347341776, 0.07684371620416641, -0.0471620187163353, -0.010122154839336872, -0.0177044328302145, 0.022298621013760567, 0.026369893923401833, 0.0018784502753987908, 0.03224647045135498, -0.018326951190829277, 0.008547182194888592, 0.021464446559548378, -0.05896497517824173, 0.02007000334560871, 0.015301510691642761, 0.03538396582007408, -0.04414902999997139, 0.004516373388469219, -0.03864596411585808, -0.009312880225479603, -0.044298432767391205, -0.04103643447160721, -0.004643989726901054, 0.00992294866591692, 0.007800159975886345, 0.023979421705007553, -0.007439098786562681, -0.013097794726490974, 0.006984660401940346, 0.0390692763030529, -0.030204609036445618, 0.030453616753220558, 0.008117644116282463, 0.014865747652947903, -0.06907468289136887, 0.0068041300401091576, 0.007632079534232616, 0.00978599488735199, -0.009194601327180862, 0.05547887086868286, -0.00357014499604702, 0.03179825842380524, 0.05996100604534149, -0.03147454932332039, -0.03164885193109512, -0.001609210972674191, -0.0030534 ...

# %%
# pring embeddings's shape. note that embeddings is a list of lists of lists
head_embedding = embeddings[0][0]
relation_embedding = embeddings[0][1]
tail_embedding = embeddings[0][2]
print("head_embedding shape:", head_embedding[0])
print("relation_embedding shape:", relation_embedding[0])
print("tail_embedding shape:", tail_embedding[0])
# Out:
# head_embedding shape: [0.023966971784830093, 0.011609974317252636, 0.0076818810775876045, -0.00022041054035071284, -0.05518006160855293, 0.0023935844656080008, -0.023904720321297646, -0.00251341937109828, 0.0343630351126194, -0.020804576575756073, 0.04581737890839577, -0.07171415537595749, 0.016471846029162407, -0.033192697912454605, 0.023705514147877693, -0.05049872025847435, -0.01980854570865631, -0.005829887930303812, -0.006309227552264929, 0.05981159955263138, 0.03491085022687912, -0.007451549172401428, -0.007327045779675245, -0.05503065511584282, -0.001314292661845684, -0.042729686945676804, -0.032943692058324814, 0.05453264340758324, 0.019173577427864075, 0.0067792292684316635, 0.032171767204999924, -0.03550846874713898, -0.03329230099916458, -0.0067543284967541695, -0.08067842572927475, 0.05234137549996376, 0.0028153411112725735, 0.0034487538505345583, -0.026021283119916916, 0.025672672316432, 0.0508224293589592, 0.005941941402852535, 0.018638210371136665, -0.00992917362600565, 0.008360426872968674, -0.02380511723458767, -0.04701261594891548, 0.042704787105321884, 0.01873781345784664, -0.017667081207036972, 0.030254410579800606, 0.018638210371136665, 0.008572082966566086, -0.015388662926852703, -0.035807278007268906, -0.05846695974469185, -0.03812304884195328, 0.004214451648294926, -0.02435293234884739, 0.02221146784722805, 0.005185581278055906, -0.054034627974033356, 0.05861636623740196, 0.024776246398687363, -0.010894077830016613, -0.00991672370582819, -0.028660763055086136, 0.05483144894242287, 0.0034114026930183172, 0.010035001672804356, 0.03705231472849846, 0.0369776114821434, -0.05707251653075218, 0.006511546205729246, 0.028162747621536255, -0.014467335306107998, -0.0026348105166107416, -0.008540957234799862, -0.013670511543750763, -0.016808005049824715, 0.017131716012954712, 0.04392492398619652, -0.05821795389056206, 0.010894077830016613, -0.012101763859391212, 0.015239258296787739, 0.011398318223655224, -0.04863116517663002, -0.022871337831020355, 0.02061782032251358, -0.008951819501817226, 0.0026799431070685387, 0.023145247250795364, 0.0008684136555530131, 0.021613851189613342, 0.03125043958425522, -0.03311799839138985, -0.06593718379735947, 0.030304212123155594, 0.041385047137737274, 0.036130987107753754, 0.017330922186374664, -0.009698841720819473, -0.05891517177224159, 0.054084427654743195, 0.009854471310973167, 0.007295919582247734, 0.009985200129449368, 0.020804576575756073, 0.022124316543340683, 0.0630984976887703, -0.039741598069667816, -0.021277690306305885, -0.018862318247556686, 0.026245390996336937, -0.0005555980023927987, -0.0179658904671669, -0.05002560466527939, 0.01720641739666462, -0.0385463610291481, -0.03787403926253319, 0.041609153151512146, -0.012120439670979977, -0.059911202639341354, -0.012506401166319847, 0.0030596796423196793, -0.041409946978092194, 0.0030814677011221647, 0.0033522634766995907, -0.05522986128926277, 0.011522822082042694, -0.044298432767391205, 0.021003782749176025, -0.00992294866591692, -0.006387042347341776, 0.07684371620416641, -0.0471620187163353, -0.010122154839336872, -0.0177044328302145, 0.022298621013760567, 0.026369893923401833, 0.0018784502753987908, 0.03224647045135498, -0.018326951190829277, 0.008547182194888592, 0.021464446559548378, -0.05896497517824173, 0.02007000334560871, 0.015301510691642761, 0.03538396582007408, -0.04414902999997139, 0.004516373388469219, -0.03864596411585808, -0.009312880225479603, -0.044298432767391205, -0.04103643447160721, -0.004643989726901054, 0.00992294866591692, 0.007800159975886345, 0.023979421705007553, -0.007439098786562681, -0.013097794726490974, 0.006984660401940346, 0.0390692763030529, -0.030204609036445618, 0.030453616753220558, 0.008117644116282463, 0.014865747652947903, -0.06907468289136887, 0.0068041300401091576, 0.007632079534232616, 0.00978599488735199, -0.009194601327180862, 0.05547887086868286, -0.00357014499604702, 0.03179825842380524, 0.05996100604534149, -0.03147454932332039, -0.03164885193109512, -0.00160921097 ...
# relation_embedding shape: [0.016521386802196503, 0.029424836859107018, -0.018835000693798065, -0.009425264783203602, -0.03826005384325981, -0.06645821034908295, -0.03847743943333626, 0.0003864921454805881, 0.009021546691656113, 0.0015488800127059221, 0.032732222229242325, 0.016148723661899567, -0.007111649494618177, -0.00538808386772871, 0.06447067111730576, -0.03891221433877945, -0.03301171585917473, 0.031039709225296974, -0.0035286513157188892, 0.08943908661603928, 0.04530959203839302, 0.027747854590415955, 0.0189281664788723, -0.02827579341828823, -0.02780996449291706, 0.00860230065882206, -0.053197622299194336, -0.004141992423683405, 0.057421132922172546, 0.027406247332692146, -0.027949713170528412, -0.049936823546886444, 0.03279433026909828, -0.006211047526448965, -0.02032565325498581, -0.03245272487401962, 0.01860208809375763, 0.005745219066739082, -0.017095908522605896, -0.01100908126682043, 0.0574832446873188, 0.03391231968998909, -6.399077392416075e-05, 0.0011034314520657063, 0.03128815069794655, -0.024952882900834084, -0.02861740067601204, 0.026288257911801338, 0.002268973272293806, 0.040868692100048065, 0.014215534552931786, 0.02546529471874237, 0.017437515780329704, -0.027080167084932327, -0.01799651049077511, -0.021148616448044777, 0.013408098369836807, -0.012111542746424675, 0.006971900817006826, -0.029455892741680145, -0.0021389294415712357, 0.01905238814651966, 0.0649675577878952, 0.028819261118769646, -0.041831403970718384, 0.041645072400569916, 0.0008316980674862862, 0.048663556575775146, -0.038228996098041534, -0.00039643951458856463, -0.00715435016900301, -0.015217066742479801, -0.005027066450566053, 0.03950226306915283, -0.00326079991646111, 0.003734392346814275, -0.00020173774100840092, 0.01179322600364685, 0.012414331547915936, -0.0026493999175727367, 0.015659604221582413, 0.011839808896183968, -0.08360069990158081, 0.01593133620917797, -0.013951565138995647, 0.013167420402169228, 0.00016813499678391963, 0.01689404994249344, -0.019906407222151756, -0.002418426563963294, 0.004056590609252453, 0.006746750324964523, 0.005248335190117359, -0.002779443748295307, 0.06288685649633408, 0.06620976328849792, -0.027608105912804604, -0.05425349995493889, 0.003870259039103985, 0.05235913023352623, -0.02326037362217903, -0.01781017892062664, -0.016800884157419205, -0.03853955119848251, 0.06832152605056763, 0.03645884990692139, 0.019595853984355927, 0.01841575652360916, 0.011513729579746723, 0.047266069799661636, 0.012150362133979797, -0.03611724078655243, -0.03254589065909386, 0.05217279866337776, 0.02451810985803604, 1.0364382433181163e-05, 0.020558567717671394, -0.01555867400020361, 0.04294939339160919, -0.04332205653190613, -0.031132875010371208, 0.030108053237199783, 0.026987001299858093, -0.033974431455135345, -0.04388105124235153, -0.01572171412408352, -0.04512326046824455, -0.0021311657037585974, -0.03496819734573364, -0.04077552631497383, -0.016319528222084045, -0.015496563166379929, 0.06515388935804367, -0.035682469606399536, -0.046800244599580765, -0.0010723761515691876, -0.03282538428902626, 0.004188575316220522, -0.046179138123989105, 0.009743580594658852, 0.053228676319122314, -0.023105096071958542, 0.0721723735332489, 0.0284621249884367, -0.0017604437889531255, -0.0363035723567009, -0.03124156966805458, 0.013004380278289318, 0.03496819734573364, -0.013214003294706345, 0.0028687275480479, 0.007915203459560871, -0.0011373980669304729, -0.07813497632741928, -0.0322042815387249, 0.017437515780329704, 0.008322803303599358, -0.04822878539562225, -0.02360198087990284, -0.009200113825500011, -0.042110901325941086, -0.02735966444015503, 0.0024281314108520746, 0.0006672023446299136, -0.05490566045045853, 0.015139427967369556, -0.023539870977401733, 0.0032239218708127737, -0.06745197623968124, 0.0073290360160171986, -0.027250971645116806, 0.021459169685840607, 0.011785462498664856, -0.04108607769012451, -0.016785355284810066, 0.015069553628563881, 0.01171558815985918, -0.01846233941614628, 0.0006036362028680742, -0 ...
# tail_embedding shape: [-0.005167373456060886, 0.017785901203751564, 0.0756041631102562, -0.007760915905237198, -0.02437535859644413, 0.02091730199754238, 0.0062909601256251335, 0.008031252771615982, 0.009016855619847775, 0.054157450795173645, -0.008346645161509514, -0.020714549347758293, -0.0188559852540493, 0.02214508131146431, 0.04703858494758606, -0.03482837975025177, 0.023789629340171814, 0.022922299802303314, 0.02694355696439743, 0.07420742511749268, 0.05573441460728645, -0.03618006035685539, 0.0024020541459321976, 0.0030103118624538183, -0.05438273400068283, -0.03791472315788269, -0.01954309083521366, 0.023248955607414246, -0.023586876690387726, 0.04388465732336044, 0.01921643316745758, -0.013956132344901562, 0.006459920667111874, -0.013640739023685455, 0.0027033670339733362, 0.014733349904417992, 0.006482448894530535, 0.00467457203194499, 0.02849799394607544, 0.04879577457904816, -0.015645736828446388, -0.01700868457555771, 0.00399309815838933, -0.021232694387435913, -0.05789710953831673, -0.027686983346939087, 0.02283218689262867, -0.014564389362931252, -0.015657000243663788, -0.00891547929495573, 0.013606946915388107, -0.001139074913226068, -0.0020416053012013435, 0.015071270987391472, 0.012435488402843475, -0.027078725397586823, -0.02180716022849083, 0.04440280422568321, -0.0036861535627394915, -0.020455477759242058, -0.043839599937200546, -0.006989330053329468, 0.028926026076078415, -0.02383468486368656, -0.014969894662499428, -0.005339149851351976, 0.013280290178954601, 0.02146923914551735, 0.04577701538801193, -0.05298599228262901, -0.022426681593060493, -0.035774555057287216, -0.06123126298189163, -0.034895963966846466, 0.05902351066470146, -0.0446506105363369, 0.01731281355023384, -0.008256533183157444, 0.03189973160624504, -0.00381850590929389, -0.0008370581781491637, 0.002364038024097681, -0.00259495060890913, 0.019464243203401566, -0.020489269867539406, 0.02694355696439743, -0.013854756020009518, 0.01123023685067892, -0.014361636713147163, -0.004111370537430048, 0.0137308519333601, -0.029399115592241287, -0.01735786907374859, 0.03246293216943741, 0.03807241842150688, -0.03692348673939705, 0.017549356445670128, -0.019948596134781837, -0.014068772085011005, 0.0064036003313958645, 0.03656303882598877, -0.022550586611032486, -0.015319079160690308, -0.02865568920969963, 0.02300114743411541, -0.04255550354719162, -0.014800934121012688, 0.017031211405992508, -0.034422874450683594, -0.013088801875710487, 0.030953552573919296, -0.0029596237000077963, 0.025344066321849823, -0.033048659563064575, 0.05388711392879486, 0.042825840413570404, -0.017098795622587204, -0.03890595585107803, 0.015893545001745224, 0.023722045123577118, 0.004604171961545944, -0.0033454166259616613, 0.004578827880322933, -0.05857295170426369, -0.014192677102982998, 0.05388711392879486, -0.03890595585107803, -0.030840910971164703, -0.02336159721016884, 0.004117002710700035, 0.039401572197675705, -0.024240190163254738, -0.021863481029868126, 0.012672033160924911, -0.03451298549771309, 0.0788482055068016, -0.0005339853814803064, -0.02574956975877285, -0.03935651853680611, -0.04003236070275307, 0.01733534038066864, 0.009478680789470673, -0.010678299702703953, -0.029083723202347755, -0.0014347557444125414, 0.007422995287925005, -0.07096338272094727, 0.032845910638570786, 0.0063247522339224815, 0.0377570241689682, -0.015724584460258484, 0.04451544210314751, 0.010678299702703953, -0.023992381989955902, -0.0001796084688976407, 0.004773132503032684, 0.02073707804083824, 0.010734619572758675, -0.0008659222512505949, 0.022054968401789665, -0.017729582265019417, -0.05050790682435036, 0.014102564193308353, 0.04021258279681206, -0.019993651658296585, -0.006375440396368504, -0.08939133584499359, 0.0014671398093923926, -0.02624518796801567, -0.016051242128014565, -0.07618989050388336, -0.005234957672655582, -0.02333906851708889, 0.015510568395256996, -0.025006145238876343, -0.018641967326402664, -0.00017828846466727555, -0.009073175489902496, -0.02215634472668171, ...

# %%
embeddings_all = generate_embeddings_batch(df, 0, -1)
print(embeddings_all)

# %%
from neo4j import GraphDatabase
import pandas as pd

# %%
df_xlsx = pd.read_excel('output_embeddings.xlsx')

def import_to_neo4j(df_xlsx):
    with driver.session() as session:
        for _, row in df_xlsx.iterrows():
            head_embedding = row['Head embedding']
            relation_embedding = row['Relation embedding']
            tail_embedding = row['Tail embedding']

            # store text
            head_text = row['Head text'].replace("'", "''")
            relation_text = row['Relation text'].replace("'", "''")
            # if tail text is not NaN, replace single quote with double single quote
            if pd.notnull(row['Tail text']):
                tail_text = row['Tail text'].replace("'", "''")

            # store Event ID, Paragraph ID, Article ID
            event_id = row['Event ID']
            paragraph_id = row['Paragraph ID']
            article_id = row['Article ID']

            # Extract and process head and tail labels as lists, replace spaces with underscores, replace "-" with "_"
            
            head_labels = [label.strip().replace(" ", "_").replace("-", "_").replace("'", "''") for label in row['Head labels'].split(",")]
            tail_labels = [label.strip().replace(" ", "_").replace("-", "_").replace("'", "''") for label in row['Tail labels'].split(",")]
            relation_label = row['Relation label'].replace(" ", "_").replace("-", "_").replace("'", "''")

            # Create Cypher labels for head and tail nodes
            head_labels_cypher = ':'.join(head_labels)
            tail_labels_cypher = ':'.join(tail_labels)

            # Create Cypher query to create head and tail nodes, with properties and relation
            query = f"""
            MERGE (head:{head_labels_cypher} {{
                text: $head_text, 
                embedding: $head_embedding, 
                event_id: $event_id, 
                paragraph_id: $paragraph_id, 
                article_id: $article_id
            }})
            MERGE (tail:{tail_labels_cypher} {{
                text: $tail_text, 
                embedding: $tail_embedding, 
                event_id: $event_id, 
                paragraph_id: $paragraph_id, 
                article_id: $article_id
            }})
            MERGE (head)-[:{relation_label} {{
                text: $relation_text,
                embedding: $relation_embedding,
                event_id: $event_id,
                paragraph_id: $paragraph_id,
                article_id: $article_id
            }}]->(tail)
            """

            parameters = {
                'head_text': head_text,
                'head_embedding': head_embedding,
                'tail_text': tail_text,
                'tail_embedding': tail_embedding,
                'event_id': event_id,
                'paragraph_id': paragraph_id,
                'article_id': article_id,
                'relation_text': relation_text,
                'relation_embedding': relation_embedding
            }
            session.run(query, parameters)

# %%
# document_relation_query = f"""
# MATCH (a), (b) 
# WHERE a.article_id = b.article_id 
# AND a.event_id <> b.event_id 
# CREATE (a)-[:IS_IN_THE_SAME_ARTICLE]->(b)
# """

# paragraph_relation_query = f"""
# MATCH (a), (b)
# WHERE a.paragraph_id = b.paragraph_id
# AND a.event_id <> b.event_id
# CREATE (a)-[:IS_IN_THE_SAME_PARAGRAPH]->(b)
# """

# %%
document_contain_paragraph_query = f"""
MATCH (n) 
WITH DISTINCT n.article_id AS article_id, n.paragraph_id AS paragraph_id 
WHERE article_id IS NOT NULL AND paragraph_id IS NOT NULL
MERGE (a:Article {{article_id: article_id}})
MERGE (p:Paragraph {{paragraph_id: paragraph_id}})
MERGE (a)-[:CONTAINS]->(p)
"""
paragraph_contain_event_query = f"""
MATCH (n) 
WITH n, n.paragraph_id AS paragraph_id, n.article_id AS article_id 
WHERE paragraph_id IS NOT NULL AND article_id IS NOT NULL
MERGE (e:Event {{event_id: n.event_id, paragraph_id: paragraph_id}})
MERGE (p:Paragraph {{paragraph_id: paragraph_id}})
MERGE (p)-[:CONTAINS]->(e)
"""
head_relation_tail_of_event_query = f"""
MATCH p=()-[r]->()
MATCH (e:Event)
WHERE r.event_id = e.event_id
RETURN p
"""
event_head_relation_tail_query = f"""
MATCH (e:Event), (h)-[r]->(t)
WHERE h.event_id = e.event_id AND t.event_id = e.event_id
MERGE (e)-[:HAS_HEAD]->(h)
MERGE (e)-[:HAS_TAIL]->(t)
RETURN e, h, r, t
"""

# %%
import_to_neo4j(df_xlsx)

# %%
with driver.session() as session:
    session.run(document_relation_query)

# %%
with driver.session() as session:
    session.run(paragraph_relation_query)

# %%
# end the session
driver.close()

# %%
from neo4j import GraphDatabase

class Neo4jRetriever:
    def __init__(self, uri="bolt://localhost:54621", username="neo4j", password="saiyan94"):
        self.driver = GraphDatabase.driver(uri, auth=(username, password))

    def embed_question(self, question):
        response = client.embeddings.create(input=question, model="text-embedding-3-small")
        return response.data[0].embedding

    def get_relevant_documents(self, similarity_query, query_embedding, top_k=5):
        with self.driver.session() as session:
            results = session.run(similarity_query, query_embedding=query_embedding, top_k=top_k)
            
            # return the full text concatenation of head, relation and tail
            return [(record['n_text'], record['r_text'], record['m_text']) for record in results]
    def close(self):
        self.driver.close()

# %%
# step_by_step_similarity_query will return the similarity of the head, based on the input_text
similarity_query = f"""
MATCH (n)-[r]->(m)
WHERE n.embedding IS NOT NULL AND m.embedding IS NOT NULL AND r.embedding IS NOT NULL
WITH n, m, r, 
    gds.similarity.cosine(n.embedding, $query_embedding) AS head_similarity,
    gds.similarity.cosine(m.embedding, $query_embedding) AS tail_similarity,
    gds.similarity.cosine(r.embedding, $query_embedding) AS relation_similarity
WHERE head_similarity > 0.5 OR tail_similarity > 0.5 OR relation_similarity > 0.5
RETURN n, m, r, n.text AS n_text, m.text AS m_text, r.text AS r_text, head_similarity, tail_similarity, relation_similarity
ORDER BY head_similarity DESC, tail_similarity DESC, relation_similarity DESC
LIMIT $top_k
"""

# %%
similarity_query_2 = f"""
MATCH (n)-[r]->(m)
WHERE n.embedding IS NOT NULL
WITH n, m, r, gds.similarity.cosine(n.embedding, $query_embedding) AS head_similarity
WHERE head_similarity > 0.5
RETURN n, m, r, n.text AS n_text, m.text AS m_text, r.text AS r_text, head_similarity
ORDER BY head_similarity DESC
LIMIT $top_k
"""

# %%
similarity_query_3 = f"""
MATCH (m:Tail)
WHERE m.embedding IS NOT NULL
WITH m, gds.similarity.cosine(m.embedding, $query_embedding) AS m_similarity
WHERE m_similarity > 0.5
MATCH (n)-[r]->(m)
WHERE n.text IS NOT NULL AND r.text IS NOT NULL
RETURN n.text AS n_text, r.text AS r_text, m.text AS m_text, m_similarity
ORDER BY m_similarity DESC
LIMIT $top_k
"""

# %%
similarity_query_4 = f"""
MATCH (n)-[r]->(m)
WHERE r.embedding IS NOT NULL  // Ensure the relationship has an embedding
WITH n, m, r, gds.similarity.cosine(r.embedding, $query_embedding) AS r_similarity  // Include n and m in the WITH clause
WHERE r_similarity > 0.3  // Filter based on the similarity threshold
RETURN n.text AS n_text, m.text AS m_text, type(r) AS relation_type, r.text AS r_text, r_similarity  // Return the type and text of the relationship along with similarity score
ORDER BY r_similarity DESC  // Order by similarity
LIMIT $top_k  // Limit results to top K
"""

# %%
neo4j_retriever = Neo4jRetriever()
question = "Tell me step by step of colonoscopy for cancer screening?"
query_embedding = neo4j_retriever.embed_question(question)
relevant_docs = neo4j_retriever.get_relevant_documents(query_embedding)
for doc in relevant_docs:
    print(doc)

# Close the retriever connection
neo4j_retriever.close()
# Out:
# ('During colonoscopy', 'any polyps seen are removed and', 'evaluated for possible cancer')
# ('Colonoscopy', 'may be valuable to rule out', 'inflammatory bowel disease')
# ('normal colonoscopy', 'negates', 'advanced colon cancer')
# ('virtual colonoscopy', 'include', 'inability to biopsy the polyps at the time of examination')
# ('virtual colonoscopy', 'include', 'radiation exposure')

# %%
neo4j_retriever = Neo4jRetriever()
question = "Tell me step by step of colonoscopy for cancer screening?"
query_embedding = neo4j_retriever.embed_question(question)
relevant_docs = neo4j_retriever.get_relevant_documents(similarity_query_2, query_embedding, top_k=10)
for doc in relevant_docs:
    print(doc)

# Close the retriever connection
neo4j_retriever.close()
# Out:
# ('During colonoscopy', 'any polyps seen are removed and', 'evaluated for possible cancer')
# ('Colonoscopy', 'may be valuable to rule out', 'inflammatory bowel disease')
# ('normal colonoscopy', 'negates', 'advanced colon cancer')
# ('virtual colonoscopy', 'include', 'inability to biopsy the polyps at the time of examination')
# ('virtual colonoscopy', 'include', 'radiation exposure')
# ('colonoscopy', 'is preferred because', 'polyps may be removed during that procedure')
# ('colonoscopy', 'alternative CRC screening tests are available for patients who decline', 'colonoscopy')
# ('colonoscopy', 'requires stopping', 'oral iron-containing medications')
# ('colonoscopy', 'requires', 'cleansing of the colon')
# ('colonoscopy', 'requires', 'rapid colonic preparation')

# %%
from neo4j import GraphDatabase

class Neo4jRetriever:
    def __init__(self, uri="bolt://localhost:54621", username="neo4j", password="saiyan94"):
        self.driver = GraphDatabase.driver(uri, auth=(username, password))

    def embed_question(self, question):
        response = client.embeddings.create(input=question, model="text-embedding-3-small")
        return response.data[0].embedding

    def get_relevant_documents(self, similarity_query, query_embedding, top_k=5):
        with self.driver.session() as session:
            results = session.run(similarity_query, query_embedding=query_embedding, top_k=top_k)
            return [(record['n_text'], record['r_text'], record['m_text']) for record in results]
            
    def close(self):
        self.driver.close()

# %%
neo4j_retriever = Neo4jRetriever()
question = "Tell me step by step of colonoscopy for cancer screening?"
query_embedding = neo4j_retriever.embed_question(question)
relevant_docs = neo4j_retriever.get_relevant_documents(similarity_query_3, query_embedding, top_k=10)
for doc in relevant_docs:
    print(doc)

# Close the retriever connection
neo4j_retriever.close()
# Out:
# ('lower GI bleeding', 'for', 'Colonoscopy')
# ('age ≥ 45', 'is a threshold for', 'screening colonoscopy')
# ('high risk of colon cancer', 'is a reason for', 'screening colonoscopy')
# ('positive fecal occult blood tests', 'require', 'colonoscopy')
# ('positive fecal DNA tests', 'require', 'colonoscopy')
# ('lower GI bleeding', 'typically includes', 'colonoscopy')
# ('Ulcerative colitis', 'diagnosis is by', 'colonoscopy')
# ('lesions seen during sigmoidoscopy', 'require', 'colonoscopy')
# ('Colorectal cancer', 'Diagnosis is by', 'colonoscopy')
# ('lesions seen during an imaging study', 'require', 'colonoscopy')

# %%
neo4j_retriever = Neo4jRetriever()
question = "Tell me step by step of colonoscopy for cancer screening?"
query_embedding = neo4j_retriever.embed_question(question)
relevant_docs = neo4j_retriever.get_relevant_documents(similarity_query_4, query_embedding, top_k=10)
for doc in relevant_docs:
    print(doc)

# Close the retriever connection
neo4j_retriever.close()
# Out:
# ('Virtual (CT) colonoscopy', 'visualizes the entire colon', 'in contrast, conventional colonoscopy does not allow the right colon to be evaluated completely in about 1 in 10 patients')
# ('average-risk patients', 'should begin screening for colorectal cancer at age 45 years', 'screening for colorectal cancer')
# ('average-risk patients', 'should continue screening for colorectal cancer until age 75 years', 'screening for colorectal cancer')
# ('adults aged 76 to 85', 'the decision whether to screen for CRC should be individualized', 'screening for colorectal cancer')
# ('colonoscopy', 'alternative CRC screening tests are available for patients who decline', 'colonoscopy')
# ('high-risk conditions (eg, ulcerative colitis)', 'screening is discussed under', 'the specific condition')
# ('economic issues preclude screening with colonoscopy', 'alternative CRC screening tests are available for patients for whom', 'colonoscopy')
# ('During colonoscopy', 'any polyps seen are removed and', 'evaluated for possible cancer')
# ('Colorectal Cancer', 'Screening Guidelines', 'American College of Gastroenterology (ACG) and the U.S. Preventive Services Task Force (USPSTF)')
# ('cancer is diagnosed', 'patients should undergo', 'complete imaging staging with CT of the chest, abdomen, and pelvis and routine laboratory tests')

# %%
neo4j_retriever = Neo4jRetriever()
questions = """
A 52-year-old man comes to to the emergency department with fatigue and shortness of breath that has become progressively worse over the past week.
He had an upper respiratory tract infection 2 weeks ago, for which he was given an antibiotic. 
He has hypertension, type 2 diabetes mellitus, and colonic polyps diagnosed on screening colonoscopy 2 years ago. 
His mother has systemic lupus erythematosus and his brother has a bicuspid aortic valve. He does not smoke cigarettes or drink alcohol. 
Current medications include lisinopril and metformin. 
His temperature is 37.3Â°C (99.1Â°F), pulse is 91/min, respirations are 18/min, and blood pressure is 145/84 mm Hg. 
His conjunctivae are pale. Cardiac examination shows a late systolic crescendo-decrescendo murmur at the right upper sternal border. 
Laboratory studies show:
Leukocyte Count 9,500/mm3
Hematocrit 24%
Platelet Count 178,000/mm3
LDH 215 U/L
Haptoglobin 22 mg/dL (N=41â€“165 mg/dL)
Serum
Na+ 140 mEq/L
K+ 4.6 mEq/L
CL- 100 mEq/L
HCO3- 25 mEq/L
Urea nitrogen 21 mg/dL
Creatinine 1.2 mg/dL
Total bilirubin 1.9 mg/dL
A peripheral blood smear is shown. 
Which of the following is the most likely cause of this patient's anemia?
"""
query_embedding = neo4j_retriever.embed_question(question)
def answer_chain_of_questions(questions):
    # feed each line in questions to the retriever, get the relevant documents, append to a list
    query_results = []
    for question in questions.split("\n"):
        query_embedding = neo4j_retriever.embed_question(question)
        relevant_docs = neo4j_retriever.get_relevant_documents(similarity_query_4, query_embedding, top_k=10)
        query_results.append(relevant_docs)
    return query_results

# %%
answer_chain_of_questions(questions)
# Out:
# [[('colon cancer', 'requires', 'diagnostic test'),
#   ('IV neostigmine', 'requires', 'cardiac monitoring'),
#   ('severe GI bleeding',
#    'requires',
#    'admission to an intensive care unit or other monitored setting'),
#   ('Massive GI bleeding', 'requires', 'quick diagnosis and treatment'),
#   ('colonoscopy', 'requires', 'cleansing of the colon'),
#   ('endoscopy',
#    'requires',
#    'no solids for 8 hours and no liquids for 2 to 4 hours before the procedure'),
#   ('Asymptomatic diverticulosis', 'requires', 'no treatment'),
#   ('colonoscopy', 'requires', 'rapid colonic preparation'),
#   ('severe GI bleeding',
#    'requires',
#    'consultation by both a gastroenterologist and a surgeon'),
#   ('distal lesion found by flexible sigmoidoscopy',
#    'requires',
#    'complete colonoscopy to the cecum')],
#  [('Mucosal prolapse in adults',
#    'may progressively worsen',
#    'progressively worsen'),
#   ('numerous colon polyps',
#    'affected patients usually present with',
#    'colorectal cancer'),
#   ('MUTYH polyposis',
#    'Affected patients are',
#    'homozygous or compound heterozygous'),
#   ('diverticulosis', 'become symptomatic with', 'pain or bleeding'),
#   ('Ulcerative colitis', 'elevates long-term risk of', 'colon cancer'),
#   ('Peutz-Jeghers syndrome', 'are at increased risk of', 'lung cancer'),
#   ('Polyps', 'are present in 50% of patients by', 'age 15 years'),
#   ('Colorectal cancer', 'Symptoms include', 'change in bowel habits'),
#   ('Hemorrhoids', 'Symptoms include', 'irritation and bleeding'),
#   ('Colorectal cancer', 'Symptoms include', 'blood in the stool')],
#  [('hemorrhoids',
#    'Symptomatic treatment of',
#    'stool softeners, warm sitz baths, anesthetic ointments containing lidocaine, or witch hazel compresses'),
#   ('immunocompromise',
#    'are at particular risk of infections with',
#    'herpes simplex and cytomegalovirus'),
#   ('Juvenile polyps',
#    'require treatment for',
#    'uncontrollable bleeding or intussusception'),
#   ('Crohn disease',
#    'is treated with',
#    '5-aminosalicylic acid, corticosteroids, immunomodulators, anticytokines, antibiotics, and often surgery'),
#   ('ischemic colitis',
#    'is treated with',
#    'supportive treatment with IV fluids, bowel rest, and antibiotics'),
#   ('Antibiotic-associated proctitis due to C. difficile',
#    'is treated with',
#    'vancomycin or fidaxomicin'),
#   ('Diverticular bleeding',
#    'Treatment is often given during',
#    'the diagnostic procedure'),
#   ('MUTYH polyposis',
#    'Affected patients are',
#    'homozygous or compound heterozygous'),
#   ('nonspecific proctitis',
#    'may be treated empirically with',
#    'ceftriaxone and doxycycline')],
#  [('average-risk patients',
#    'should begin screening for colorectal cancer at age 45 years',
#    'screening for colorectal cancer'),
#   ('average-risk patients',
#    'should continue screening for colorectal cancer until age 75 years',
#    'screening for colorectal cancer'),
#   ('intestinal polyp', 'diagnosed by', 'endoscopy'),
#   ('Ileus', 'diagnosed by', 'x-ray findings and clinical impression'),
#   ('economic issues preclude screening with colonoscopy',
#    'alternative CRC screening tests are available for patients for whom',
#    'colonoscopy'),
#   ('colonoscopy',
#    'alternative CRC screening tests are available for patients who decline',
#    'colonoscopy'),
#   ('ischemic colitis', 'is diagnosed by', 'CT or colonoscopy'),
#   ('Crohn disease', 'is diagnosed by', 'colonoscopy and imaging studies'),
#   ('Fundic gland polyps', 'should be biopsied for', 'dysplasia'),
#   ('children of parents with familial adenomatous polyposis',
#    'may be screened for',
#    'hepatoblastoma from birth to age 5 years with annual serum alpha-fetoprotein levels and possibly liver ultrasound')],
#  [],
#  [('Ulcerative colitis', 'treatment is with', 'biologics'),
#   ('Ulcerative colitis', 'treatment is with', 'corticosteroids'),
#   ('Ulcerative colitis', 'treatment is with', '5-aminosalicylic acid'),
#   ('Ulcerative colitis', 'treatment is with', 'antibiotics'),
#   ('Ulcerative colitis', 'treatment is with', 'immunomodulators'),
#   ('Octreotide', 'is used in patients with', 'suspected variceal bleeding'),
#   ('nonspecific proctitis',
#    'may be treated empirically with',
#    'ceftriaxone and doxycycline'),
#   ('pain', 'can be treated with', 'nonsteroidal anti-inflammatory drugs'),
#   ('Infective proctitis', 'can be treated with', 'antibiotics'),
#   ('Radiation proctitis that is bleeding',
#    'is usually treated with',
#    'a topical drug')],
#  [],
#  [('Diverticular bleeding',
#    'stigmata of recent hemorrhage are identified in',
#    '8 to 15% of patients during colonoscopy'),
#   ('numerous colon polyps',
#    'affected patients usually present with',
#    'colorectal cancer'),
#   ('Mucosal prolapse in adults',
#    'may progressively worsen',
#    'progressively worsen'),
#   ('ileus persisting > 1 week',
#    'probably has a mechanical obstructive cause',
#    'mechanical obstruction'),
#   ('cordlike tract', 'can often be palpated', 'indicating a tract'),
#   ('an initial attack of ulcerative colitis',
#    'becomes fulminant with',
#    'massive hemorrhage, perforation, or sepsis and toxemia'),
#   ('anorectal abscess',
#    'on inspection, can be seen as',
#    'one or more secondary openings'),
#   ('severe bleeding', 'should be monitored closely', 'platelet count'),
#   ('family history of Crohn disease',
#    'increases the index of suspicion for',
#    'Crohn disease'),
#   ('diverticulosis',
#    'occurs coincidentally in patients with',
#    'irritable bowel syndrome')],
#  [('Giving preparations in a split-dose fashion',
#    'has been shown to improve',
#    'patient compliance, examination quality, and adenoma detection rate'),
#   ('Doppler-guided hemorrhoid artery ligation',
#    'is promising but requires further study to determine its overall utility',
#    'hemorrhoid treatment'),
#   ('Rectal swabs',
#    'should be tested for',
#    'Neisseria gonorrhoeae and Chlamydia species, enteric pathogens, and viral pathogens'),
#   ('CT',
#    'is the most accurate study for detecting and localizing',
#    'urinary calculi'),
#   ('endoscopic treatment (epinephrine injection, application of endoclips or fibrin sealant, heater probe or bipolar coagulation, and band ligation)',
#    'results in lower',
#    'early and late recurring bleeding rates in patients with definitive colonic diverticular bleeding'),
#   ('Colonic diverticulosis',
#    'Diagnosis is by',
#    'colonoscopy, capsule endoscopy, barium enema, CT, or MRI'),
#   ('MUTYH polyposis syndrome', 'Diagnosis is by', 'genetic testing'),
#   ('Colorectal cancer', 'Diagnosis is by', 'colonoscopy'),
#   ('Rectal prolapse', 'Diagnosis is by', 'inspection'),
#   ('Hemorrhoids', 'Diagnosis is by', 'inspection or anoscopy')],
#  [('increased risk of cancer in the brain',
#    'medulloblastoma in < 1%',
#    'cancer in the brain'),
#   ('Polyps', 'are present in 95% of patients by', 'age 35 years'),
#   ('recurrence',
#    'About 5% of patients have',
#    'strictures develop at the site of the ischemia')],
#  [('increased risk of cancer in the duodenum',
#    '5 to 11%',
#    'cancer in the duodenum'),
#   ('increased risk of cancer in the pancreas', '2%', 'cancer in the pancreas'),
#   ('increased risk of cancer in the thyroid', '2%', 'cancer in the thyroid'),
#   ('Diverticular bleeding',
#    'stigmata of recent hemorrhage are identified in',
#    '8 to 15% of patients during colonoscopy'),
#   ('recurrence',
#    'About 5% of patients have',
#    'strictures develop at the site of the ischemia'),
#   ('Bleeding vessel is an arteriole',
#    'the amount of blood loss is usually',
#    'moderate to severe'),
#   ('sporadic cases', 'About 80% of cases are', 'inheritable component'),
#   ('Endoscopy', 'mortality rate', '0.03%'),
#   ('cancer limited to the mucosa', '5-year survival rate approaches', '90%'),
#   ('Endoscopy', 'complication rate', '0.1 to 0.2%')],
#  [('Polyps', 'are present in 95% of patients by', 'age 35 years')],
#  [('severe bleeding', 'should be monitored closely', 'platelet count'),
#   ('Rectal swabs',
#    'should be tested for',
#    'Neisseria gonorrhoeae and Chlamydia species, enteric pathogens, and viral pathogens'),
#   ('mucosal biopsy', 'may be needed to diagnose', 'certain conditions'),
#   ('increased risk of cancer in the liver',
#    'hepatoblastoma in 0.7% of children < 5 years',
#    'cancer in the liver'),
#   ('Female first-degree relatives of patients with Lynch syndrome',
#    'should be tested annually for',
#    'endometrial and ovarian cancer'),
#   ('Hemorrhoids', 'Diagnosis is by', 'inspection or anoscopy'),
#   ('MUTYH polyposis syndrome', 'Diagnosis is by', 'genetic testing'),
#   ('Colorectal cancer', 'Diagnosis is by', 'colonoscopy'),
#   ('Proctitis', 'Diagnosis is by', 'proctoscopy or sigmoidoscopy'),
#   ('Colonic diverticulosis',
#    'Diagnosis is by',
#    'colonoscopy, capsule endoscopy, barium enema, CT, or MRI')],
#  [('increased risk of cancer in the liver',
#    'hepatoblastoma in 0.7% of children < 5 years',
#    'cancer in the liver'),
#   ('increased risk of cancer in the duodenum',
#    '5 to 11%',
#    'cancer in the duodenum'),
#   ('severe bleeding', 'should be monitored closely', 'platelet count')],
#  [],
#  [('ileus',
#    'maintaining an adequate serum potassium level',
#    '> 4 mEq/L [> 4.00 mmol/L]')],
#  [('ileus',
#    'maintaining an adequate serum potassium level',
#    '> 4 mEq/L [> 4.00 mmol/L]'),
#   ('severe bleeding', 'should be monitored closely', 'platelet count')],
#  [('ileus',
#    'maintaining an adequate serum potassium level',
#    '> 4 mEq/L [> 4.00 mmol/L]'),
#   ('severe bleeding', 'should be monitored closely', 'platelet count'),
#   ('Ulcerative colitis', 'treatment is with', 'corticosteroids'),
#   ('Ulcerative colitis', 'treatment is with', 'antibiotics'),
#   ('Ulcerative colitis', 'treatment is with', 'immunomodulators'),
#   ('Ulcerative colitis', 'treatment is with', 'biologics'),
#   ('Ulcerative colitis', 'treatment is with', '5-aminosalicylic acid'),
#   ('Crohn disease',
#    'is treated with',
#    '5-aminosalicylic acid, corticosteroids, immunomodulators, anticytokines, antibiotics, and often surgery'),
#   ('ischemic colitis',
#    'is treated with',
#    'supportive treatment with IV fluids, bowel rest, and antibiotics'),
#   ('Antibiotic-associated proctitis due to C. difficile',
#    'is treated with',
#    'vancomycin or fidaxomicin')],
#  [('ileus',
#    'maintaining an adequate serum potassium level',
#    '> 4 mEq/L [> 4.00 mmol/L]'),
#   ('severe bleeding', 'should be monitored closely', 'platelet count')],
#  [('ileus',
#    'maintaining an adequate serum potassium level',
#    '> 4 mEq/L [> 4.00 mmol/L]'),
#   ('increased risk of cancer in the duodenum',
#    '5 to 11%',
#    'cancer in the duodenum'),
#   ('severe bleeding', 'should be monitored closely', 'platelet count')],
#  [('ileus',
#    'maintaining an adequate serum potassium level',
#    '> 4 mEq/L [> 4.00 mmol/L]'),
#   ('severe bleeding', 'should be monitored closely', 'platelet count'),
#   ('family history of Crohn disease',
#    'increases the index of suspicion for',
#    'Crohn disease'),
#   ('increased risk of cancer in the brain',
#    'medulloblastoma in < 1%',
#    'cancer in the brain')],
#  [('increased risk of cancer in the liver',
#    'hepatoblastoma in 0.7% of children < 5 years',
#    'cancer in the liver')],
#  [('MUTYH polyposis syndrome', 'Diagnosis is by', 'genetic testing'),
#   ('Colonic diverticulosis',
#    'Diagnosis is by',
#    'colonoscopy, capsule endoscopy, barium enema, CT, or MRI'),
#   ('Familial adenomatous polyposis',
#    'Diagnosis is by',
#    'endoscopy and genetic testing'),
#   ('Rectal prolapse', 'Diagnosis is by', 'inspection'),
#   ('Proctitis', 'Diagnosis is by', 'proctoscopy or sigmoidoscopy'),
#   ('Hemorrhoids', 'Diagnosis is by', 'inspection or anoscopy'),
#   ('Colorectal cancer', 'Diagnosis is by', 'colonoscopy'),
#   ('Diverticular bleeding',
#    'stigmata of recent hemorrhage are identified in',
#    '8 to 15% of patients during colonoscopy'),
#   ('Ulcerative colitis', 'diagnosis is by', 'colonoscopy'),
#   ('Monoallelic carriers', 'are screened for', 'colorectal cancer')],
#  [('abdominal surgery', 'is the most common cause of', 'ileus'),
#   ('hemorrhoids', 'are the most common causes of', 'minor bleeding'),
#   ('peptic ulcer', 'are the most common causes of', 'major bleeding'),
#   ('angiodysplasia', 'are the most common causes of', 'major bleeding'),
#   ('colorectal cancer', 'are the most common causes of', 'minor bleeding'),
#   ('diverticular disease', 'are the most common causes of', 'major bleeding'),
#   ('Procidentia', 'The primary cause of', 'is unclear'),
#   ('active upper GI bleeding',
#    'is a major cause of',
#    'aspiration of blood with subsequent respiratory compromise'),
#   ('recurrence',
#    'About 5% of patients have',
#    'strictures develop at the site of the ischemia'),
#   ('numerous colon polyps',
#    'affected patients usually present with',
#    'colorectal cancer')],
#  [('colon cancer', 'requires', 'diagnostic test'),
#   ('IV neostigmine', 'requires', 'cardiac monitoring'),
#   ('severe GI bleeding',
#    'requires',
#    'admission to an intensive care unit or other monitored setting'),
#   ('Massive GI bleeding', 'requires', 'quick diagnosis and treatment'),
#   ('colonoscopy', 'requires', 'cleansing of the colon'),
#   ('endoscopy',
#    'requires',
#    'no solids for 8 hours and no liquids for 2 to 4 hours before the procedure'),
#   ('Asymptomatic diverticulosis', 'requires', 'no treatment'),
#   ('colonoscopy', 'requires', 'rapid colonic preparation'),
#   ('severe GI bleeding',
#    'requires',
#    'consultation by both a gastroenterologist and a surgeon'),
#   ('distal lesion found by flexible sigmoidoscopy',
#    'requires',
#    'complete colonoscopy to the cecum')]]

# %%
# write function to use Langchain Chat API to answer the questions, based on the return of the answer_chain_of_questions
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-4o",
    api_key="sk-proj-pjGUyMNiHPDiH7CLYv4rT3BlbkFJQpZiY1U0sYAqOATygpnJ",
    temperature=0.0,
    max_tokens=None
    )
def answer_questions(query_results):
    # feed each relevant document to the Langchain Chat API, get the answer
    answers = []
    message_template = [
        (
            "system",
            """You are a medical doctor, experienced in conducting colonoscopy and diagnosing colonic diseases. Based on the patient's information,
            what are the possible causes of the patient's condition?
            """
        ),
        (
            "user",
            "{patient_information}"
        )
    ]
    # use llm.invoke() to get the answer
    for query_result in query_results:
        for doc in query_result:
            # get all the text from the doc, concatenate them
            patient_information = doc[0] + " " + doc[1] + " " + doc[2]
            
            # Create a new message with the patient information replaced
            message = [
                message_template[0],  # system message stays the same
                (
                    message_template[1][0],  # 'doctor' part of the tuple
                    message_template[1][1].replace("{patient_information}", patient_information)  # replace patient info in the string
                )
            ]
            answer = llm.invoke(message)
            answers.append(answer)
    return answers

# %%
questions_chain = answer_chain_of_questions(questions)
# Out:
# None

# %%
answers = answer_questions(questions_chain)
print(answers)
# Out:
# [AIMessage(content="To diagnose colon cancer, several diagnostic tests and procedures may be utilized. These include:\n\n1. **Colonoscopy**: This is the most common and effective test for diagnosing colon cancer. During a colonoscopy, a long, flexible tube with a camera (colonoscope) is inserted into the rectum to examine the entire colon. If any suspicious areas are found, biopsies can be taken for further analysis.\n\n2. **Biopsy**: If a suspicious lesion is found during a colonoscopy, a biopsy is performed to remove a small sample of tissue for examination under a microscope to check for cancer cells.\n\n3. **CT Colonography (Virtual Colonoscopy)**: This is a non-invasive imaging test that uses CT scans to produce detailed images of the colon and rectum. It is less invasive than a traditional colonoscopy but may not detect small polyps as effectively.\n\n4. **Fecal Occult Blood Test (FOBT) or Fecal Immunochemical Test (FIT)**: These tests check for hidden blood in the stool, which can be an early sign of cancer. They are less invasive but not as definitive as a colonoscopy.\n\n5. **Stool DNA Test**: This test looks for certain DNA markers in stool samples that are associated with colon cancer or precancerous polyps.\n\n6. **Flexible Sigmoidoscopy**: Similar to a colonoscopy, but only examines the rectum and the lower part of the colon. It is less comprehensive than a full colonoscopy.\n\n7. **Barium Enema**: An X-ray exam of the colon and rectum where barium sulfate is used to provide contrast on the X-ray images. It is less commonly used today due to the availability of more advanced imaging techniques.\n\n8. **CT Scan or MRI**: These imaging tests can help determine the extent of cancer spread if a diagnosis is confirmed.\n\n9. **Carcinoembryonic Antigen (CEA) Test**: A blood test that measures the level of CEA, a protein that may be higher in some people with colon cancer.\n\nEach of these tests has its own indications, benefits, and limitations. The choice of test depends on the patient's symptoms, risk factors, and the clinical judgment of the healthcare provider. If colon cancer is suspected, a colonoscopy with biopsy is typically the most definitive diagnostic approach.", response_metadata={'token_usage': {'completion_tokens': 478, 'prompt_tokens': 51, 'total_tokens': 529, 'prompt_tokens_details': {'cached_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_a7d06e42a7', 'finish_reason': 'stop', 'logprobs': None}), AIMessage(content="Neostigmine is a medication used to treat certain conditions, such as myasthenia gravis, and to reverse the effects of muscle relaxants after surgery. It is also used off-label for the treatment of acute colonic pseudo-obstruction (Ogilvie's syndrome). When administered intravenously, neostigmine can have significant cardiovascular effects, which is why cardiac monitoring is recommended. \n\nThe possible causes for requiring cardiac monitoring during IV neostigmine administration include:\n\n1. **Bradycardia**: Neostigmine can cause a decrease in heart rate, which can be significant and potentially dangerous, especially in patients with pre-existing cardiac conditions.\n\n2. **Arrhythmias**: The drug can induce various types of arrhythmias, including atrioventricular block or other conduction abnormalities.\n\n3. **Hypotension**: Neostigmine can lead to a drop in blood pressure, which needs to be monitored closely.\n\n4. **Increased Parasympathetic Activity**: As an acetylcholinesterase inhibitor, neostigmine increases acetylcholine levels, enhancing parasympathetic activity, which can affect heart rate and rhythm.\n\n5. **Potential for Cardiac Arrest**: In rare cases, severe bradycardia or arrhythmias can lead to cardiac arrest, necessitating immediate intervention.\n\nDue to these potential cardiovascular effects, continuous cardiac monitoring is essential to promptly identify and manage any adverse events during and afte ...

# %%
print(len(answers))
# Out:
# 149

# %%
# print all answers in the list, connect all "content"
for answer in answers:
    print(answer.content)
# Out:
# To diagnose colon cancer, several diagnostic tests and procedures may be utilized. These include:
#
# 1. **Colonoscopy**: This is the most common and effective test for diagnosing colon cancer. During a colonoscopy, a long, flexible tube with a camera (colonoscope) is inserted into the rectum to examine the entire colon. If any suspicious areas are found, biopsies can be taken for further analysis.
#
# 2. **Biopsy**: If a suspicious lesion is found during a colonoscopy, a biopsy is performed to remove a small sample of tissue for examination under a microscope to check for cancer cells.
#
# 3. **CT Colonography (Virtual Colonoscopy)**: This is a non-invasive imaging test that uses CT scans to produce detailed images of the colon and rectum. It is less invasive than a traditional colonoscopy but may not detect small polyps as effectively.
#
# 4. **Fecal Occult Blood Test (FOBT) or Fecal Immunochemical Test (FIT)**: These tests check for hidden blood in the stool, which can be an early sign of cancer. They are less invasive but not as definitive as a colonoscopy.
#
# 5. **Stool DNA Test**: This test looks for certain DNA markers in stool samples that are associated with colon cancer or precancerous polyps.
#
# 6. **Flexible Sigmoidoscopy**: Similar to a colonoscopy, but only examines the rectum and the lower part of the colon. It is less comprehensive than a full colonoscopy.
#
# 7. **Barium Enema**: An X-ray exam of the colon and rectum where barium sulfate is used to provide contrast on the X-ray images. It is less commonly used today due to the availability of more advanced imaging techniques.
#
# 8. **CT Scan or MRI**: These imaging tests can help determine the extent of cancer spread if a diagnosis is confirmed.
#
# 9. **Carcinoembryonic Antigen (CEA) Test**: A blood test that measures the level of CEA, a protein that may be higher in some people with colon cancer.
#
# Each of these tests has its own indications, benefits, and limitations. The choice of test depends on the patient's symptoms, risk factors, and the clinical judgment of the healthcare provider. If colon cancer is suspected, a colonoscopy with biopsy is typically the most definitive diagnostic approach.
# Neostigmine is a medication used to treat certain conditions, such as myasthenia gravis, and to reverse the effects of muscle relaxants after surgery. It is also used off-label for the treatment of acute colonic pseudo-obstruction (Ogilvie's syndrome). When administered intravenously, neostigmine can have significant cardiovascular effects, which is why cardiac monitoring is recommended.
#
# The possible causes for requiring cardiac monitoring during IV neostigmine administration include:
#
# 1. **Bradycardia**: Neostigmine can cause a decrease in heart rate, which can be significant and potentially dangerous, especially in patients with pre-existing cardiac conditions.
#
# 2. **Arrhythmias**: The drug can induce various types of arrhythmias, including atrioventricular block or other conduction abnormalities.
#
# 3. **Hypotension**: Neostigmine can lead to a drop in blood pressure, which needs to be monitored closely.
#
# 4. **Increased Parasympathetic Activity**: As an acetylcholinesterase inhibitor, neostigmine increases acetylcholine levels, enhancing parasympathetic activity, which can affect heart rate and rhythm.
#
# 5. **Potential for Cardiac Arrest**: In rare cases, severe bradycardia or arrhythmias can lead to cardiac arrest, necessitating immediate intervention.
#
# Due to these potential cardiovascular effects, continuous cardiac monitoring is essential to promptly identify and manage any adverse events during and after the administration of IV neostigmine.
# Severe gastrointestinal (GI) bleeding can be life-threatening and requires immediate medical attention, often necessitating admission to an intensive care unit (ICU) or a closely monitored setting. The possible causes of severe GI bleeding can vary depending on whether the bleeding is from the upper or lower GI tract. Here are some potential causes:
#
# 1. **Upper GI Bleeding:**
#    - **Peptic Ulcer Disease:** Ulcers in the stomach or duodenum can erode into blood vessels, causing significant bleeding.
#    - **Esophageal Varices:** Often related to liver cirrhosis, these are dilated veins in the esophagus that can rupture and bleed profusely.
#    - **Gastritis or Esophagitis:** Inflammation of the stomach lining or esophagus can lead to bleeding.
#    - **Mallory-Weiss Tear:** A tear in the mucous membrane at the junction of the stomach and esophagus, often due to severe vomiting.
#    - **Gastric or Esophageal Cancer:** Tumors can erode into blood vessels and cause bleeding.
#
# 2. **Lower GI Bleeding:**
#    - **Diverticular Disease:** Diverticula in the colon can bleed, sometimes massively.
#    - **Angiodysplasia:** Abnormal blood vessels in the colon can cause bleeding.
#    - **Colorectal Cancer:** Tumors in the colon or rectum can bleed.
#    - **Inflammatory Bowel Disease (IBD):** Conditions like Crohn's disease or ulcerative colitis can cause bleeding.
#    - **Hemorrhoids or Anal Fissures:** Although usually causing minor bleeding, severe cases can lead to significant blood loss.
#    - **Ischemic Colitis:** Reduced blood flow to the colon can cause bleeding.
#
# 3. **Other Causes:**
#    - **Coagulopathy:** Disorders of blood clotting can lead to spontaneous bleeding.
#    - **Use of Anticoagulants or Antiplatelet Drugs:** Medications like warfarin, heparin, or aspirin can increase the risk of bleeding.
#    - **Aortoenteric Fistula:** A rare but serious condition where an abnormal connection forms between the aorta and the GI tract.
#
# In a clinical setting, the specific cause of GI bleeding would be determined through a combination of patient history, physical examination, laboratory tests, imaging studies, and endoscopic procedures like colonoscopy or upper endoscopy. Immediate stabilization of the patient, including fluid resuscitation and blood transfusions, is critical in managing severe GI bleeding.
# Massive gastrointestinal (GI) bleeding can be a life-threatening condition and requires prompt diagnosis and management. The possible causes of massive GI bleeding can vary depending on whether the bleeding is from the upper or lower GI tract. Since you mentioned colonoscopy, I will focus on potential causes related to the lower GI tract:
#
# 1. **Diverticular Disease**: Diverticulosis, particularly in the colon, can lead to significant bleeding if a diverticulum ruptures.
#
# 2. **Angiodysplasia**: These are abnormal blood vessels in the colon that can cause significant bleeding, often seen in older adults.
#
# 3. **Colorectal Cancer**: Tumors in the colon or rectum can erode into blood vessels, leading to bleeding.
#
# 4. **Inflammatory Bowel Disease (IBD)**: Conditions such as ulcerative colitis or Crohn's disease can cause severe inflammation and ulceration, leading to bleeding.
#
# 5. **Ischemic Colitis**: Reduced blood flow to the colon can cause tissue damage and bleeding.
#
# 6. **Hemorrhoids**: Although usually causing minor bleeding, large or ruptured hemorrhoids can occasionally lead to significant blood loss.
#
# 7. **Post-Polypectomy Bleeding**: Recent removal of polyps during a colonoscopy can sometimes result in delayed bleeding.
#
# 8. **Radiation Colitis**: Previous radiation therapy to the pelvis can cause damage to the colon, leading to bleeding.
#
# 9. **Infectious Colitis**: Severe infections, such as those caused by Clostridioides difficile, can lead to significant bleeding.
#
# 10. **Meckel's Diverticulum**: Although more common in the small intestine, it can sometimes be a source of lower GI bleeding.
#
# In the context of massive GI bleeding, it is crucial to stabilize the patient with fluid resuscitation and blood transfusions if necessary, while simultaneously working to identify the source of bleeding through diagnostic procedures such as colonoscopy, angiography, or CT scans.
# Yes, a colonoscopy requires thorough cleansing of the colon to ensure clear visibility of the colon walls and to allow for accurate diagnosis. Inadequate bowel preparation can obscure lesions, polyps, or other abnormalities, potentially leading to missed diagnoses. The cleansing process typically involves:
#
# 1. **Dietary Restrictions**: Patients are usually advised to follow a clear liquid diet for 24 hours before the procedure. This includes consuming clear broths, tea, coffee without milk or cream, clear juices, and gelatin.
#
# 2. **Laxatives**: Patients are often prescribed a bowel preparation solution, which is a strong laxative that helps to clear the colon. This is usually taken the day before the procedure and sometimes on the morning of the procedure as well.
#
# 3. **Hydration**: It is important for patients to stay well-hydrated during the preparation process to prevent dehydration, as the laxatives can cause significant fluid loss.
#
# 4. **Timing**: The timing of the bowel preparation is crucial. Split-dose regimens, where part of the preparation is taken the evening before and the remainder on the morning of the procedure, are often recommended for better cleansing.
#
# If the colon is not adequately cleansed, the procedure may need to be rescheduled, or the results may be less reliable. Proper preparation is essential for the detection of conditions such as polyps, colorectal cancer, inflammatory bowel disease, and other colonic diseases.
# The instructions you've mentioned are typical pre-procedure guidelines for an endoscopy to ensure the stomach is empty, reducing the risk of aspiration and allowing for a clear view during the procedure. However, if a patient is experiencing symptoms that require an endoscopy, such as abdominal pain, bleeding, or changes in bowel habits, there are several possible causes for these symptoms that the endoscopy might help diagnose. Some potential causes include:
#
# 1. **Gastroesophageal Reflux Disease (GERD):** Chronic acid reflux can cause symptoms like heartburn and regurgitation.
#
# 2. **Peptic Ulcers:** Sores in the lining of the stomach or the first part of the small intestine can cause pain and bleeding.
#
# 3. **Gastritis:** Inflammation of the stomach lining can lead to discomfort and nausea.
#
# 4. **Esophagitis:** Inflammation of the esophagus, often due to acid reflux, can cause pain and difficulty swallowing.
#
# 5. **Barrett's Esophagus:** A condition where the esophageal lining changes, often due to chronic GERD, which can increase cancer risk.
#
# 6. **Hiatal Hernia:** Part of the stomach pushes up through the diaphragm, potentially causing reflux symptoms.
#
# 7. **Celiac Disease:** An autoimmune disorder where ingestion of gluten leads to damage in the small intestine.
#
# 8. **Esophageal or Gastric Cancer:** Tumors in the esophagus or stomach can cause various symptoms, including pain, weight loss, and bleeding.
#
# 9. **Esophageal Strictures or Rings:** Narrowing of the esophagus can cause swallowing difficulties.
#
# 10. **Infections:** Such as Helicobacter pylori infection, which can lead to ulcers and gastritis.
#
# 11. **Inflammatory Bowel Disease (IBD):** Conditions like Crohn's disease or ulcerative colitis can affect the gastrointestinal tract.
#
# The endoscopy will help visualize the upper gastrointestinal tract and potentially allow for biopsies to be taken, aiding in the diagnosis of these conditions.
# Asymptomatic diverticulosis is a condition where small pouches, called diverticula, form in the wall of the colon but do not cause any symptoms. It is a common finding, especially in older adults, and often discovered incidentally during a colonoscopy or imaging studies done for other reasons. Since it is asymptomatic, it typically does not require treatment. However, there are some considerations and potential causes for the development of diverticulosis:
#
# 1. **Dietary Factors**: A low-fiber diet is often associated with the development of diverticulosis. A diet high in refined carbohydrates and low in fiber can lead to constipation and increased colonic pressure, contributing to the formation of diverticula.
#
# 2. **Age**: The prevalence of diverticulosis increases with age. It is more common in individuals over the age of 50.
#
# 3. **Genetic Predisposition**: There may be a genetic component, as diverticulosis can run in families.
#
# 4. **Lifestyle Factors**: Obesity, lack of physical activity, and smoking have been associated with an increased risk of developing diverticulosis.
#
# 5. **Colonic Motility**: Altered colonic motility and increased intraluminal pressure can contribute to the formation of diverticula.
#
# 6. **Connective Tissue Changes**: Changes in the connective tissue of the colon wall, often related to aging, can make the colon more susceptible to forming diverticula.
#
# While asymptomatic diverticulosis does not require treatment, patients are often advised to increase their dietary fiber intake to help prevent complications such as diverticulitis or diverticular bleeding. Regular follow-up and monitoring may be recommended to ensure that the condition remains asymptomatic.
# Rapid colonic preparation is often required for a colonoscopy to ensure that the colon is thoroughly cleansed, allowing for clear visualization of the colon walls and any potential abnormalities. Inadequate preparation can lead to missed lesions or the need to repeat the procedure. There are several potential causes or reasons why a patient might require rapid colonic preparation:
#
# 1. **Urgency of the Procedure**: If a colonoscopy is needed urgently due to symptoms such as significant gastrointestinal bleeding, severe abdominal pain, or suspicion of a serious condition like colorectal cancer, rapid preparation may be necessary.
#
# 2. **Inadequate Initial Preparation**: If a patient has undergone a standard preparation but the colon is not adequately cleansed, a rapid preparation might be needed to repeat the procedure promptly.
#
# 3. **Patient Non-Compliance**: Some patients may not follow the initial preparation instructions properly, necessitating a rapid preparation to ensure the colon is adequately cleansed.
#
# 4. **Medical Conditions**: Certain medical conditions, such as chronic constipation or slow colonic transit, may require more aggressive or rapid preparation methods to ensure the colon is clean.
#
# 5. **Scheduling Constraints**: In some cases, logistical or scheduling constraints may necessitate a rapid preparation to fit the procedure into a specific timeframe.
#
# 6. **Previous Poor Preparation History**: Patients with a history of poor bowel preparation in past colonoscopies may be candidates for a more rapid or intensive preparation regimen.
#
# 7. **Dietary Factors**: If a patient has consumed foods that are difficult to clear from the colon, such as seeds or high-fiber foods, a rapid preparation might be needed.
#
# 8. **Medication Interference**: Certain medications can interfere with bowel preparation, requiring adjustments or more rapid preparation methods.
#
# In any case, the choice of preparation method should be tailored to the individual patient, taking into account their medical history, current health status, and any specific risks or needs they may have.
# Severe gastrointestinal (GI) bleeding can have several potential causes, and the involvement of both a gastroenterologist and a surgeon is often necessary to accurately diagnose and manage the condition. Here are some possible causes of severe GI bleeding:
#
# 1. **Peptic Ulcer Disease**: Ulcers in the stomach or duodenum can erode into blood vessels, leading to significant bleeding.
#
# 2. **Esophageal Varices**: Often associated with liver cirrhosis, these are dilated veins in the esophagus that can rupture and cause massive bleeding.
#
# 3. **Diverticular Disease**: Diverticula in the colon can bleed profusely, often presenting as painless rectal bleeding.
#
# 4. **Angiodysplasia**: Abnormal blood vessels in the GI tract, particularly in the colon, can cause bleeding.
#
# 5. **Inflammatory Bowel Disease (IBD)**: Conditions like Crohn's disease and ulcerative colitis can cause bleeding due to inflammation and ulceration of the intestinal lining.
#
# 6. **Colorectal Cancer**: Tumors in the colon or rectum can bleed, sometimes significantly.
#
# 7. **Gastrointestinal Tumors**: Other tumors, benign or malignant, in the GI tract can also cause bleeding.
#
# 8. **Mallory-Weiss Tear**: A tear in the mucous membrane at the junction of the stomach and esophagus, often due to severe vomiting, can cause bleeding.
#
# 9. **Hemorrhoids**: Although usually causing minor bleeding, severe cases can lead to significant blood loss.
#
# 10. **Ischemic Colitis**: Reduced blood flow to the colon can cause inflammation and bleeding.
#
# 11. **Meckel's Diverticulum**: A congenital abnormality that can cause bleeding, particularly in younger patients.
#
# 12. **Aortoenteric Fistula**: A rare but life-threatening condition where there is a connection between the aorta and the GI tract, often following aortic surgery.
#
# The specific cause of the bleeding will guide the treatment approach, which may include endoscopic interventions, medication, or surgery. The gastroenterologist will typically perform diagnostic procedures like endoscopy or colonoscopy to identify the source of bleeding, while the surgeon may be involved in cases where surgical intervention is necessary.
# When a distal lesion is found during a flexible sigmoidoscopy, it is often recommended to perform a complete colonoscopy to the cecum to ensure a thorough evaluation of the entire colon. This is because the presence of a distal lesion can sometimes indicate the possibility of additional lesions or pathology elsewhere in the colon. Here are some possible causes or conditions that might necessitate a complete colonoscopy:
#
# 1. **Colorectal Polyps**: Polyps found in the distal colon may suggest the presence of additional polyps in the proximal colon. Some polyps have the potential to become cancerous, so identifying and removing them is crucial.
#
# 2. **Colorectal Cancer**: A distal lesion could be an indication of colorectal cancer. A complete colonoscopy is necessary to assess the extent of the disease and to check for synchronous lesions.
#
# 3. **Inflammatory Bowel Disease (IBD)**: Conditions such as ulcerative colitis or Crohn's disease can cause lesions in the colon. A full colonoscopy helps in assessing the extent and severity of the disease.
#
# 4. **Diverticular Disease**: Diverticulosis or diverticulitis can cause lesions or changes in the colon. A complete colonoscopy can help evaluate the extent of diverticular disease.
#
# 5. **Ischemic Colitis**: This condition can cause lesions due to reduced blood flow to the colon. A full colonoscopy can help determine the extent of ischemic damage.
#
# 6. **Infectious Colitis**: Infections can cause lesions or inflammation in the colon. A complete colonoscopy can help identify the extent of infection and inflammation.
#
# 7. **Hereditary Syndromes**: Conditions like Lynch syndrome or familial adenomatous polyposis (FAP) can cause multiple polyps or lesions throughout the colon, necessitating a full evaluation.
#
# 8. **Non-neoplastic Lesions**: Conditions such as hyperplastic polyps or benign lesions may also be present and require evaluation.
#
# In summary, a complete colonoscopy is essential to rule out or confirm additional pathology, assess the extent of disease, and guide appropriate management and treatment.
# Mucosal prolapse in adults can be caused by several factors, and its progression can lead to worsening symptoms. Here are some possible causes and contributing factors:
#
# 1. **Chronic Straining**: Repeated straining during bowel movements, often due to constipation, can lead to increased pressure on the rectal and colonic walls, contributing to mucosal prolapse.
#
# 2. **Weakness of Pelvic Floor Muscles**: Weakness or dysfunction of the pelvic floor muscles can lead to inadequate support for the rectal and colonic tissues, increasing the risk of prolapse.
#
# 3. **Aging**: As people age, the connective tissues and muscles supporting the colon and rectum can weaken, making prolapse more likely.
#
# 4. **Previous Surgery or Trauma**: Surgical procedures or trauma to the pelvic area can alter the normal anatomy and support structures, potentially leading to prolapse.
#
# 5. **Chronic Diarrhea**: Persistent diarrhea can also contribute to prolapse due to frequent bowel movements and straining.
#
# 6. **Genetic Predisposition**: Some individuals may have a genetic predisposition to weaker connective tissues, making them more susceptible to prolapse.
#
# 7. **Obesity**: Excess body weight can increase abdominal pressure, contributing to the development of prolapse.
#
# 8. **Neurological Disorders**: Conditions that affect nerve function in the pelvic area can lead to poor muscle coordination and support, increasing the risk of prolapse.
#
# 9. **Rectal Intussusception**: This condition, where part of the rectum telescopes into itself, can be associated with mucosal prolapse.
#
# 10. **Inflammatory Bowel Disease (IBD)**: Chronic inflammation from conditions like ulcerative colitis or Crohn's disease can weaken the bowel wall, potentially leading to prolapse.
#
# If a patient is experiencing symptoms of mucosal prolapse, such as rectal bleeding, a sensation of incomplete evacuation, or visible prolapse, it is important to conduct a thorough evaluation, including a colonoscopy, to determine the underlying cause and appropriate treatment. Treatment options may include dietary changes, pelvic floor exercises, medications, or surgical intervention, depending on the severity and underlying cause of the prolapse.
# Patients with numerous colon polyps, particularly those with a hereditary predisposition, are at an increased risk of developing colorectal cancer. The possible causes or conditions associated with this presentation include:
#
# 1. **Familial Adenomatous Polyposis (FAP):** This is an inherited condition characterized by the development of hundreds to thousands of adenomatous polyps in the colon and rectum, often leading to colorectal cancer if not managed appropriately.
#
# 2. **Lynch Syndrome (Hereditary Nonpolyposis Colorectal Cancer - HNPCC):** Although it typically involves fewer polyps than FAP, Lynch syndrome is another hereditary condition that significantly increases the risk of colorectal cancer and other cancers.
#
# 3. **MUTYH-Associated Polyposis (MAP):** This is an autosomal recessive disorder caused by mutations in the MUTYH gene, leading to multiple adenomatous polyps and an increased risk of colorectal cancer.
#
# 4. **Peutz-Jeghers Syndrome:** This is a genetic condition characterized by the development of hamartomatous polyps in the gastrointestinal tract and an increased risk of various cancers, including colorectal cancer.
#
# 5. **Juvenile Polyposis Syndrome:** This condition involves the presence of multiple juvenile polyps in the gastrointestinal tract and an increased risk of colorectal cancer.
#
# 6. **Serrated Polyposis Syndrome:** This condition is characterized by multiple serrated polyps in the colon, which can increase the risk of colorectal cancer.
#
# 7. **Hyperplastic Polyposis Syndrome:** Although hyperplastic polyps are generally considered benign, having numerous hyperplastic polyps can be associated with an increased risk of colorectal cancer.
#
# 8. **Chronic Inflammatory Conditions:** Conditions such as inflammatory bowel disease (IBD), including ulcerative colitis and Crohn's disease, can lead to the development of dysplastic polyps and increase the risk of colorectal cancer over time.
#
# In patients presenting with numerous colon polyps, a thorough family history, genetic testing, and regular surveillance are crucial for early detection and management of potential colorectal cancer.
# MUTYH-associated polyposis (MAP) is an autosomal recessive condition caused by biallelic mutations in the MUTYH gene. Patients with MAP typically present with multiple colorectal adenomas and an increased risk of colorectal cancer. The possible causes of the patient's condition, given that they are affected by MUTYH polyposis, include:
#
# 1. **Genetic Mutations**: The patient is either homozygous or compound heterozygous for mutations in the MUTYH gene. This means they have inherited one mutated copy of the gene from each parent, leading to the development of multiple adenomatous polyps in the colon.
#
# 2. **Defective DNA Repair**: The MUTYH gene is involved in base excision repair, a pathway that corrects oxidative DNA damage. Mutations in this gene lead to an accumulation of DNA errors, particularly G:C to T:A transversions, which can result in the formation of adenomas and progression to colorectal cancer.
#
# 3. **Environmental and Lifestyle Factors**: While the primary cause is genetic, environmental factors such as diet, smoking, and alcohol consumption may influence the number and growth of polyps, although they are not direct causes of the condition.
#
# 4. **Family History**: Although MAP is recessive, a family history of colorectal cancer or polyps may be present, especially if both parents are carriers of a MUTYH mutation.
#
# 5. **Age and Gender**: The condition can manifest at various ages, but symptoms often appear in adulthood. There is no strong gender predilection, but the age of onset and severity can vary.
#
# In summary, the primary cause of the patient's condition is the presence of biallelic mutations in the MUTYH gene, leading to defective DNA repair and the development of multiple colorectal adenomas.
# Diverticulosis is a condition where small pouches, called diverticula, form in the wall of the colon. While diverticulosis itself is often asymptomatic, it can become symptomatic in certain situations, leading to pain or bleeding. Here are some possible causes for these symptoms:
#
# 1. **Diverticulitis**: This occurs when the diverticula become inflamed or infected. It can cause significant abdominal pain, usually in the lower left quadrant, along with fever, nausea, and changes in bowel habits.
#
# 2. **Diverticular Bleeding**: This is one of the most common causes of lower gastrointestinal bleeding. It occurs when a blood vessel near a diverticulum ruptures, leading to painless rectal bleeding. The bleeding can be significant and may require medical intervention.
#
# 3. **Colonic Spasm**: The presence of diverticula can sometimes lead to spasms in the colon, causing abdominal pain or discomfort.
#
# 4. **Irritation or Pressure**: Increased pressure within the colon, possibly due to constipation or a low-fiber diet, can irritate the diverticula, leading to pain.
#
# 5. **Complications of Diverticulitis**: If diverticulitis is not treated, it can lead to complications such as abscess formation, perforation of the colon, fistula formation, or bowel obstruction, all of which can cause significant pain and other symptoms.
#
# 6. **Ischemia**: Although less common, reduced blood flow to the area of the diverticula can cause pain and potentially lead to bleeding.
#
# If a patient with known diverticulosis presents with pain or bleeding, it is important to evaluate them thoroughly to determine the exact cause and provide appropriate treatment. This may involve imaging studies, colonoscopy, and possibly laboratory tests to assess for infection or anemia.
# Yes, ulcerative colitis is a chronic inflammatory bowel disease that primarily affects the colon and rectum. It is characterized by inflammation and ulceration of the innermost lining of the colon. One of the significant long-term risks associated with ulcerative colitis is an increased risk of developing colorectal cancer. The risk factors for colon cancer in patients with ulcerative colitis include:
#
# 1. **Duration of Disease**: The risk of colon cancer increases with the duration of ulcerative colitis. Patients with a history of the disease for more than 8-10 years are at a higher risk.
#
# 2. **Extent of Colonic Involvement**: Patients with pancolitis (involvement of the entire colon) have a higher risk compared to those with left-sided colitis or proctitis.
#
# 3. **Severity of Inflammation**: Chronic and severe inflammation is associated with a higher risk of dysplasia and subsequent cancer development.
#
# 4. **Family History**: A family history of colorectal cancer can further increase the risk.
#
# 5. **Primary Sclerosing Cholangitis (PSC)**: Patients with ulcerative colitis who also have PSC are at an even higher risk of developing colorectal cancer.
#
# 6. **Dysplasia**: The presence of dysplasia (precancerous changes in the cells lining the colon) is a strong risk factor for the development of colorectal cancer.
#
# Regular surveillance colonoscopy is recommended for patients with ulcerative colitis to monitor for dysplasia and early signs of cancer, allowing for timely intervention. The frequency of surveillance colonoscopy is typically determined by the duration and extent of the disease, as well as the presence of additional risk factors.
# Peutz-Jeghers syndrome (PJS) is a genetic condition characterized by the development of distinctive pigmented spots on the skin and mucous membranes, as well as the growth of hamartomatous polyps in the gastrointestinal tract. Individuals with PJS are at an increased risk for various types of cancer, including gastrointestinal cancers (such as colorectal, stomach, and pancreatic cancer) and extraintestinal cancers (such as breast, ovarian, and testicular cancer).
#
# While the primary cancer risks associated with Peutz-Jeghers syndrome are typically gastrointestinal and certain other specific types, there is some evidence suggesting a potential increased risk for lung cancer as well. However, this risk is not as well-documented or as prominent as the risks for other cancers associated with PJS. It is important for individuals with PJS to undergo regular surveillance and screening for various cancers, as recommended by their healthcare providers, to manage and mitigate these risks.
# The presence of polyps in 50% of patients by age 15 years is highly suggestive of a hereditary polyposis syndrome. The most likely condition in this scenario is Familial Adenomatous Polyposis (FAP). FAP is an autosomal dominant disorder characterized by the development of hundreds to thousands of adenomatous polyps in the colon and rectum, typically beginning in adolescence. If left untreated, there is a nearly 100% risk of progression to colorectal cancer, often by the age of 40.
#
# Other possible hereditary conditions that could present with early-onset polyps include:
#
# 1. **Attenuated Familial Adenomatous Polyposis (AFAP):** A milder form of FAP with fewer polyps and a later onset of colorectal cancer.
#
# 2. **MUTYH-Associated Polyposis (MAP):** An autosomal recessive condition caused by mutations in the MUTYH gene, leading to multiple adenomatous polyps and an increased risk of colorectal cancer.
#
# 3. **Peutz-Jeghers Syndrome:** Characterized by hamartomatous polyps and mucocutaneous pigmentation, though the polyps are typically not adenomatous.
#
# 4. **Juvenile Polyposis Syndrome:** Characterized by the presence of multiple juvenile polyps, which are hamartomatous, and an increased risk of gastrointestinal cancers.
#
# 5. **Serrated Polyposis Syndrome:** Characterized by multiple serrated polyps in the colon, which can also increase the risk of colorectal cancer.
#
# Given the early age of onset and high prevalence of polyps, a genetic evaluation and counseling are recommended to confirm the diagnosis and guide management, including surveillance and potential prophylactic surgery.
# The symptoms of colorectal cancer can indeed include changes in bowel habits. However, it's important to consider a range of possible causes for such symptoms, as they can be indicative of various conditions. Here are some potential causes:
#
# 1. **Colorectal Cancer**: As you mentioned, changes in bowel habits, such as diarrhea, constipation, or a change in the consistency of your stool, can be symptoms of colorectal cancer. Other symptoms might include rectal bleeding, persistent abdominal discomfort, weakness or fatigue, and unexplained weight loss.
#
# 2. **Irritable Bowel Syndrome (IBS)**: This is a common disorder that affects the large intestine, causing symptoms like cramping, abdominal pain, bloating, gas, and diarrhea or constipation, or both.
#
# 3. **Inflammatory Bowel Disease (IBD)**: This includes conditions like Crohn's disease and ulcerative colitis, which can cause chronic inflammation of the gastrointestinal tract, leading to symptoms such as diarrhea, abdominal pain, and changes in bowel habits.
#
# 4. **Diverticulitis**: This condition occurs when small, bulging pouches (diverticula) in the digestive tract become inflamed or infected, leading to symptoms like abdominal pain, fever, and changes in bowel habits.
#
# 5. **Infections**: Bacterial, viral, or parasitic infections can cause changes in bowel habits, often accompanied by symptoms like diarrhea, abdominal pain, and fever.
#
# 6. **Celiac Disease**: An autoimmune disorder where ingestion of gluten leads to damage in the small intestine, causing symptoms like diarrhea, fatigue, and weight loss.
#
# 7. **Colonic Polyps**: While often asymptomatic, larger polyps can cause changes in bowel habits or bleeding.
#
# 8. **Medications**: Certain medications, such as antibiotics or those containing magnesium, can alter bowel habits.
#
# 9. **Dietary Factors**: Changes in diet, including increased fiber intake or consumption of certain foods, can affect bowel habits.
#
# 10. **Stress and Anxiety**: Psychological factors can also impact bowel habits, often exacerbating conditions like IBS.
#
# A thorough evaluation, including a detailed medical history, physical examination, and possibly diagnostic tests such as a colonoscopy, is necessary to determine the exact cause of the symptoms.
# Based on the symptoms of irritation and bleeding, the possible causes of the patient's condition could include:
#
# 1. **Hemorrhoids**: Swollen veins in the lower rectum or anus, which can cause irritation, itching, and bleeding, especially during bowel movements.
#
# 2. **Anal Fissures**: Small tears in the lining of the anus, often caused by passing hard stools, which can lead to pain, irritation, and bleeding.
#
# 3. **Colorectal Polyps**: Although less common, polyps can sometimes cause bleeding. They are growths on the inner lining of the colon or rectum.
#
# 4. **Inflammatory Bowel Disease (IBD)**: Conditions like Crohn's disease or ulcerative colitis can cause inflammation of the colon, leading to irritation and bleeding.
#
# 5. **Diverticular Disease**: Diverticulosis or diverticulitis can cause bleeding and irritation in the colon.
#
# 6. **Colorectal Cancer**: Though less likely, especially in younger patients, colorectal cancer can cause bleeding and should be ruled out, particularly if there are other risk factors or symptoms.
#
# 7. **Infections**: Certain infections of the gastrointestinal tract can cause irritation and bleeding.
#
# 8. **Radiation Proctitis**: In patients who have undergone radiation therapy, this can cause inflammation and bleeding in the rectum.
#
# A thorough clinical evaluation, including a detailed history, physical examination, and possibly a colonoscopy, would be necessary to determine the exact cause of the symptoms.
# Blood in the stool can be a symptom of several conditions, including but not limited to colorectal cancer. Here are some possible causes:
#
# 1. **Colorectal Cancer**: As you mentioned, blood in the stool can be a symptom of colorectal cancer. This can occur due to bleeding from a tumor in the colon or rectum.
#
# 2. **Hemorrhoids**: Swollen blood vessels in the rectum or anus can cause bright red blood in the stool, often associated with pain or discomfort during bowel movements.
#
# 3. **Anal Fissures**: Small tears in the lining of the anus can cause bleeding and are often accompanied by pain during bowel movements.
#
# 4. **Diverticular Disease**: Diverticulosis can lead to diverticulitis, which may cause bleeding if the diverticula become inflamed or infected.
#
# 5. **Inflammatory Bowel Disease (IBD)**: Conditions such as Crohn's disease and ulcerative colitis can cause inflammation and ulceration in the colon, leading to blood in the stool.
#
# 6. **Gastrointestinal Infections**: Certain infections can cause inflammation and bleeding in the gastrointestinal tract.
#
# 7. **Angiodysplasia**: Abnormal blood vessels in the colon can lead to bleeding.
#
# 8. **Polyps**: Benign growths in the colon can sometimes bleed, and some polyps have the potential to become cancerous over time.
#
# 9. **Ischemic Colitis**: Reduced blood flow to the colon can cause inflammation and bleeding.
#
# 10. **Colonic Arteriovenous Malformations (AVMs)**: These are abnormal connections between arteries and veins in the colon that can cause bleeding.
#
# It is important for the patient to undergo a thorough evaluation, including a colonoscopy, to determine the exact cause of the bleeding and to rule out or confirm colorectal cancer or other serious conditions.
# Based on the information provided, the patient is experiencing symptoms related to hemorrhoids. Hemorrhoids are swollen veins in the lower rectum or anus and can be internal or external. The symptomatic treatment mentioned suggests that the patient is experiencing discomfort or pain, which is common with hemorrhoids.
#
# Possible causes of hemorrhoids include:
#
# 1. **Chronic Constipation or Diarrhea**: Straining during bowel movements can increase pressure on the veins in the rectal area, leading to hemorrhoids.
#
# 2. **Prolonged Sitting**: Sitting for long periods, especially on the toilet, can increase pressure on the anal veins.
#
# 3. **Pregnancy**: Increased pressure in the pelvic area during pregnancy can lead to hemorrhoids.
#
# 4. **Obesity**: Excess body weight can increase pressure on the pelvic veins.
#
# 5. **Low-Fiber Diet**: A diet low in fiber can lead to constipation, which can contribute to the development of hemorrhoids.
#
# 6. **Heavy Lifting**: Regularly lifting heavy objects can increase abdominal pressure, contributing to hemorrhoid formation.
#
# 7. **Aging**: As people age, the tissues supporting the veins in the rectum and anus can weaken and stretch, making hemorrhoids more likely.
#
# 8. **Genetic Predisposition**: A family history of hemorrhoids can increase the likelihood of developing them.
#
# The treatment options mentioned, such as stool softeners, warm sitz baths, anesthetic ointments, and witch hazel compresses, are aimed at alleviating symptoms and reducing discomfort. If symptoms persist or worsen, further evaluation by a healthcare professional may be necessary to rule out other conditions or to consider more advanced treatments.
# In immunocompromised patients, the risk of infections with viruses such as herpes simplex virus (HSV) and cytomegalovirus (CMV) is significantly increased. These infections can affect various parts of the body, including the gastrointestinal tract. In the context of a colonoscopy and colonic diseases, the following conditions could be considered:
#
# 1. **CMV Colitis**: This is a common manifestation of CMV infection in immunocompromised individuals. It can cause symptoms such as diarrhea, abdominal pain, fever, and weight loss. Colonoscopy may reveal ulcerations, and biopsy with histopathological examination can confirm the presence of CMV inclusion bodies.
#
# 2. **HSV Colitis**: Although less common than CMV colitis, HSV can also cause colitis in immunocompromised patients. Symptoms are similar to those of CMV colitis, and endoscopic findings may include ulcerations. Diagnosis is confirmed through biopsy and identification of HSV in tissue samples.
#
# 3. **Other Opportunistic Infections**: Immunocompromised patients are also at risk for other opportunistic infections that can affect the colon, such as fungal infections (e.g., Candida, Histoplasma) and other viral infections (e.g., Epstein-Barr virus).
#
# 4. **Medication-Induced Colitis**: Some medications used in immunocompromised patients, such as immunosuppressants, can lead to colitis either directly or by predisposing to infections.
#
# 5. **Inflammatory Bowel Disease (IBD)**: While not directly caused by immunocompromise, IBD can be exacerbated in these patients, and the presentation may overlap with infectious colitis.
#
# 6. **Ischemic Colitis**: Immunocompromised patients may also be at risk for ischemic colitis due to underlying conditions or medications that affect blood flow to the colon.
#
# In any case, a thorough clinical evaluation, including history, physical examination, laboratory tests, and colonoscopy with biopsy, is essential to determine the exact cause of the colonic symptoms in an immunocompromised patient.
# Juvenile polyps are typically benign growths that occur in the colon, often in children and adolescents. They are usually solitary and can cause symptoms such as rectal bleeding, abdominal pain, or prolapse. The possible causes of the patient's condition, particularly if they are experiencing uncontrollable bleeding or intussusception, include:
#
# 1. **Juvenile Polyposis Syndrome (JPS):** This is a genetic condition characterized by the presence of multiple juvenile polyps in the gastrointestinal tract. It can lead to significant bleeding and an increased risk of intussusception due to the size and number of polyps.
#
# 2. **Mechanical Obstruction:** Large polyps can cause a blockage in the intestine, leading to intussusception, where one part of the intestine telescopes into another, causing obstruction and potentially severe pain.
#
# 3. **Vascular Compromise:** The presence of polyps can lead to vascular compromise, resulting in bleeding. This is particularly concerning if the bleeding is uncontrollable, as it may require intervention.
#
# 4. **Inflammation or Ulceration:** Polyps can become inflamed or ulcerated, leading to bleeding. This is more common if the polyps are large or numerous.
#
# 5. **Trauma to the Polyp:** Physical trauma, such as during bowel movements, can cause bleeding from the surface of the polyp.
#
# 6. **Coagulation Disorders:** Although not directly caused by the polyps, underlying coagulation disorders can exacerbate bleeding tendencies in patients with juvenile polyps.
#
# Treatment typically involves endoscopic removal of the polyps to prevent complications such as bleeding or intussusception. In cases of juvenile polyposis syndrome, regular surveillance and management are necessary to monitor for potential malignant transformation.
# Based on the information provided, the patient is likely dealing with Crohn's disease, a type of inflammatory bowel disease (IBD). The treatment options mentioned are consistent with standard therapies for managing Crohn's disease. Here are the possible causes and considerations for the patient's condition:
#
# 1. **Genetic Factors**: Crohn's disease has a genetic component, and a family history of IBD can increase the risk of developing the condition.
#
# 2. **Immune System Dysfunction**: An abnormal immune response may lead to chronic inflammation in the gastrointestinal tract, which is characteristic of Crohn's disease.
#
# 3. **Environmental Factors**: Certain environmental factors, such as smoking, diet, and stress, may contribute to the development or exacerbation of Crohn's disease.
#
# 4. **Microbiome Imbalance**: Alterations in the gut microbiota may play a role in the pathogenesis of Crohn's disease, although the exact mechanisms are not fully understood.
#
# 5. **Infections**: Some studies suggest that infections, particularly in early life, might trigger or exacerbate Crohn's disease in genetically susceptible individuals.
#
# 6. **Dietary Factors**: While not a direct cause, certain dietary patterns may influence the course of the disease or trigger flare-ups.
#
# Given these potential causes, the treatment regimen aims to reduce inflammation, manage symptoms, and maintain remission. The use of 5-aminosalicylic acid, corticosteroids, immunomodulators, anticytokines, and antibiotics targets different aspects of the disease process, while surgery may be necessary for complications or when medical management is insufficient.
# Ischemic colitis occurs when there is a reduction in blood flow to the colon, leading to inflammation and injury. The treatment approach you mentioned is indeed standard for mild to moderate cases of ischemic colitis. Here are some possible causes of ischemic colitis:
#
# 1. **Atherosclerosis**: Hardening and narrowing of the arteries can reduce blood flow to the colon.
#
# 2. **Hypotension**: Low blood pressure, which can occur due to dehydration, heart failure, or shock, may lead to reduced blood flow to the colon.
#
# 3. **Vascular Surgery or Procedures**: Recent surgeries or procedures involving the aorta or other major blood vessels can disrupt blood flow to the colon.
#
# 4. **Medications**: Certain medications, such as vasoconstrictors, diuretics, or digitalis, can reduce blood flow to the colon.
#
# 5. **Thrombosis or Embolism**: Blood clots in the arteries supplying the colon can lead to ischemia.
#
# 6. **Heart Failure**: Reduced cardiac output can lead to decreased blood flow to the colon.
#
# 7. **Hypercoagulable States**: Conditions that increase the risk of blood clot formation can lead to ischemic colitis.
#
# 8. **Strenuous Physical Activity**: Intense exercise, especially in older adults, can lead to temporary reductions in blood flow to the colon.
#
# 9. **Inflammatory Conditions**: Conditions like vasculitis can affect blood vessels and lead to ischemia.
#
# 10. **Infections**: Severe infections can lead to systemic hypotension and reduced blood flow to the colon.
#
# In severe cases, or if there is evidence of complications such as perforation or gangrene, surgical intervention may be necessary. Identifying and addressing the underlying cause is crucial in managing ischemic colitis effectively.
# Antibiotic-associated proctitis due to Clostridioides difficile (C. difficile) is a condition where inflammation of the rectum occurs following antibiotic use, leading to an overgrowth of C. difficile bacteria. This condition is part of the spectrum of C. difficile infections, which can range from mild diarrhea to severe colitis.
#
# The standard treatment for C. difficile infection, including proctitis, involves the use of specific antibiotics that target the C. difficile bacteria. The primary treatments include:
#
# 1. **Vancomycin**: This is often the first-line treatment for moderate to severe C. difficile infections. It is usually administered orally to ensure it reaches the colon effectively.
#
# 2. **Fidaxomicin**: This is another antibiotic specifically used for C. difficile infections. It is often used as an alternative to vancomycin, particularly in cases where there is a high risk of recurrence or in patients who have had multiple recurrences.
#
# In addition to these treatments, it is important to discontinue the use of the antibiotic that initially led to the C. difficile overgrowth, if possible. Supportive care, including hydration and electrolyte management, is also crucial.
#
# In some cases, particularly severe or recurrent infections, other treatments such as fecal microbiota transplantation (FMT) may be considered to restore the normal gut flora.
#
# It is important to note that the choice of treatment may vary based on the severity of the infection, patient history, and any previous occurrences of C. difficile infection. Therefore, treatment should be tailored to the individual patient's needs and circumstances.
# Diverticular bleeding is a common cause of lower gastrointestinal bleeding, particularly in older adults. During a colonoscopy, which is both a diagnostic and therapeutic procedure, several treatment options can be employed to manage diverticular bleeding:
#
# 1. **Endoscopic Hemostasis**: This involves direct intervention during the colonoscopy to stop the bleeding. Techniques include:
#    - **Clipping**: Endoscopic clips can be applied to the bleeding site to mechanically compress the vessel and stop the bleeding.
#    - **Thermal Coagulation**: This involves using heat to cauterize the bleeding vessel. Methods include bipolar coagulation or heater probe.
# ...
#
# 3. **Hypotension**: Neostigmine can lead to a drop in blood pressure, which needs to be monitored closely.
#
# 4. **Increased Parasympathetic Activity**: As an acetylcholinesterase inhibitor, neostigmine increases acetylcholine levels, enhancing parasympathetic nervous system activity, which can affect heart rate and rhythm.
#
# 5. **Potential for Cardiac Arrest**: In rare cases, severe bradycardia or arrhythmias can lead to cardiac arrest, necessitating immediate intervention.
#
# Given these potential cardiovascular effects, continuous cardiac monitoring is essential to promptly identify and manage any adverse events during and after the administration of IV neostigmine.
# Severe gastrointestinal (GI) bleeding is a critical condition that requires immediate medical attention and often admission to an intensive care unit (ICU) or a monitored setting. The possible causes of severe GI bleeding can vary depending on whether the bleeding is from the upper or lower GI tract. Here are some potential causes:
#
# ### Upper GI Bleeding:
# 1. **Peptic Ulcer Disease**: Ulcers in the stomach or duodenum can erode into blood vessels, causing significant bleeding.
# 2. **Esophageal Varices**: Often related to liver cirrhosis, these are dilated veins in the esophagus that can rupture and bleed profusely.
# 3. **Gastritis**: Inflammation of the stomach lining, often due to NSAIDs or alcohol, can lead to bleeding.
# 4. **Mallory-Weiss Tear**: A tear in the mucous membrane at the junction of the stomach and esophagus, often due to severe vomiting.
# 5. **Esophagitis**: Inflammation of the esophagus, possibly due to acid reflux, can cause bleeding.
#
# ### Lower GI Bleeding:
# 1. **Diverticular Disease**: Diverticula in the colon can bleed, sometimes massively.
# 2. **Angiodysplasia**: Abnormal blood vessels in the colon can cause bleeding.
# 3. **Colorectal Cancer**: Tumors in the colon or rectum can bleed.
# 4. **Inflammatory Bowel Disease (IBD)**: Conditions like Crohn's disease or ulcerative colitis can cause bleeding.
# 5. **Hemorrhoids**: Although usually causing minor bleeding, severe cases can lead to significant blood loss.
# 6. **Ischemic Colitis**: Reduced blood flow to the colon can cause bleeding.
#
# ### Other Considerations:
# - **Coagulopathy**: Disorders of blood clotting can exacerbate bleeding from any source.
# - **Medications**: Anticoagulants or antiplatelet drugs can increase the risk of bleeding.
# - **Trauma or Post-Procedure Complications**: Recent surgeries or procedures involving the GI tract can lead to bleeding.
#
# In a clinical setting, the specific cause of severe GI bleeding would be determined through a combination of patient history, physical examination, laboratory tests, imaging studies, and endoscopic evaluation. Immediate stabilization of the patient, including fluid resuscitation and blood transfusions if necessary, is crucial while the underlying cause is being identified and treated.
# Massive gastrointestinal (GI) bleeding can be a life-threatening condition and requires prompt evaluation and management. The possible causes of massive GI bleeding can vary depending on whether the bleeding is from the upper or lower GI tract. Since you mentioned colonoscopy, I will focus on potential causes related to the lower GI tract:
#
# 1. **Diverticular Disease**: Diverticulosis, particularly in the colon, can lead to significant bleeding if a diverticulum ruptures.
#
# 2. **Angiodysplasia**: These are abnormal blood vessels in the colon that can cause significant bleeding, especially in older adults.
#
# 3. **Colorectal Cancer**: Tumors in the colon or rectum can erode blood vessels and cause bleeding.
#
# 4. **Inflammatory Bowel Disease (IBD)**: Conditions such as ulcerative colitis or Crohn's disease can cause severe inflammation and bleeding.
#
# 5. **Ischemic Colitis**: Reduced blood flow to the colon can lead to tissue damage and bleeding.
#
# 6. **Hemorrhoids**: Although usually causing minor bleeding, severe hemorrhoids can occasionally lead to significant blood loss.
#
# 7. **Post-Polypectomy Bleeding**: Recent removal of polyps during a colonoscopy can sometimes result in bleeding.
#
# 8. **Radiation Colitis**: Previous radiation therapy to the pelvic area can cause damage to the colon and result in bleeding.
#
# 9. **Infectious Colitis**: Severe infections of the colon, such as those caused by Clostridioides difficile, can lead to bleeding.
#
# 10. **Meckel's Diverticulum**: Although more common in the small intestine, it can sometimes be a source of lower GI bleeding.
#
# In the context of massive GI bleeding, it is crucial to stabilize the patient, often with fluid resuscitation and blood transfusions, and to perform diagnostic procedures such as colonoscopy, angiography, or CT scans to identify the source of bleeding. Treatment will depend on the underlying cause and may include endoscopic interventions, surgery, or medical management.
# Yes, a colonoscopy requires thorough cleansing of the colon to ensure clear visibility of the colon walls and to allow for accurate diagnosis. This process is known as bowel preparation and typically involves the following steps:
#
# 1. **Dietary Restrictions**: Patients are usually advised to follow a clear liquid diet for 24 to 48 hours before the procedure. This includes consuming clear broths, tea, coffee without milk or cream, clear juices, and gelatin.
#
# 2. **Laxatives**: Patients are often prescribed a strong laxative solution to drink the day before the procedure. This helps to evacuate the contents of the colon.
#
# 3. **Hydration**: It is important for patients to stay well-hydrated during the preparation process, as the laxatives can cause dehydration.
#
# 4. **Adjustments to Medications**: Patients may need to adjust or temporarily stop certain medications, such as blood thinners, as advised by their doctor.
#
# Proper bowel preparation is crucial for the success of the colonoscopy, as any residual stool can obscure the view and potentially lead to missed lesions or polyps. If the colon is not adequately cleansed, the procedure may need to be rescheduled.
# The patient's condition is not explicitly stated, but if we are considering a scenario where a patient is undergoing an endoscopy, particularly a colonoscopy, and there are issues such as incomplete bowel preparation or complications during the procedure, several potential causes could be considered:
#
# 1. **Inadequate Bowel Preparation**: If the patient did not adhere to the dietary restrictions or bowel prep instructions, the colon may not be adequately cleansed, leading to poor visualization during the procedure.
#
# 2. **Dehydration**: If the patient did not consume enough clear liquids before the fasting period, they might experience dehydration, which can complicate the procedure or recovery.
#
# 3. **Gastrointestinal Obstruction**: Conditions such as strictures, tumors, or severe constipation could prevent adequate bowel cleansing or cause symptoms that necessitate the endoscopy.
#
# 4. **Medication Non-compliance**: If the patient did not stop certain medications as advised (e.g., anticoagulants, NSAIDs), it could lead to complications such as bleeding.
#
# 5. **Underlying Gastrointestinal Conditions**: Conditions like inflammatory bowel disease, diverticulitis, or ischemic colitis could cause symptoms that require endoscopy for diagnosis and might also affect the preparation process.
#
# 6. **Anxiety or Non-compliance**: Anxiety about the procedure might lead to non-compliance with preparation instructions, affecting the outcome.
#
# 7. **Metabolic or Systemic Conditions**: Conditions like diabetes might affect gastric emptying or bowel motility, complicating preparation.
#
# If the patient is experiencing specific symptoms or complications, further details would be needed to narrow down the possible causes.
# Asymptomatic diverticulosis is a condition where small pouches, called diverticula, form in the wall of the colon but do not cause any symptoms. It is a common finding, especially in older adults, and often discovered incidentally during a colonoscopy or imaging studies done for other reasons. Since it is asymptomatic, it typically does not require treatment. However, there are some considerations and potential causes for the development of diverticulosis:
#
# 1. **Dietary Factors**: A low-fiber diet is often associated with the development of diverticulosis. A diet high in refined carbohydrates and low in fiber can lead to constipation and increased colonic pressure, contributing to the formation of diverticula.
#
# 2. **Age**: The prevalence of diverticulosis increases with age. It is more common in individuals over the age of 50.
#
# 3. **Genetic Predisposition**: There may be a genetic component, as diverticulosis can run in families.
#
# 4. **Lifestyle Factors**: Obesity, lack of physical activity, and smoking have been associated with an increased risk of developing diverticulosis.
#
# 5. **Colonic Motility**: Altered colonic motility and increased intraluminal pressure can contribute to the formation of diverticula.
#
# 6. **Connective Tissue Changes**: Changes in the connective tissue of the colon wall, which can occur with aging, may predispose individuals to diverticulosis.
#
# While asymptomatic diverticulosis does not require treatment, patients are often advised to increase their dietary fiber intake to help prevent complications such as diverticulitis (inflammation of the diverticula) or diverticular bleeding. Regular follow-up and monitoring may be recommended to ensure that the condition remains asymptomatic.
# Rapid colonic preparation is often required for a colonoscopy to ensure that the colon is thoroughly cleansed, allowing for clear visualization of the colon walls and any potential abnormalities. Inadequate preparation can lead to missed lesions or the need to repeat the procedure. There are several potential causes or considerations related to the need for rapid colonic preparation:
#
# 1. **Patient Non-Compliance**: Sometimes, patients may not follow the standard bowel preparation instructions properly, necessitating a rapid preparation approach.
#
# 2. **Urgent Medical Indications**: In cases where a colonoscopy is needed urgently, such as in acute gastrointestinal bleeding or severe abdominal pain, rapid preparation may be necessary to expedite the procedure.
#
# 3. **Previous Inadequate Preparation**: If a patient has a history of inadequate bowel preparation during previous colonoscopies, a more aggressive or rapid preparation regimen might be considered.
#
# 4. **Chronic Constipation**: Patients with chronic constipation may require a more intensive preparation to ensure the colon is adequately cleansed.
#
# 5. **Shortened Time Frame**: In some clinical settings, there may be a need to perform the colonoscopy on short notice, requiring a rapid preparation protocol.
#
# 6. **Specific Medical Conditions**: Certain medical conditions, such as motility disorders or obstructive lesions, might necessitate a more rapid or intensive preparation.
#
# 7. **Medication Interactions**: Some medications can affect bowel motility or fluid balance, potentially impacting the effectiveness of standard bowel preparations.
#
# 8. **Dietary Factors**: A patient's diet leading up to the preparation can influence the effectiveness of the bowel cleansing process. A diet high in fiber or certain foods might require a more aggressive preparation.
#
# In any case, the choice of preparation method should be tailored to the individual patient, taking into account their medical history, current medications, and specific clinical circumstances. It is important to balance the need for rapid preparation with the patient's safety and comfort.
# Severe gastrointestinal (GI) bleeding can have several potential causes, and the involvement of both a gastroenterologist and a surgeon is often necessary to accurately diagnose and manage the condition. Here are some possible causes of severe GI bleeding:
#
# 1. **Peptic Ulcer Disease**: Ulcers in the stomach or duodenum can erode into blood vessels, causing significant bleeding.
#
# 2. **Diverticular Disease**: Diverticula in the colon can bleed profusely, often without warning.
#
# 3. **Angiodysplasia**: Abnormal blood vessels in the GI tract, often in the colon, can lead to bleeding.
#
# 4. **Inflammatory Bowel Disease (IBD)**: Conditions like Crohn's disease and ulcerative colitis can cause bleeding due to inflammation and ulceration of the intestinal lining.
#
# 5. **Colorectal Cancer**: Tumors in the colon or rectum can bleed, especially if they are ulcerated.
#
# 6. **Hemorrhoids**: Although usually causing minor bleeding, severe hemorrhoids can sometimes lead to significant blood loss.
#
# 7. **Gastrointestinal Tumors**: Besides colorectal cancer, other tumors in the GI tract can cause bleeding.
#
# 8. **Esophageal Varices**: Often related to liver cirrhosis, these are dilated veins in the esophagus that can rupture and bleed massively.
#
# 9. **Mallory-Weiss Tear**: A tear in the mucous membrane at the junction of the stomach and esophagus, often due to severe vomiting, can cause bleeding.
#
# 10. **Ischemic Colitis**: Reduced blood flow to the colon can cause inflammation and bleeding.
#
# 11. **Meckel's Diverticulum**: A congenital abnormality that can cause bleeding, especially in younger patients.
#
# 12. **Aortoenteric Fistula**: A rare but life-threatening condition where there is a connection between the aorta and the GI tract, leading to massive bleeding.
#
# The specific cause of the bleeding would need to be determined through a combination of patient history, physical examination, endoscopic evaluation (such as colonoscopy or upper endoscopy), imaging studies, and possibly surgical exploration. The management would depend on the underlying cause, the severity of the bleeding, and the patient's overall condition.
# When a distal lesion is found during a flexible sigmoidoscopy, it is often recommended to perform a complete colonoscopy to the cecum to ensure a thorough evaluation of the entire colon. This is because the presence of a distal lesion can be associated with additional lesions or pathology elsewhere in the colon. Here are some possible causes or conditions that might be considered:
#
# 1. **Colorectal Polyps**: These are growths on the inner lining of the colon, which can be benign (hyperplastic) or have the potential to become cancerous (adenomatous polyps). Finding a polyp in the distal colon may indicate the presence of additional polyps elsewhere.
#
# 2. **Colorectal Cancer**: A distal lesion could be an early sign of colorectal cancer. A complete colonoscopy is necessary to check for other potential cancerous lesions throughout the colon.
#
# 3. **Inflammatory Bowel Disease (IBD)**: Conditions such as ulcerative colitis or Crohn's disease can cause lesions in the colon. A full colonoscopy can help assess the extent and severity of the disease.
#
# 4. **Diverticular Disease**: Diverticulosis or diverticulitis can cause lesions or changes in the colon wall. A complete examination can help determine the extent of diverticular disease.
#
# 5. **Ischemic Colitis**: Reduced blood flow to the colon can cause ischemic changes, which may appear as lesions. A full colonoscopy can help assess the extent of ischemia.
#
# 6. **Infectious Colitis**: Infections can cause inflammation and lesions in the colon. A complete colonoscopy can help identify the extent and possibly the cause of the infection.
#
# 7. **Radiation Colitis**: Previous radiation therapy to the pelvic area can cause changes in the colon, which may appear as lesions.
#
# 8. **Lymphoid Hyperplasia**: This benign condition can cause nodular lesions in the colon, often requiring further evaluation to rule out other causes.
#
# A complete colonoscopy allows for a comprehensive assessment, biopsy of suspicious areas, and removal of polyps if necessary. It is crucial for accurate diagnosis and appropriate management of the underlying condition.

# %%
# convert each answer to a list of [{"head": head_text, "relation": relation_text, "tail": tail_text}] with each dict contain an event in the answer
# the conversion would be done by feeding to the openai chat API
answer_conversion_prompt_templage="""
Think step by step. You are a medical doctor, experienced in conducting colonoscopy and diagnosing colonic diseases. Based on the patient's information,
you have identified a possible cause of the patient's condition. Please provide a list of events that led to the diagnosis.
convert each answer to a list of [{"head": head_text, "relation": relation_text, "tail": tail_text}] with each dict contain an event in the answer
"""
message_template = [
    (
        "system",
        answer_conversion_prompt_templage
    ),
    (
        "user",
        "{answer}"
    )
]

def convert_answer_to_event(answer):
    message = [
        message_template[0],
        (
            message_template[1][0],
            message_template[1][1].replace("{answer}", answer)
        )
    ]
    event = llm.invoke(message)
    return event

# %%
# get all the events from the answers, convert them to a list of events
events = []
for answer in answers:
    event = convert_answer_to_event(answer.content)
    events.append(event)

# %%
print(events[0].content)
# Out:
# Here is a list of events that led to the diagnosis of colon cancer, formatted as requested:
#
# 1. [{"head": "Colonoscopy", "relation": "used for", "tail": "diagnosing colon cancer"}]
# 2. [{"head": "Colonoscopy", "relation": "procedure", "tail": "insertion of colonoscope to examine colon"}]
# 3. [{"head": "Suspicious areas found", "relation": "action", "tail": "biopsies taken for analysis"}]
# 4. [{"head": "Biopsy", "relation": "purpose", "tail": "examine tissue for cancer cells"}]
# 5. [{"head": "CT Colonography", "relation": "alternative", "tail": "non-invasive imaging test"}]
# 6. [{"head": "CT Colonography", "relation": "limitation", "tail": "may not detect small polyps effectively"}]
# 7. [{"head": "FOBT or FIT", "relation": "purpose", "tail": "check for hidden blood in stool"}]
# 8. [{"head": "FOBT or FIT", "relation": "limitation", "tail": "less definitive than colonoscopy"}]
# 9. [{"head": "Stool DNA Test", "relation": "purpose", "tail": "detect DNA markers for cancer"}]
# 10. [{"head": "Flexible Sigmoidoscopy", "relation": "scope", "tail": "examines rectum and lower colon"}]
# 11. [{"head": "Barium Enema", "relation": "procedure", "tail": "X-ray exam with barium sulfate contrast"}]
# 12. [{"head": "Barium Enema", "relation": "current use", "tail": "less common due to advanced imaging"}]
# 13. [{"head": "CT Scan or MRI", "relation": "purpose", "tail": "determine extent of cancer spread"}]
# 14. [{"head": "CEA Test", "relation": "purpose", "tail": "measure CEA protein level in blood"}]
# 15. [{"head": "Choice of test", "relation": "depends on", "tail": "patient's symptoms and risk factors"}]
# 16. [{"head": "Suspected colon cancer", "relation": "definitive approach", "tail": "colonoscopy with biopsy"}]

# %%
# Use regex to extract the events from the answer. format: [{"head": head_text, "relation": relation_text, "tail": tail_text}]
import re
def extract_events(event):
    # use regex to extract the events
    pattern = r"\{.*\}"
    events = re.findall(pattern, event)
    return events

# extract all events from the list of events
extracted_events = []
for event in events:
    extracted_event = extract_events(event.content)
    extracted_events.append(extracted_event)

# %%
print(len(extracted_events))
# Out:
# 149

# %%
extract_events(events[1].content)
# Out:
# ['{"head": "Neostigmine administration", "relation": "can cause", "tail": "Bradycardia"}',
#  '{"head": "Bradycardia", "relation": "is", "tail": "a decrease in heart rate"}',
#  '{"head": "Bradycardia", "relation": "is significant and potentially dangerous", "tail": "in patients with pre-existing cardiac conditions"}',
#  '{"head": "Neostigmine administration", "relation": "can induce", "tail": "Arrhythmias"}',
#  '{"head": "Arrhythmias", "relation": "include", "tail": "atrioventricular block or other conduction abnormalities"}',
#  '{"head": "Neostigmine administration", "relation": "can lead to", "tail": "Hypotension"}',
#  '{"head": "Hypotension", "relation": "is", "tail": "a drop in blood pressure"}',
#  '{"head": "Neostigmine", "relation": "is", "tail": "an acetylcholinesterase inhibitor"}',
#  '{"head": "Acetylcholinesterase inhibition", "relation": "increases", "tail": "acetylcholine levels"}',
#  '{"head": "Increased acetylcholine levels", "relation": "enhance", "tail": "parasympathetic activity"}',
#  '{"head": "Increased parasympathetic activity", "relation": "can affect", "tail": "heart rate and rhythm"}',
#  '{"head": "Severe bradycardia or arrhythmias", "relation": "can lead to", "tail": "cardiac arrest"}',
#  '{"head": "Cardiac arrest", "relation": "necessitates", "tail": "immediate intervention"}',
#  '{"head": "IV neostigmine administration", "relation": "requires", "tail": "continuous cardiac monitoring"}',
#  '{"head": "Continuous cardiac monitoring", "relation": "is essential to", "tail": "promptly identify and manage adverse events"}']

# %%
for event in events:
    print(event.content)
# Out:
# Here is a list of events that led to the diagnosis of colon cancer, formatted as requested:
#
# 1. [{"head": "Colonoscopy", "relation": "used for", "tail": "diagnosing colon cancer"}]
# 2. [{"head": "Colonoscopy", "relation": "procedure", "tail": "insertion of colonoscope to examine colon"}]
# 3. [{"head": "Suspicious areas found", "relation": "action", "tail": "biopsies taken for analysis"}]
# 4. [{"head": "Biopsy", "relation": "purpose", "tail": "examine tissue for cancer cells"}]
# 5. [{"head": "CT Colonography", "relation": "alternative", "tail": "non-invasive imaging test"}]
# 6. [{"head": "CT Colonography", "relation": "limitation", "tail": "may not detect small polyps effectively"}]
# 7. [{"head": "FOBT or FIT", "relation": "purpose", "tail": "check for hidden blood in stool"}]
# 8. [{"head": "FOBT or FIT", "relation": "limitation", "tail": "less definitive than colonoscopy"}]
# 9. [{"head": "Stool DNA Test", "relation": "purpose", "tail": "detect DNA markers for cancer"}]
# 10. [{"head": "Flexible Sigmoidoscopy", "relation": "scope", "tail": "examines rectum and lower colon"}]
# 11. [{"head": "Barium Enema", "relation": "procedure", "tail": "X-ray exam with barium sulfate contrast"}]
# 12. [{"head": "Barium Enema", "relation": "current use", "tail": "less common due to advanced imaging"}]
# 13. [{"head": "CT Scan or MRI", "relation": "purpose", "tail": "determine extent of cancer spread"}]
# 14. [{"head": "CEA Test", "relation": "purpose", "tail": "measure CEA protein level in blood"}]
# 15. [{"head": "Choice of test", "relation": "depends on", "tail": "patient's symptoms and risk factors"}]
# 16. [{"head": "Suspected colon cancer", "relation": "definitive approach", "tail": "colonoscopy with biopsy"}]
# 1. [{"head": "Neostigmine administration", "relation": "can cause", "tail": "Bradycardia"}]
# 2. [{"head": "Bradycardia", "relation": "is", "tail": "a decrease in heart rate"}]
# 3. [{"head": "Bradycardia", "relation": "is significant and potentially dangerous", "tail": "in patients with pre-existing cardiac conditions"}]
# 4. [{"head": "Neostigmine administration", "relation": "can induce", "tail": "Arrhythmias"}]
# 5. [{"head": "Arrhythmias", "relation": "include", "tail": "atrioventricular block or other conduction abnormalities"}]
# 6. [{"head": "Neostigmine administration", "relation": "can lead to", "tail": "Hypotension"}]
# 7. [{"head": "Hypotension", "relation": "is", "tail": "a drop in blood pressure"}]
# 8. [{"head": "Neostigmine", "relation": "is", "tail": "an acetylcholinesterase inhibitor"}]
# 9. [{"head": "Acetylcholinesterase inhibition", "relation": "increases", "tail": "acetylcholine levels"}]
# 10. [{"head": "Increased acetylcholine levels", "relation": "enhance", "tail": "parasympathetic activity"}]
# 11. [{"head": "Increased parasympathetic activity", "relation": "can affect", "tail": "heart rate and rhythm"}]
# 12. [{"head": "Severe bradycardia or arrhythmias", "relation": "can lead to", "tail": "cardiac arrest"}]
# 13. [{"head": "Cardiac arrest", "relation": "necessitates", "tail": "immediate intervention"}]
# 14. [{"head": "IV neostigmine administration", "relation": "requires", "tail": "continuous cardiac monitoring"}]
# 15. [{"head": "Continuous cardiac monitoring", "relation": "is essential to", "tail": "promptly identify and manage adverse events"}]
# 1. [{"head": "Severe gastrointestinal (GI) bleeding", "relation": "requires", "tail": "immediate medical attention"}]
# 2. [{"head": "Severe GI bleeding", "relation": "necessitates", "tail": "admission to an intensive care unit (ICU)"}]
# 3. [{"head": "Upper GI Bleeding", "relation": "possible cause", "tail": "Peptic Ulcer Disease"}]
# 4. [{"head": "Upper GI Bleeding", "relation": "possible cause", "tail": "Esophageal Varices"}]
# 5. [{"head": "Upper GI Bleeding", "relation": "possible cause", "tail": "Gastritis or Esophagitis"}]
# 6. [{"head": "Upper GI Bleeding", "relation": "possible cause", "tail": "Mallory-Weiss Tear"}]
# 7. [{"head": "Upper GI Bleeding", "relation": "possible cause", "tail": "Gastric or Esophageal Cancer"}]
# 8. [{"head": "Lower GI Bleeding", "relation": "possible cause", "tail": "Diverticular Disease"}]
# 9. [{"head": "Lower GI Bleeding", "relation": "possible cause", "tail": "Angiodysplasia"}]
# 10. [{"head": "Lower GI Bleeding", "relation": "possible cause", "tail": "Colorectal Cancer"}]
# 11. [{"head": "Lower GI Bleeding", "relation": "possible cause", "tail": "Inflammatory Bowel Disease (IBD)"}]
# 12. [{"head": "Lower GI Bleeding", "relation": "possible cause", "tail": "Hemorrhoids or Anal Fissures"}]
# 13. [{"head": "Lower GI Bleeding", "relation": "possible cause", "tail": "Ischemic Colitis"}]
# 14. [{"head": "Other Causes", "relation": "possible cause", "tail": "Coagulopathy"}]
# 15. [{"head": "Other Causes", "relation": "possible cause", "tail": "Use of Anticoagulants or Antiplatelet Drugs"}]
# 16. [{"head": "Other Causes", "relation": "possible cause", "tail": "Aortoenteric Fistula"}]
# 17. [{"head": "Specific cause of GI bleeding", "relation": "determined through", "tail": "patient history, physical examination, laboratory tests, imaging studies, and endoscopic procedures"}]
# 18. [{"head": "Management of severe GI bleeding", "relation": "includes", "tail": "immediate stabilization, fluid resuscitation, and blood transfusions"}]
# 1. [{"head": "Massive GI bleeding", "relation": "requires", "tail": "prompt diagnosis and management"}]
#
# 2. [{"head": "Lower GI tract", "relation": "potential causes", "tail": "Diverticular Disease"}]
#
# 3. [{"head": "Diverticular Disease", "relation": "can lead to", "tail": "significant bleeding if a diverticulum ruptures"}]
#
# 4. [{"head": "Lower GI tract", "relation": "potential causes", "tail": "Angiodysplasia"}]
#
# 5. [{"head": "Angiodysplasia", "relation": "can cause", "tail": "significant bleeding, often seen in older adults"}]
#
# 6. [{"head": "Lower GI tract", "relation": "potential causes", "tail": "Colorectal Cancer"}]
#
# 7. [{"head": "Colorectal Cancer", "relation": "can lead to", "tail": "bleeding by eroding into blood vessels"}]
#
# 8. [{"head": "Lower GI tract", "relation": "potential causes", "tail": "Inflammatory Bowel Disease (IBD)"}]
#
# 9. [{"head": "Inflammatory Bowel Disease (IBD)", "relation": "can cause", "tail": "severe inflammation and ulceration, leading to bleeding"}]
#
# 10. [{"head": "Lower GI tract", "relation": "potential causes", "tail": "Ischemic Colitis"}]
#
# 11. [{"head": "Ischemic Colitis", "relation": "can cause", "tail": "tissue damage and bleeding due to reduced blood flow"}]
#
# 12. [{"head": "Lower GI tract", "relation": "potential causes", "tail": "Hemorrhoids"}]
#
# 13. [{"head": "Hemorrhoids", "relation": "can occasionally lead to", "tail": "significant blood loss if large or ruptured"}]
#
# 14. [{"head": "Lower GI tract", "relation": "potential causes", "tail": "Post-Polypectomy Bleeding"}]
#
# 15. [{"head": "Post-Polypectomy Bleeding", "relation": "can result in", "tail": "delayed bleeding after polyp removal"}]
#
# 16. [{"head": "Lower GI tract", "relation": "potential causes", "tail": "Radiation Colitis"}]
#
# 17. [{"head": "Radiation Colitis", "relation": "can cause", "tail": "damage to the colon, leading to bleeding"}]
#
# 18. [{"head": "Lower GI tract", "relation": "potential causes", "tail": "Infectious Colitis"}]
#
# 19. [{"head": "Infectious Colitis", "relation": "can lead to", "tail": "significant bleeding due to severe infections"}]
#
# 20. [{"head": "Lower GI tract", "relation": "potential causes", "tail": "Meckel's Diverticulum"}]
#
# 21. [{"head": "Meckel's Diverticulum", "relation": "can sometimes be", "tail": "a source of lower GI bleeding"}]
#
# 22. [{"head": "Massive GI bleeding", "relation": "requires", "tail": "stabilization with fluid resuscitation and blood transfusions"}]
#
# 23. [{"head": "Massive GI bleeding", "relation": "requires", "tail": "identification of bleeding source through diagnostic procedures"}]
# 1. [{"head": "Colonoscopy", "relation": "requires", "tail": "thorough cleansing of the colon"}]
# 2. [{"head": "Inadequate bowel preparation", "relation": "can lead to", "tail": "obscured lesions, polyps, or other abnormalities"}]
# 3. [{"head": "Obscured lesions", "relation": "can result in", "tail": "missed diagnoses"}]
# 4. [{"head": "Dietary Restrictions", "relation": "involves", "tail": "clear liquid diet for 24 hours before procedure"}]
# 5. [{"head": "Clear liquid diet", "relation": "includes", "tail": "clear broths, tea, coffee without milk or cream, clear juices, and gelatin"}]
# 6. [{"head": "Laxatives", "relation": "prescribed as", "tail": "bowel preparation solution"}]
# 7. [{"head": "Bowel preparation solution", "relation": "helps to", "tail": "clear the colon"}]
# 8. [{"head": "Hydration", "relation": "important for", "tail": "preventing dehydration during preparation"}]
# 9. [{"head": "Laxatives", "relation": "can cause", "tail": "significant fluid loss"}]
# 10. [{"head": "Timing", "relation": "crucial for", "tail": "effective bowel preparation"}]
# 11. [{"head": "Split-dose regimens", "relation": "recommended for", "tail": "better cleansing"}]
# 12. [{"head": "Improper cleansing", "relation": "may require", "tail": "rescheduling of procedure or less reliable results"}]
# 13. [{"head": "Proper preparation", "relation": "essential for", "tail": "detection of polyps, colorectal cancer, inflammatory bowel disease, and other colonic diseases"}]
# 1. [{"head": "Patient", "relation": "experiencing symptoms", "tail": "abdominal pain, bleeding, or changes in bowel habits"}]
# 2. [{"head": "Endoscopy", "relation": "purpose", "tail": "diagnose potential causes of symptoms"}]
# 3. [{"head": "Potential cause", "relation": "example", "tail": "Gastroesophageal Reflux Disease (GERD)"}]
# 4. [{"head": "Potential cause", "relation": "example", "tail": "Peptic Ulcers"}]
# 5. [{"head": "Potential cause", "relation": "example", "tail": "Gastritis"}]
# 6. [{"head": "Potential cause", "relation": "example", "tail": "Esophagitis"}]
# 7. [{"head": "Potential cause", "relation": "example", "tail": "Barrett's Esophagus"}]
# 8. [{"head": "Potential cause", "relation": "example", "tail": "Hiatal Hernia"}]
# 9. [{"head": "Potential cause", "relation": "example", "tail": "Celiac Disease"}]
# 10. [{"head": "Potential cause", "relation": "example", "tail": "Esophageal or Gastric Cancer"}]
# 11. [{"head": "Potential cause", "relation": "example", "tail": "Esophageal Strictures or Rings"}]
# 12. [{"head": "Potential cause", "relation": "example", "tail": "Infections such as Helicobacter pylori"}]
# 13. [{"head": "Potential cause", "relation": "example", "tail": "Inflammatory Bowel Disease (IBD)"}]
# 14. [{"head": "Endoscopy", "relation": "function", "tail": "visualize upper gastrointestinal tract"}]
# 15. [{"head": "Endoscopy", "relation": "function", "tail": "allow for biopsies to aid diagnosis"}]
# 1. [{"head": "Low-fiber diet", "relation": "associated with", "tail": "development of diverticulosis"}]
# 2. [{"head": "Diet high in refined carbohydrates", "relation": "leads to", "tail": "constipation and increased colonic pressure"}]
# 3. [{"head": "Increased colonic pressure", "relation": "contributes to", "tail": "formation of diverticula"}]
# 4. [{"head": "Age", "relation": "increases", "tail": "prevalence of diverticulosis"}]
# 5. [{"head": "Individuals over age 50", "relation": "more common in", "tail": "diverticulosis"}]
# 6. [{"head": "Genetic predisposition", "relation": "may cause", "tail": "diverticulosis running in families"}]
# 7. [{"head": "Obesity", "relation": "associated with", "tail": "increased risk of diverticulosis"}]
# 8. [{"head": "Lack of physical activity", "relation": "associated with", "tail": "increased risk of diverticulosis"}]
# 9. [{"head": "Smoking", "relation": "associated with", "tail": "increased risk of diverticulosis"}]
# 10. [{"head": "Altered colonic motility", "relation": "contributes to", "tail": "formation of diverticula"}]
# 11. [{"head": "Increased intraluminal pressure", "relation": "contributes to", "tail": "formation of diverticula"}]
# 12. [{"head": "Connective tissue changes", "relation": "make colon susceptible to", "tail": "forming diverticula"}]
# 13. [{"head": "Aging", "relation": "related to", "tail": "connective tissue changes in colon wall"}]
# 14. [{"head": "Asymptomatic diverticulosis", "relation": "does not require", "tail": "treatment"}]
# 15. [{"head": "Patients advised", "relation": "to increase", "tail": "dietary fiber intake"}]
# 16. [{"head": "Increased dietary fiber", "relation": "helps prevent", "tail": "complications like diverticulitis or diverticular bleeding"}]
# 17. [{"head": "Regular follow-up", "relation": "recommended for", "tail": "ensuring condition remains asymptomatic"}]
# 1. [{"head": "Urgency of the Procedure", "relation": "requires", "tail": "rapid colonic preparation due to symptoms like significant gastrointestinal bleeding"}]
# 2. [{"head": "Inadequate Initial Preparation", "relation": "leads to", "tail": "need for rapid preparation to repeat colonoscopy"}]
# 3. [{"head": "Patient Non-Compliance", "relation": "necessitates", "tail": "rapid preparation to ensure colon is cleansed"}]
# 4. [{"head": "Medical Conditions", "relation": "require", "tail": "more aggressive or rapid preparation methods"}]
# 5. [{"head": "Scheduling Constraints", "relation": "necessitate", "tail": "rapid preparation to fit procedure into timeframe"}]
# 6. [{"head": "Previous Poor Preparation History", "relation": "makes patient candidate for", "tail": "more rapid or intensive preparation regimen"}]
# 7. [{"head": "Dietary Factors", "relation": "result in", "tail": "need for rapid preparation due to difficult-to-clear foods"}]
# 8. [{"head": "Medication Interference", "relation": "requires", "tail": "adjustments or more rapid preparation methods"}]
# 1. [{"head": "Severe gastrointestinal (GI) bleeding", "relation": "can be caused by", "tail": "Peptic Ulcer Disease"}]
# 2. [{"head": "Peptic Ulcer Disease", "relation": "leads to", "tail": "erosion into blood vessels"}]
# 3. [{"head": "Erosion into blood vessels", "relation": "results in", "tail": "significant bleeding"}]
# 4. [{"head": "Severe gastrointestinal (GI) bleeding", "relation": "can be caused by", "tail": "Esophageal Varices"}]
# 5. [{"head": "Esophageal Varices", "relation": "associated with", "tail": "liver cirrhosis"}]
# 6. [{"head": "Dilated veins in the esophagus", "relation": "can rupture and cause", "tail": "massive bleeding"}]
# 7. [{"head": "Severe gastrointestinal (GI) bleeding", "relation": "can be caused by", "tail": "Diverticular Disease"}]
# 8. [{"head": "Diverticula in the colon", "relation": "can lead to", "tail": "profuse bleeding"}]
# 9. [{"head": "Profuse bleeding", "relation": "often presents as", "tail": "painless rectal bleeding"}]
# 10. [{"head": "Severe gastrointestinal (GI) bleeding", "relation": "can be caused by", "tail": "Angiodysplasia"}]
# 11. [{"head": "Abnormal blood vessels in the GI tract", "relation": "can cause", "tail": "bleeding"}]
# 12. [{"head": "Severe gastrointestinal (GI) bleeding", "relation": "can be caused by", "tail": "Inflammatory Bowel Disease (IBD)"}]
# 13. [{"head": "Inflammatory Bowel Disease (IBD)", "relation": "includes", "tail": "Crohn's disease and ulcerative colitis"}]
# 14. [{"head": "Inflammation and ulceration of the intestinal lining", "relation": "can cause", "tail": "bleeding"}]
# 15. [{"head": "Severe gastrointestinal (GI) bleeding", "relation": "can be caused by", "tail": "Colorectal Cancer"}]
# 16. [{"head": "Tumors in the colon or rectum", "relation": "can lead to", "tail": "significant bleeding"}]
# 17. [{"head": "Severe gastrointestinal (GI) bleeding", "relation": "can be caused by", "tail": "Gastrointestinal Tumors"}]
# 18. [{"head": "Tumors in the GI tract", "relation": "can be", "tail": "benign or malignant"}]
# 19. [{"head": "Severe gastrointestinal (GI) bleeding", "relation": "can be caused by", "tail": "Mallory-Weiss Tear"}]
# 20. [{"head": "Tear in the mucous membrane", "relation": "often due to", "tail": "severe vomiting"}]
# 21. [{"head": "Severe vomiting", "relation": "can cause", "tail": "bleeding"}]
# 22. [{"head": "Severe gastrointestinal (GI) bleeding", "relation": "can be caused by", "tail": "Hemorrhoids"}]
# 23. [{"head": "Severe cases of hemorrhoids", "relation": "can lead to", "tail": "significant blood loss"}]
# 24. [{"head": "Severe gastrointestinal (GI) bleeding", "relation": "can be caused by", "tail": "Ischemic Colitis"}]
# 25. [{"head": "Reduced blood flow to the colon", "relation": "can cause", "tail": "inflammation and bleeding"}]
# 26. [{"head": "Severe gastrointestinal (GI) bleeding", "relation": "can be caused by", "tail": "Meckel's Diverticulum"}]
# 27. [{"head": "Meckel's Diverticulum", "relation": "is a", "tail": "congenital abnormality"}]
# 28. [{"head": "Congenital abnormality", "relation": "can cause", "tail": "bleeding, particularly in younger patients"}]
# 29. [{"head": "Severe gastrointestinal (GI) bleeding", "relation": "can be caused by", "tail": "Aortoenteric Fistula"}]
# 30. [{"head": "Aortoenteric Fistula", "relation": "is a", "tail": "rare but life-threatening condition"}]
# 31. [{"head": "Connection between the aorta and the GI tract", "relation": "often follows", "tail": "aortic surgery"}]
# 32. [{"head": "Specific cause of bleeding", "relation": "guides", "tail": "treatment approach"}]
# 33. [{"head": "Gastroenterologist", "relation": "performs", "tail": "diagnostic procedures like endoscopy or colonoscopy"}]
# 34. [{"head": "Surgeon", "relation": "involved in", "tail": "cases where surgical intervention is necessary"}]
# 1. [{"head": "Distal lesion found", "relation": "leads to", "tail": "Recommendation for complete colonoscopy"}]
#
# 2. [{"head": "Presence of distal lesion", "relation": "indicates", "tail": "Possibility of additional lesions in colon"}]
#
# 3. [{"head": "Colorectal Polyps", "relation": "suggests", "tail": "Additional polyps in proximal colon"}]
#
# 4. [{"head": "Polyps", "relation": "potential to become", "tail": "Cancerous"}]
#
# 5. [{"head": "Colorectal Cancer", "relation": "indicated by", "tail": "Distal lesion"}]
#
# 6. [{"head": "Complete colonoscopy", "relation": "necessary for", "tail": "Assessing extent of colorectal cancer"}]
#
# 7. [{"head": "Inflammatory Bowel Disease (IBD)", "relation": "causes", "tail": "Lesions in colon"}]
#
# 8. [{"head": "Full colonoscopy", "relation": "helps in", "tail": "Assessing extent and severity of IBD"}]
#
# 9. [{"head": "Diverticular Disease", "relation": "causes", "tail": "Lesions or changes in colon"}]
#
# 10. [{"head": "Complete colonoscopy", "relation": "evaluates", "tail": "Extent of diverticular disease"}]
#
# 11. [{"head": "Ischemic Colitis", "relation": "causes", "tail": "Lesions due to reduced blood flow"}]
#
# 12. [{"head": "Full colonoscopy", "relation": "determines", "tail": "Extent of ischemic damage"}]
#
# 13. [{"head": "Infectious Colitis", "relation": "causes", "tail": "Lesions or inflammation in colon"}]
#
# 14. [{"head": "Complete colonoscopy", "relation": "identifies", "tail": "Extent of infection and inflammation"}]
#
# 15. [{"head": "Hereditary Syndromes", "relation": "cause", "tail": "Multiple polyps or lesions throughout colon"}]
#
# 16. [{"head": "Non-neoplastic Lesions", "relation": "may be", "tail": "Present and require evaluation"}]
#
# 17. [{"head": "Complete colonoscopy", "relation": "essential for", "tail": "Ruling out or confirming additional pathology"}]
#
# 18. [{"head": "Complete colonoscopy", "relation": "assesses", "tail": "Extent of disease"}]
#
# 19. [{"head": "Complete colonoscopy", "relation": "guides", "tail": "Appropriate management and treatment"}]
# 1. [{"head": "Chronic Straining", "relation": "contributes to", "tail": "mucosal prolapse"}]
# 2. [{"head": "Weakness of Pelvic Floor Muscles", "relation": "increases risk of", "tail": "mucosal prolapse"}]
# 3. [{"head": "Aging", "relation": "makes more likely", "tail": "mucosal prolapse"}]
# 4. [{"head": "Previous Surgery or Trauma", "relation": "potentially leads to", "tail": "mucosal prolapse"}]
# 5. [{"head": "Chronic Diarrhea", "relation": "contributes to", "tail": "mucosal prolapse"}]
# 6. [{"head": "Genetic Predisposition", "relation": "makes more susceptible to", "tail": "mucosal prolapse"}]
# 7. [{"head": "Obesity", "relation": "contributes to", "tail": "mucosal prolapse"}]
# 8. [{"head": "Neurological Disorders", "relation": "increases risk of", "tail": "mucosal prolapse"}]
# 9. [{"head": "Rectal Intussusception", "relation": "associated with", "tail": "mucosal prolapse"}]
# 10. [{"head": "Inflammatory Bowel Disease (IBD)", "relation": "potentially leads to", "tail": "mucosal prolapse"}]
# 1. [{"head": "Numerous colon polyps", "relation": "associated with", "tail": "increased risk of colorectal cancer"}]
#
# 2. [{"head": "Familial Adenomatous Polyposis (FAP)", "relation": "characterized by", "tail": "hundreds to thousands of adenomatous polyps"}]
#
# 3. [{"head": "FAP", "relation": "leads to", "tail": "colorectal cancer if not managed"}]
#
# 4. [{"head": "Lynch Syndrome", "relation": "involves", "tail": "fewer polyps than FAP"}]
#
# 5. [{"head": "Lynch Syndrome", "relation": "increases risk of", "tail": "colorectal cancer and other cancers"}]
#
# 6. [{"head": "MUTYH-Associated Polyposis (MAP)", "relation": "caused by", "tail": "mutations in the MUTYH gene"}]
#
# 7. [{"head": "MAP", "relation": "leads to", "tail": "multiple adenomatous polyps and increased risk of colorectal cancer"}]
#
# 8. [{"head": "Peutz-Jeghers Syndrome", "relation": "characterized by", "tail": "hamartomatous polyps in the gastrointestinal tract"}]
#
# 9. [{"head": "Peutz-Jeghers Syndrome", "relation": "increases risk of", "tail": "various cancers, including colorectal cancer"}]
#
# 10. [{"head": "Juvenile Polyposis Syndrome", "relation": "involves", "tail": "multiple juvenile polyps in the gastrointestinal tract"}]
#
# 11. [{"head": "Juvenile Polyposis Syndrome", "relation": "increases risk of", "tail": "colorectal cancer"}]
#
# 12. [{"head": "Serrated Polyposis Syndrome", "relation": "characterized by", "tail": "multiple serrated polyps in the colon"}]
#
# 13. [{"head": "Serrated Polyposis Syndrome", "relation": "increases risk of", "tail": "colorectal cancer"}]
#
# 14. [{"head": "Hyperplastic Polyposis Syndrome", "relation": "associated with", "tail": "increased risk of colorectal cancer despite benign nature"}]
#
# 15. [{"head": "Chronic Inflammatory Conditions", "relation": "includes", "tail": "inflammatory bowel disease (IBD)"}]
#
# 16. [{"head": "IBD", "relation": "leads to", "tail": "development of dysplastic polyps"}]
#
# 17. [{"head": "IBD", "relation": "increases risk of", "tail": "colorectal cancer over time"}]
#
# 18. [{"head": "Patients with numerous colon polyps", "relation": "require", "tail": "thorough family history, genetic testing, and regular surveillance"}]
# 1. [{"head": "Patient", "relation": "has", "tail": "biallelic mutations in the MUTYH gene"}]
# 2. [{"head": "Biallelic mutations in the MUTYH gene", "relation": "cause", "tail": "development of multiple adenomatous polyps in the colon"}]
# 3. [{"head": "MUTYH gene", "relation": "involved in", "tail": "base excision repair"}]
# 4. [{"head": "Mutations in MUTYH gene", "relation": "lead to", "tail": "accumulation of DNA errors"}]
# 5. [{"head": "DNA errors", "relation": "result in", "tail": "formation of adenomas and progression to colorectal cancer"}]
# 6. [{"head": "Environmental factors", "relation": "influence", "tail": "number and growth of polyps"}]
# 7. [{"head": "Family history", "relation": "may be present if", "tail": "both parents are carriers of a MUTYH mutation"}]
# 8. [{"head": "Condition", "relation": "manifests at", "tail": "various ages, often in adulthood"}]
# 9. [{"head": "Primary cause of condition", "relation": "is", "tail": "biallelic mutations in the MUTYH gene"}]
# 1. [{"head": "Diverticulosis", "relation": "can lead to", "tail": "formation of diverticula in the colon wall"}]
#
# 2. [{"head": "Diverticulosis", "relation": "is often", "tail": "asymptomatic"}]
#
# 3. [{"head": "Diverticulitis", "relation": "occurs when", "tail": "diverticula become inflamed or infected"}]
#
# 4. [{"head": "Diverticulitis", "relation": "causes", "tail": "abdominal pain, fever, nausea, changes in bowel habits"}]
#
# 5. [{"head": "Diverticular Bleeding", "relation": "occurs when", "tail": "blood vessel near diverticulum ruptures"}]
#
# 6. [{"head": "Diverticular Bleeding", "relation": "leads to", "tail": "painless rectal bleeding"}]
#
# 7. [{"head": "Colonic Spasm", "relation": "can be caused by", "tail": "presence of diverticula"}]
#
# 8. [{"head": "Colonic Spasm", "relation": "results in", "tail": "abdominal pain or discomfort"}]
#
# 9. [{"head": "Irritation or Pressure", "relation": "caused by", "tail": "increased pressure within the colon"}]
#
# 10. [{"head": "Irritation or Pressure", "relation": "leads to", "tail": "pain in diverticula"}]
#
# 11. [{"head": "Complications of Diverticulitis", "relation": "include", "tail": "abscess formation, perforation, fistula, bowel obstruction"}]
#
# 12. [{"head": "Complications of Diverticulitis", "relation": "cause", "tail": "significant pain and symptoms"}]
#
# 13. [{"head": "Ischemia", "relation": "caused by", "tail": "reduced blood flow to diverticula"}]
#
# 14. [{"head": "Ischemia", "relation": "can lead to", "tail": "pain and potentially bleeding"}]
#
# 15. [{"head": "Patient with diverticulosis", "relation": "presents with", "tail": "pain or bleeding"}]
#
# 16. [{"head": "Evaluation of symptoms", "relation": "involves", "tail": "imaging studies, colonoscopy, laboratory tests"}]
# 1. [{"head": "Ulcerative Colitis", "relation": "characterized by", "tail": "inflammation and ulceration of the innermost lining of the colon"}]
#
# 2. [{"head": "Ulcerative Colitis", "relation": "associated with", "tail": "increased risk of developing colorectal cancer"}]
#
# 3. [{"head": "Duration of Disease", "relation": "increases risk of", "tail": "colon cancer in ulcerative colitis patients"}]
#
# 4. [{"head": "Extent of Colonic Involvement", "relation": "higher risk in", "tail": "pancolitis compared to left-sided colitis or proctitis"}]
#
# 5. [{"head": "Severity of Inflammation", "relation": "associated with", "tail": "higher risk of dysplasia and cancer development"}]
#
# 6. [{"head": "Family History", "relation": "increases risk of", "tail": "colorectal cancer in ulcerative colitis patients"}]
#
# 7. [{"head": "Primary Sclerosing Cholangitis (PSC)", "relation": "increases risk of", "tail": "colorectal cancer in ulcerative colitis patients"}]
#
# 8. [{"head": "Dysplasia", "relation": "strong risk factor for", "tail": "development of colorectal cancer"}]
#
# 9. [{"head": "Regular Surveillance Colonoscopy", "relation": "recommended for", "tail": "monitoring dysplasia and early signs of cancer in ulcerative colitis patients"}]
#
# 10. [{"head": "Frequency of Surveillance Colonoscopy", "relation": "determined by", "tail": "duration and extent of disease, and presence of additional risk factors"}]
# 1. [{"head": "Peutz-Jeghers syndrome (PJS)", "relation": "characterized by", "tail": "development of distinctive pigmented spots on the skin and mucous membranes"}]
# 2. [{"head": "Peutz-Jeghers syndrome (PJS)", "relation": "characterized by", "tail": "growth of hamartomatous polyps in the gastrointestinal tract"}]
# 3. [{"head": "Individuals with PJS", "relation": "increased risk for", "tail": "various types of cancer"}]
# 4. [{"head": "Individuals with PJS", "relation": "increased risk for", "tail": "gastrointestinal cancers (colorectal, stomach, pancreatic)"}]
# 5. [{"head": "Individuals with PJS", "relation": "increased risk for", "tail": "extraintestinal cancers (breast, ovarian, testicular)"}]
# 6. [{"head": "Peutz-Jeghers syndrome", "relation": "potential increased risk for", "tail": "lung cancer"}]
# 7. [{"head": "Risk for lung cancer in PJS", "relation": "described as", "tail": "not well-documented or prominent"}]
# 8. [{"head": "Individuals with PJS", "relation": "recommended to undergo", "tail": "regular surveillance and screening for various cancers"}]
# 9. [{"head": "Regular surveillance and screening", "relation": "purpose", "tail": "manage and mitigate cancer risks in PJS"}]
# 1. [{"head": "Presence of polyps in 50% of patients by age 15", "relation": "suggests", "tail": "hereditary polyposis syndrome"}]
# 2. [{"head": "Hereditary polyposis syndrome", "relation": "most likely condition", "tail": "Familial Adenomatous Polyposis (FAP)"}]
# 3. [{"head": "FAP", "relation": "characterized by", "tail": "development of hundreds to thousands of adenomatous polyps"}]
# 4. [{"head": "Adenomatous polyps", "relation": "location", "tail": "colon and rectum"}]
# 5. [{"head": "FAP", "relation": "onset", "tail": "typically beginning in adolescence"}]
# 6. [{"head": "Untreated FAP", "relation": "risk", "tail": "nearly 100% progression to colorectal cancer"}]
# 7. [{"head": "Colorectal cancer", "relation": "age of risk", "tail": "often by age 40"}]
# 8. [{"head": "Attenuated Familial Adenomatous Polyposis (AFAP)", "relation": "characterized by", "tail": "fewer polyps and later onset of colorectal cancer"}]
# 9. [{"head": "MUTYH-Associated Polyposis (MAP)", "relation": "caused by", "tail": "mutations in the MUTYH gene"}]
# 10. [{"head": "MAP", "relation": "characterized by", "tail": "multiple adenomatous polyps and increased risk of colorectal cancer"}]
# 11. [{"head": "Peutz-Jeghers Syndrome", "relation": "characterized by", "tail": "hamartomatous polyps and mucocutaneous pigmentation"}]
# 12. [{"head": "Peutz-Jeghers Syndrome", "relation": "polyp type", "tail": "typically not adenomatous"}]
# 13. [{"head": "Juvenile Polyposis Syndrome", "relation": "characterized by", "tail": "multiple juvenile polyps and increased risk of gastrointestinal cancers"}]
# 14. [{"head": "Juvenile Polyps", "relation": "type", "tail": "hamartomatous"}]
# 15. [{"head": "Serrated Polyposis Syndrome", "relation": "characterized by", "tail": "multiple serrated polyps in the colon"}]
# 16. [{"head": "Serrated Polyps", "relation": "risk", "tail": "increased risk of colorectal cancer"}]
# 17. [{"head": "Early age of onset and high prevalence of polyps", "relation": "recommendation", "tail": "genetic evaluation and counseling"}]
# 18. [{"head": "Genetic evaluation and counseling", "relation": "purpose", "tail": "confirm diagnosis and guide management"}]
# 19. [{"head": "Management", "relation": "includes", "tail": "surveillance and potential prophylactic surgery"}]
# 1. [{"head": "Symptoms", "relation": "can include", "tail": "changes in bowel habits"}]
# 2. [{"head": "Colorectal Cancer", "relation": "symptoms include", "tail": "changes in bowel habits, rectal bleeding, persistent abdominal discomfort, weakness or fatigue, unexplained weight loss"}]
# 3. [{"head": "Irritable Bowel Syndrome (IBS)", "relation": "causes", "tail": "cramping, abdominal pain, bloating, gas, diarrhea or constipation"}]
# 4. [{"head": "Inflammatory Bowel Disease (IBD)", "relation": "includes", "tail": "Crohn's disease and ulcerative colitis"}]
# 5. [{"head": "Inflammatory Bowel Disease (IBD)", "relation": "causes", "tail": "chronic inflammation of the gastrointestinal tract"}]
# 6. [{"head": "Inflammatory Bowel Disease (IBD)", "relation": "symptoms include", "tail": "diarrhea, abdominal pain, changes in bowel habits"}]
# 7. [{"head": "Diverticulitis", "relation": "occurs when", "tail": "small, bulging pouches in the digestive tract become inflamed or infected"}]
# 8. [{"head": "Diverticulitis", "relation": "symptoms include", "tail": "abdominal pain, fever, changes in bowel habits"}]
# 9. [{"head": "Infections", "relation": "can cause", "tail": "changes in bowel habits, diarrhea, abdominal pain, fever"}]
# 10. [{"head": "Celiac Disease", "relation": "is", "tail": "an autoimmune disorder where ingestion of gluten leads to damage in the small intestine"}]
# 11. [{"head": "Celiac Disease", "relation": "symptoms include", "tail": "diarrhea, fatigue, weight loss"}]
# 12. [{"head": "Colonic Polyps", "relation": "can cause", "tail": "changes in bowel habits or bleeding"}]
# 13. [{"head": "Medications", "relation": "can alter", "tail": "bowel habits"}]
# 14. [{"head": "Dietary Factors", "relation": "can affect", "tail": "bowel habits"}]
# 15. [{"head": "Stress and Anxiety", "relation": "can impact", "tail": "bowel habits"}]
# 16. [{"head": "Evaluation", "relation": "includes", "tail": "detailed medical history, physical examination, diagnostic tests such as a colonoscopy"}]
# 17. [{"head": "Evaluation", "relation": "necessary to determine", "tail": "exact cause of symptoms"}]
# 1. [{"head": "Symptoms of irritation and bleeding", "relation": "could be caused by", "tail": "Hemorrhoids"}]
#
# 2. [{"head": "Symptoms of irritation and bleeding", "relation": "could be caused by", "tail": "Anal Fissures"}]
#
# 3. [{"head": "Symptoms of irritation and bleeding", "relation": "could be caused by", "tail": "Colorectal Polyps"}]
#
# 4. [{"head": "Symptoms of irritation and bleeding", "relation": "could be caused by", "tail": "Inflammatory Bowel Disease (IBD)"}]
#
# 5. [{"head": "Symptoms of irritation and bleeding", "relation": "could be caused by", "tail": "Diverticular Disease"}]
#
# 6. [{"head": "Symptoms of irritation and bleeding", "relation": "could be caused by", "tail": "Colorectal Cancer"}]
#
# 7. [{"head": "Symptoms of irritation and bleeding", "relation": "could be caused by", "tail": "Infections"}]
#
# 8. [{"head": "Symptoms of irritation and bleeding", "relation": "could be caused by", "tail": "Radiation Proctitis"}]
#
# 9. [{"head": "Determining the exact cause of symptoms", "relation": "requires", "tail": "Thorough clinical evaluation"}]
#
# 10. [{"head": "Thorough clinical evaluation", "relation": "includes", "tail": "Detailed history, physical examination, and possibly a colonoscopy"}]
# 1. [{"head": "Blood in the stool", "relation": "can be a symptom of", "tail": "Colorectal Cancer"}]
# 2. [{"head": "Blood in the stool", "relation": "can be a symptom of", "tail": "Hemorrhoids"}]
# 3. [{"head": "Blood in the stool", "relation": "can be a symptom of", "tail": "Anal Fissures"}]
# 4. [{"head": "Blood in the stool", "relation": "can be a symptom of", "tail": "Diverticular Disease"}]
# 5. [{"head": "Blood in the stool", "relation": "can be a symptom of", "tail": "Inflammatory Bowel Disease (IBD)"}]
# 6. [{"head": "Blood in the stool", "relation": "can be a symptom of", "tail": "Gastrointestinal Infections"}]
# 7. [{"head": "Blood in the stool", "relation": "can be a symptom of", "tail": "Angiodysplasia"}]
# 8. [{"head": "Blood in the stool", "relation": "can be a symptom of", "tail": "Polyps"}]
# 9. [{"head": "Blood in the stool", "relation": "can be a symptom of", "tail": "Ischemic Colitis"}]
# 10. [{"head": "Blood in the stool", "relation": "can be a symptom of", "tail": "Colonic Arteriovenous Malformations (AVMs)"}]
# 1. [{"head": "Patient", "relation": "experiencing symptoms", "tail": "related to hemorrhoids"}]
# 2. [{"head": "Hemorrhoids", "relation": "defined as", "tail": "swollen veins in the lower rectum or anus"}]
# 3. [{"head": "Hemorrhoids", "relation": "can be", "tail": "internal or external"}]
# 4. [{"head": "Patient", "relation": "experiencing", "tail": "discomfort or pain"}]
# 5. [{"head": "Discomfort or pain", "relation": "common with", "tail": "hemorrhoids"}]
# 6. [{"head": "Chronic Constipation or Diarrhea", "relation": "cause", "tail": "hemorrhoids"}]
# 7. [{"head": "Straining during bowel movements", "relation": "increases pressure on", "tail": "veins in the rectal area"}]
# 8. [{"head": "Prolonged Sitting", "relation": "increases pressure on", "tail": "anal veins"}]
# 9. [{"head": "Pregnancy", "relation": "leads to", "tail": "increased pressure in the pelvic area"}]
# 10. [{"head": "Increased pressure in the pelvic area", "relation": "can lead to", "tail": "hemorrhoids"}]
# 11. [{"head": "Obesity", "relation": "increases pressure on", "tail": "pelvic veins"}]
# 12. [{"head": "Low-Fiber Diet", "relation": "can lead to", "tail": "constipation"}]
# 13. [{"head": "Constipation", "relation": "contributes to", "tail": "development of hemorrhoids"}]
# 14. [{"head": "Heavy Lifting", "relation": "increases", "tail": "abdominal pressure"}]
# 15. [{"head": "Increased abdominal pressure", "relation": "contributes to", "tail": "hemorrhoid formation"}]
# 16. [{"head": "Aging", "relation": "causes", "tail": "weakening and stretching of tissues supporting veins"}]
# 17. [{"head": "Weakening and stretching of tissues", "relation": "makes", "tail": "hemorrhoids more likely"}]
# 18. [{"head": "Genetic Predisposition", "relation": "increases likelihood of", "tail": "developing hemorrhoids"}]
# 19. [{"head": "Treatment options", "relation": "aimed at", "tail": "alleviating symptoms and reducing discomfort"}]
# 20. [{"head": "Persistent or worsening symptoms", "relation": "require", "tail": "further evaluation by a healthcare professional"}]
# 21. [{"head": "Further evaluation", "relation": "necessary to", "tail": "rule out other conditions or consider advanced treatments"}]
# 1. [{"head": "Immunocompromised patients", "relation": "increased risk of", "tail": "infections with viruses such as HSV and CMV"}]
#
# 2. [{"head": "CMV Colitis", "relation": "common manifestation in", "tail": "immunocompromised individuals"}]
#
# 3. [{"head": "CMV Colitis", "relation": "causes symptoms such as", "tail": "diarrhea, abdominal pain, fever, and weight loss"}]
#
# 4. [{"head": "Colonoscopy", "relation": "may reveal", "tail": "ulcerations in CMV Colitis"}]
#
# 5. [{"head": "Biopsy with histopathological examination", "relation": "confirms presence of", "tail": "CMV inclusion bodies"}]
#
# 6. [{"head": "HSV Colitis", "relation": "less common than", "tail": "CMV Colitis"}]
#
# 7. [{"head": "HSV Colitis", "relation": "causes similar symptoms to", "tail": "CMV Colitis"}]
#
# 8. [{"head": "Endoscopic findings", "relation": "may include", "tail": "ulcerations in HSV Colitis"}]
#
# 9. [{"head": "Biopsy", "relation": "identifies", "tail": "HSV in tissue samples"}]
#
# 10. [{"head": "Immunocompromised patients", "relation": "risk for", "tail": "other opportunistic infections affecting the colon"}]
#
# 11. [{"head": "Opportunistic infections", "relation": "include", "tail": "fungal infections and other viral infections"}]
#
# 12. [{"head": "Medications", "relation": "can lead to", "tail": "medication-induced colitis"}]
#
# 13. [{"head": "Immunosuppressants", "relation": "can predispose to", "tail": "infections leading to colitis"}]
#
# 14. [{"head": "Inflammatory Bowel Disease (IBD)", "relation": "can be exacerbated in", "tail": "immunocompromised patients"}]
#
# 15. [{"head": "IBD", "relation": "presentation may overlap with", "tail": "infectious colitis"}]
#
# 16. [{"head": "Immunocompromised patients", "relation": "risk for", "tail": "ischemic colitis"}]
#
# 17. [{"head": "Ischemic Colitis", "relation": "due to", "tail": "underlying conditions or medications affecting blood flow"}]
#
# 18. [{"head": "Clinical evaluation", "relation": "includes", "tail": "history, physical examination, laboratory tests, and colonoscopy with biopsy"}]
#
# 19. [{"head": "Clinical evaluation", "relation": "essential to determine", "tail": "exact cause of colonic symptoms in immunocompromised patient"}]
# 1. [{"head": "Juvenile polyps", "relation": "cause", "tail": "rectal bleeding, abdominal pain, or prolapse"}]
# 2. [{"head": "Juvenile Polyposis Syndrome (JPS)", "relation": "characterized by", "tail": "multiple juvenile polyps in the gastrointestinal tract"}]
# 3. [{"head": "Juvenile Polyposis Syndrome (JPS)", "relation": "leads to", "tail": "significant bleeding and increased risk of intussusception"}]
# 4. [{"head": "Large polyps", "relation": "cause", "tail": "mechanical obstruction"}]
# 5. [{"head": "Mechanical obstruction", "relation": "leads to", "tail": "intussusception"}]
# 6. [{"head": "Intussusception", "relation": "causes", "tail": "obstruction and potentially severe pain"}]
# 7. [{"head": "Presence of polyps", "relation": "leads to", "tail": "vascular compromise"}]
# 8. [{"head": "Vascular compromise", "relation": "results in", "tail": "bleeding"}]
# 9. [{"head": "Inflammation or ulceration of polyps", "relation": "leads to", "tail": "bleeding"}]
# 10. [{"head": "Trauma to the polyp", "relation": "causes", "tail": "bleeding from the surface of the polyp"}]
# 11. [{"head": "Coagulation disorders", "relation": "exacerbate", "tail": "bleeding tendencies in patients with juvenile polyps"}]
# 12. [{"head": "Endoscopic removal of polyps", "relation": "prevents", "tail": "complications such as bleeding or intussusception"}]
# 13. [{"head": "Juvenile Polyposis Syndrome", "relation": "requires", "tail": "regular surveillance and management"}]
# 14. [{"head": "Regular surveillance and management", "relation": "monitor for", "tail": "potential malignant transformation"}]
# 1. [{"head": "Genetic Factors", "relation": "cause", "tail": "Family history of IBD increases risk of Crohn's disease"}]
#
# 2. [{"head": "Immune System Dysfunction", "relation": "cause", "tail": "Abnormal immune response leads to chronic inflammation in Crohn's disease"}]
#
# 3. [{"head": "Environmental Factors", "relation": "cause", "tail": "Smoking, diet, and stress contribute to Crohn's disease development or exacerbation"}]
#
# 4. [{"head": "Microbiome Imbalance", "relation": "cause", "tail": "Alterations in gut microbiota play a role in Crohn's disease pathogenesis"}]
#
# 5. [{"head": "Infections", "relation": "cause", "tail": "Infections, especially in early life, might trigger Crohn's disease in susceptible individuals"}]
#
# 6. [{"head": "Dietary Factors", "relation": "influence", "tail": "Certain dietary patterns may influence disease course or trigger flare-ups"}]
# 1. [{"head": "Atherosclerosis", "relation": "can cause", "tail": "reduced blood flow to the colon"}]
# 2. [{"head": "Hypotension", "relation": "can lead to", "tail": "reduced blood flow to the colon"}]
# 3. [{"head": "Vascular Surgery or Procedures", "relation": "can disrupt", "tail": "blood flow to the colon"}]
# 4. [{"head": "Medications", "relation": "can reduce", "tail": "blood flow to the colon"}]
# 5. [{"head": "Thrombosis or Embolism", "relation": "can lead to", "tail": "ischemia in the colon"}]
# 6. [{"head": "Heart Failure", "relation": "can cause", "tail": "decreased blood flow to the colon"}]
# 7. [{"head": "Hypercoagulable States", "relation": "can lead to", "tail": "ischemic colitis"}]
# 8. [{"head": "Strenuous Physical Activity", "relation": "can lead to", "tail": "temporary reductions in blood flow to the colon"}]
# 9. [{"head": "Inflammatory Conditions", "relation": "can lead to", "tail": "ischemia in the colon"}]
# 10. [{"head": "Infections", "relation": "can cause", "tail": "systemic hypotension and reduced blood flow to the colon"}]
# 1. [{"head": "Antibiotic use", "relation": "leads to", "tail": "overgrowth of C. difficile bacteria"}]
# 2. [{"head": "Overgrowth of C. difficile", "relation": "causes", "tail": "inflammation of the rectum (proctitis)"}]
# 3. [{"head": "C. difficile infection", "relation": "ranges from", "tail": "mild diarrhea to severe colitis"}]
# 4. [{"head": "Standard treatment for C. difficile", "relation": "involves", "tail": "use of specific antibiotics"}]
# 5. [{"head": "Vancomycin", "relation": "used as", "tail": "first-line treatment for moderate to severe C. difficile infections"}]
# 6. [{"head": "Vancomycin", "relation": "administered", "tail": "orally to reach the colon effectively"}]
# 7. [{"head": "Fidaxomicin", "relation": "used as", "tail": "alternative to vancomycin"}]
# 8. [{"head": "Fidaxomicin", "relation": "considered in", "tail": "high risk of recurrence or multiple recurrences"}]
# 9. [{"head": "Discontinuation of initial antibiotic", "relation": "important for", "tail": "reducing C. difficile overgrowth"}]
# 10. [{"head": "Supportive care", "relation": "includes", "tail": "hydration and electrolyte management"}]
# 11. [{"head": "Severe or recurrent infections", "relation": "may require", "tail": "fecal microbiota transplantation (FMT)"}]
# 12. [{"head": "Choice of treatment", "relation": "depends on", "tail": "severity of infection, patient history, and previous occurrences"}]
# 13. [{"head": "Treatment", "relation": "should be", "tail": "tailored to individual patient's needs and circumstances"}]
# 1. [{"head": "Diverticular bleeding", "relation": "is a common cause of", "tail": "lower gastrointestinal bleeding in older adults"}]
# 2. [{"head": "Colonoscopy", "relation": "is used for", "tail": "diagnostic and therapeutic purposes in diverticular bleeding"}]
# 3. [{"head": "Endoscopic Hemostasis", "relation": "involves", "tail": "direct intervention to stop bleeding during colonoscopy"}]
# 4. [{"head": "Clipping", "relation": "is a technique of", "tail": "applying endoscopic clips to compress the vessel and stop bleeding"}]
# 5. [{"head": "Thermal Coagulation", "relation": "involves", "tail": "using heat to cauterize the bleeding vessel"}]
# 6. [{"head": "Injection Therapy", "relation": "involves", "tail": "injecting epinephrine or sclerosing agents to induce vasoconstriction"}]
# 7. [{"head": "Endoscopic Band Ligation", "relation": "can be adapted for", "tail": "use in the colon to manage diverticular bleeding"}]
# 8. [{"head": "Argon Plasma Coagulation (APC)", "relation": "is a method of", "tail": "using ionized argon gas to coagulate tissue and control bleeding"}]
# 9. [{"head": "Combination Therapy", "relation": "involves", "tail": "using multiple methods to achieve hemostasis"}]
# 10. [{"head": "Endoscopic treatment", "relation": "may be followed by", "tail": "angiographic embolization or surgical resection if unsuccessful"}]
# 11. [{"head": "Diverticular bleeding", "relation": "can sometimes", "tail": "stop spontaneously"}]
# 12. [{"head": "Supportive care", "relation": "includes", "tail": "fluid resuscitation and blood transfusions depending on severity"}]
# 1. [{"head": "MUTYH-associated polyposis (MAP)", "relation": "caused by", "tail": "biallelic mutations in the MUTYH gene"}]
#
# 2. [{"head": "Biallelic mutations in the MUTYH gene", "relation": "impair", "tail": "base excision repair pathway"}]
#
# 3. [{"head": "Impaired base excision repair pathway", "relation": "leads to", "tail": "accumulation of DNA damage"}]
#
# 4. [{"head": "Accumulation of DNA damage", "relation": "increases risk of", "tail": "polyp formation and colorectal cancer"}]
#
# 5. [{"head": "MAP inheritance", "relation": "pattern", "tail": "autosomal recessive"}]
#
# 6. [{"head": "Both parents of affected individual", "relation": "typically carriers of", "tail": "single MUTYH mutation"}]
#
# 7. [{"head": "Family history", "relation": "may include", "tail": "colorectal cancer or polyps in siblings"}]
#
# 8. [{"head": "Environmental factors", "relation": "influence", "tail": "development and progression of polyps and cancer"}]
#
# 9. [{"head": "Environmental factors", "relation": "examples", "tail": "diet, smoking, and alcohol consumption"}]
#
# 10. [{"head": "Age of presentation", "relation": "typically between", "tail": "40 and 60 years"}]
#
# 11. [{"head": "Polyps in MAP", "relation": "can develop", "tail": "earlier than typical age range"}]
#
# 12. [{"head": "Other genetic syndromes", "relation": "may contribute to", "tail": "polyp formation and cancer risk"}]
#
# 13. [{"head": "Management of MAP", "relation": "involves", "tail": "regular colonoscopic surveillance"}]
#
# 14. [{"head": "Regular colonoscopic surveillance", "relation": "purpose", "tail": "monitor and remove polyps"}]
#
# 15. [{"head": "Surgical intervention", "relation": "may be necessary to", "tail": "reduce cancer risk"}]
#
# 16. [{"head": "Genetic counseling", "relation": "recommended for", "tail": "affected individuals and their families"}]
# 1. [{"head": "Nonspecific proctitis", "relation": "refers to", "tail": "inflammation of the rectum without a clearly identified cause"}]
# 2. [{"head": "Empirical treatment with antibiotics", "relation": "suggests", "tail": "suspicion of an infectious etiology, particularly STIs"}]
# 3. [{"head": "Ceftriaxone", "relation": "is effective against", "tail": "Neisseria gonorrhoeae, which can cause proctitis"}]
# 4. [{"head": "Doxycycline", "relation": "is used to treat", "tail": "Chlamydia trachomatis, which can lead to proctitis"}]
# 5. [{"head": "Herpes Simplex Virus (HSV)", "relation": "can cause", "tail": "proctitis, though not treated with ceftriaxone or doxycycline"}]
# 6. [{"head": "Inflammatory Bowel Disease (IBD)", "relation": "can cause", "tail": "proctitis, not treated with antibiotics"}]
# ...
#
# ### Upper GI Bleeding:
# 4. [{"head": "Peptic Ulcer Disease", "relation": "can cause", "tail": "significant bleeding by eroding into blood vessels"}]
# 5. [{"head": "Esophageal Varices", "relation": "related to", "tail": "liver cirrhosis and can rupture"}]
# 6. [{"head": "Gastritis", "relation": "caused by", "tail": "NSAIDs or alcohol, leading to bleeding"}]
# 7. [{"head": "Mallory-Weiss Tear", "relation": "occurs at", "tail": "junction of stomach and esophagus due to severe vomiting"}]
# 8. [{"head": "Esophagitis", "relation": "caused by", "tail": "acid reflux, leading to bleeding"}]
#
# ### Lower GI Bleeding:
# 9. [{"head": "Diverticular Disease", "relation": "can cause", "tail": "massive bleeding from diverticula in the colon"}]
# 10. [{"head": "Angiodysplasia", "relation": "involves", "tail": "abnormal blood vessels in the colon causing bleeding"}]
# 11. [{"head": "Colorectal Cancer", "relation": "can cause", "tail": "bleeding from tumors in the colon or rectum"}]
# 12. [{"head": "Inflammatory Bowel Disease (IBD)", "relation": "includes", "tail": "Crohn's disease or ulcerative colitis causing bleeding"}]
# 13. [{"head": "Hemorrhoids", "relation": "usually cause", "tail": "minor bleeding but can lead to significant blood loss in severe cases"}]
# 14. [{"head": "Ischemic Colitis", "relation": "caused by", "tail": "reduced blood flow to the colon leading to bleeding"}]
#
# ### Other Considerations:
# 15. [{"head": "Coagulopathy", "relation": "can exacerbate", "tail": "bleeding from any source"}]
# 16. [{"head": "Medications", "relation": "such as", "tail": "anticoagulants or antiplatelet drugs increase bleeding risk"}]
# 17. [{"head": "Trauma or Post-Procedure Complications", "relation": "can lead to", "tail": "bleeding in the GI tract"}]
#
# 18. [{"head": "Diagnosis of severe GI bleeding", "relation": "determined through", "tail": "patient history, physical examination, laboratory tests, imaging studies, and endoscopic evaluation"}]
# 19. [{"head": "Immediate stabilization of the patient", "relation": "includes", "tail": "fluid resuscitation and blood transfusions if necessary"}]
# 20. [{"head": "Underlying cause of bleeding", "relation": "identified and treated", "tail": "after stabilization of the patient"}]
# 1. [{"head": "Massive GI bleeding", "relation": "requires", "tail": "prompt evaluation and management"}]
#
# 2. [{"head": "Lower GI tract", "relation": "potential causes", "tail": "Diverticular Disease"}]
#
# 3. [{"head": "Diverticular Disease", "relation": "can lead to", "tail": "significant bleeding if a diverticulum ruptures"}]
#
# 4. [{"head": "Lower GI tract", "relation": "potential causes", "tail": "Angiodysplasia"}]
#
# 5. [{"head": "Angiodysplasia", "relation": "can cause", "tail": "significant bleeding, especially in older adults"}]
#
# 6. [{"head": "Lower GI tract", "relation": "potential causes", "tail": "Colorectal Cancer"}]
#
# 7. [{"head": "Colorectal Cancer", "relation": "can cause", "tail": "bleeding by eroding blood vessels"}]
#
# 8. [{"head": "Lower GI tract", "relation": "potential causes", "tail": "Inflammatory Bowel Disease (IBD)"}]
#
# 9. [{"head": "Inflammatory Bowel Disease (IBD)", "relation": "can cause", "tail": "severe inflammation and bleeding"}]
#
# 10. [{"head": "Lower GI tract", "relation": "potential causes", "tail": "Ischemic Colitis"}]
#
# 11. [{"head": "Ischemic Colitis", "relation": "can lead to", "tail": "tissue damage and bleeding"}]
#
# 12. [{"head": "Lower GI tract", "relation": "potential causes", "tail": "Hemorrhoids"}]
#
# 13. [{"head": "Hemorrhoids", "relation": "can occasionally lead to", "tail": "significant blood loss"}]
#
# 14. [{"head": "Lower GI tract", "relation": "potential causes", "tail": "Post-Polypectomy Bleeding"}]
#
# 15. [{"head": "Post-Polypectomy Bleeding", "relation": "can result from", "tail": "recent removal of polyps during a colonoscopy"}]
#
# 16. [{"head": "Lower GI tract", "relation": "potential causes", "tail": "Radiation Colitis"}]
#
# 17. [{"head": "Radiation Colitis", "relation": "can result from", "tail": "previous radiation therapy to the pelvic area"}]
#
# 18. [{"head": "Lower GI tract", "relation": "potential causes", "tail": "Infectious Colitis"}]
#
# 19. [{"head": "Infectious Colitis", "relation": "can lead to", "tail": "bleeding from severe infections of the colon"}]
#
# 20. [{"head": "Lower GI tract", "relation": "potential causes", "tail": "Meckel's Diverticulum"}]
#
# 21. [{"head": "Meckel's Diverticulum", "relation": "can sometimes be", "tail": "a source of lower GI bleeding"}]
#
# 22. [{"head": "Massive GI bleeding", "relation": "requires", "tail": "stabilization with fluid resuscitation and blood transfusions"}]
#
# 23. [{"head": "Massive GI bleeding", "relation": "diagnostic procedures", "tail": "colonoscopy, angiography, or CT scans"}]
#
# 24. [{"head": "Treatment", "relation": "depends on", "tail": "underlying cause"}]
#
# 25. [{"head": "Treatment", "relation": "may include", "tail": "endoscopic interventions, surgery, or medical management"}]
# 1. [{"head": "Colonoscopy", "relation": "requires", "tail": "thorough cleansing of the colon"}]
# 2. [{"head": "Thorough cleansing", "relation": "ensures", "tail": "clear visibility of the colon walls"}]
# 3. [{"head": "Clear visibility", "relation": "allows for", "tail": "accurate diagnosis"}]
# 4. [{"head": "Bowel preparation", "relation": "involves", "tail": "dietary restrictions"}]
# 5. [{"head": "Dietary restrictions", "relation": "include", "tail": "clear liquid diet for 24 to 48 hours"}]
# 6. [{"head": "Clear liquid diet", "relation": "includes", "tail": "clear broths, tea, coffee without milk or cream, clear juices, and gelatin"}]
# 7. [{"head": "Bowel preparation", "relation": "involves", "tail": "laxatives"}]
# 8. [{"head": "Laxatives", "relation": "help", "tail": "evacuate the contents of the colon"}]
# 9. [{"head": "Bowel preparation", "relation": "involves", "tail": "hydration"}]
# 10. [{"head": "Hydration", "relation": "is important for", "tail": "preventing dehydration from laxatives"}]
# 11. [{"head": "Bowel preparation", "relation": "involves", "tail": "adjustments to medications"}]
# 12. [{"head": "Adjustments to medications", "relation": "may include", "tail": "temporarily stopping blood thinners"}]
# 13. [{"head": "Proper bowel preparation", "relation": "is crucial for", "tail": "success of the colonoscopy"}]
# 14. [{"head": "Residual stool", "relation": "can obscure", "tail": "view and lead to missed lesions or polyps"}]
# 15. [{"head": "Inadequate cleansing", "relation": "may require", "tail": "rescheduling the procedure"}]
# 1. [{"head": "Patient", "relation": "did not adhere to", "tail": "dietary restrictions or bowel prep instructions"}]
# 2. [{"head": "Colon", "relation": "not adequately cleansed", "tail": "poor visualization during procedure"}]
# 3. [{"head": "Patient", "relation": "did not consume enough", "tail": "clear liquids before fasting period"}]
# 4. [{"head": "Patient", "relation": "experienced", "tail": "dehydration"}]
# 5. [{"head": "Dehydration", "relation": "can complicate", "tail": "procedure or recovery"}]
# 6. [{"head": "Gastrointestinal Obstruction", "relation": "caused by", "tail": "strictures, tumors, or severe constipation"}]
# 7. [{"head": "Obstruction", "relation": "prevents", "tail": "adequate bowel cleansing"}]
# 8. [{"head": "Patient", "relation": "did not stop", "tail": "certain medications as advised"}]
# 9. [{"head": "Medication Non-compliance", "relation": "leads to", "tail": "complications such as bleeding"}]
# 10. [{"head": "Underlying Gastrointestinal Conditions", "relation": "include", "tail": "inflammatory bowel disease, diverticulitis, ischemic colitis"}]
# 11. [{"head": "Conditions", "relation": "cause", "tail": "symptoms requiring endoscopy"}]
# 12. [{"head": "Anxiety", "relation": "leads to", "tail": "non-compliance with preparation instructions"}]
# 13. [{"head": "Non-compliance", "relation": "affects", "tail": "outcome of procedure"}]
# 14. [{"head": "Metabolic or Systemic Conditions", "relation": "include", "tail": "diabetes"}]
# 15. [{"head": "Diabetes", "relation": "affects", "tail": "gastric emptying or bowel motility"}]
# 16. [{"head": "Complicated Preparation", "relation": "caused by", "tail": "metabolic or systemic conditions"}]
# 1. [{"head": "Low-fiber diet", "relation": "associated with", "tail": "development of diverticulosis"}]
# 2. [{"head": "Diet high in refined carbohydrates", "relation": "leads to", "tail": "constipation and increased colonic pressure"}]
# 3. [{"head": "Increased colonic pressure", "relation": "contributes to", "tail": "formation of diverticula"}]
# 4. [{"head": "Age", "relation": "increases", "tail": "prevalence of diverticulosis"}]
# 5. [{"head": "Individuals over age 50", "relation": "more common in", "tail": "diverticulosis"}]
# 6. [{"head": "Genetic predisposition", "relation": "may cause", "tail": "diverticulosis to run in families"}]
# 7. [{"head": "Obesity", "relation": "associated with", "tail": "increased risk of diverticulosis"}]
# 8. [{"head": "Lack of physical activity", "relation": "associated with", "tail": "increased risk of diverticulosis"}]
# 9. [{"head": "Smoking", "relation": "associated with", "tail": "increased risk of diverticulosis"}]
# 10. [{"head": "Altered colonic motility", "relation": "contributes to", "tail": "formation of diverticula"}]
# 11. [{"head": "Increased intraluminal pressure", "relation": "contributes to", "tail": "formation of diverticula"}]
# 12. [{"head": "Connective tissue changes", "relation": "predispose individuals to", "tail": "diverticulosis"}]
# 13. [{"head": "Aging", "relation": "causes", "tail": "changes in connective tissue of colon wall"}]
# 14. [{"head": "Asymptomatic diverticulosis", "relation": "does not require", "tail": "treatment"}]
# 15. [{"head": "Increased dietary fiber intake", "relation": "advised to", "tail": "prevent complications like diverticulitis"}]
# 16. [{"head": "Regular follow-up and monitoring", "relation": "recommended to", "tail": "ensure condition remains asymptomatic"}]
# 1. [{"head": "Patient Non-Compliance", "relation": "necessitates", "tail": "rapid preparation approach"}]
#
# 2. [{"head": "Urgent Medical Indications", "relation": "require", "tail": "rapid preparation to expedite procedure"}]
#
# 3. [{"head": "Previous Inadequate Preparation", "relation": "leads to", "tail": "consideration of aggressive preparation regimen"}]
#
# 4. [{"head": "Chronic Constipation", "relation": "requires", "tail": "more intensive preparation"}]
#
# 5. [{"head": "Shortened Time Frame", "relation": "necessitates", "tail": "rapid preparation protocol"}]
#
# 6. [{"head": "Specific Medical Conditions", "relation": "necessitate", "tail": "more rapid or intensive preparation"}]
#
# 7. [{"head": "Medication Interactions", "relation": "impact", "tail": "effectiveness of standard bowel preparations"}]
#
# 8. [{"head": "Dietary Factors", "relation": "influence", "tail": "effectiveness of bowel cleansing process"}]
# 1. [{"head": "Severe gastrointestinal bleeding", "relation": "potential cause", "tail": "Peptic Ulcer Disease"}]
# 2. [{"head": "Peptic Ulcer Disease", "relation": "mechanism", "tail": "Ulcers erode into blood vessels"}]
# 3. [{"head": "Severe gastrointestinal bleeding", "relation": "potential cause", "tail": "Diverticular Disease"}]
# 4. [{"head": "Diverticular Disease", "relation": "mechanism", "tail": "Diverticula in the colon bleed profusely"}]
# 5. [{"head": "Severe gastrointestinal bleeding", "relation": "potential cause", "tail": "Angiodysplasia"}]
# 6. [{"head": "Angiodysplasia", "relation": "mechanism", "tail": "Abnormal blood vessels in the GI tract"}]
# 7. [{"head": "Severe gastrointestinal bleeding", "relation": "potential cause", "tail": "Inflammatory Bowel Disease (IBD)"}]
# 8. [{"head": "Inflammatory Bowel Disease", "relation": "mechanism", "tail": "Inflammation and ulceration of the intestinal lining"}]
# 9. [{"head": "Severe gastrointestinal bleeding", "relation": "potential cause", "tail": "Colorectal Cancer"}]
# 10. [{"head": "Colorectal Cancer", "relation": "mechanism", "tail": "Tumors in the colon or rectum bleed"}]
# 11. [{"head": "Severe gastrointestinal bleeding", "relation": "potential cause", "tail": "Hemorrhoids"}]
# 12. [{"head": "Hemorrhoids", "relation": "mechanism", "tail": "Severe hemorrhoids lead to significant blood loss"}]
# 13. [{"head": "Severe gastrointestinal bleeding", "relation": "potential cause", "tail": "Gastrointestinal Tumors"}]
# 14. [{"head": "Gastrointestinal Tumors", "relation": "mechanism", "tail": "Tumors in the GI tract cause bleeding"}]
# 15. [{"head": "Severe gastrointestinal bleeding", "relation": "potential cause", "tail": "Esophageal Varices"}]
# 16. [{"head": "Esophageal Varices", "relation": "mechanism", "tail": "Dilated veins in the esophagus rupture"}]
# 17. [{"head": "Severe gastrointestinal bleeding", "relation": "potential cause", "tail": "Mallory-Weiss Tear"}]
# 18. [{"head": "Mallory-Weiss Tear", "relation": "mechanism", "tail": "Tear in the mucous membrane due to severe vomiting"}]
# 19. [{"head": "Severe gastrointestinal bleeding", "relation": "potential cause", "tail": "Ischemic Colitis"}]
# 20. [{"head": "Ischemic Colitis", "relation": "mechanism", "tail": "Reduced blood flow to the colon causes inflammation and bleeding"}]
# 21. [{"head": "Severe gastrointestinal bleeding", "relation": "potential cause", "tail": "Meckel's Diverticulum"}]
# 22. [{"head": "Meckel's Diverticulum", "relation": "mechanism", "tail": "Congenital abnormality causes bleeding"}]
# 23. [{"head": "Severe gastrointestinal bleeding", "relation": "potential cause", "tail": "Aortoenteric Fistula"}]
# 24. [{"head": "Aortoenteric Fistula", "relation": "mechanism", "tail": "Connection between aorta and GI tract leads to massive bleeding"}]
# 25. [{"head": "Diagnosis of GI bleeding", "relation": "method", "tail": "Patient history and physical examination"}]
# 26. [{"head": "Diagnosis of GI bleeding", "relation": "method", "tail": "Endoscopic evaluation (colonoscopy or upper endoscopy)"}]
# 27. [{"head": "Diagnosis of GI bleeding", "relation": "method", "tail": "Imaging studies"}]
# 28. [{"head": "Diagnosis of GI bleeding", "relation": "method", "tail": "Surgical exploration"}]
# 1. [{"head": "Distal lesion found", "relation": "leads to", "tail": "Recommendation for complete colonoscopy"}]
# 2. [{"head": "Complete colonoscopy", "relation": "ensures", "tail": "Thorough evaluation of entire colon"}]
# 3. [{"head": "Presence of distal lesion", "relation": "associated with", "tail": "Additional lesions or pathology elsewhere"}]
# 4. [{"head": "Colorectal Polyps", "relation": "potential cause", "tail": "Presence of additional polyps elsewhere"}]
# 5. [{"head": "Distal lesion", "relation": "could be", "tail": "Early sign of colorectal cancer"}]
# 6. [{"head": "Complete colonoscopy", "relation": "necessary for", "tail": "Checking other potential cancerous lesions"}]
# 7. [{"head": "Inflammatory Bowel Disease (IBD)", "relation": "potential cause", "tail": "Lesions in the colon"}]
# 8. [{"head": "Full colonoscopy", "relation": "helps assess", "tail": "Extent and severity of IBD"}]
# 9. [{"head": "Diverticular Disease", "relation": "potential cause", "tail": "Lesions or changes in colon wall"}]
# 10. [{"head": "Complete examination", "relation": "helps determine", "tail": "Extent of diverticular disease"}]
# 11. [{"head": "Ischemic Colitis", "relation": "potential cause", "tail": "Ischemic changes appearing as lesions"}]
# 12. [{"head": "Full colonoscopy", "relation": "helps assess", "tail": "Extent of ischemia"}]
# 13. [{"head": "Infectious Colitis", "relation": "potential cause", "tail": "Inflammation and lesions in colon"}]
# 14. [{"head": "Complete colonoscopy", "relation": "helps identify", "tail": "Extent and cause of infection"}]
# 15. [{"head": "Radiation Colitis", "relation": "potential cause", "tail": "Changes in colon appearing as lesions"}]
# 16. [{"head": "Lymphoid Hyperplasia", "relation": "potential cause", "tail": "Nodular lesions in colon"}]
# 17. [{"head": "Complete colonoscopy", "relation": "allows for", "tail": "Comprehensive assessment and biopsy"}]
# 18. [{"head": "Complete colonoscopy", "relation": "crucial for", "tail": "Accurate diagnosis and management"}]

# %%
test_event = extracted_events[0][0]

# %%
import json
dict_event = json.loads(test_event)
print(dict_event['head'])
# Out:
# Colonoscopy

# %%
print(extract_events(events[0].content))
# Out:
# ['{"head": "Colonoscopy", "relation": "used for", "tail": "diagnosing colon cancer"}', '{"head": "Colonoscopy", "relation": "procedure", "tail": "insertion of colonoscope to examine colon"}', '{"head": "Suspicious areas found", "relation": "action", "tail": "biopsies taken for analysis"}', '{"head": "Biopsy", "relation": "purpose", "tail": "examine tissue for cancer cells"}', '{"head": "CT Colonography", "relation": "alternative", "tail": "non-invasive imaging test"}', '{"head": "CT Colonography", "relation": "limitation", "tail": "may not detect small polyps effectively"}', '{"head": "FOBT or FIT", "relation": "purpose", "tail": "check for hidden blood in stool"}', '{"head": "FOBT or FIT", "relation": "limitation", "tail": "less definitive than colonoscopy"}', '{"head": "Stool DNA Test", "relation": "purpose", "tail": "detect DNA markers for cancer"}', '{"head": "Flexible Sigmoidoscopy", "relation": "scope", "tail": "examines rectum and lower colon"}', '{"head": "Barium Enema", "relation": "procedure", "tail": "X-ray exam with barium sulfate contrast"}', '{"head": "Barium Enema", "relation": "current use", "tail": "less common due to advanced imaging"}', '{"head": "CT Scan or MRI", "relation": "purpose", "tail": "determine extent of cancer spread"}', '{"head": "CEA Test", "relation": "purpose", "tail": "measure CEA protein level in blood"}', '{"head": "Choice of test", "relation": "depends on", "tail": "patient\'s symptoms and risk factors"}', '{"head": "Suspected colon cancer", "relation": "definitive approach", "tail": "colonoscopy with biopsy"}']

# %%
# import the extracted events to the Neo4j database, along with the head, relation and tail embeddings
# extracted events: [[{},{}...]]
def import_events_to_neo4j(events):
    with driver.session() as session:
        for event in events:
            for extracted_event in event:
                extracted_event = json.loads(extracted_event)
                head_text = extracted_event['head']
                relation_text = extracted_event['relation']
                tail_text = extracted_event['tail']
                head_embedding = get_openai_embedding(head_text)
                relation_embedding = get_openai_embedding(relation_text)
                tail_embedding = get_openai_embedding(tail_text)
                
                # Dynamically construct the query with the relation type
                query = f"""
                MERGE (head:HeadDemo {{text: $head_text, embedding: $head_embedding}})
                MERGE (tail:TailDemo {{text: $tail_text, embedding: $tail_embedding}})
                MERGE (head)-[:`{relation_text}` {{text: $relation_text, embedding: $relation_embedding}}]->(tail)
                """
                
                parameters = {
                    'head_text': head_text,
                    'head_embedding': head_embedding,
                    'tail_text': tail_text,
                    'tail_embedding': tail_embedding,
                    'relation_text': relation_text,
                    'relation_embedding': relation_embedding
                }
                session.run(query, parameters)

# %%
import_events_to_neo4j(extracted_events)

# %%
question = "How is colonoscopy performed?"
query_embedding = neo4j_retriever.embed_question(question)
relevant_docs = neo4j_retriever.get_relevant_documents(query_embedding)
for doc in relevant_docs:
    print(doc)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_28604\2670019931.py:12: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   with self.driver.session() as session:
# ('During colonoscopy', 'any polyps seen are removed and', 'evaluated for possible cancer')
# ('Colonoscopy', 'may be valuable to rule out', 'inflammatory bowel disease')
# ('normal colonoscopy', 'negates', 'advanced colon cancer')
# ('colonoscopy', 'alternative CRC screening tests are available for patients who decline', 'colonoscopy')
# ('colonoscopy', 'requires', 'rapid colonic preparation')

# %%
QA_template = [
    (
        "system",
        "You are a medical doctor, experienced in conducting colonoscopy and diagnosing colonic diseases. Based on the patient's information, you are to provide possible causes of the patient's condition, and ruling, and diagnosis."
    ),
    (
        "user",
        "Based on {patient_information}, what are the possible causes of the patient's condition?"
    )
]

patient_information_1 = """
A 52-year-old man comes to to the emergency department with fatigue and shortness of breath that has become progressively worse over the past week. 
He had an upper respiratory tract infection 2 weeks ago, for which he was given an antibiotic. 
He has hypertension, type 2 diabetes mellitus, and colonic polyps diagnosed on screening colonoscopy 2 years ago. 
His mother has systemic lupus erythematosus and his brother has a bicuspid aortic valve. He does not smoke cigarettes or drink alcohol. 
Current medications include lisinopril and metformin. 
His temperature is 37.3Â°C (99.1Â°F), pulse is 91/min, respirations are 18/min, and blood pressure is 145/84 mm Hg. 
His conjunctivae are pale. Cardiac examination shows a late systolic crescendo-decrescendo murmur at the right upper sternal border. 
Laboratory studies show:
Leukocyte Count 9,500/mm3
Hematocrit 24%
Platelet Count 178,000/mm3
LDH 215 U/L
Haptoglobin 22 mg/dL (N=41â€“165 mg/dL)
Serum
Na+ 140 mEq/L
K+ 4.6 mEq/L
CL- 100 mEq/L
HCO3- 25 mEq/L
Urea nitrogen 21 mg/dL
Creatinine 1.2 mg/dL
Total bilirubin 1.9 mg/dL
A peripheral blood smear is shown."
"""

# vector query “potential causes of {p.patient_context}” from the “CMG”, and Generate reasoning for ruling
# Use Confirmatory Evidence: Tie laboratory findings, such as the presence of schistocytes, directly to the diagnosis.
# Conclude with Clear Justification: Summarize the reasoning leading to the final answer in a concise manner.

# Use the Langchain OpeAI Chat API to semantically split the question into parts: 
# patient general information, patient history, patient physical examination, patient laboratory findings, patient imaging findings, patient diagnosis, patient treatment, patient prognosis
# and question.

def get_patient_information(patient_information):
    message = [
        (
            'system',
            "You are a medical doctor, experienced in conducting colonoscopy and diagnosing colonic diseases. Based on the patient's information, you are to provide possible causes of the patient's condition, and ruling, and diagnosis."
        ),
        (
            "user",
            "split the {patient_information} into parts: patient general information, patient history, patient physical examination, patient laboratory findings, patient imaging findings, patient diagnosis, patient treatment, patient prognosisand question.".replace('{patient_information}', patient_information_1)
        )
    ]
    patient_information = llm.invoke(message)
    return patient_information

# %%
p_info = get_patient_information(patient_information_1)

# %%
print(p_info.content)
# Out:
# Certainly, here is the information split into the requested parts:
#
# **Patient General Information:**
# - Age: 52 years old
# - Gender: Male
#
# **Patient History:**
# - Presenting symptoms: Fatigue and shortness of breath progressively worsening over the past week
# - Recent illness: Upper respiratory tract infection 2 weeks ago, treated with an antibiotic
# - Medical history: Hypertension, type 2 diabetes mellitus, colonic polyps diagnosed on screening colonoscopy 2 years ago
# - Family history: Mother with systemic lupus erythematosus, brother with a bicuspid aortic valve
# - Lifestyle: Does not smoke cigarettes or drink alcohol
# - Current medications: Lisinopril, Metformin
#
# **Patient Physical Examination:**
# - Temperature: 37.3°C (99.1°F)
# - Pulse: 91/min
# - Respirations: 18/min
# - Blood pressure: 145/84 mm Hg
# - Conjunctivae: Pale
# - Cardiac examination: Late systolic crescendo-decrescendo murmur at the right upper sternal border
#
# **Patient Laboratory Findings:**
# - Leukocyte Count: 9,500/mm³
# - Hematocrit: 24%
# - Platelet Count: 178,000/mm³
# - LDH: 215 U/L
# - Haptoglobin: 22 mg/dL (Normal = 41–165 mg/dL)
# - Serum Electrolytes:
#   - Na+: 140 mEq/L
#   - K+: 4.6 mEq/L
#   - Cl-: 100 mEq/L
#   - HCO3-: 25 mEq/L
# - Urea nitrogen: 21 mg/dL
# - Creatinine: 1.2 mg/dL
# - Total bilirubin: 1.9 mg/dL
#
# **Patient Imaging Findings:**
# - A peripheral blood smear is mentioned but not described in detail.
#
# **Patient Diagnosis:**
# - The combination of symptoms, laboratory findings, and family history suggests a possible diagnosis of hemolytic anemia, potentially drug-induced or related to an underlying condition such as an autoimmune process.
#
# **Patient Treatment:**
# - Treatment would likely focus on addressing the underlying cause of the hemolytic anemia, which may include discontinuing any offending medications, managing symptoms, and possibly initiating treatment for an autoimmune condition if confirmed.
#
# **Patient Prognosis:**
# - Prognosis would depend on the underlying cause of the anemia and the patient's response to treatment. If drug-induced, removal of the offending agent may lead to improvement. If autoimmune, long-term management may be necessary.
#
# **Question:**
# - What is the most likely cause of the patient's anemia, and what further tests or treatments should be considered to confirm the diagnosis and manage the condition?

# %%
neo4j_retriever = Neo4jRetriever()
question = "Mechanical destruction of erythrocytes"
query_embedding = neo4j_retriever.embed_question(question)
relevant_docs = neo4j_retriever.get_relevant_documents(similarity_query_4, query_embedding, top_k=10)
for doc in relevant_docs:
    print(doc)

# Close the retriever connection
neo4j_retriever.close()
# Out:
# ('Radiation therapy', 'can damage tissues', 'lead to abscess formation')
# ('obstructing tumors', 'can be debulked by', 'electrocoagulation')
# ('local trauma from impacted feces in a diverticulum', 'can erode', 'adjacent vessel')
# ('Juvenile polyps', 'outgrow their blood supply and autoamputate', 'during or after puberty')

# %%
def extract_key_information(patient_information):
    message = [
        (
            'system',
            "You are a medical doctor, experienced in conducting colonoscopy and diagnosing colonic diseases."
        ),
        (
            "user",
            """
            Extract relevant clinical {patient_information} from the following MedQA-USMLE question and answer text, focusing specifically on colonic diseases. Use the provided form to structure the extracted data. If any key information is missing, leave it blank.
            If any additional information is present, include it in the appropriate section.

            Extract the following:
            - Demographics: Include age, gender, family history, social history, and relevant medical history of gastrointestinal conditions.
            - Chief Complaint: Describe the patient's main gastrointestinal issue (e.g., changes in bowel habits, rectal bleeding, abdominal pain).
            - Gastrointestinal Examination: Focus on specific gastrointestinal exam findings, such as abdominal palpation results, rectal examination, or visible signs of colon-related issues.
            - Laboratory Findings: Extract relevant lab results like leukocyte count, platelet count, fecal occult blood test (FOBT), and carcinoembryonic antigen (CEA). Include specific inflammatory markers if relevant (e.g., calprotectin for IBD).
            - Imaging Findings: Extract imaging results such as colonoscopy findings, CT colonography results, and biopsy histopathology reports.
            - Past Medical History: Include previous gastrointestinal surgeries, conditions like IBD, previous colonoscopy reports, or any surgical history related to the gastrointestinal system.
            - Review of Gastrointestinal System: Include any specific symptoms related to colonic diseases (e.g., bowel habit changes, rectal bleeding, abdominal pain, bloating, unexplained weight loss).
            - Assessment/Diagnosis: Extract provisional or final diagnoses, focusing on specific conditions like colorectal cancer, diverticulitis, polyps, or IBD.
            - Treatment Plan: Extract treatment recommendations, including medication (e.g., anti-inflammatory drugs for IBD, chemotherapy for colorectal cancer), polyp removal, and dietary recommendations. Specify surgical intervention if mentioned.
            - Patient Education: Summarize how the findings were explained to the patient and any lifestyle or follow-up recommendations provided.

            Example:

            Given the question:
            \"A 50-year-old male presents with a 6-month history of rectal bleeding and changes in bowel habits. Colonoscopy reveals a 3 cm polyp in the sigmoid colon...\"

            The extracted information should be (note that extract info if available, but leave blank if not mentioned):
            {
                "demographic": {
                    "Age": "50",
                    "Gender": "Male",
                    "Family History": "Not mentioned",
                    "Social History": "Not mentioned",
                    "Medical History": "Not mentioned"
                },
                "chief_complaint": {
                    "Chief Complaint": "6-month history of rectal bleeding and changes in bowel habits."
                },
                "gastrointestinal_examination": {
                    "Abdominal Palpation": "Not mentioned",
                    "Rectal Examination": "Not mentioned",
                    "Visible Signs": "Not mentioned"
                },
                "laboratory_findings": {
                    "Leukocyte Count": "Not mentioned",
                    "Platelet Count": "Not mentioned",
                    "FOBT": "Not mentioned",
                    "CEA": "Not mentioned",
                    "Liver Function Tests": "Not mentioned",
                    "Serum": {
                        "Na+": "Not mentioned",
                        "K+": "Not mentioned"
                    }
                },
                "imaging_findings": {
                    "Colonoscopy Findings": "3 cm polyp in the sigmoid colon.",
                    "Colonoscopy Biopsy Results": "Not mentioned",
                    "CT Colonography": "Not mentioned",
                    "MRI": "Not mentioned"
                },
                "past_medical_history": {
                    "Chronic Conditions": "Not mentioned",
                    "Previous Colonoscopies": "Not mentioned",
                    "Previous Surgeries": "Not mentioned",
                    "Allergies": "Not mentioned"
                },
                "review_of_gastrointestinal_system": {
                    "Bowel Habits": "Changes in bowel habits",
                    "Rectal Bleeding": "Yes",
                    "Abdominal Pain": "Not mentioned",
                    "Unexplained Weight Loss": "Not mentioned"
                },
                "diagnostic_studies": {
                    "Colonoscopy Report": "3 cm polyp in the sigmoid colon.",
                    "CT Scan": "Not mentioned",
                    "MRI": "Not mentioned",
                    "Pathology Report": "Not mentioned"
                },
                "assessment_diagnosis": {
                    "Provisional Diagnosis": "Polyp in sigmoid colon",
                    "Differential Diagnosis": "Not mentioned",
                    "Final Diagnosis": "Not mentioned"
                },
                "treatment_plan": {
                    "Polyp Removal": "Recommendation for polyp removal",
                    "Medications Prescribed": "Not mentioned",
                    "Dietary Recommendations": "Not mentioned",
                    "Follow-up Colonoscopy": "Not mentioned",
                    "Referrals": "Not mentioned"
                },
                "patient_education": {
                    "Explanation of Findings": "Not mentioned",
                    "Lifestyle Modifications": "Not mentioned"
                }
            }
            """.replace('{patient_information}', patient_information)
        )
    ]
    key_information = llm.invoke(message)
    return key_information

def generate_potential_causes(key_information, addition_message=None):
    message = [
        (
            'system',
            "You are a medical doctor, experienced in conducting colonoscopy and diagnosing colonic diseases."
        ),
        (
            "user",
            """
            From key info as evidence, generate potential causes and reasoning of {key_information}, in the form of 
            [
            {
            "Evidence": [list of evidence],
            "Cause": "Potential Cause 1", 
            "Reasoning": "Reasoning for Potential Cause 1"},
            {
            "Evidence": [list of evidence],
            "Cause": "Potential Cause 2",
            "Reasoning": "Reasoning for Potential Cause 2"},
            ]
            """.replace('{key_information}', key_information)
        )
    ]
    message.append(addition_message)
    potential_causes = llm.invoke(message)
    return potential_causes

def generate_potential_next_steps_for_each_cause(potential_causes, addition_message=None):
    message = [
        (
            'system',
            "You are a medical doctor, experienced in conducting colonoscopy and diagnosing colonic diseases."
        ),
        (
            "user",
            """
            From potential causes {potential_causes}, generate potential next steps for each cause, in the form of
            [
            {
            "Cause": "Potential Cause 1",
            "Next Steps": "Next Steps for Potential Cause 1"},
            {
            "Cause": "Potential Cause 2",
            "Next Steps": "Next Steps for Potential Cause 2"}
            ]
            """.replace('{potential_causes}', potential_causes)
        )
    ]
    potential_next_steps = llm.invoke(message.append(addition_message))
    return potential_next_steps

def generate_reasoning_for_ruling(input_information):
    message = [
        (
            'system',
            "You are a medical doctor, experienced in conducting colonoscopy and diagnosing colonic diseases."
        ),
        (
            "user",
            "generate reasoning for ruling based on {input_information}".replace('{input_information}', input_information)
        )
    ]
    reasoning_for_ruling = llm.invoke(message)
    return reasoning_for_ruling

def generate_confirmatory_evidence(patient_information):
    message = [
        (
            'system',
            "You are a medical doctor, experienced in conducting colonoscopy and diagnosing colonic diseases."
        ),
        (
            "user",
            "generate confirmatory evidence based on {patient_information}".replace('{patient_information}', patient_information)
        )
    ]
    confirmatory_evidence = llm.invoke(message)
    return confirmatory_evidence

# %%
# extract key information from the patient information
key_information = extract_key_information(patient_information_1)
print(key_information.content)
# Out:
# ```json
# {
#     "demographic": {
#         "Age": "52",
#         "Gender": "Male",
#         "Family History": "Mother has systemic lupus erythematosus, brother has a bicuspid aortic valve",
#         "Social History": "Does not smoke cigarettes or drink alcohol",
#         "Medical History": "Colonic polyps diagnosed on screening colonoscopy 2 years ago"
#     },
#     "chief_complaint": {
#         "Chief Complaint": "Fatigue and shortness of breath progressively worse over the past week"
#     },
#     "gastrointestinal_examination": {
#         "Abdominal Palpation": "Not mentioned",
#         "Rectal Examination": "Not mentioned",
#         "Visible Signs": "Not mentioned"
#     },
#     "laboratory_findings": {
#         "Leukocyte Count": "9,500/mm3",
#         "Platelet Count": "178,000/mm3",
#         "FOBT": "Not mentioned",
#         "CEA": "Not mentioned",
#         "Liver Function Tests": "Total bilirubin 1.9 mg/dL",
#         "Serum": {
#             "Na+": "140 mEq/L",
#             "K+": "4.6 mEq/L"
#         }
#     },
#     "imaging_findings": {
#         "Colonoscopy Findings": "Colonic polyps diagnosed on screening colonoscopy 2 years ago",
#         "Colonoscopy Biopsy Results": "Not mentioned",
#         "CT Colonography": "Not mentioned",
#         "MRI": "Not mentioned"
#     },
#     "past_medical_history": {
#         "Chronic Conditions": "Hypertension, type 2 diabetes mellitus",
#         "Previous Colonoscopies": "Colonic polyps diagnosed on screening colonoscopy 2 years ago",
#         "Previous Surgeries": "Not mentioned",
#         "Allergies": "Not mentioned"
#     },
#     "review_of_gastrointestinal_system": {
#         "Bowel Habits": "Not mentioned",
#         "Rectal Bleeding": "Not mentioned",
#         "Abdominal Pain": "Not mentioned",
#         "Unexplained Weight Loss": "Not mentioned"
#     },
#     "assessment_diagnosis": {
#         "Provisional Diagnosis": "Not mentioned",
#         "Differential Diagnosis": "Not mentioned",
#         "Final Diagnosis": "Not mentioned"
#     },
#     "treatment_plan": {
#         "Polyp Removal": "Not mentioned",
#         "Medications Prescribed": "Lisinopril and metformin",
#         "Dietary Recommendations": "Not mentioned",
#         "Follow-up Colonoscopy": "Not mentioned",
#         "Referrals": "Not mentioned"
#     },
#     "patient_education": {
#         "Explanation of Findings": "Not mentioned",
#         "Lifestyle Modifications": "Not mentioned"
#     }
# }
# ```

# %%
# generate potential causes from the key information
potential_causes = generate_potential_causes(key_information.content)
print(potential_causes.content)
# Out:
# ```json
# [
#     {
#         "Evidence": [
#             "Age: 52",
#             "Gender: Male",
#             "Colonic polyps diagnosed on screening colonoscopy 2 years ago",
#             "Fatigue and shortness of breath progressively worse over the past week"
#         ],
#         "Cause": "Anemia due to gastrointestinal bleeding",
#         "Reasoning": "The patient's age and history of colonic polyps increase the risk of gastrointestinal bleeding, which can lead to anemia. Anemia could explain the symptoms of fatigue and shortness of breath. However, the absence of reported rectal bleeding or FOBT results makes this less certain."
#     },
#     {
#         "Evidence": [
#             "Age: 52",
#             "Gender: Male",
#             "Chronic Conditions: Hypertension, type 2 diabetes mellitus",
#             "Fatigue and shortness of breath progressively worse over the past week",
#             "Total bilirubin: 1.9 mg/dL"
#         ],
#         "Cause": "Cardiovascular disease",
#         "Reasoning": "The patient's age, gender, and history of hypertension and type 2 diabetes mellitus are risk factors for cardiovascular disease, which could manifest as fatigue and shortness of breath. The elevated bilirubin level might suggest liver involvement or hemolysis, which can be associated with cardiovascular issues."
#     },
#     {
#         "Evidence": [
#             "Age: 52",
#             "Gender: Male",
#             "Family History: Mother has systemic lupus erythematosus",
#             "Fatigue and shortness of breath progressively worse over the past week"
#         ],
#         "Cause": "Autoimmune disorder",
#         "Reasoning": "The family history of systemic lupus erythematosus suggests a potential genetic predisposition to autoimmune disorders. Fatigue and shortness of breath could be symptoms of an autoimmune condition affecting the lungs or causing systemic inflammation."
#     },
#     {
#         "Evidence": [
#             "Age: 52",
#             "Gender: Male",
#             "Fatigue and shortness of breath progressively worse over the past week",
#             "Total bilirubin: 1.9 mg/dL"
#         ],
#         "Cause": "Liver dysfunction",
#         "Reasoning": "The elevated total bilirubin level suggests possible liver dysfunction, which could lead to symptoms such as fatigue and shortness of breath. This could be due to a variety of causes, including medication side effects, non-alcoholic fatty liver disease, or other liver conditions."
#     }
# ]
# ```

# %%
# append an additional clause into user prompt of message_template
addition_message = (
    "user",
    "limit the potential causes only direct cause, not the indirect cause") 

poten_cause = generate_potential_causes(key_information.content, addition_message)

# %%
print(poten_cause.content)
# Out:
# ```json
# [
#     {
#         "Evidence": [
#             "Age: 52",
#             "Gender: Male",
#             "Medical History: Colonic polyps diagnosed on screening colonoscopy 2 years ago",
#             "Chief Complaint: Fatigue and shortness of breath progressively worse over the past week"
#         ],
#         "Cause": "Anemia due to gastrointestinal bleeding",
#         "Reasoning": "The patient's fatigue and shortness of breath could be indicative of anemia, which might be caused by bleeding from colonic polyps. Although there is no direct evidence of bleeding, the history of colonic polyps raises the possibility of occult gastrointestinal bleeding leading to anemia."
#     },
#     {
#         "Evidence": [
#             "Age: 52",
#             "Gender: Male",
#             "Medical History: Hypertension, type 2 diabetes mellitus",
#             "Chief Complaint: Fatigue and shortness of breath progressively worse over the past week",
#             "Serum Creatinine: 1.2 mg/dL",
#             "Total bilirubin: 1.9 mg/dL"
#         ],
#         "Cause": "Chronic kidney disease",
#         "Reasoning": "The patient's fatigue and shortness of breath could be related to chronic kidney disease, which is a common complication of hypertension and diabetes. The slightly elevated creatinine level and the presence of fatigue and shortness of breath could suggest a decline in renal function, contributing to these symptoms."
#     }
# ]
# ```

# %%
# Write a function to answer Multiple choice USMLE questions
def answer_multiple_choice_question(question, options):
    message = [
        (
            'system',
            "You are a medical doctor, experienced in diagnosing diseases."
        ),
        (
            "user",
            """"A": "IV fluid resuscitation", "B": "Administration of supplemental oxygen", "C": "Scheduled meal times", "D": "Monitoring and stress counseling", "E": "PO bismuth subsalicylate", "F": "Trial of metoclopramide", "G": "Discontinuation of ginger and vitamin B6", "H": "Addition of doxylamine""A": "IV fluid resuscitation", "B": "Administration of supplemental oxygen", "C": "Scheduled meal times", "D": "Monitoring and stress counseling", "E": "PO bismuth subsalicylate", "F": "Trial of metoclopramide", "G": "Discontinuation of ginger and vitamin B6", "H": "Addition of doxylamine"
            Answer the following multiple choice question: {question} {options} To answer this questions, do:
            - Action 1: for each answer option, find evidences to rule them out
            - Action 2: for each answer option, find evidences that may lead to inference on the causal path of patient infos
            - reasoning over Action 1 and Action 2 in a debate
            """.replace('{question}', question).replace('{options}', options)
        )
    ]
    answer = llm.invoke(message)
    return answer

# %%
multiple_choice_question = """
A 52-year-old man comes to to the emergency department with fatigue and shortness of breath that has become progressively worse over the past week. He had an upper respiratory tract infection 2 weeks ago, for which he was given an antibiotic. He has hypertension, type 2 diabetes mellitus, and colonic polyps diagnosed on screening colonoscopy 2 years ago. His mother has systemic lupus erythematosus and his brother has a bicuspid aortic valve. He does not smoke cigarettes or drink alcohol. Current medications include lisinopril and metformin. His temperature is 37.3°C (99.1°F), pulse is 91/min, respirations are 18/min, and blood pressure is 145/84 mm Hg. His conjunctivae are pale. Cardiac examination shows a late systolic crescendo-decrescendo murmur at the right upper sternal border. Laboratory studies show:\nLeukocyte Count 9,500/mm3\nHematocrit 24%\nPlatelet Count 178,000/mm3\nLDH 215 U/L\nHaptoglobin 22 mg/dL (N=41–165 mg/dL)\nSerum\nNa+ 140 mEq/L\nK+ 4.6 mEq/L\nCL- 100 mEq/L\nHCO3- 25 mEq/L\nUrea nitrogen 21 mg/dL\nCreatinine 1.2 mg/dL\nTotal bilirubin 1.9 mg/dL\nA peripheral blood smear is shown. Which of the following is the most likely cause of this patient's anemia?\
"""

multiple_choice_options = """
{"A": "Autoimmune destruction of erythrocytes", "B": "Occult blood loss", "C": "Erythrocyte membrane fragility", "D": "Erythrocyte enzyme defect", "E": "Mechanical destruction of erythrocytes"}
"""

# %%
multiple_choice_question_2 = """
A 46-year-old man is brought to the emergency department 15 minutes after being involved in a motor vehicle collision where he was the unrestrained driver. On arrival, he is unconscious. His respirations are 24/min, and palpable systolic blood pressure is 60 mm Hg, and pulse is 141/min and irregularly irregular. Examination shows multiple ecchymoses over the chest. There is a 3-cm (1.2-in) laceration over the abdomen and a 4-cm (1.6-in) laceration over the scalp. Jugular venous pressure is increased. Bilateral crackles are heard at the lung bases. Cardiac examination shows no murmurs, rubs, or gallops. The abdomen is soft. Two large bore intravenous catheters are inserted and 0.9% saline infusion is begun. Focused assessment with sonography in trauma (FAST) is negative. An electrocardiogram shows absent p-waves. After 5 minutes, his pulse is 160/min and palpable systolic blood pressure is 50 mm Hg. Vasopressors are administered. One hour later, the patient dies. Which of the following was the most likely diagnosis?
"""

multiple_choice_options_2 = """
"A": "Tracheobronchial injury", "B": "Cardiac contusion", "C": "Splenic rupture", "D": "Hemothorax", "E": "Aortic dissection", "F": "Pulmonary contusion", "G": "Cardiac tamponade\n\""
"""

# %%
multiple_choice_question_3 = """
A 29-year-old, gravida 1 para 0, at 10 weeks' gestation comes to the physician for progressively worsening emesis, nausea, and a 2-kg (4.7-lb) weight loss over the past 2 weeks. The most recent bouts of vomiting occur around 3–4 times a day, and she is stressed that she had to take a sick leave from work the last 2 days. She is currently taking ginger and vitamin B6 with limited relief. Her pulse is 80/min, blood pressure is 100/60 mmHg, and respiratory rate is 13/min. Orthostatic vital signs are within normal limits. The patient is alert and oriented. Her abdomen is soft and nontender. Urinalysis shows no abnormalities. Her hematocrit is 40%. Venous blood gas shows:\npH 7.43\npO2 42 mmHg\npCO2 54 mmHg\nHCO3- 31 mEq/L\nSO2 80%\nIn addition to oral fluid resuscitation, which of the following is the most appropriate next step in management?\
"""

multiple_choice_options_3 = """
"A": "IV fluid resuscitation", "B": "Administration of supplemental oxygen", "C": "Scheduled meal times", "D": "Monitoring and stress counseling", "E": "PO bismuth subsalicylate", "F": "Trial of metoclopramide", "G": "Discontinuation of ginger and vitamin B6", "H": "Addition of doxylamine"
"""

# %%
multiple_choice_answer = answer_multiple_choice_question(multiple_choice_question, multiple_choice_options)
print(multiple_choice_answer.content)
# Out:
# To determine the most likely cause of this patient's anemia, let's evaluate each answer option based on the provided clinical information and laboratory findings.
#
# **Action 1: Rule Out Evidence**
#
# - **A: Autoimmune destruction of erythrocytes**
#   - Typically associated with positive direct Coombs test and spherocytes on peripheral smear. The patient's history and lab findings do not specifically indicate autoimmune hemolytic anemia.
#
# - **B: Occult blood loss**
#   - Would typically present with iron deficiency anemia, characterized by microcytic, hypochromic anemia. The lab findings do not suggest iron deficiency (e.g., no mention of low MCV or low serum iron).
#
# - **C: Erythrocyte membrane fragility**
#   - Conditions like hereditary spherocytosis would show spherocytes on the blood smear and a positive osmotic fragility test. The patient's history and lab findings do not suggest this.
#
# - **D: Erythrocyte enzyme defect**
#   - Conditions like G6PD deficiency would present with hemolytic anemia, often triggered by certain drugs or infections, and show bite cells or Heinz bodies on the smear. The history of recent antibiotic use could be relevant, but specific smear findings are not mentioned.
#
# - **E: Mechanical destruction of erythrocytes**
#   - Associated with schistocytes on the peripheral smear, elevated LDH, low haptoglobin, and elevated indirect bilirubin, consistent with microangiopathic hemolytic anemia or mechanical heart valve issues. The presence of a heart murmur and the lab findings support this.
#
# **Action 2: Evidence Supporting Each Option**
#
# - **A: Autoimmune destruction of erythrocytes**
#   - The family history of autoimmune disease (mother with lupus) could suggest a predisposition, but no direct evidence of autoimmune hemolysis is provided.
#
# - **B: Occult blood loss**
#   - The patient has colonic polyps, which could potentially bleed, but the lab findings do not indicate iron deficiency anemia.
#
# - **C: Erythrocyte membrane fragility**
#   - No specific evidence of hereditary spherocytosis or similar conditions is provided.
#
# - **D: Erythrocyte enzyme defect**
#   - The recent antibiotic use could suggest a trigger for G6PD deficiency, but specific peripheral smear findings are not mentioned.
#
# - **E: Mechanical destruction of erythrocytes**
#   - The presence of a heart murmur and the lab findings (low haptoglobin, elevated LDH, elevated bilirubin) are consistent with hemolysis due to mechanical destruction, such as from aortic stenosis or a prosthetic valve.
#
# **Reasoning and Debate**
#
# - **Autoimmune destruction** is less likely due to the lack of specific evidence such as a positive Coombs test or spherocytes.
# - **Occult blood loss** is unlikely given the absence of microcytic anemia or iron deficiency indicators.
# - **Erythrocyte membrane fragility** is not supported by the clinical or laboratory findings.
# - **Erythrocyte enzyme defect** could be considered due to recent antibiotic use, but without specific smear findings, it is less likely.
# - **Mechanical destruction** is the most supported by the evidence: the heart murmur suggests possible aortic stenosis, and the lab findings are consistent with hemolytic anemia due to mechanical causes.
#
# Based on the evidence and reasoning, the most likely cause of this patient's anemia is **E: Mechanical destruction of erythrocytes**.

# %%
multiple_choice_answer = answer_multiple_choice_question(multiple_choice_question, options="None")
print(multiple_choice_answer.content)
# Out:
# To determine the most likely cause of this patient's anemia, we need to analyze the clinical presentation and laboratory findings. The key findings include fatigue, shortness of breath, pale conjunctivae, a heart murmur, low hematocrit, low haptoglobin, elevated LDH, and elevated total bilirubin. The peripheral blood smear is not provided here, but we can infer it might show schistocytes given the context.
#
# Let's consider potential causes of anemia and evaluate them:
#
# 1. **Iron Deficiency Anemia:**
#    - **Action 1 (Rule Out):** Iron deficiency anemia typically presents with microcytic, hypochromic anemia. The low haptoglobin and elevated LDH and bilirubin suggest hemolysis, which is not characteristic of iron deficiency anemia.
#    - **Action 2 (Inference):** The patient's history of colonic polyps and potential gastrointestinal bleeding could suggest iron deficiency, but the laboratory findings are more indicative of hemolysis.
#
# 2. **Anemia of Chronic Disease:**
#    - **Action 1 (Rule Out):** Anemia of chronic disease usually presents with normocytic or microcytic anemia and is associated with chronic inflammation or infection. The hemolytic markers (low haptoglobin, elevated LDH, and bilirubin) are not typical.
#    - **Action 2 (Inference):** The patient's chronic conditions (hypertension, diabetes) could contribute to anemia of chronic disease, but the acute presentation and lab findings suggest otherwise.
#
# 3. **Hemolytic Anemia (e.g., Drug-Induced Hemolytic Anemia):**
#    - **Action 1 (Rule Out):** The presence of hemolytic markers (low haptoglobin, elevated LDH, elevated bilirubin) supports hemolysis. The recent antibiotic use could suggest drug-induced hemolytic anemia.
#    - **Action 2 (Inference):** The patient's recent antibiotic use, combined with the hemolytic markers, suggests a possible drug-induced hemolytic anemia, especially if the antibiotic was one known to cause hemolysis (e.g., cephalosporins, penicillins).
#
# 4. **Autoimmune Hemolytic Anemia:**
#    - **Action 1 (Rule Out):** Autoimmune hemolytic anemia would also present with hemolytic markers. However, there is no direct evidence of autoimmune activity (e.g., positive Coombs test) provided.
#    - **Action 2 (Inference):** The family history of systemic lupus erythematosus could suggest a predisposition to autoimmune conditions, but the acute presentation following antibiotic use leans more towards drug-induced hemolysis.
#
# 5. **Mechanical Hemolysis (e.g., from aortic stenosis):**
#    - **Action 1 (Rule Out):** Mechanical hemolysis can occur with aortic stenosis, which could be suggested by the heart murmur. However, the murmur described is more consistent with aortic sclerosis or mild stenosis.
#    - **Action 2 (Inference):** The heart murmur could suggest some degree of mechanical hemolysis, but the acute presentation following antibiotic use is more suggestive of drug-induced hemolysis.
#
# **Debate and Conclusion:**
# The most compelling evidence points towards drug-induced hemolytic anemia. The acute onset of symptoms following antibiotic use, combined with the laboratory findings of hemolysis (low haptoglobin, elevated LDH, elevated bilirubin), strongly suggests this diagnosis. While other forms of hemolytic anemia and mechanical causes could be considered, the temporal relationship with antibiotic use is a key factor. Therefore, the most likely cause of this patient's anemia is drug-induced hemolytic anemia.

# %%
multilple_choice_answer_2 = answer_multiple_choice_question(multiple_choice_question_2, multiple_choice_options_2)
print(multilple_choice_answer_2.content)
# Out:
# To determine the most likely diagnosis for this patient, let's evaluate each option based on the provided clinical information.
#
# ### Action 1: Rule Out Evidence
#
# - **A: Tracheobronchial injury**
#   - Typically presents with respiratory distress, subcutaneous emphysema, and pneumothorax. The patient has increased jugular venous pressure and bilateral crackles, which are not classic for tracheobronchial injury.
#
# - **B: Cardiac contusion**
#   - Can cause arrhythmias and hypotension. The irregularly irregular pulse and absent p-waves suggest atrial fibrillation, which can occur with cardiac contusion. However, the rapid deterioration and increased jugular venous pressure are more suggestive of another condition.
#
# - **C: Splenic rupture**
#   - Would likely present with abdominal pain, tenderness, and signs of internal bleeding. The FAST exam was negative, and the abdomen is soft, making splenic rupture less likely.
#
# - **D: Hemothorax**
#   - Would present with decreased breath sounds and dullness to percussion on the affected side. The bilateral crackles and increased jugular venous pressure are not typical for hemothorax.
#
# - **E: Aortic dissection**
#   - Typically presents with severe chest or back pain and may cause differential blood pressures in the limbs. The absence of these symptoms and the presence of increased jugular venous pressure make this less likely.
#
# - **F: Pulmonary contusion**
#   - Can cause respiratory distress and crackles, but would not typically cause increased jugular venous pressure or the rapid hemodynamic instability seen here.
#
# - **G: Cardiac tamponade**
#   - Presents with hypotension, increased jugular venous pressure, and muffled heart sounds (Beck's triad). The increased jugular venous pressure and hypotension are consistent with tamponade, even though muffled heart sounds are not mentioned.
#
# ### Action 2: Evidence Supporting Each Option
#
# - **A: Tracheobronchial injury**
#   - The presence of respiratory distress could be a supporting factor, but the other symptoms do not align well.
#
# - **B: Cardiac contusion**
#   - The arrhythmia and hypotension could support this, but the rapid decline and jugular venous pressure suggest a more acute cardiac compromise.
#
# - **C: Splenic rupture**
#   - The hypotension could suggest internal bleeding, but the negative FAST and soft abdomen argue against it.
#
# - **D: Hemothorax**
#   - Hypotension could be due to blood loss, but the lung findings and jugular venous pressure do not support this.
#
# - **E: Aortic dissection**
#   - The hypotension could be due to aortic rupture, but the jugular venous pressure and lack of classic symptoms make it unlikely.
#
# - **F: Pulmonary contusion**
#   - The crackles could support this, but the jugular venous pressure and rapid decline are not typical.
#
# - **G: Cardiac tamponade**
#   - The increased jugular venous pressure, hypotension, and rapid decline are classic for tamponade, even without muffled heart sounds.
#
# ### Reasoning and Conclusion
#
# The patient's presentation of hypotension, increased jugular venous pressure, and rapid deterioration is most consistent with **cardiac tamponade**. While the classic Beck's triad includes muffled heart sounds, the absence of this finding does not rule out tamponade, especially in a trauma setting where rapid accumulation of blood in the pericardial space can occur. The negative FAST could be due to the limitations of the exam or rapid progression of the condition. Therefore, the most likely diagnosis is **G: Cardiac tamponade**.

# %%
multiple_choice_question_3 = answer_multiple_choice_question(multiple_choice_question_3, multiple_choice_options_3)
print(multiple_choice_question_3.content)
# Out:
# To address the question, let's evaluate each answer option based on the patient's presentation and the available evidence.
#
# **Action 1: Rule Out Evidence for Each Option**
#
# - **A: IV fluid resuscitation**
#   - The patient is not showing signs of dehydration or orthostatic hypotension, and her vital signs are stable. Oral fluid resuscitation is already mentioned, suggesting that IV fluids may not be necessary at this point.
#
# - **B: Administration of supplemental oxygen**
#   - The patient is not exhibiting respiratory distress or hypoxia. The low pO2 and SO2 are likely due to venous blood gas sampling, which is not indicative of her actual oxygenation status.
#
# - **C: Scheduled meal times**
#   - While helpful in managing nausea, this option does not directly address the severity of her symptoms or provide immediate relief.
#
# - **D: Monitoring and stress counseling**
#   - While stress counseling may be beneficial, it does not address the acute management of her nausea and vomiting.
#
# - **E: PO bismuth subsalicylate**
#   - This is not typically used for nausea and vomiting in pregnancy and is not recommended due to potential risks.
#
# - **F: Trial of metoclopramide**
#   - Metoclopramide is an antiemetic that could be considered, but it is not the first-line treatment for nausea and vomiting in pregnancy.
#
# - **G: Discontinuation of ginger and vitamin B6**
#   - Ginger and vitamin B6 are safe and commonly used for nausea in pregnancy. Discontinuing them would not be beneficial.
#
# - **H: Addition of doxylamine**
#   - Doxylamine, in combination with vitamin B6, is a first-line treatment for nausea and vomiting in pregnancy (NVP).
#
# **Action 2: Evidence Leading to Inference on Causal Path**
#
# - **A: IV fluid resuscitation**
#   - If the patient were dehydrated or had electrolyte imbalances, IV fluids would be appropriate, but her stable vitals and normal urinalysis suggest otherwise.
#
# - **B: Administration of supplemental oxygen**
#   - The venous blood gas results are not indicative of a need for oxygen therapy.
#
# - **C: Scheduled meal times**
#   - This could help manage symptoms long-term but does not provide immediate relief.
#
# - **D: Monitoring and stress counseling**
#   - While beneficial for overall well-being, it does not address the acute symptoms.
#
# - **E: PO bismuth subsalicylate**
#   - Not recommended for use in pregnancy due to potential risks.
#
# - **F: Trial of metoclopramide**
#   - Could be considered if first-line treatments fail, but not the initial step.
#
# - **G: Discontinuation of ginger and vitamin B6**
#   - These are safe and effective for mild symptoms, so discontinuation is not advised.
#
# - **H: Addition of doxylamine**
#   - Evidence supports the use of doxylamine with vitamin B6 as a first-line treatment for NVP, providing a logical next step in management.
#
# **Reasoning Over Action 1 and Action 2 in a Debate**
#
# The patient's symptoms are consistent with nausea and vomiting of pregnancy (NVP), and she is already using vitamin B6 with limited relief. The addition of doxylamine is supported by guidelines as a first-line treatment for NVP, making it the most appropriate next step. Other options either do not address the acute management of her symptoms or are not recommended in pregnancy. Therefore, the best choice is:
#
# **H: Addition of doxylamine**

# %%
fine_tune_prompt = """
If the question were open-ended and "mechanical destruction of erythrocytes" wasn't explicitly listed, a clinician would need to methodically reason through the patient's presentation, physical findings, and lab results to deduce the most likely cause. Here's how a doctor might approach this case step-by-step:

### 1. **Assess the Patient’s Symptoms and History:**
   - **Fatigue and shortness of breath:** These are common symptoms of anemia, indicating reduced oxygen-carrying capacity of the blood.
   - **Recent upper respiratory infection:** This could suggest an immune or inflammatory trigger, potentially leading to hemolysis, but not necessarily indicating a specific type yet.
   - **Chronic conditions:** Hypertension and type 2 diabetes may not directly cause acute anemia, but they are important background details.
   - **Family history of systemic lupus erythematosus and bicuspid aortic valve:** These are relevant. Lupus could predispose to autoimmune conditions, while a bicuspid aortic valve suggests a possible genetic predisposition to aortic stenosis or other valve disorders.

### 2. **Examine the Physical Findings:**
   - **Pale conjunctivae:** A sign of anemia, confirming the clinical suspicion of low hemoglobin or hematocrit.
   - **Heart murmur:** This is a key finding. The **late systolic crescendo-decrescendo murmur** heard at the **right upper sternal border** is characteristic of **aortic stenosis**, which is often linked to a **bicuspid aortic valve**.
     - A bicuspid valve is prone to degeneration, leading to stenosis.
     - In stenosis, red blood cells passing through the turbulent flow across the valve can be mechanically damaged, leading to hemolysis.

### 3. **Interpret the Laboratory Findings:**
   - **Elevated bilirubin (1.9 mg/dL)** and **low haptoglobin (22 mg/dL):** These suggest hemolysis. Bilirubin is a breakdown product of hemoglobin, and haptoglobin binds free hemoglobin released from destroyed red blood cells.
   - **Normal LDH:** LDH is slightly elevated, which supports ongoing hemolysis but not at an overwhelming level.
   - **Leukocyte and platelet counts are normal:** This helps rule out conditions like bone marrow suppression or severe inflammatory disease that would alter other blood cell lines.

### 4. **Generate Hypotheses for the Cause of Hemolysis:**
   At this point, a clinician is aware that hemolysis is occurring but needs to figure out the underlying cause. The key decision-making process involves:
   - **Autoimmune hemolysis:** Given the recent infection, AIHA (autoimmune hemolytic anemia) is a reasonable consideration, especially with a family history of lupus. However, there is no mention of a Coombs test result (direct antibody test) that would be critical for confirming this diagnosis.
   - **Enzyme defects (like G6PD deficiency):** This can cause hemolysis, especially triggered by infections or certain medications. But there is no mention of drug triggers or typical findings like "bite cells" or "Heinz bodies" on the blood smear.
   - **Mechanical hemolysis:** The **murmur** and **family history of bicuspid aortic valve** are critical clues that suggest **mechanical destruction of erythrocytes** due to **aortic stenosis**. The turbulence created by the stenotic valve can shear red blood cells, leading to hemolysis, which would explain the low haptoglobin and high bilirubin.

### 5. **Synthesize the Information:**
   Based on the evidence:
   - **Hemolysis is confirmed** (low haptoglobin, elevated bilirubin).
   - **Aortic stenosis** is highly likely, given the heart murmur, family history, and patient age.
   - Mechanical destruction from the stenotic valve is the most plausible cause of hemolysis, given the absence of autoimmune markers or signs of other causes like enzyme defects.

### 6. **Final Deduction:**
   - Even without the option of "mechanical destruction of erythrocytes," the presence of a heart murmur (suggesting aortic stenosis) and the clear evidence of hemolysis would push a doctor toward the conclusion that **the heart valve abnormality is likely causing the anemia**. The clinical reasoning would point toward **mechanical hemolysis secondary to aortic stenosis**, especially in the context of a known family history of bicuspid aortic valve disease.

In summary, a doctor would start with general causes of anemia, narrow down to hemolysis based on lab findings, and use the heart murmur as the critical clue to deduce mechanical destruction of erythrocytes due to aortic stenosis.
"""

# %%
# Write a function to answer Multiple choice USMLE questions
def answer_multiple_choice_question_noexplain(question, options="None", fine_tune_prompt="None"):
    message = [
        (
            'system',
            "You are a medical doctor, experienced in diagnosing diseases."
        ),
        (
            "user",
            """
            Answer the following multiple choice question: {question} {options} To answer this questions, do:
            - If 'options' is 'None', Generate 5 potential causes. the answer should follow {fine_tune_prompt}
            - Action 1: for each answer option, find evidences to rule them out
            - Action 2: for each answer option, find evidences that may lead to inference on the causal path of patient infos
            - reasoning over Action 1 and Action 2 in a debate
            - Criteria and Scoring System:
            1. Level of Evidence Supported in the Context (available in the text)
            High (3 points): Direct evidence in the clinical scenario strongly supports the cause.
            Moderate (2 points): Some evidence in the text supports the cause, but it's not conclusive.
            Low (1 point): Little or no evidence in the text supports the cause.
            2. Level of Evidence Supported in the Causal Path Inference (available through deduction)
            High (3 points): Strong deductive reasoning leads to this cause based on history, lab results, and the clinical picture.
            Moderate (2 points): Deductive reasoning could support this cause but requires more assumptions or is less likely.
            Low (1 point): Deductive reasoning provides little to no support for this cause.
            3. Amount of Next Step Examinations Needed for Ruling Out or Confirmation
            Low (3 points): Few or no additional tests are required because the current evidence is sufficient to make the diagnosis.
            Moderate (2 points): Some additional tests are required to confirm or rule out the cause.
            High (1 point): Several additional tests are needed because the current evidence is insufficient to confirm or rule out the cause.
            - Only return the answer with the highest confidence score, with format:
            '{
                "Answer_letter": "Answer option A, B, C, etc.",
                "level_of_evidence": "3, 2, 1",
                "level_of_deduction": "3, 2, 1",
                "amount_of_next_step": "3, 2, 1",
                "Answer_text": "Answer text"
            }'
            """.replace('{question}', question).replace('{options}', options).replace('{fine_tune_prompt}', fine_tune_prompt)
        )
    ]
    answer = llm.invoke(message)
    return answer

# %%
Norm_rubric_prompt = """
Criteria and Scoring System:
1. Level of Evidence Supported in the Context (available in the text)
High (3 points): Direct evidence in the clinical scenario strongly supports the cause.
Moderate (2 points): Some evidence in the text supports the cause, but it's not conclusive.
Low (1 point): Little or no evidence in the text supports the cause.
2. Level of Evidence Supported in the Causal Path Inference (available through deduction)
High (3 points): Strong deductive reasoning leads to this cause based on history, lab results, and the clinical picture.
Moderate (2 points): Deductive reasoning could support this cause but requires more assumptions or is less likely.
Low (1 point): Deductive reasoning provides little to no support for this cause.
3. Amount of Next Step Examinations Needed for Ruling Out or Confirmation
Low (3 points): Few or no additional tests are required because the current evidence is sufficient to make the diagnosis.
Moderate (2 points): Some additional tests are required to confirm or rule out the cause.
High (1 point): Several additional tests are needed because the current evidence is insufficient to confirm or rule out the cause.

Output format:
{
    "Answer_letter": "Answer option A, B, C, etc.",
    "level_of_evidence": "3, 2, 1",
    "level_of_deduction": "3, 2, 1",
    "amount_of_next_step": "3, 2, 1",
    "Answer_text": "Answer text"
}
"""

Criterion_rubric_prompt = """
Scoring guide:
High (3 points): The answer provides direct evidence or uses widely accepted medical guidelines.
Moderate (2 points): The answer relies on some inferential reasoning or partial evidence but is plausible.
Low (1 point): The answer lacks sufficient evidence, or there’s significant uncertainty
Deduction question reasoning:
Strength of Evidence: Does the answer cite relevant studies, guidelines, or well-established practices?
Relevance to Clinical Scenario: Is the answer directly addressing the scenario without speculation?
Logical Consistency: Is the answer logically coherent and free of contradictions?
Comprehensiveness: Does the answer account for all the symptoms or findings provided in the scenario?

Rubric:
1. Strength of Evidence
High (3 points): Supported by direct evidence or widely accepted clinical guidelines.
Moderate (2 points): Supported by inferential reasoning or partial evidence.
Low (1 point): Lacks sufficient evidence or has significant uncertainty.
2. Relevance to Clinical Scenario
High (3 points): Directly addresses the scenario without speculation.
Moderate (2 points): Partially addresses the scenario or includes some speculation.
Low (1 point): Lacks relevance to the scenario or is highly speculative.
3. Logical Consistency
High (3 points): Logically coherent and free of contradictions, strong deductive reasoning.
Moderate (2 points): Contains some deductive assumptions but generally coherent.
Low (1 point): Contains logical inconsistencies or contradictions.
4. Comprehensiveness
High (3 points): Accounts for all symptoms or findings in the scenario.
Moderate (2 points): Addresses most symptoms or findings but may miss some.
Low (1 point): Few symptoms considered or Fails to address key symptoms or findings.

Output format:
{
    "Strength of Evidence": "3, 2, 1",
    "Relevance to Clinical Scenario": "3, 2, 1",
    "Logical Consistency": "3, 2, 1",
    "Comprehensiveness": "3, 2, 1",
    "Answer": "Answer text",
    "Answer_letter": "Answer option A, B, C, etc. if present"
}
"""

Generatiion_Confidence_scoring_prompt = """
evaluate how confident they are about the answer’s accuracy based on the provided evidence.
Confidence scoring adds an extra layer of objectivity by assessing how well the answer fits with known medical knowledge or guidelines.
Confidence can be expressed on a 1 to 5 scale where raters score their certainty based on clinical evidence and reasoning:
5 (Very High Confidence): Strong clinical guidelines or consensus support the answer.
4 (High Confidence): Strong deductive reasoning and partial evidence support the answer.
3 (Moderate Confidence): The answer is plausible but lacks strong supporting evidence.
2 (Low Confidence): The answer requires further confirmation or evidence.
1 (Very Low Confidence): The answer is unlikely to be correct based on available information.
"""

# For the idea of breaking down the question into parts, I follow up by using this simple prompt to break down the question into parts
Structured_open_ended_response_prompt = """
Break down the question into parts:
Proposed Diagnosis
Proposed Treatment
Evidence/Reasoning Supporting Diagnosis
Evidence/Reasoning Supporting Treatment
"""

# %%
# Write a function to answer Open-ended USMLE questions

def answer_open_ended_question(question, fine_tune_prompt="None", options = "None", rubric_prompt="None"):
    message = [
        (
            'system',
            "You are a medical doctor, experienced in diagnosing diseases."
        ),
        (
            'user',
            """
            If {options} is not 'None', follow {rubric_prompt}, return the best answer based on the rubric
            If {options} is 'None',
            Answer the following open-ended question: {question} To answer this questions, do:
            - If 'fine_tune_prompt' is not 'None' the answer should follow {fine_tune_prompt}
            - Action 1: Generate all potential causes. the answer should follow {fine_tune_prompt}
            - Action 2: for each potential cause, evaluate by using {rubric_prompt}. If 'rubric_prompt' is 'None', generate a rubric for evaluation
            Output format: follow the rubric.
            """.replace('{question}', question).replace('{fine_tune_prompt}', fine_tune_prompt).replace('{options}', options).replace('{rubric_prompt}', rubric_prompt)
        )
    ]
    answer = llm.invoke(message)
    return answer

# %%
open_ended_question_answer = answer_open_ended_question(multiple_choice_question, rubric_prompt=Criterion_rubric_prompt)
print(open_ended_question_answer.content)
# Out:
# **Action 1: Generate 5 potential causes for the patient's anemia.**
#
# 1. Hemolytic anemia due to drug-induced hemolysis.
# 2. Anemia of chronic disease.
# 3. Iron deficiency anemia.
# 4. Vitamin B12 or folate deficiency anemia.
# 5. Aplastic anemia.
#
# **Action 2: Evaluate each potential cause using the scoring guide.**
#
# 1. **Hemolytic anemia due to drug-induced hemolysis**
#    - **Strength of Evidence:** High (3 points) - The low haptoglobin, elevated bilirubin, and recent antibiotic use suggest hemolysis, which is a well-documented cause of anemia.
#    - **Relevance to Clinical Scenario:** High (3 points) - Directly addresses the symptoms and lab findings, including the recent history of antibiotic use.
#    - **Logical Consistency:** High (3 points) - The findings are consistent with hemolytic anemia.
#    - **Comprehensiveness:** High (3 points) - Accounts for the anemia, jaundice, and recent medication history.
#
# 2. **Anemia of chronic disease**
#    - **Strength of Evidence:** Moderate (2 points) - While plausible given the patient's chronic conditions, the lab findings are more indicative of hemolysis.
#    - **Relevance to Clinical Scenario:** Moderate (2 points) - Partially addresses the scenario but does not explain the low haptoglobin and elevated bilirubin.
#    - **Logical Consistency:** Moderate (2 points) - Somewhat consistent but lacks explanation for all lab findings.
#    - **Comprehensiveness:** Moderate (2 points) - Does not fully account for the lab findings.
#
# 3. **Iron deficiency anemia**
#    - **Strength of Evidence:** Low (1 point) - No evidence of microcytic anemia or low iron studies provided.
#    - **Relevance to Clinical Scenario:** Low (1 point) - Does not address the lab findings or recent history.
#    - **Logical Consistency:** Low (1 point) - Inconsistent with the lab findings.
#    - **Comprehensiveness:** Low (1 point) - Fails to address key symptoms and findings.
#
# 4. **Vitamin B12 or folate deficiency anemia**
#    - **Strength of Evidence:** Low (1 point) - No evidence of macrocytic anemia or neurological symptoms.
#    - **Relevance to Clinical Scenario:** Low (1 point) - Does not address the lab findings or recent history.
#    - **Logical Consistency:** Low (1 point) - Inconsistent with the lab findings.
#    - **Comprehensiveness:** Low (1 point) - Fails to address key symptoms and findings.
#
# 5. **Aplastic anemia**
#    - **Strength of Evidence:** Low (1 point) - Normal leukocyte and platelet counts do not support this diagnosis.
#    - **Relevance to Clinical Scenario:** Low (1 point) - Does not address the lab findings or recent history.
#    - **Logical Consistency:** Low (1 point) - Inconsistent with the lab findings.
#    - **Comprehensiveness:** Low (1 point) - Fails to address key symptoms and findings.
#
# **Conclusion:**
# The most likely cause of this patient's anemia is hemolytic anemia due to drug-induced hemolysis, as it scores the highest across all evaluation criteria.

# %%
open_ended_question_answer = answer_open_ended_question(multiple_choice_question, fine_tune_prompt=fine_tune_prompt, rubric_prompt=Criterion_rubric_prompt)
print(open_ended_question_answer.content)
# Out:
# ### Potential Causes of Anemia in This Patient:
#
# 1. **Mechanical Destruction of Erythrocytes (Hemolysis due to Aortic Stenosis):**
#    - **Strength of Evidence:** High (3 points) - The presence of a heart murmur characteristic of aortic stenosis, combined with a family history of bicuspid aortic valve, strongly supports this diagnosis. The lab findings of low haptoglobin and elevated bilirubin are consistent with hemolysis.
#    - **Relevance to Clinical Scenario:** High (3 points) - Directly addresses the scenario with the heart murmur and lab findings pointing towards mechanical hemolysis.
#    - **Logical Consistency:** High (3 points) - The reasoning is coherent, linking the heart murmur to mechanical hemolysis.
#    - **Comprehensiveness:** High (3 points) - Accounts for all symptoms and findings, including the heart murmur, family history, and lab results.
#
# 2. **Autoimmune Hemolytic Anemia (AIHA):**
#    - **Strength of Evidence:** Moderate (2 points) - The recent infection could trigger AIHA, and the family history of lupus supports an autoimmune process, but there is no direct evidence like a positive Coombs test.
#    - **Relevance to Clinical Scenario:** Moderate (2 points) - Partially addresses the scenario, but lacks specific evidence of autoimmune activity.
#    - **Logical Consistency:** Moderate (2 points) - The reasoning is plausible but lacks direct evidence.
#    - **Comprehensiveness:** Moderate (2 points) - Considers some symptoms but lacks confirmation of autoimmune hemolysis.
#
# 3. **Drug-Induced Hemolytic Anemia:**
#    - **Strength of Evidence:** Low (1 point) - No specific drug known to cause hemolysis is mentioned, and the antibiotics used are not specified.
#    - **Relevance to Clinical Scenario:** Low (1 point) - Lacks relevance without specific drug information.
#    - **Logical Consistency:** Low (1 point) - Speculative without evidence of drug involvement.
#    - **Comprehensiveness:** Low (1 point) - Fails to address key symptoms or findings.
#
# 4. **G6PD Deficiency:**
#    - **Strength of Evidence:** Low (1 point) - No mention of typical triggers or findings like "bite cells" or "Heinz bodies."
#    - **Relevance to Clinical Scenario:** Low (1 point) - Lacks relevance without specific triggers or findings.
#    - **Logical Consistency:** Low (1 point) - Speculative without supporting evidence.
#    - **Comprehensiveness:** Low (1 point) - Does not account for the specific symptoms or findings.
#
# 5. **Anemia of Chronic Disease:**
#    - **Strength of Evidence:** Low (1 point) - The lab findings are more indicative of hemolysis rather than anemia of chronic disease.
#    - **Relevance to Clinical Scenario:** Low (1 point) - Does not directly address the acute presentation and lab findings.
#    - **Logical Consistency:** Low (1 point) - Inconsistent with the acute nature and lab findings.
#    - **Comprehensiveness:** Low (1 point) - Fails to address the acute symptoms and specific lab findings.
#
# ### Evaluation Rubric:
#
# 1. **Strength of Evidence:**
#    - High (3 points): Supported by direct evidence or widely accepted clinical guidelines.
#    - Moderate (2 points): Supported by inferential reasoning or partial evidence.
#    - Low (1 point): Lacks sufficient evidence or has significant uncertainty.
#
# 2. **Relevance to Clinical Scenario:**
#    - High (3 points): Directly addresses the scenario without speculation.
#    - Moderate (2 points): Partially addresses the scenario or includes some speculation.
#    - Low (1 point): Lacks relevance to the scenario or is highly speculative.
#
# 3. **Logical Consistency:**
#    - High (3 points): Logically coherent and free of contradictions, strong deductive reasoning.
#    - Moderate (2 points): Contains some deductive assumptions but generally coherent.
#    - Low (1 point): Contains logical inconsistencies or contradictions.
#
# 4. **Comprehensiveness:**
#    - High (3 points): Accounts for all symptoms or findings in the scenario.
#    - Moderate (2 points): Addresses most symptoms or findings but may miss some.
#    - Low (1 point): Few symptoms considered or fails to address key symptoms or findings.

# %%
open_ended_question_answer_2 = answer_open_ended_question(multiple_choice_question_2, fine_tune_prompt=fine_tune_prompt, rubric_prompt=Norm_rubric_prompt)
print(open_ended_question_answer_2.content)
# Out:
# To address the clinical scenario of the 46-year-old man involved in a motor vehicle collision, we need to determine the most likely cause of his rapid deterioration and subsequent death. Here is a step-by-step approach to the case:
#
# ### 1. **Assess the Patient’s Symptoms and History:**
#    - **Unconsciousness and irregularly irregular pulse:** Suggests a possible cardiac arrhythmia, such as atrial fibrillation.
#    - **Hypotension (systolic BP 60 mm Hg) and tachycardia (pulse 141/min):** Indicate shock, likely hypovolemic or cardiogenic.
#    - **Increased jugular venous pressure and bilateral crackles:** Suggestive of cardiac tamponade or heart failure.
#
# ### 2. **Examine the Physical Findings:**
#    - **Multiple ecchymoses over the chest:** Could indicate significant chest trauma.
#    - **Lacerations over the abdomen and scalp:** Indicate potential for internal bleeding or head injury.
#    - **Jugular venous distension and crackles:** Point towards cardiac tamponade or tension pneumothorax.
#
# ### 3. **Interpret the Diagnostic Findings:**
#    - **FAST negative:** Rules out significant hemoperitoneum or hemothorax.
#    - **ECG shows absent p-waves:** Consistent with atrial fibrillation, which can lead to hemodynamic instability.
#
# ### 4. **Generate Hypotheses for the Cause of Deterioration:**
#    - **Cardiac tamponade:** Given the increased jugular venous pressure and hypotension, this is a strong possibility.
#    - **Tension pneumothorax:** Could cause similar symptoms but would likely show on FAST or physical exam.
#    - **Massive pulmonary embolism:** Could cause sudden cardiovascular collapse but less likely given the trauma context.
#    - **Severe hemorrhagic shock:** Despite negative FAST, could be due to retroperitoneal or other non-visible bleeding.
#    - **Traumatic brain injury:** Could explain unconsciousness but not the cardiovascular findings.
#
# ### 5. **Evaluate Each Potential Cause:**
#
# 1. **Cardiac Tamponade:**
#    - **Context Evidence:** High (3 points) - Jugular venous distension and hypotension are classic signs.
#    - **Causal Path Inference:** High (3 points) - Trauma can lead to pericardial effusion and tamponade.
#    - **Next Step Examinations:** Low (3 points) - Pericardiocentesis or echocardiogram could confirm.
#
# 2. **Tension Pneumothorax:**
#    - **Context Evidence:** Moderate (2 points) - Respiratory distress and hypotension fit, but FAST negative.
#    - **Causal Path Inference:** Moderate (2 points) - Trauma can cause pneumothorax, but less likely with negative FAST.
#    - **Next Step Examinations:** Moderate (2 points) - Chest X-ray or clinical decompression could confirm.
#
# 3. **Massive Pulmonary Embolism:**
#    - **Context Evidence:** Low (1 point) - Less likely in trauma without prior risk factors.
#    - **Causal Path Inference:** Low (1 point) - Unlikely given the acute trauma setting.
#    - **Next Step Examinations:** High (1 point) - Requires CT pulmonary angiography for confirmation.
#
# 4. **Severe Hemorrhagic Shock:**
#    - **Context Evidence:** Moderate (2 points) - Hypotension and tachycardia suggest shock, but FAST negative.
#    - **Causal Path Inference:** Moderate (2 points) - Possible with retroperitoneal bleed.
#    - **Next Step Examinations:** High (1 point) - Requires further imaging or surgical exploration.
#
# 5. **Traumatic Brain Injury:**
#    - **Context Evidence:** Low (1 point) - Unconsciousness fits, but not cardiovascular findings.
#    - **Causal Path Inference:** Low (1 point) - Does not explain shock or jugular venous distension.
#    - **Next Step Examinations:** High (1 point) - CT scan of the head needed.
#
# ### Conclusion:
# The most likely diagnosis, given the clinical presentation and rapid deterioration, is **cardiac tamponade** due to trauma. This is supported by the increased jugular venous pressure, hypotension, and the context of chest trauma.

# %%
open_ended_question_answer_2 = answer_open_ended_question(multiple_choice_question_2, fine_tune_prompt=fine_tune_prompt, rubric_prompt=Norm_rubric_prompt)
print(open_ended_question_answer_2.content)
# Out:
# The scenario provided describes a 46-year-old man who was involved in a motor vehicle collision and presented with signs of severe trauma and hemodynamic instability. The key clinical findings include unconsciousness, irregularly irregular pulse, hypotension, increased jugular venous pressure, bilateral crackles, and a negative FAST exam. The ECG shows absent p-waves, and the patient deteriorates rapidly despite intervention.
#
# Given these findings, the most likely diagnosis is cardiac tamponade secondary to traumatic injury. The increased jugular venous pressure, hypotension, and muffled heart sounds (though not explicitly mentioned, the absence of murmurs, rubs, or gallops could imply this) are classic signs of Beck's triad, which is indicative of cardiac tamponade. The irregularly irregular pulse and absent p-waves on ECG suggest atrial fibrillation, which can occur in the setting of cardiac tamponade due to atrial compression.
#
# Here's how the evaluation would be structured:
#
# ### Evaluation of Cardiac Tamponade as the Most Likely Diagnosis:
#
# 1. **Level of Evidence Supported in the Context:**
#    - **High (3 points):** The clinical scenario strongly supports cardiac tamponade with the presence of hypotension, increased jugular venous pressure, and the rapid deterioration of the patient.
#
# 2. **Level of Evidence Supported in the Causal Path Inference:**
#    - **High (3 points):** The deduction is strong given the mechanism of injury (motor vehicle collision), the clinical signs (Beck's triad), and the rapid progression to death despite intervention.
#
# 3. **Amount of Next Step Examinations Needed for Ruling Out or Confirmation:**
#    - **Low (3 points):** The current evidence is sufficient to make the diagnosis, especially with the negative FAST exam ruling out other sources of hemorrhagic shock and the clinical presentation aligning with cardiac tamponade.
#
# ### Output Format:
#
# ```json
# {
#     "Answer_letter": "A",
#     "level_of_evidence": "3",
#     "level_of_deduction": "3",
#     "amount_of_next_step": "3",
#     "Answer_text": "Cardiac tamponade secondary to traumatic injury",
#     "Answer_option": "A"
# }
# ```
#
# This evaluation suggests that cardiac tamponade is the most likely diagnosis given the clinical presentation and the context of the traumatic event.

# %%
open_ended_question_answer_2 = answer_open_ended_question(multiple_choice_question_2, options=multiple_choice_options_2, fine_tune_prompt=fine_tune_prompt, rubric_prompt=Norm_rubric_prompt)
print(open_ended_question_answer_2.content)
# Out:
# To address the open-ended question regarding the most likely diagnosis for the 46-year-old man involved in a motor vehicle collision, we need to analyze the clinical presentation and findings:
#
# ### Clinical Presentation:
# - **Unconsciousness**: Suggests severe injury or shock.
# - **Respirations 24/min**: Indicates possible respiratory distress or compensation for shock.
# - **Systolic BP 60 mm Hg, Pulse 141/min and irregularly irregular**: Suggests shock, possibly due to hemorrhage or cardiac dysfunction.
# - **Multiple ecchymoses over the chest**: Indicates significant chest trauma.
# - **Jugular venous pressure increased**: Suggests possible cardiac tamponade or tension pneumothorax.
# - **Bilateral crackles at lung bases**: Could indicate pulmonary contusion or heart failure.
# - **FAST negative**: Rules out significant intra-abdominal bleeding.
# - **ECG shows absent p-waves**: Suggests atrial fibrillation, which can be secondary to cardiac contusion or tamponade.
#
# ### Potential Diagnoses:
# 1. **Cardiac Tamponade**: Increased JVP, hypotension, and tachycardia are classic signs. The irregular pulse could be due to atrial fibrillation secondary to cardiac injury.
# 2. **Cardiac Contusion**: Could explain the irregularly irregular pulse and hypotension, but less likely to cause increased JVP.
# 3. **Pulmonary Contusion**: Bilateral crackles could indicate this, but it doesn't explain the hemodynamic instability.
# 4. **Aortic Dissection**: Unlikely given the negative FAST and lack of specific symptoms.
# 5. **Hemothorax**: Would likely show on FAST or present with more respiratory distress.
# 6. **Tracheobronchial Injury**: Would present with respiratory distress and possibly subcutaneous emphysema.
#
# ### Evaluation Using Criteria and Scoring System:
# #### Cardiac Tamponade:
# - **Level of Evidence Supported in the Context**: High (3 points) - Increased JVP, hypotension, and tachycardia strongly suggest tamponade.
# - **Level of Evidence Supported in the Causal Path Inference**: High (3 points) - Trauma can lead to pericardial effusion and tamponade.
# - **Amount of Next Step Examinations Needed for Ruling Out or Confirmation**: Low (3 points) - Clinical presentation is quite suggestive, though an echocardiogram would confirm.
#
# #### Cardiac Contusion:
# - **Level of Evidence Supported in the Context**: Moderate (2 points) - Irregular pulse and chest trauma suggest contusion.
# - **Level of Evidence Supported in the Causal Path Inference**: Moderate (2 points) - Trauma can cause contusion, but it doesn't fully explain the hemodynamic instability.
# - **Amount of Next Step Examinations Needed for Ruling Out or Confirmation**: Moderate (2 points) - Cardiac enzymes and echocardiogram would be needed.
#
# #### Pulmonary Contusion:
# - **Level of Evidence Supported in the Context**: Moderate (2 points) - Bilateral crackles suggest contusion.
# - **Level of Evidence Supported in the Causal Path Inference**: Low (1 point) - Doesn't explain the hemodynamic instability.
# - **Amount of Next Step Examinations Needed for Ruling Out or Confirmation**: High (1 point) - Chest X-ray or CT would be needed.
#
# ### Conclusion:
# Based on the clinical presentation and evaluation, the most likely diagnosis is **Cardiac Tamponade**.
#
# ```json
# {
#     "Answer_letter": "G",
#     "level_of_evidence": "3",
#     "level_of_deduction": "3",
#     "amount_of_next_step": "3",
#     "Answer_text": "Cardiac tamponade",
#     "Answer_option": "G"
# }
# ```

# %%
open_ended_question_answer_2 = answer_open_ended_question(multiple_choice_question_2, options=multiple_choice_options_2, fine_tune_prompt=fine_tune_prompt, rubric_prompt=Criterion_rubric_prompt)
print(open_ended_question_answer_2.content)
# Out:
# {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "Cardiac tamponade is the most likely diagnosis. The patient presents with hypotension, jugular venous distension, and tachycardia, which are classic signs of cardiac tamponade. The irregularly irregular pulse suggests atrial fibrillation, which can occur in the setting of cardiac tamponade. The negative FAST exam does not rule out cardiac tamponade as it may not detect small pericardial effusions. The rapid deterioration and death are consistent with the hemodynamic instability caused by cardiac tamponade.",
#     "Answer_letter": "G"
# }

# %%
open_ended_question_answer_q5 = answer_open_ended_question(q5, options=options_q5, fine_tune_prompt=fine_tune_prompt, rubric_prompt=Norm_rubric_prompt)
print(open_ended_question_answer_q5.content)
# Out:
# {
#     "Answer_letter": "A",
#     "level_of_evidence": "3",
#     "level_of_deduction": "3",
#     "amount_of_next_step": "3",
#     "Answer_text": "Placing the infant in a supine position on a firm mattress while sleeping"
# }

# %%
open_ended_question_answer_2 = answer_open_ended_question(multiple_choice_question_2, options=multiple_choice_options_2, fine_tune_prompt=fine_tune_prompt, rubric_prompt=Norm_rubric_prompt)
print(open_ended_question_answer_2.content)
# Out:
# {
#     "Answer_letter": "G",
#     "level_of_evidence": "3",
#     "level_of_deduction": "3",
#     "amount_of_next_step": "3",
#     "Answer_text": "Cardiac tamponade",
#     "Answer_option": "Answer option G"
# }

# %%
print(multiple_choice_options_2)
# Out:
# "A": "Tracheobronchial injury", "B": "Cardiac contusion", "C": "Splenic rupture", "D": "Hemothorax", "E": "Aortic dissection", "F": "Pulmonary contusion", "G": "Cardiac tamponade
# ""

# %%
mcq_question_answer_2 = answer_open_ended_question(multiple_choice_question_2, options="multilple_choice_options_2", rubric_prompt=Criterion_rubric_prompt, fine_tune_prompt=fine_tune_prompt)
print(mcq_question_answer_2.content)
# Out:
# In the given scenario, the patient is a 46-year-old man who was involved in a motor vehicle collision and presented with several critical findings. The most likely diagnosis, considering the clinical presentation and the rapid deterioration leading to death, is cardiac tamponade. Here's the reasoning:
#
# ### 1. **Assess the Patient’s Symptoms and History:**
#    - **Unconsciousness and hypotension:** These are indicative of severe shock or compromised cardiac output.
#    - **Irregularly irregular pulse:** Suggests atrial fibrillation, which can be associated with cardiac trauma or underlying cardiac conditions.
#    - **Increased jugular venous pressure:** A classic sign of elevated central venous pressure, often seen in cardiac tamponade.
#    - **Bilateral crackles at lung bases:** Could indicate pulmonary congestion, possibly due to heart failure or fluid overload.
#
# ### 2. **Examine the Physical Findings:**
#    - **Multiple ecchymoses over the chest:** Suggests significant blunt trauma, which could lead to cardiac injury.
#    - **Lacerations over the abdomen and scalp:** Indicate trauma but are not directly related to the cause of death.
#    - **Soft abdomen:** Reduces the likelihood of intra-abdominal bleeding as the primary cause of shock.
#    - **Negative FAST:** Rules out significant hemoperitoneum or hemothorax, making cardiac causes more likely.
#
# ### 3. **Interpret the Clinical Course:**
#    - **Rapid deterioration despite fluid resuscitation:** Suggests a non-hemorrhagic cause of shock, such as cardiac tamponade, where fluid resuscitation alone is insufficient.
#    - **Administration of vasopressors:** Indicates persistent hypotension, which is common in cardiac tamponade due to impaired cardiac filling.
#
# ### 4. **Generate Hypotheses for the Cause of Death:**
#    - **Cardiac tamponade:** The combination of increased jugular venous pressure, hypotension, and muffled heart sounds (though not explicitly mentioned, the absence of murmurs, rubs, or gallops could imply muffled heart sounds) is suggestive of Beck's triad, which is classic for cardiac tamponade.
#    - **Tension pneumothorax:** Could cause similar symptoms but would likely be detected on FAST or physical exam.
#    - **Massive pulmonary embolism:** Could cause sudden cardiovascular collapse but is less likely given the trauma context and lack of specific supporting findings.
#
# ### 5. **Final Deduction:**
#    - The most likely diagnosis is **cardiac tamponade** due to traumatic injury, leading to rapid hemodynamic compromise and death. The clinical presentation aligns with this diagnosis, especially considering the increased jugular venous pressure and the context of chest trauma.
#
# ### Evaluation Rubric:
# 1. **Strength of Evidence:**
#    - High (3 points): The diagnosis of cardiac tamponade is supported by the classic signs and the context of trauma.
# 2. **Relevance to Clinical Scenario:**
#    - High (3 points): The diagnosis directly addresses the scenario and explains the rapid deterioration.
# 3. **Logical Consistency:**
#    - High (3 points): The reasoning is coherent and consistent with the clinical findings.
# 4. **Comprehensiveness:**
#    - High (3 points): The diagnosis accounts for all major symptoms and findings, including the negative FAST and the rapid decline despite intervention.
#
# In summary, the clinical presentation and findings strongly suggest cardiac tamponade as the most likely cause of death in this scenario.

# %%
q5 = """
A 3-month-old baby died suddenly at night while asleep. His mother noticed that he had died only after she awoke in the morning. No cause of death was determined based on the autopsy. Which of the following precautions could have prevented the death of the baby?
"""

options_q5 = """
"A": "Placing the infant in a supine position on a firm mattress while sleeping", "B": "Routine postnatal electrocardiogram (ECG)", "C": "Keeping the infant covered and maintaining a high room temperature", "D": "Application of a device to maintain the sleeping position", "E": "Avoiding pacifier use during sleep"
"""

answer_q5 = "Placing the infant in a supine position on a firm mattress while sleeping"

# %%
open_ended_question_answer_q5 = answer_open_ended_question(q5, options=options_q5, rubric_prompt=Criterion_rubric_prompt, fine_tune_prompt=fine_tune_prompt)
print(open_ended_question_answer_q5.content)
# Out:
# To address the scenario of a 3-month-old baby who died suddenly at night while asleep, with no cause of death determined based on the autopsy, we need to consider potential precautions that could have prevented this tragic event. This situation is often associated with Sudden Infant Death Syndrome (SIDS), and there are several well-established guidelines aimed at reducing the risk of SIDS.
#
# ### Potential Precautions:
#
# 1. **Placing the Infant in a Supine Position on a Firm Mattress While Sleeping (A):**
#    - **Strength of Evidence:** High (3 points) - This is supported by direct evidence and widely accepted guidelines, such as those from the American Academy of Pediatrics (AAP), which recommend placing infants on their backs to sleep to reduce the risk of SIDS.
#    - **Relevance to Clinical Scenario:** High (3 points) - Directly addresses the scenario as improper sleeping position is a known risk factor for SIDS.
#    - **Logical Consistency:** High (3 points) - This recommendation is logically coherent and consistent with current medical guidelines.
#    - **Comprehensiveness:** High (3 points) - This precaution addresses a key factor in SIDS prevention.
#
# 2. **Routine Postnatal Electrocardiogram (ECG) (B):**
#    - **Strength of Evidence:** Low (1 point) - Routine ECGs are not standard practice for SIDS prevention and lack direct evidence supporting their use in this context.
#    - **Relevance to Clinical Scenario:** Low (1 point) - Does not directly address the scenario of SIDS.
#    - **Logical Consistency:** Moderate (2 points) - While ECGs can detect some cardiac abnormalities, they are not typically used for SIDS prevention.
#    - **Comprehensiveness:** Low (1 point) - Does not address the primary concerns related to SIDS.
#
# 3. **Keeping the Infant Covered and Maintaining a High Room Temperature (C):**
#    - **Strength of Evidence:** Low (1 point) - Overheating is a risk factor for SIDS, and this recommendation contradicts guidelines.
#    - **Relevance to Clinical Scenario:** Low (1 point) - This is not a recommended practice for SIDS prevention.
#    - **Logical Consistency:** Low (1 point) - Inconsistent with guidelines that advise against overheating.
#    - **Comprehensiveness:** Low (1 point) - Does not address SIDS prevention effectively.
#
# 4. **Application of a Device to Maintain the Sleeping Position (D):**
#    - **Strength of Evidence:** Moderate (2 points) - Some devices are marketed for this purpose, but they are not universally recommended due to safety concerns.
#    - **Relevance to Clinical Scenario:** Moderate (2 points) - Partially addresses the scenario by aiming to maintain a safe sleeping position.
#    - **Logical Consistency:** Moderate (2 points) - While the intention is logical, the safety and efficacy of such devices are debated.
#    - **Comprehensiveness:** Moderate (2 points) - Addresses sleeping position but not other SIDS risk factors.
#
# 5. **Avoiding Pacifier Use During Sleep (E):**
#    - **Strength of Evidence:** Low (1 point) - Contrary to evidence, as pacifier use is actually associated with a reduced risk of SIDS.
#    - **Relevance to Clinical Scenario:** Low (1 point) - Does not align with SIDS prevention guidelines.
#    - **Logical Consistency:** Low (1 point) - Inconsistent with current recommendations.
#    - **Comprehensiveness:** Low (1 point) - Does not address SIDS prevention effectively.
#
# ### Conclusion:
# The most effective precaution, based on current guidelines, is placing the infant in a supine position on a firm mattress while sleeping (A). This practice is strongly supported by evidence and directly addresses the risk factors associated with SIDS.

# %%
open_ended_question_answer_q5 = answer_open_ended_question(q5, rubric_prompt=Criterion_rubric_prompt, fine_tune_prompt=fine_tune_prompt)
print(open_ended_question_answer_q5.content)
# Out:
# To address the open-ended question regarding the sudden death of a 3-month-old baby during sleep, we need to consider potential causes and preventive measures. The scenario described is suggestive of Sudden Infant Death Syndrome (SIDS), a condition where an infant dies unexpectedly during sleep with no clear cause found even after an autopsy.
#
# ### Potential Preventive Measures for SIDS:
#
# 1. **Safe Sleep Environment:**
#    - **Back to Sleep:** Always place the baby on their back to sleep, for naps and at night, to reduce the risk of SIDS.
#    - **Firm Sleep Surface:** Use a firm mattress with a fitted sheet in a safety-approved crib. Avoid soft bedding, pillows, or toys in the crib.
#    - **Room Sharing Without Bed Sharing:** Keep the baby's sleep area in the same room where you sleep for the first year, but on a separate surface designed for infants.
#
# 2. **Avoid Overheating:**
#    - Dress the baby in light sleep clothing and keep the room at a comfortable temperature. Avoid heavy blankets or overdressing.
#
# 3. **Pacifier Use:**
#    - Consider offering a pacifier at nap time and bedtime. If breastfeeding, wait until breastfeeding is well established (usually by 3 to 4 weeks) before introducing a pacifier.
#
# 4. **Avoid Exposure to Smoke, Alcohol, and Drugs:**
#    - Maintain a smoke-free environment around the baby. Avoid alcohol and illicit drug use during pregnancy and after birth.
#
# 5. **Regular Prenatal Care:**
#    - Ensure regular prenatal care during pregnancy to reduce the risk of SIDS.
#
# 6. **Breastfeeding:**
#    - Breastfeed the baby, if possible, as breastfeeding is associated with a reduced risk of SIDS.
#
# ### Evaluation of Preventive Measures:
#
# 1. **Strength of Evidence:**
#    - High (3 points): These recommendations are supported by direct evidence and widely accepted guidelines from organizations like the American Academy of Pediatrics (AAP).
#
# 2. **Relevance to Clinical Scenario:**
#    - High (3 points): The measures directly address the scenario of preventing sudden infant death during sleep without speculation.
#
# 3. **Logical Consistency:**
#    - High (3 points): The recommendations are logically coherent and consistent with established guidelines for reducing the risk of SIDS.
#
# 4. **Comprehensiveness:**
#    - High (3 points): The measures account for various factors that contribute to SIDS, including sleep position, sleep environment, and parental behaviors.
#
# In summary, following these preventive measures can significantly reduce the risk of SIDS, although it may not eliminate it entirely. These guidelines are based on extensive research and are recommended by pediatric health authorities.

# %%
open_ended_question_answer_2_1 = answer_open_ended_question(multiple_choice_question_2, fine_tune_prompt=fine_tune_prompt, rubric_prompt=Criterion_rubric_prompt)
print(open_ended_question_answer_2_1.content)
# Out:
# In this scenario, the patient presents with signs of severe trauma and hemodynamic instability following a motor vehicle collision. The key findings include unconsciousness, irregularly irregular pulse, hypotension, increased jugular venous pressure, bilateral crackles in the lungs, and a negative FAST exam. The ECG shows absent p-waves, suggesting atrial fibrillation. Despite resuscitative efforts, the patient deteriorates and dies.
#
# ### Potential Causes:
#
# 1. **Cardiac Tamponade:**
#    - **Strength of Evidence:** High (3 points) - The increased jugular venous pressure, hypotension, and muffled heart sounds (though not explicitly mentioned) are classic signs of Beck's triad for cardiac tamponade.
#    - **Relevance to Clinical Scenario:** High (3 points) - Directly addresses the scenario with the presence of trauma and hemodynamic instability.
#    - **Logical Consistency:** High (3 points) - The symptoms align with cardiac tamponade, especially post-trauma.
#    - **Comprehensiveness:** High (3 points) - Accounts for the hypotension, jugular venous distension, and potential for rapid deterioration.
#
# 2. **Tension Pneumothorax:**
#    - **Strength of Evidence:** Moderate (2 points) - While increased JVP and hypotension are present, the absence of tracheal deviation or hyperresonance on examination makes this less likely.
#    - **Relevance to Clinical Scenario:** Moderate (2 points) - Partially addresses the scenario but lacks some key findings.
#    - **Logical Consistency:** Moderate (2 points) - Some symptoms fit, but not all are consistent with tension pneumothorax.
#    - **Comprehensiveness:** Moderate (2 points) - Does not fully explain the bilateral crackles or irregular pulse.
#
# 3. **Massive Hemothorax:**
#    - **Strength of Evidence:** Moderate (2 points) - Could explain hypotension and respiratory distress, but the negative FAST and lack of specific findings make it less likely.
#    - **Relevance to Clinical Scenario:** Moderate (2 points) - Partially relevant but lacks specific supporting evidence.
#    - **Logical Consistency:** Moderate (2 points) - Somewhat consistent but lacks comprehensive support.
#    - **Comprehensiveness:** Moderate (2 points) - Does not fully account for all symptoms, especially the irregular pulse.
#
# 4. **Pulmonary Contusion:**
#    - **Strength of Evidence:** Moderate (2 points) - Bilateral crackles could suggest lung injury, but does not explain the hemodynamic instability.
#    - **Relevance to Clinical Scenario:** Low (1 point) - Does not directly address the main hemodynamic issues.
#    - **Logical Consistency:** Low (1 point) - Lacks coherence with the primary symptoms of hypotension and irregular pulse.
#    - **Comprehensiveness:** Low (1 point) - Fails to address key symptoms like hypotension and irregular pulse.
#
# 5. **Aortic Dissection:**
#    - **Strength of Evidence:** Moderate (2 points) - Could explain hypotension and irregular pulse, but less likely without specific findings like differential blood pressures.
#    - **Relevance to Clinical Scenario:** Moderate (2 points) - Partially relevant but lacks specific supporting evidence.
#    - **Logical Consistency:** Moderate (2 points) - Somewhat consistent but lacks comprehensive support.
#    - **Comprehensiveness:** Moderate (2 points) - Does not fully account for all symptoms, especially the negative FAST.
#
# ### Conclusion:
# The most likely diagnosis, given the scenario, is **Cardiac Tamponade** due to the combination of trauma, hypotension, increased jugular venous pressure, and rapid deterioration. This diagnosis aligns well with the clinical presentation and the context of a traumatic event.

# %%
multiple_choice_question_3_noexplain = answer_multiple_choice_question_noexplain(multiple_choice_question_3, multiple_choice_options_3)
print(multiple_choice_question_3_noexplain.content)
# Out:
# To determine the most appropriate next step in management for this patient, let's evaluate each option:
#
# **Action 1: Rule Out Evidence**
#
# - **A: IV fluid resuscitation**: The patient is not orthostatic, and her vital signs are stable, suggesting she is not significantly dehydrated. Therefore, IV fluids may not be immediately necessary.
#
# - **B: Administration of supplemental oxygen**: The patient is not hypoxic, and her oxygen saturation is adequate. The low pO2 and SO2 are likely due to venous blood gas, not arterial. Therefore, supplemental oxygen is not indicated.
#
# - **C: Scheduled meal times**: While helpful in managing nausea, this does not address the acute symptoms or provide immediate relief.
#
# - **D: Monitoring and stress counseling**: This is supportive care but does not address the acute symptoms of nausea and vomiting.
#
# - **E: PO bismuth subsalicylate**: This is typically used for gastrointestinal upset related to diarrhea, not for nausea and vomiting in pregnancy.
#
# - **F: Trial of metoclopramide**: Metoclopramide is an antiemetic that can be used for nausea and vomiting, but it is not the first-line treatment in pregnancy.
#
# - **G: Discontinuation of ginger and vitamin B6**: The patient is already taking these with limited relief, so discontinuation is not likely to improve her symptoms.
#
# - **H: Addition of doxylamine**: Doxylamine, in combination with vitamin B6, is a first-line treatment for nausea and vomiting in pregnancy (NVP).
#
# **Action 2: Evidence for Causal Path**
#
# - **A: IV fluid resuscitation**: Not immediately necessary due to stable vitals and lack of orthostatic changes.
#
# - **B: Administration of supplemental oxygen**: Not indicated due to normal oxygenation status.
#
# - **C: Scheduled meal times**: May help long-term but not an immediate solution.
#
# - **D: Monitoring and stress counseling**: Supportive but not directly addressing the acute issue.
#
# - **E: PO bismuth subsalicylate**: Not appropriate for NVP.
#
# - **F: Trial of metoclopramide**: Could be considered if first-line treatments fail.
#
# - **G: Discontinuation of ginger and vitamin B6**: Unlikely to help as they are already providing limited relief.
#
# - **H: Addition of doxylamine**: Supported by guidelines as a first-line treatment for NVP, especially when vitamin B6 alone is insufficient.
#
# **Reasoning and Conclusion**
#
# The patient is experiencing significant nausea and vomiting during pregnancy, and the current treatment with ginger and vitamin B6 is not providing adequate relief. The addition of doxylamine to vitamin B6 is a well-established first-line treatment for nausea and vomiting in pregnancy. Other options either do not address the acute symptoms or are not appropriate for this condition.
#
# ```json
# {
#     "Answer_letter": "H",
#     "Confidence": "High",
#     "Answer_text": "Addition of doxylamine"
# }
# ```

# %%
multiple_choice_question_3_noexplain = answer_multiple_choice_question_noexplain(multiple_choice_question_3, multiple_choice_options_3)
print(multiple_choice_question_3_noexplain.content)
# Out:
# ```json
# {
#     "Answer_letter": "H",
#     "level_of_evidence": "3",
#     "level_of_deduction": "3",
#     "amount_of_next_step": "3",
#     "Answer_text": "Addition of doxylamine"
# }
# ```
#
# **Reasoning:**
#
# - **Action 1: Evidence to Rule Out Options**
#   - **A (IV fluid resuscitation):** The patient is not orthostatic, indicating no significant dehydration, so IV fluids are not immediately necessary.
#   - **B (Administration of supplemental oxygen):** The patient is not hypoxic; the low pO2 and SO2 are due to venous blood gas, not arterial.
#   - **C (Scheduled meal times):** While helpful, this is not an immediate treatment for severe nausea and vomiting.
#   - **D (Monitoring and stress counseling):** This addresses stress but not the acute symptoms.
#   - **E (PO bismuth subsalicylate):** Not typically used for pregnancy-related nausea and vomiting.
#   - **F (Trial of metoclopramide):** Could be considered, but doxylamine is first-line for pregnancy-related nausea.
#   - **G (Discontinuation of ginger and vitamin B6):** These are safe and can be continued; discontinuation is not advised.
#
# - **Action 2: Evidence for Causal Path Inference**
#   - **H (Addition of doxylamine):** The patient is already on vitamin B6 with limited relief. Doxylamine, in combination with vitamin B6, is a first-line treatment for nausea and vomiting in pregnancy (NVP).
#
# **Scoring:**
# - **Level of Evidence Supported in the Context:** High (3 points) - The clinical scenario of pregnancy-related nausea and vomiting supports the use of doxylamine.
# - **Level of Evidence Supported in the Causal Path Inference:** High (3 points) - Doxylamine is a well-established treatment for NVP, especially when vitamin B6 alone is insufficient.
# - **Amount of Next Step Examinations Needed for Ruling Out or Confirmation:** Low (3 points) - No additional tests are needed; the treatment can be initiated based on the current clinical picture.

# %%
multiple_choice_question_4 = """
A 52-year-old man comes to to the emergency department with fatigue and shortness of breath that has become progressively worse over the past week. He had an upper respiratory tract infection 2 weeks ago, for which he was given an antibiotic. He has hypertension, type 2 diabetes mellitus, and colonic polyps diagnosed on screening colonoscopy 2 years ago. His mother has systemic lupus erythematosus and his brother has a bicuspid aortic valve. He does not smoke cigarettes or drink alcohol. Current medications include lisinopril and metformin. His temperature is 37.3°C (99.1°F), pulse is 91/min, respirations are 18/min, and blood pressure is 145/84 mm Hg. His conjunctivae are pale. Cardiac examination shows a late systolic crescendo-decrescendo murmur at the right upper sternal border. Laboratory studies show:\nLeukocyte Count 9,500/mm3\nHematocrit 24%\nPlatelet Count 178,000/mm3\nLDH 215 U/L\nHaptoglobin 22 mg/dL (N=41–165 mg/dL)\nSerum\nNa+ 140 mEq/L\nK+ 4.6 mEq/L\nCL- 100 mEq/L\nHCO3- 25 mEq/L\nUrea nitrogen 21 mg/dL\nCreatinine 1.2 mg/dL\nTotal bilirubin 1.9 mg/dL\nA peripheral blood smear is shown. Which of the following is the most likely cause of this patient's anemia?
"""

multiple_choice_options_4 = """
{"A": "Autoimmune destruction of erythrocytes", "B": "Occult blood loss", "C": "Erythrocyte membrane fragility", "D": "Erythrocyte enzyme defect", "E": "Mechanical destruction of erythrocytes"}
"""

# %%
multiple_choice_question_4_noexplain = answer_multiple_choice_question_noexplain(multiple_choice_question_4, multiple_choice_options_4)
print(multiple_choice_question_4_noexplain.content)
# Out:
# ```json
# {
#     "Answer_letter": "E",
#     "level_of_evidence": "3",
#     "level_of_deduction": "3",
#     "amount_of_next_step": "3",
#     "Answer_text": "Mechanical destruction of erythrocytes"
# }
# ```
#
# **Reasoning:**
#
# - **Action 1: Evidence to Rule Out Options**
#   - **A: Autoimmune destruction of erythrocytes**: The patient does not have a history of autoimmune conditions, and there is no mention of positive direct Coombs test or other autoimmune markers.
#   - **B: Occult blood loss**: The patient does not have symptoms or history suggestive of gastrointestinal bleeding or other sources of blood loss.
#   - **C: Erythrocyte membrane fragility**: Conditions like hereditary spherocytosis are not suggested by the clinical history or lab findings.
#   - **D: Erythrocyte enzyme defect**: There is no history of G6PD deficiency or similar enzyme defects, and the clinical picture does not suggest this.
#   - **E: Mechanical destruction of erythrocytes**: The presence of a heart murmur and the lab findings (low haptoglobin, elevated bilirubin, and anemia) suggest hemolysis, which can be caused by mechanical destruction, such as from aortic stenosis or prosthetic heart valves.
#
# - **Action 2: Evidence for Causal Path Inference**
#   - **A: Autoimmune destruction of erythrocytes**: Requires more evidence like a positive Coombs test, which is not provided.
#   - **B: Occult blood loss**: Would typically present with iron deficiency anemia, which is not indicated here.
#   - **C: Erythrocyte membrane fragility**: Would require specific findings on blood smear, not indicated here.
#   - **D: Erythrocyte enzyme defect**: Would require specific triggers or history, not present here.
#   - **E: Mechanical destruction of erythrocytes**: The combination of anemia, elevated LDH, low haptoglobin, and elevated bilirubin, along with a heart murmur, strongly suggests mechanical hemolysis, likely due to aortic stenosis.
#
# - **Criteria and Scoring System:**
#   - **Level of Evidence Supported in the Context**: High (3 points) for option E, as the clinical scenario strongly supports mechanical hemolysis.
#   - **Level of Evidence Supported in the Causal Path Inference**: High (3 points) for option E, as the reasoning based on the heart murmur and lab findings is strong.
#   - **Amount of Next Step Examinations Needed for Ruling Out or Confirmation**: Low (3 points) for option E, as the current evidence is sufficient to suggest mechanical hemolysis without needing further tests.

# %%
multiple_choice_question_4_noexplain = answer_multiple_choice_question_noexplain(multiple_choice_question_4, options = "None")
print(multiple_choice_question_4_noexplain.content)
# Out:
# To address the question, we need to generate five potential causes for the patient's anemia and evaluate them based on the criteria provided.
#
# ### Potential Causes:
# 1. **Autoimmune Hemolytic Anemia (AIHA)**
# 2. **Drug-Induced Hemolytic Anemia**
# 3. **Iron Deficiency Anemia**
# 4. **Anemia of Chronic Disease**
# 5. **Thalassemia**
#
# ### Evaluation:
#
# #### 1. Autoimmune Hemolytic Anemia (AIHA)
# - **Evidence in Context**:
#   - High (3 points): The low haptoglobin, elevated bilirubin, and anemia suggest hemolysis, which is consistent with AIHA.
# - **Causal Path Inference**:
#   - Moderate (2 points): The family history of autoimmune disease (mother with lupus) could suggest a predisposition to autoimmune conditions.
# - **Next Step Examinations**:
#   - Moderate (2 points): A direct Coombs test would be needed to confirm AIHA.
#
# #### 2. Drug-Induced Hemolytic Anemia
# - **Evidence in Context**:
#   - High (3 points): Recent antibiotic use could trigger hemolysis, especially if the antibiotic is known to cause hemolytic anemia.
# - **Causal Path Inference**:
#   - High (3 points): The temporal relationship between antibiotic use and symptom onset supports this cause.
# - **Next Step Examinations**:
#   - Moderate (2 points): Identifying the specific antibiotic and its known side effects would help confirm this diagnosis.
#
# #### 3. Iron Deficiency Anemia
# - **Evidence in Context**:
#   - Low (1 point): The lab findings suggest hemolysis rather than iron deficiency.
# - **Causal Path Inference**:
#   - Low (1 point): The acute presentation and lab findings do not support iron deficiency.
# - **Next Step Examinations**:
#   - High (1 point): Iron studies would be needed to confirm or rule out this cause.
#
# #### 4. Anemia of Chronic Disease
# - **Evidence in Context**:
#   - Low (1 point): The lab findings are more indicative of hemolysis than anemia of chronic disease.
# - **Causal Path Inference**:
#   - Low (1 point): The acute nature and lab findings do not align with anemia of chronic disease.
# - **Next Step Examinations**:
#   - High (1 point): Additional tests would be needed to explore this possibility.
#
# #### 5. Thalassemia
# - **Evidence in Context**:
#   - Low (1 point): The patient's age and acute presentation are not typical for thalassemia.
# - **Causal Path Inference**:
#   - Low (1 point): The lab findings do not suggest thalassemia.
# - **Next Step Examinations**:
#   - High (1 point): Hemoglobin electrophoresis would be needed to confirm or rule out thalassemia.
#
# ### Conclusion:
# Based on the evaluation, Drug-Induced Hemolytic Anemia has the highest confidence score.
#
# ```json
# {
#     "Answer_letter": "Answer option B",
#     "level_of_evidence": "3",
#     "level_of_deduction": "3",
#     "amount_of_next_step": "2",
#     "Answer_text": "Drug-Induced Hemolytic Anemia"
# }
# ```

# %%
multiple_choice_question_4_noexplain = answer_multiple_choice_question_noexplain(multiple_choice_question_4, options = "None")
print(multiple_choice_question_4_noexplain.content)
# Out:
# To address the question, we need to generate potential causes for the patient's anemia and evaluate them based on the criteria provided.
#
# ### Potential Causes of Anemia:
# 1. **Autoimmune Hemolytic Anemia (AIHA)**
# 2. **Drug-Induced Hemolytic Anemia**
# 3. **Iron Deficiency Anemia**
# 4. **Anemia of Chronic Disease**
# 5. **Thrombotic Thrombocytopenic Purpura (TTP)**
#
# ### Evaluation of Each Cause:
#
# #### 1. Autoimmune Hemolytic Anemia (AIHA)
# - **Evidence in Context**:
#   - Low haptoglobin and elevated bilirubin suggest hemolysis.
#   - Pale conjunctivae indicate anemia.
#   - No direct evidence of autoimmune etiology.
# - **Causal Path Inference**:
#   - Moderate: Family history of autoimmune disease (mother with lupus) could suggest a predisposition.
# - **Next Step Examinations**:
#   - Moderate: Direct Coombs test needed to confirm AIHA.
#
# #### 2. Drug-Induced Hemolytic Anemia
# - **Evidence in Context**:
#   - Recent antibiotic use could trigger hemolysis.
#   - Low haptoglobin and elevated bilirubin support hemolysis.
# - **Causal Path Inference**:
#   - High: Temporal relationship with antibiotic use.
# - **Next Step Examinations**:
#   - Moderate: Identification of the specific drug and its known side effects.
#
# #### 3. Iron Deficiency Anemia
# - **Evidence in Context**:
#   - Pale conjunctivae and fatigue are consistent with anemia.
#   - No evidence of microcytic anemia or low iron studies provided.
# - **Causal Path Inference**:
#   - Low: No evidence of iron deficiency or blood loss.
# - **Next Step Examinations**:
#   - High: Iron studies needed to confirm.
#
# #### 4. Anemia of Chronic Disease
# - **Evidence in Context**:
#   - Chronic conditions like diabetes and hypertension present.
#   - No specific markers of inflammation or chronic disease anemia.
# - **Causal Path Inference**:
#   - Low: No direct link to chronic disease anemia.
# - **Next Step Examinations**:
#   - High: Additional tests for inflammation markers needed.
#
# #### 5. Thrombotic Thrombocytopenic Purpura (TTP)
# - **Evidence in Context**:
#   - Hemolytic anemia (low haptoglobin, elevated bilirubin) and normal platelet count.
#   - No neurological symptoms or renal impairment mentioned.
# - **Causal Path Inference**:
#   - Moderate: Some features overlap, but not classic presentation.
# - **Next Step Examinations**:
#   - High: ADAMTS13 activity test needed.
#
# ### Conclusion:
# Based on the evaluation, **Drug-Induced Hemolytic Anemia** is the most likely cause due to the temporal relationship with antibiotic use and the laboratory findings suggestive of hemolysis.
#
# ```json
# {
#     "Answer_letter": "Answer option B",
#     "level_of_evidence": "3",
#     "level_of_deduction": "3",
#     "amount_of_next_step": "2",
#     "Answer_text": "Drug-Induced Hemolytic Anemia"
# }
# ```
#
# Since the amount of next step is not Low, further exploration of sub-causes could include identifying the specific antibiotic used and its known potential to cause hemolytic anemia, such as penicillin or cephalosporins.

# %%
multiple_choice_question_4_with_fine_tune = answer_multiple_choice_question_noexplain(multiple_choice_question_4, fine_tune_prompt)
print(multiple_choice_question_4_with_fine_tune.content)
# Out:
# To address the question, let's first generate potential causes of anemia in this patient:
#
# 1. Autoimmune hemolytic anemia (AIHA)
# 2. Mechanical destruction of erythrocytes (due to aortic stenosis)
# 3. Anemia of chronic disease
# 4. Iron deficiency anemia
# 5. Drug-induced hemolytic anemia
#
# Now, let's evaluate each potential cause using the criteria and scoring system:
#
# ### Option 1: Autoimmune Hemolytic Anemia (AIHA)
# - **Level of Evidence Supported in the Context:** Low (1 point)
#   - There is no direct mention of a positive Coombs test or other autoimmune markers.
# - **Level of Evidence Supported in the Causal Path Inference:** Moderate (2 points)
#   - Family history of lupus could suggest a predisposition to autoimmune conditions, but no direct evidence of AIHA.
# - **Amount of Next Step Examinations Needed for Ruling Out or Confirmation:** High (1 point)
#   - A direct Coombs test would be needed to confirm AIHA.
#
# ### Option 2: Mechanical Destruction of Erythrocytes (due to Aortic Stenosis)
# - **Level of Evidence Supported in the Context:** High (3 points)
#   - The presence of a heart murmur consistent with aortic stenosis and family history of bicuspid aortic valve strongly supports this cause.
# - **Level of Evidence Supported in the Causal Path Inference:** High (3 points)
#   - The clinical picture and lab findings (hemolysis indicators) align with mechanical hemolysis due to aortic stenosis.
# - **Amount of Next Step Examinations Needed for Ruling Out or Confirmation:** Low (3 points)
#   - The current evidence is sufficient to make this diagnosis, with the heart murmur being a key indicator.
#
# ### Option 3: Anemia of Chronic Disease
# - **Level of Evidence Supported in the Context:** Low (1 point)
#   - The lab findings do not support anemia of chronic disease, as there is evidence of hemolysis.
# - **Level of Evidence Supported in the Causal Path Inference:** Low (1 point)
#   - The acute presentation and lab findings are not typical for anemia of chronic disease.
# - **Amount of Next Step Examinations Needed for Ruling Out or Confirmation:** High (1 point)
#   - Additional tests would be needed to confirm this, as the current evidence does not support it.
#
# ### Option 4: Iron Deficiency Anemia
# - **Level of Evidence Supported in the Context:** Low (1 point)
#   - There is no mention of microcytic anemia or low iron studies.
# - **Level of Evidence Supported in the Causal Path Inference:** Low (1 point)
#   - The lab findings and clinical presentation do not suggest iron deficiency.
# - **Amount of Next Step Examinations Needed for Ruling Out or Confirmation:** High (1 point)
#   - Iron studies would be needed to confirm or rule out this cause.
#
# ### Option 5: Drug-Induced Hemolytic Anemia
# - **Level of Evidence Supported in the Context:** Low (1 point)
#   - No specific drug known to cause hemolysis is mentioned.
# - **Level of Evidence Supported in the Causal Path Inference:** Low (1 point)
#   - The clinical picture does not strongly suggest drug-induced hemolysis.
# - **Amount of Next Step Examinations Needed for Ruling Out or Confirmation:** High (1 point)
#   - Further investigation into drug history and specific tests would be needed.
#
# Based on the scoring:
#
# ```json
# {
#     "Answer_letter": "Option 2",
#     "level_of_evidence": "3",
#     "level_of_deduction": "3",
#     "amount_of_next_step": "3",
#     "Answer_text": "Mechanical destruction of erythrocytes (due to aortic stenosis)"
# }
# ```

# %%
multiple_choice_question_3_with_fine_tune = answer_multiple_choice_question_noexplain(multiple_choice_question_3, fine_tune_prompt)
print(multiple_choice_question_3_with_fine_tune.content)
# Out:
# To address the question, let's first analyze the clinical scenario and the provided lab results. The patient is experiencing significant nausea and vomiting during early pregnancy, which is consistent with hyperemesis gravidarum. The blood gas analysis shows a compensated metabolic alkalosis, which is typical in cases of prolonged vomiting due to loss of gastric acid.
#
# Now, let's evaluate the potential management options:
#
# ### Action 1: Rule Out Options
# 1. **IV Fluid Resuscitation**: The patient is already receiving oral fluid resuscitation, and her orthostatic vital signs are normal, suggesting she is not significantly dehydrated.
# 2. **Antiemetic Medication**: The patient is taking ginger and vitamin B6 with limited relief, indicating that stronger antiemetic therapy might be needed.
# 3. **Hospitalization**: The patient is alert, oriented, and not orthostatic, suggesting that outpatient management might be sufficient.
# 4. **Nutritional Support**: There is no indication of severe malnutrition or electrolyte imbalance that would necessitate immediate nutritional support.
# 5. **Psychological Support**: While stress is mentioned, there is no indication that psychological support is the primary need at this moment.
#
# ### Action 2: Infer Causal Path
# 1. **Antiemetic Medication**: Given the limited relief from current treatment, stronger antiemetic therapy could directly address the patient's symptoms.
# 2. **IV Fluid Resuscitation**: While important, the current evidence does not suggest severe dehydration.
# 3. **Hospitalization**: Not immediately necessary based on the current clinical picture.
# 4. **Nutritional Support**: Not indicated as a primary intervention.
# 5. **Psychological Support**: While beneficial, it is not the immediate next step for symptom relief.
#
# ### Debate and Scoring
# - **Antiemetic Medication**:
#   - **Level of Evidence**: High (3 points) - The patient is experiencing significant nausea and vomiting, and current treatment is insufficient.
#   - **Level of Deduction**: High (3 points) - Strong deductive reasoning supports the need for more effective antiemetic therapy.
#   - **Amount of Next Step**: Low (3 points) - Few additional tests are needed; the clinical picture supports this intervention.
#
# - **IV Fluid Resuscitation**:
#   - **Level of Evidence**: Moderate (2 points) - While important, the patient is not orthostatic, suggesting adequate hydration.
#   - **Level of Deduction**: Moderate (2 points) - Could be considered, but not immediately necessary.
#   - **Amount of Next Step**: Moderate (2 points) - Some additional assessment might be needed.
#
# - **Hospitalization**:
#   - **Level of Evidence**: Low (1 point) - The patient is stable and alert.
#   - **Level of Deduction**: Low (1 point) - Not immediately indicated.
#   - **Amount of Next Step**: High (1 point) - Would require significant justification.
#
# - **Nutritional Support**:
#   - **Level of Evidence**: Low (1 point) - No immediate indication.
#   - **Level of Deduction**: Low (1 point) - Not directly supported.
#   - **Amount of Next Step**: High (1 point) - Would require further assessment.
#
# - **Psychological Support**:
#   - **Level of Evidence**: Low (1 point) - Not the primary issue.
#   - **Level of Deduction**: Low (1 point) - Not directly supported.
#   - **Amount of Next Step**: High (1 point) - Would require further assessment.
#
# Based on the scoring, the most appropriate next step in management is:
#
# ```json
# {
#     "Answer_letter": "Antiemetic Medication",
#     "level_of_evidence": "3",
#     "level_of_deduction": "3",
#     "amount_of_next_step": "3",
#     "Answer_text": "Initiate stronger antiemetic therapy to manage the patient's significant nausea and vomiting."
# }
# ```

# %%
import csv
import json
import re
import pandas as pd

# %%
question_bank_jsonl = r'C:\Users\PC\NIT6001\CMG_prog_v3\MedQA-USMLE\questions\US\endoscopy_questions.jsonl'
# import jsonlines using pandas
df = pd.read_json(question_bank_jsonl, lines=True)
df.head()
# Out:
#                                             question answer  \
# 0  A 50-year-old man comes to the physician becau...      B
# 1  A 65-year-old Asian woman comes to the physici...      C
# 2  A gastroenterology fellow is interested in the...      C
# 3  A 23-year-old woman with Ehlers-Danlos syndrom...      A
# 4  A 60-year-old man comes to the physician for a...      D
#
#                                              options meta_info
# 0  {'A': 'Injection sclerotherapy', 'B': 'Nadolol...     step2
# 1  {'A': 'Cholesterol embolism', 'B': 'Traumatic ...     step2
# 2  {'A': 'Random error', 'B': 'Effect modificatio...     step2
# 3  {'A': 'Arthroscopy', 'B': 'Above knee cast', '...     step2
# 4  {'A': 'Perform prostate biopsy', 'B': 'Obtain ...     step2

# %%
# open_ended_question_answer_2 = answer_open_ended_question(multiple_choice_question_2, options=multiple_choice_options_2, fine_tune_prompt=fine_tune_prompt, rubric_prompt=Norm_rubric_prompt)
# print(open_ended_question_answer_2.content)

# %%
# We will write a function to loop through all rows of question bank, extract the question and options, parse them into function answer_open_ended_question(question, options, fine_tune_prompt=fine_tune_prompt, rubric_prompt=Criterion_rubric_prompt). append the result.content to a list

def answer_all_questions(df):
    answers = []
    for index, row in df.iterrows():
        question = row['question']
        options = row['options']
        answer = answer_open_ended_question(question, options=str(options), fine_tune_prompt=fine_tune_prompt, rubric_prompt=Criterion_rubric_prompt)
        answers.append(answer.content)
    return answers

# %%
# check the first 5 rows of the dataframe using itterrows
for index, row in df.head().iterrows():
    print(type(row['question']), row['question'])
    print(type(row['options']), row['options'])

# row['options'] returns a dictionary, we will convert it to a string
for index, row in df.head().iterrows():
    print(type(row['question']), row['question'])
    print(type(str(row['options'])), str(row['options']))
# Out:
# <class 'str'> A 50-year-old man comes to the physician because of a 6-month history of difficulties having sexual intercourse due to erectile dysfunction. He has type 2 diabetes mellitus that is well controlled with metformin. He does not smoke. He drinks 5–6 beers daily. His vital signs are within normal limits. Physical examination shows bilateral pedal edema, decreased testicular volume, and increased breast tissue. The spleen is palpable 2 cm below the left costal margin. Abdominal ultrasound shows an atrophic, hyperechoic, nodular liver. An upper endoscopy is performed and shows dilated submucosal veins 2 mm in diameter with red spots on their surface in the distal esophagus. Therapy with a sildenafil is initiated for his erectile dysfunction. Which of the following is the most appropriate next step in management of this patient's esophageal findings?
# <class 'dict'> {'A': 'Injection sclerotherapy', 'B': 'Nadolol therapy', 'C': 'Losaratan therapy', 'D': 'Octreotide therapy', 'E': 'Isosorbide mononitrate therapy', 'F': 'Endoscopic band ligation', 'G': 'Transjugular intrahepatic portosystemic shunt', 'H': 'Metoprolol therapy\n"'}
# <class 'str'> A 65-year-old Asian woman comes to the physician for a routine health maintenance examination. On questioning, she has had occasional night sweats during the past 2 months. She has not had fevers or weight loss. Seven months ago, she had an acute myocardial infarction and was treated with percutaneous coronary intervention. She has hypertension, hyperlipidemia, and gastroesophageal reflux disease. She has smoked one pack of cigarettes daily for 37 years. Current medications include aspirin, atorvastatin, ramipril, metoprolol, and esomeprazole. She is 178 cm (5 ft 10 in) tall and weighs 89 kg (207 lbs); BMI is 29.7 kg/m2. Her temperature is 37.4°C (99.3°F), pulse is 84/min, respirations are 18/min, and blood pressure is 145/80 mm Hg. The lungs are clear to auscultation. Cardiac examination shows an S4. There is a nontender skin lesion near the right large toenail. A photograph of the lesion is shown. The remainder of the examination shows no abnormalities. Which of the following is the most likely diagnosis?
# <class 'dict'> {'A': 'Cholesterol embolism', 'B': 'Traumatic subungual hemorrhage', 'C': 'Malignant melanoma', 'D': 'Onychomycosis', 'E': 'Squamous cell carcinoma'}
# <class 'str'> A gastroenterology fellow is interested in the relationship between smoking and incidence of Barrett esophagus. At a departmental grand rounds she recently attended, one of the presenters claimed that smokers are only at increased risk for Barrett esophagus in the presence of acid reflux. She decides to design a retrospective cohort study to investigate the association between smoking and Barrett esophagus. After comparing 400 smokers to 400 non-smokers identified via chart review, she finds that smokers were at increased risk of Barrett esophagus at the end of a 10-year follow-up period (RR = 1.82, p < 0.001). Among patients with a history of acid reflux, there was no relationship between smoking and Barrett esophagus (p = 0.52). Likewise, no relationship was found between smoking and Barrett esophagus among patients without a history of acid reflux (p = 0.48). The results of this study are best explained by which of the following?
# <class 'dict'> {'A': 'Random error', 'B': 'Effect modification', 'C': 'Confounding', 'D': 'Selection bias', 'E': 'Stratification', 'F': 'Matching'}
# <class 'str'> A 23-year-old woman with Ehlers-Danlos syndrome is brought to the emergency department with right knee pain and swelling after she twisted it while dancing. She had two similar episodes last year that were treated conservatively. She was treated for a fracture of her humerus 2 years ago. She has gastroesophageal reflux disease. Her sister has allergic rhinitis. Her only medication is omeprazole. She appears tense and uncomfortable. Her temperature is 37.1°C (99.3°F), pulse is 97/min, and blood pressure is 110/70 mm Hg. Examination shows mild scoliosis. The lungs are clear to auscultation. Cardiac examination shows a mid-systolic click. The right knee shows a large, tender effusion and the patella is displaced laterally. Lachman's test, the posterior drawer test, and Apley's test are negative. A complete blood count and serum concentrations of electrolytes, urea nitrogen, and creatinine are within the reference range. Toxicology screening is negative. X-ray of the knee joint shows an osteochondral fragment within the knee joint. What is the most appropriate next step in management?
# <class 'dict'> {'A': 'Arthroscopy', 'B': 'Above knee cast', 'C': 'Knee brace only', 'D': 'Closed reduction', 'E': 'Total knee replacement', 'F': 'Physiotherapy only'}
# <class 'str'> A 60-year-old man comes to the physician for a routine health maintenance examination. He feels well. Five years ago, he underwent a colonoscopy, which was unremarkable. He has no history of serious illness except for an episode of poststreptococcal glomerulonephritis at the age of 10 years. His father died of bladder carcinoma at the age of 55 years. The patient works at a rubber factory. He has smoked one pack of cigarettes daily for the past 25 years. He drinks 1–2 cans of beer per day. He takes no medications. He has never received any pneumococcal vaccination. His temperature is 37°C (98.6°F), pulse is 70/min, and blood pressure is 120/80 mm Hg. Digital rectal examination shows mild symmetrical enlargement of the prostate with no masses. Which of the following is the most appropriate next step in management?
# <class 'dict'> {'A': 'Perform prostate biopsy', 'B': 'Obtain urine sample for cytology', 'C': 'Recommend colonoscopy', 'D': 'Discuss PSA assessment with patient', 'E': 'Obtain low-dose CT scan of the chest', 'F': 'Administer pneumococcal conjugate vaccination', 'G': 'Perform cystoscopy', 'H': 'Obtain CT urography', 'I': 'Obtain renal ultrasound'}
# <class 'str'> A 50-year-old man comes to the physician because of a 6-month history of difficulties having sexual intercourse due to erectile dysfunction. He has type 2 diabetes mellitus that is well controlled with metformin. He does not smoke. He drinks 5–6 beers daily. His vital signs are within normal limits. Physical examination shows bilateral pedal edema, decreased testicular volume, and increased breast tissue. The spleen is palpable 2 cm below the left costal margin. Abdominal ultrasound shows an atrophic, hyperechoic, nodular liver. An upper endoscopy is performed and shows dilated submucosal veins 2 mm in diameter with red spots on their surface in the distal esophagus. Therapy with a sildenafil is initiated for his erectile dysfunction. Which of the following is the most appropriate next step in management of this patient's esophageal findings?
# <class 'str'> {'A': 'Injection sclerotherapy', 'B': 'Nadolol therapy', 'C': 'Losaratan therapy', 'D': 'Octreotide therapy', 'E': 'Isosorbide mononitrate therapy', 'F': 'Endoscopic band ligation', 'G': 'Transjugular intrahepatic portosystemic shunt', 'H': 'Metoprolol therapy\n"'}
# <class 'str'> A 65-year-old Asian woman comes to the physician for a routine health maintenance examination. On questioning, she has had occasional night sweats during the past 2 months. She has not had fevers or weight loss. Seven months ago, she had an acute myocardial infarction and was treated with percutaneous coronary intervention. She has hypertension, hyperlipidemia, and gastroesophageal reflux disease. She has smoked one pack of cigarettes daily for 37 years. Current medications include aspirin, atorvastatin, ramipril, metoprolol, and esomeprazole. She is 178 cm (5 ft 10 in) tall and weighs 89 kg (207 lbs); BMI is 29.7 kg/m2. Her temperature is 37.4°C (99.3°F), pulse is 84/min, respirations are 18/min, and blood pressure is 145/80 mm Hg. The lungs are clear to auscultation. Cardiac examination shows an S4. There is a nontender skin lesion near the right large toenail. A photograph of the lesion is shown. The remainder of the examination shows no abnormalities. Which of the following is the most likely diagnosis?
# <class 'str'> {'A': 'Cholesterol embolism', 'B': 'Traumatic subungual hemorrhage', 'C': 'Malignant melanoma', 'D': 'Onychomycosis', 'E': 'Squamous cell carcinoma'}
# <class 'str'> A gastroenterology fellow is interested in the relationship between smoking and incidence of Barrett esophagus. At a departmental grand rounds she recently attended, one of the presenters claimed that smokers are only at increased risk for Barrett esophagus in the presence of acid reflux. She decides to design a retrospective cohort study to investigate the association between smoking and Barrett esophagus. After comparing 400 smokers to 400 non-smokers identified via chart review, she finds that smokers were at increased risk of Barrett esophagus at the end of a 10-year follow-up period (RR = 1.82, p < 0.001). Among patients with a history of acid reflux, there was no relationship between smoking and Barrett esophagus (p = 0.52). Likewise, no relationship was found between smoking and Barrett esophagus among patients without a history of acid reflux (p = 0.48). The results of this study are best explained by which of the following?
# <class 'str'> {'A': 'Random error', 'B': 'Effect modification', 'C': 'Confounding', 'D': 'Selection bias', 'E': 'Stratification', 'F': 'Matching'}
# <class 'str'> A 23-year-old woman with Ehlers-Danlos syndrome is brought to the emergency department with right knee pain and swelling after she twisted it while dancing. She had two similar episodes last year that were treated conservatively. She was treated for a fracture of her humerus 2 years ago. She has gastroesophageal reflux disease. Her sister has allergic rhinitis. Her only medication is omeprazole. She appears tense and uncomfortable. Her temperature is 37.1°C (99.3°F), pulse is 97/min, and blood pressure is 110/70 mm Hg. Examination shows mild scoliosis. The lungs are clear to auscultation. Cardiac examination shows a mid-systolic click. The right knee shows a large, tender effusion and the patella is displaced laterally. Lachman's test, the posterior drawer test, and Apley's test are negative. A complete blood count and serum concentrations of electrolytes, urea nitrogen, and creatinine are within the reference range. Toxicology screening is negative. X-ray of the knee joint shows an osteochondral fragment within the knee joint. What is the most appropriate next step in management?
# <class 'str'> {'A': 'Arthroscopy', 'B': 'Above knee cast', 'C': 'Knee brace only', 'D': 'Closed reduction', 'E': 'Total knee replacement', 'F': 'Physiotherapy only'}
# <class 'str'> A 60-year-old man comes to the physician for a routine health maintenance examination. He feels well. Five years ago, he underwent a colonoscopy, which was unremarkable. He has no history of serious illness except for an episode of poststreptococcal glomerulonephritis at the age of 10 years. His father died of bladder carcinoma at the age of 55 years. The patient works at a rubber factory. He has smoked one pack of cigarettes daily for the past 25 years. He drinks 1–2 cans of beer per day. He takes no medications. He has never received any pneumococcal vaccination. His temperature is 37°C (98.6°F), pulse is 70/min, and blood pressure is 120/80 mm Hg. Digital rectal examination shows mild symmetrical enlargement of the prostate with no masses. Which of the following is the most appropriate next step in management?
# <class 'str'> {'A': 'Perform prostate biopsy', 'B': 'Obtain urine sample for cytology', 'C': 'Recommend colonoscopy', 'D': 'Discuss PSA assessment with patient', 'E': 'Obtain low-dose CT scan of the chest', 'F': 'Administer pneumococcal conjugate vaccination', 'G': 'Perform cystoscopy', 'H': 'Obtain CT urography', 'I': 'Obtain renal ultrasound'}

# %%
# initiate the function
answers = answer_all_questions(df)

# %%
answers_2 = answer_all_questions(df)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[154], line 1
# ----> 1 answers_2 = answer_all_questions(df)
#
# Cell In[95], line 8, in answer_all_questions(df)
#       6     question = row['question']
#       7     options = row['options']
# ----> 8     answer = answer_open_ended_question(question, options=str(options), fine_tune_prompt=fine_tune_prompt, rubric_prompt=Criterion_rubric_prompt)
#       9     answers.append(answer.content)
#      10 return answers
#
# Cell In[152], line 22, in answer_open_ended_question(question, fine_tune_prompt, options, rubric_prompt)
#       3 def answer_open_ended_question(question, fine_tune_prompt="None", options = "None", rubric_prompt="None"):
#       4     message = [
#       5         (
#       6             'system',
#    (...)
#      20         )
#      21     ]
# ---> 22     answer = llm.invoke(message)
#      23     return answer
#
# File c:\Users\PC\miniconda3\envs\NIT6003\lib\site-packages\langchain_core\language_models\chat_models.py:153, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     142 def invoke(
#     143     self,
#     144     input: LanguageModelInput,
#    (...)
#     148     **kwargs: Any,
#     149 ) -> BaseMessage:
#     150     config = ensure_config(config)
#     151     return cast(
#     152         ChatGeneration,
# --> 153         self.generate_prompt(
#     154             [self._convert_input(input)],
#     155             stop=stop,
#     156             callbacks=config.get("callbacks"),
#     157             tags=config.get("tags"),
#     158             metadata=config.get("metadata"),
#     159             run_name=config.get("run_name"),
#     160             **kwargs,
#     161         ).generations[0][0],
#     162     ).message
#
# File c:\Users\PC\miniconda3\envs\NIT6003\lib\site-packages\langchain_core\language_models\chat_models.py:546, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     538 def generate_prompt(
#     539     self,
#     540     prompts: List[PromptValue],
#    (...)
#     543     **kwargs: Any,
#     544 ) -> LLMResult:
#     545     prompt_messages = [p.to_messages() for p in prompts]
# --> 546     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\PC\miniconda3\envs\NIT6003\lib\site-packages\langchain_core\language_models\chat_models.py:407, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     405         if run_managers:
#     406             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 407         raise e
#     408 flattened_outputs = [
#     409     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     410     for res in results
#     411 ]
#     412 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File c:\Users\PC\miniconda3\envs\NIT6003\lib\site-packages\langchain_core\language_models\chat_models.py:397, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     394 for i, m in enumerate(messages):
#     395     try:
#     396         results.append(
# --> 397             self._generate_with_cache(
#     398                 m,
#     399                 stop=stop,
#     400                 run_manager=run_managers[i] if run_managers else None,
#     401                 **kwargs,
#     402             )
#     403         )
#     404     except BaseException as e:
#     405         if run_managers:
#
# File c:\Users\PC\miniconda3\envs\NIT6003\lib\site-packages\langchain_core\language_models\chat_models.py:589, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     585         raise ValueError(
#     586             "Asked to cache, but no cache found at `langchain.cache`."
#     587         )
#     588 if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 589     result = self._generate(
#     590         messages, stop=stop, run_manager=run_manager, **kwargs
#     591     )
#     592 else:
#     593     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\PC\miniconda3\envs\NIT6003\lib\site-packages\langchain_openai\chat_models\base.py:484, in ChatOpenAI._generate(self, messages, stop, run_manager, stream, **kwargs)
#     478 message_dicts, params = self._create_message_dicts(messages, stop)
#     479 params = {
#     480     **params,
#     481     **({"stream": stream} if stream is not None else {}),
#     482     **kwargs,
#     483 }
# --> 484 response = self.client.create(messages=message_dicts, **params)
#     485 return self._create_chat_result(response)
#
# File c:\Users\PC\miniconda3\envs\NIT6003\lib\site-packages\openai\_utils\_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File c:\Users\PC\miniconda3\envs\NIT6003\lib\site-packages\openai\resources\chat\completions.py:590, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     558 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     559 def create(
#     560     self,
#    (...)
#     588     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     589 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 590     return self._post(
#     591         "/chat/completions",
#     592         body=maybe_transform(
#     593             {
#     594                 "messages": messages,
#     595                 "model": model,
#     596                 "frequency_penalty": frequency_penalty,
#     597                 "function_call": function_call,
#     598                 "functions": functions,
#     599                 "logit_bias": logit_bias,
#     600                 "logprobs": logprobs,
#     601                 "max_tokens": max_tokens,
#     602                 "n": n,
#     603                 "presence_penalty": presence_penalty,
#     604                 "response_format": response_format,
#     605                 "seed": seed,
#     606                 "stop": stop,
#     607                 "stream": stream,
#     608                 "stream_options": stream_options,
#     609                 "temperature": temperature,
#     610                 "tool_choice": tool_choice,
#     611                 "tools": tools,
#     612                 "top_logprobs": top_logprobs,
#     613                 "top_p": top_p,
#     614                 "user": user,
#     615             },
#     616             completion_create_params.CompletionCreateParams,
#     617         ),
#     618         options=make_request_options(
#     619             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     620         ),
#     621         cast_to=ChatCompletion,
#     622         stream=stream or False,
#     623         stream_cls=Stream[ChatCompletionChunk],
#     624     )
#
# File c:\Users\PC\miniconda3\envs\NIT6003\lib\site-packages\openai\_base_client.py:1240, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1226 def post(
#    1227     self,
#    1228     path: str,
#    (...)
#    1235     stream_cls: type[_StreamT] | None = None,
#    1236 ) -> ResponseT | _StreamT:
#    1237     opts = FinalRequestOptions.construct(
#    1238         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1239     )
# -> 1240     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\PC\miniconda3\envs\NIT6003\lib\site-packages\openai\_base_client.py:921, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     912 def request(
#     913     self,
#     914     cast_to: Type[ResponseT],
#    (...)
#     919     stream_cls: type[_StreamT] | None = None,
#     920 ) -> ResponseT | _StreamT:
# --> 921     return self._request(
#     922         cast_to=cast_to,
#     923         options=options,
#     924         stream=stream,
#     925         stream_cls=stream_cls,
#     926         remaining_retries=remaining_retries,
#     927     )
#
# File c:\Users\PC\miniconda3\envs\NIT6003\lib\site-packages\openai\_base_client.py:1005, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1003 if retries > 0 and self._should_retry(err.response):
#    1004     err.response.close()
# -> 1005     return self._retry_request(
#    1006         options,
#    1007         cast_to,
#    1008         retries,
#    1009         err.response.headers,
#    1010         stream=stream,
#    1011         stream_cls=stream_cls,
#    1012     )
#    1014 # If the response is streamed then we need to explicitly read the response
#    1015 # to completion before attempting to access the response text.
#    1016 if not err.response.is_closed:
#
# File c:\Users\PC\miniconda3\envs\NIT6003\lib\site-packages\openai\_base_client.py:1053, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1049 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1050 # different thread if necessary.
#    1051 time.sleep(timeout)
# -> 1053 return self._request(
#    1054     options=options,
#    1055     cast_to=cast_to,
#    1056     remaining_retries=remaining,
#    1057     stream=stream,
#    1058     stream_cls=stream_cls,
#    1059 )
#
# File c:\Users\PC\miniconda3\envs\NIT6003\lib\site-packages\openai\_base_client.py:1005, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1003 if retries > 0 and self._should_retry(err.response):
#    1004     err.response.close()
# -> 1005     return self._retry_request(
#    1006         options,
#    1007         cast_to,
#    1008         retries,
#    1009         err.response.headers,
#    1010         stream=stream,
#    1011         stream_cls=stream_cls,
#    1012     )
#    1014 # If the response is streamed then we need to explicitly read the response
#    1015 # to completion before attempting to access the response text.
#    1016 if not err.response.is_closed:
#
# File c:\Users\PC\miniconda3\envs\NIT6003\lib\site-packages\openai\_base_client.py:1053, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1049 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1050 # different thread if necessary.
#    1051 time.sleep(timeout)
# -> 1053 return self._request(
#    1054     options=options,
#    1055     cast_to=cast_to,
#    1056     remaining_retries=remaining,
#    1057     stream=stream,
#    1058     stream_cls=stream_cls,
#    1059 )
#
# File c:\Users\PC\miniconda3\envs\NIT6003\lib\site-packages\openai\_base_client.py:1020, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1017         err.response.read()
#    1019     log.debug("Re-raising status error")
# -> 1020     raise self._make_status_error_from_response(err.response) from None
#    1022 return self._process_response(
#    1023     cast_to=cast_to,
#    1024     options=options,
#    (...)
#    1027     stream_cls=stream_cls,
#    1028 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
type(answers)
# Out:
# list

# %%
print(answers[0])
# Out:
# {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "Endoscopic band ligation is the most appropriate next step in the management of this patient's esophageal varices.",
#     "Answer_letter": "F"
# }

# %%
# convert answers[0] to a dictionary
answers_dict = json.loads(answers[0])
answers_dict
# Out:
# {'Strength of Evidence': '3',
#  'Relevance to Clinical Scenario': '3',
#  'Logical Consistency': '3',
#  'Comprehensiveness': '3',
#  'Answer': "Endoscopic band ligation is the most appropriate next step in the management of this patient's esophageal varices.",
#  'Answer_letter': 'F'}

# %%
answers_dict['Answer']
# Out:
# "Endoscopic band ligation is the most appropriate next step in the management of this patient's esophageal varices."

# %%
# write function to save the answers to a file
filename = 'answers.txt'
def save_answers_to_file(answers, filename):
    with open(filename, 'w') as f:
        for answer in answers:
            f.write(answer + '\n')

# save the answers to a file
save_answers_to_file(answers, filename)

# %%
answers[0]
# Out:
# '{\n    "Strength of Evidence": "3",\n    "Relevance to Clinical Scenario": "3",\n    "Logical Consistency": "3",\n    "Comprehensiveness": "3",\n    "Answer": "Endoscopic band ligation is the most appropriate next step in the management of this patient\'s esophageal varices.",\n    "Answer_letter": "F"\n}'

# %%
# wirte a function to compare the answers to the correct answers
# iterrate through the dataframe and compare the answers to the correct answers
# return 'True' if the answer matches the correct answer and 'False' if it does not match
# match the answers['Answer_letter'] to the 'answer' column in the dataframe
# make new column to the dataframe: add answers['Answer'] to the dataframe, add a column 'correct' to the dataframe
# return the dataframe

def compare_answers(df, answers):
    for index, row in df.iterrows():
        for answer in answers:
            answer = json.loads(answer)
            if answer['Answer_letter'].strip().lower() == row['answer'].strip().lower():
                row['correct'] = True
                # add the answer to the dataframe
                row['LLM_answer'] = answer['Answer']
            else:
                row['correct'] = False
                # add the answer to the dataframe
                row['LLM_answer'] = answer['Answer']

    return df

# initiate the function
df_answer = compare_answers(df, answers)

# %%
# check the first 5 rows of the dataframe
df_answer.head()
# Out:
#                                             question answer  \
# 0  A 50-year-old man comes to the physician becau...      B
# 1  A 65-year-old Asian woman comes to the physici...      C
# 2  A gastroenterology fellow is interested in the...      C
# 3  A 23-year-old woman with Ehlers-Danlos syndrom...      A
# 4  A 60-year-old man comes to the physician for a...      D
#
#                                              options meta_info
# 0  {'A': 'Injection sclerotherapy', 'B': 'Nadolol...     step2
# 1  {'A': 'Cholesterol embolism', 'B': 'Traumatic ...     step2
# 2  {'A': 'Random error', 'B': 'Effect modificatio...     step2
# 3  {'A': 'Arthroscopy', 'B': 'Above knee cast', '...     step2
# 4  {'A': 'Perform prostate biopsy', 'B': 'Obtain ...     step2

# %%
answers[0]
# Out:
# '{\n    "Strength of Evidence": "3",\n    "Relevance to Clinical Scenario": "3",\n    "Logical Consistency": "3",\n    "Comprehensiveness": "3",\n    "Answer": "Endoscopic band ligation is the most appropriate next step in the management of this patient\'s esophageal varices.",\n    "Answer_letter": "F"\n}'

# %%
answers_dict = json.loads(answers[0])
# compare the answers to the correct answer of the first row
answers_dict['Answer_letter'], df_answer['answer'][0]
answers_dict['Answer_letter'] ==  df_answer['answer'][0]
# Out:
# False

# %%
df_answer['options'][0]
# Out:
# {'A': 'Injection sclerotherapy',
#  'B': 'Nadolol therapy',
#  'C': 'Losaratan therapy',
#  'D': 'Octreotide therapy',
#  'E': 'Isosorbide mononitrate therapy',
#  'F': 'Endoscopic band ligation',
#  'G': 'Transjugular intrahepatic portosystemic shunt',
#  'H': 'Metoprolol therapy\n"'}

# %%
# print all answer letter of answers, compare to the correct answer in the dataframe
count = 0
for i in range(len(answers)):
    answers_dict = json.loads(answers[i])
    if answers_dict['Answer_letter'] == df_answer['answer'][i]:
        count += 1
    print(answers_dict['Answer_letter'], df_answer['answer'][i])
print(count)
# Out:
# F B
# C C
# B C
# A A
# F D
# K K
# D D
# F F
# E E
# C C
# None C
# D F
# F F
# A A
# C C
# D D
# A F
# A E
# D D
# A A
# None C
# C C
# C C
# A C
# A A
# A E
# C C
# B G
# C C
# D D
# D E
# None B
# B B
# D C
# C C
# D F
# C C
# D D
# A A
# A A
# A B
# A A
# A C
# G G
# B B
# F C
# D D
# F A
# C C
# G G
# C C
# C C
# B B
# D D
# H A
# C B
# C A
# B B
# A A
# B B
# B B
# I I
# F F
# B B
# B B
# G G
# G G
# C D
# E G
# F F
# C C
# E B
# D B
# D D
# B B
# C C
# C D
# A A
# None E
# E E
# None D
# C B
# G F
# D E
# None A
# E E
# A D
# F F
# A A
# C C
# F G
# G G
# B E
# E G
# C C
# A A
# None F
# B B
# E C
# A A
# D D
# A A
# D D
# F A
# None C
# A A
# B B
# A D
# F F
# D D
# F F
# B B
# G G
# B B
# E E
# C C
# A A
# F D
# E E
# D D
# C C
# C C
# C C
# B B
# A A
# E E
# B B
# E C
# D D
# B D
# F F
# F F
# G G
# F B
# None C
# D A
# C C
# C D
# C C
# A F
# B B
# C C
# D E
# A F
# C F
# C C
# C C
# E E
# A A
# D E
# F F
# G G
# D C
# D E
# E E
# E E
# B E
# C B
# D D
# E E
# E E
# A A
#  D
# B B
# F F
# D D
# E E
# A D
# B B
# C C
# B C
# D D
# B E
# E E
# B D
# E E
# B C
# D D
# E E
# B B
# C C
# A A
# E E
# C A
# A A
# C B
# B B
# E E
# E A
# None D
# D D
# B B
# A A
# B B
# B B
# D D
# D D
# E B
# D A
# E A
# E C
# E D
# B B
# D D
# C C
# D A
# B E
# E B
# D A
# E E
# E D
# B B
# D D
# E E
# D D
# D D
# None A
# D D
# D D
# D A
# D D
# A A
# E B
# A B
# A A
# E E
# A D
# C C
# A A
# C C
# B B
# C C
# D D
# E C
# A A
# E B
# D D
# C C
# E B
# E E
# None C
# B B
# B B
# A A
# A A
# C B
# A A
# E E
# B B
# D A
# B B
# E E
# B B
# A A
# D D
# B B
# C C
# A A
# D D
# None A
# B D
# D D
# B B
# D D
# C C
# C C
# A A
# A B
# A B
# A C
# B D
# E B
# D D
# E C
# D D
# E E
# B D
# B B
# B B
# D D
# B A
# D D
# D A
# E E
# B B
# C C
# B B
# A A
# C C
# A A
# A C
# E E
# C C
# A A
# C C
# E B
# B B
# C C
# A A
# A A
# D D
# E E
# C C
# E E
# C C
# E E
# C C
# None C
# C D
# C C
# B B
# B B
# B B
# E E
# D E
# A A
# E E
# A A
# None F
# C C
# D D
# A A
# None A
# C C
# D A
# C C
# C C
# D D
# B B
# D E
# B B
# D C
# D A
# A A
# B B
# B B
# B B
# A A
# D D
# E E
# E E
# E B
# E B
# B B
# D C
# B B
# D D
# C C
# B B
# B D
# A B
# B B
# D A
# B B
# E E
# B B
# None E
# E E
# A B
# B B
# D E
# D D
# C C
# A A
# C D
# D D
# D D
# B B
# C C
# E E
# E E
# C E
# A A
# B B
# B B
# D D
# A C
# A A
# B B
# A E
# C C
# B B
# A A
# D D
# C E
# F F
# D D
# C C
# E E
# C C
# E B
# B B
# E E
# A A
# D D
# A A
# A A
# None C
# A A
# B B
# A A
# C C
# None E
# D D
# A D
# D D
# E E
# C C
# E E
# A A
# C C
# C C
# None C
# C A
# D D
# C D
# D D
# E C
# B B
# C B
# D D
# B B
# A A
# A D
# A A
# B C
# A A
# B B
# E E
# E C
# B B
# E E
# D D
# C C
# E E
# E E
# A B
# C C
# D D
# C A
# A A
# D B
# B B
# A A
# B A
# D D
# A A
# C A
# None C
# E E
# E E
# A A
# None E
# B D
# C C
# E E
# B B
# E C
# E E
# D C
# B B
# B B
# C B
# B B
# B D
# C C
# D D
# E E
# B B
# D B
# D D
# D A
# B D
# C C
# E E
# E B
# C C
# C A
# E E
# D A
# E E
# A D
# C D
# E D
# None C
# B B
# A A
# B B
# D D
# D A
# A A
# None D
# E A
# C B
# B A
# B E
# A A
# D D
# None C
# A A
# C C
# A B
# 335

# %%
a = 335/502
a
# Out:
# 0.6673306772908366

# %%
# compare the answers Answer_letter to the answer column in the dataframe, if they match, return True, else return False, add a new column 'correct' to the dataframe
# add the answer to the dataframe
# return the dataframe
def compare_answers(df, answers):
    for index, row in df.iterrows():
        for answer in answers:
            answer = json.loads(answer)
            if answer['Answer_letter'].strip().lower() == row['answer'].strip().lower():
                row['correct'] = True
                # add the answer to the dataframe
                row['LLM_answer'] = answer['Answer']
            else:
                row['correct'] = False
                # add the answer to the dataframe
                row['LLM_answer'] = answer['Answer']

    return df

# initiate the function
df_answer = compare_answers(df, answers)

# %%
df_answer.head()
# Out:
#                                             question answer  \
# 0  A 50-year-old man comes to the physician becau...      B
# 1  A 65-year-old Asian woman comes to the physici...      C
# 2  A gastroenterology fellow is interested in the...      C
# 3  A 23-year-old woman with Ehlers-Danlos syndrom...      A
# 4  A 60-year-old man comes to the physician for a...      D
#
#                                              options meta_info  correct  \
# 0  {'A': 'Injection sclerotherapy', 'B': 'Nadolol...     step2     True
# 1  {'A': 'Cholesterol embolism', 'B': 'Traumatic ...     step2     True
# 2  {'A': 'Random error', 'B': 'Effect modificatio...     step2     True
# 3  {'A': 'Arthroscopy', 'B': 'Above knee cast', '...     step2     True
# 4  {'A': 'Perform prostate biopsy', 'B': 'Obtain ...     step2     True
#
#                                           LLM_answer LLM_answer_letter
# 0  The results of the study are best explained by...                 B
# 1                                 Malignant melanoma                 C
# 2                                 Malignant melanoma                 C
# 3  Arthroscopy is the most appropriate next step ...                 A
# 4                        Fasting serum gastrin level                 D

# %%
# count the number of correct answers
correct_answers = df_answer['correct'].sum()
total_questions = len(df_answer)
accuracy = correct_answers / total_questions

print(f"Number of correct answers: {correct_answers}")
print(f"Total number of questions: {total_questions}")
print(f"Accuracy: {accuracy:.2%}")
# Out:
# Number of correct answers: 502
# Total number of questions: 502
# Accuracy: 100.00%

# %%
# print options and LLM_answer to compare, and answer letter. We will check the first 5 rows
for index, row in df_answer.head().iterrows():
    print(row['options'], row['LLM_answer'], row['answer'])
# Out:
# {'A': 'Injection sclerotherapy', 'B': 'Nadolol therapy', 'C': 'Losaratan therapy', 'D': 'Octreotide therapy', 'E': 'Isosorbide mononitrate therapy', 'F': 'Endoscopic band ligation', 'G': 'Transjugular intrahepatic portosystemic shunt', 'H': 'Metoprolol therapy\n"'} The results of the study are best explained by effect modification. The presence of acid reflux modifies the effect of smoking on the risk of Barrett esophagus, as indicated by the lack of association between smoking and Barrett esophagus in both the presence and absence of acid reflux. B
# {'A': 'Cholesterol embolism', 'B': 'Traumatic subungual hemorrhage', 'C': 'Malignant melanoma', 'D': 'Onychomycosis', 'E': 'Squamous cell carcinoma'} Malignant melanoma C
# {'A': 'Random error', 'B': 'Effect modification', 'C': 'Confounding', 'D': 'Selection bias', 'E': 'Stratification', 'F': 'Matching'} Malignant melanoma C
# {'A': 'Arthroscopy', 'B': 'Above knee cast', 'C': 'Knee brace only', 'D': 'Closed reduction', 'E': 'Total knee replacement', 'F': 'Physiotherapy only'} Arthroscopy is the most appropriate next step in management for this patient. The presence of an osteochondral fragment within the knee joint, as seen on the X-ray, suggests a loose body that could be causing mechanical symptoms and pain. Arthroscopy would allow for direct visualization and removal of the fragment, addressing the underlying issue. A
# {'A': 'Perform prostate biopsy', 'B': 'Obtain urine sample for cytology', 'C': 'Recommend colonoscopy', 'D': 'Discuss PSA assessment with patient', 'E': 'Obtain low-dose CT scan of the chest', 'F': 'Administer pneumococcal conjugate vaccination', 'G': 'Perform cystoscopy', 'H': 'Obtain CT urography', 'I': 'Obtain renal ultrasound'} Fasting serum gastrin level D

# %%
# write a function to answer multiple choice questions, simple prompt, zero shot, no explaination
# Write a function to answer Multiple choice USMLE questions
def answer_mcq_zeroshot(question, fine_tune_prompt="None", options = "None", rubric_prompt="None"):
    message = [
        (
            'system',
            "You are a medical doctor, experienced in diagnosing diseases. You are presented with a clinical scenario and asked to provide a conclusion, based on the information provided."
        ),
        (
            'user',
            """
            Based on the following clinical scenario in {question}, provide an answer based on the list of {options}
            Output format:
            {
                "Answer": "Answer text",
                "Answer_letter": "Answer option A, B, C, etc."
                "Reasoning": "Reasoning text"
            }
            """.replace('{question}', question).replace('{fine_tune_prompt}', fine_tune_prompt).replace('{options}', options).replace('{rubric_prompt}', rubric_prompt)
        )
    ]
    answer = llm.invoke(message)
    return answer

# %%
question_bank_jsonl = r'C:\Users\PC\NIT6001\CMG_prog_v3\MedQA-USMLE\questions\US\endoscopy_questions.jsonl'
# import jsonlines using pandas
df = pd.read_json(question_bank_jsonl, lines=True)
df.head()
# Out:
#                                             question answer  \
# 0  A 50-year-old man comes to the physician becau...      B
# 1  A 65-year-old Asian woman comes to the physici...      C
# 2  A gastroenterology fellow is interested in the...      C
# 3  A 23-year-old woman with Ehlers-Danlos syndrom...      A
# 4  A 60-year-old man comes to the physician for a...      D
#
#                                              options meta_info
# 0  {'A': 'Injection sclerotherapy', 'B': 'Nadolol...     step2
# 1  {'A': 'Cholesterol embolism', 'B': 'Traumatic ...     step2
# 2  {'A': 'Random error', 'B': 'Effect modificatio...     step2
# 3  {'A': 'Arthroscopy', 'B': 'Above knee cast', '...     step2
# 4  {'A': 'Perform prostate biopsy', 'B': 'Obtain ...     step2

# %%
# write a function to loop through all rows of question bank, extract the question and options, parse them into function answer_mcq_zeroshot. append the result.content to a list

def answer_all_questions_mcq_zeroshot(df):
    mcq_zeroshot_answers = []
    for index, row in df.iterrows():
        question = row['question']
        options = row['options']
        answer = answer_mcq_zeroshot(question, options=str(options), fine_tune_prompt=fine_tune_prompt, rubric_prompt=Criterion_rubric_prompt)
        mcq_zeroshot_answers.append(answer.content)
    return mcq_zeroshot_answers

# initiate the function
mcq_zeroshot_answers = answer_all_questions_mcq_zeroshot(df)

# %%
# remove ```json\n ... \n``` wrapper from the answers
mcq_zeroshot_answers_clean = [re.sub(r'```json\n|\n```', '', answer) for answer in mcq_zeroshot_answers]

# %%
# save the answers to a file
filename = 'mcq_zeroshot_answers.txt'
save_answers_to_file(mcq_zeroshot_answers_clean, filename)

# %%
json.loads(mcq_zeroshot_answers_clean[0])['Answer_letter']
# Out:
# 'B'

# %%
count = 0
for i in range(len(mcq_zeroshot_answers_clean)):
    answers_dict = json.loads(mcq_zeroshot_answers_clean[i])
    if answers_dict['Answer_letter'] == df['answer'][i]:
        count += 1
    print(answers_dict['Answer_letter'], df['answer'][i])
print(count)
# Out:
# B B
# A C
# C C
# A A
# F D
# K K
# D D
# F F
# E E
# C C
# C C
# F F
# F F
# A A
# C C
# D D
# F F
# E E
# D D
# A A
# A C
# C C
# C C
# A C
# A A
# A E
# C C
# G G
# C C
# D D
# D E
# B B
# B B
# C C
# C C
# F F
# C C
# D D
# A A
# A A
# B B
# A A
# C C
# G G
# B B
# F C
# D D
# A A
# C C
# G G
# C C
# C C
# B B
# D D
# H A
# B B
# D A
# B B
# A A
# B B
# B B
# I I
# C F
# B B
# B B
# G G
# G G
# D D
# E G
# F F
# C C
# B B
# B B
# D D
# B B
# C C
# E D
# A A
# E E
# E E
# D D
# F B
# G F
# E E
# A A
# E E
# D D
# D F
# A A
# C C
# G G
# G G
# B E
# E G
# C C
# A A
# F F
# B B
# E C
# A A
# D D
# A A
# D D
# A A
# C C
# A A
# B B
# D D
# F F
# D D
# F F
# B B
# G G
# B B
# E E
# C C
# A A
# D D
# E E
# D D
# C C
# C C
# C C
# B B
# A A
# E E
# B B
# B C
# A D
# D D
# F F
# F F
# F G
# B B
# C C
# D A
# C C
# D D
# C C
# A F
# A B
# C C
# D E
# F F
# C F
# C C
# C C
# E E
# A A
# E E
# A F
# G G
# C C
# A E
# E E
# E E
# E E
# B B
# D D
# E E
# E E
# B A
# D D
# B B
# F F
# D D
# E E
# D D
# B B
# C C
# C C
# D D
# E E
# E E
# D D
# E E
# C C
# D D
# E E
# B B
# D C
# A A
# E E
# A A
# A A
# C B
# B B
# E E
# A A
# D D
# D D
# B B
# A A
# B B
# B B
# D D
# D D
# E B
# A A
# E A
# B C
# D D
# B B
# E D
# C C
# A A
# B E
# E B
# D A
# E E
# C D
# B B
# B D
# D E
# D D
# D D
# A A
# D D
# D D
# A A
# D D
# A A
# B B
# A B
# A A
# C E
# A D
# C C
# A A
# C C
# B B
# C C
# D D
# C C
# A A
# E B
# C D
# C C
# E B
# E E
# C C
# B B
# B B
# A A
# A A
# C B
# A A
# E E
# E B
# D A
# B B
# E E
# B B
# B A
# D D
# B B
# C C
# A A
# D D
# B A
# B D
# D D
# B B
# D D
# C C
# C C
# A A
# B B
# B B
# A C
# B D
# B B
# D D
# E C
# D D
# E E
# B D
# B B
# B B
# D D
# B A
# D D
# C A
# E E
# B B
# C C
# B B
# A A
# C C
# A A
# A C
# E E
# C C
# A A
# C C
# B B
# B B
# C C
# A A
# A A
# D D
# E E
# C C
# E E
# C C
# E E
# C C
# E C
# D D
# C C
# B B
# B B
# B B
# E E
# E E
# A A
# E E
# A A
# B F
# C C
# D D
# A A
# A A
# C C
# A A
# C C
# C C
# D D
# B B
# E E
# B B
# D C
# A A
# A A
# B B
# C B
# B B
# A A
# D D
# E E
# E E
# B B
# E B
# B B
# C C
# B B
# D D
# C C
# B B
# B D
# B B
# B B
# A A
# B B
# E E
# B B
# E E
# E E
# B B
# B B
# D E
# D D
# C C
# A A
# C D
# D D
# D D
# B B
# C C
# E E
# E E
# E E
# A A
# B B
# B B
# D D
# A C
# A A
# B B
# D E
# C C
# B B
# A A
# D D
# C E
# F F
# D D
# C C
# E E
# C C
# B B
# B B
# E E
# A A
# E D
# A A
# A A
# C C
# A A
# B B
# A A
# C C
# E E
# D D
# D D
# D D
# E E
# C C
# E E
# A A
# C C
# C C
# C C
# B A
# D D
# D D
# D D
# C C
# B B
# B B
# D D
# B B
# A A
# D D
# A A
# B C
# A A
# B B
# E E
# C C
# B B
# E E
# D D
# C C
# E E
# E E
# A B
# C C
# D D
# A A
# A A
# B B
# B B
# A A
# B A
# D D
# A A
# A A
# C C
# E E
# E E
# A A
# E E
# B D
# C C
# E E
# B B
# E C
# E E
# D C
# D B
# B B
# C B
# B B
# D D
# C C
# D D
# E E
# B B
# B B
# C D
# B A
# D D
# C C
# E E
# B B
# C C
# A A
# E E
# D A
# E E
# D D
# D D
# D D
# C C
# B B
# A A
# B B
# D D
# A A
# A A
# D D
# A A
# C B
# B A
# B E
# A A
# D D
# C C
# A A
# C C
# B B
# 415

# %%
a = 415/502
a
# Out:
# 0.8266932270916335

# %%
def answer_mcq_with_rubric(question, fine_tune_prompt="None", options = "None", rubric_prompt="None"):
    message = [
        (
            'system',
            "You are a medical doctor, experienced in diagnosing diseases."
        ),
        (
            'user',
            """
            Think step by step:
            If {options} is not 'None', follow {rubric_prompt}, return the best answer based on the rubric
            If {options} is 'None',
            Answer the following open-ended question: {question} To answer this questions, do:
            - If 'fine_tune_prompt' is not 'None' the answer should follow {fine_tune_prompt}
            - Action 1: Generate all potential causes. the answer should follow {fine_tune_prompt}
            - Action 2: for each potential cause, evaluate by using {rubric_prompt}. If 'rubric_prompt' is 'None', generate a rubric for evaluation
            Output format: follow the rubric, including reasoning
            """.replace('{question}', question).replace('{fine_tune_prompt}', fine_tune_prompt).replace('{options}', options).replace('{rubric_prompt}', rubric_prompt)
        )
    ]
    answer = llm.invoke(message)
    return answer

# %%
def answer_all_questions_mcq_with_rubric(df):
    mcq_with_rubric_answers = []
    for index, row in df.iterrows():
        question = row['question']
        options = row['options']
        answer = answer_mcq_with_rubric(question, options=str(options), fine_tune_prompt=fine_tune_prompt, rubric_prompt=Criterion_rubric_prompt)
        mcq_with_rubric_answers.append(answer.content)
    return mcq_with_rubric_answers

# %%
# test answer_mcq_with_rubric function with the first row of the dataframe
question = df['question'][0]
options = df['options'][0]
answer = answer_mcq_with_rubric(question, options=str(options), fine_tune_prompt=fine_tune_prompt, rubric_prompt=Criterion_rubric_prompt)
answer.content
# Out:
# 'To address the clinical scenario provided, we need to determine the most appropriate next step in managing the patient\'s esophageal findings, which are indicative of esophageal varices due to portal hypertension, likely secondary to liver cirrhosis. The patient has a history of alcohol use, which is a common cause of liver cirrhosis.\n\n### Evaluation of Potential Management Options:\n\n1. **Injection Sclerotherapy (A):**\n   - **Strength of Evidence:** Moderate (2 points). Sclerotherapy is an older method for managing esophageal varices but is less commonly used now due to the availability of more effective treatments.\n   - **Relevance to Clinical Scenario:** Moderate (2 points). It addresses the varices but is not the first-line treatment.\n   - **Logical Consistency:** Moderate (2 points). It is a logical option but not the most current standard of care.\n   - **Comprehensiveness:** Moderate (2 points). It addresses the varices but not the underlying portal hypertension.\n\n2. **Nadolol Therapy (B):**\n   - **Strength of Evidence:** High (3 points). Non-selective beta-blockers like nadolol are recommended for primary prophylaxis of variceal bleeding.\n   - **Relevance to Clinical Scenario:** High (3 points). Directly addresses the prevention of variceal bleeding.\n   - **Logical Consistency:** High (3 points). It is consistent with current guidelines for managing esophageal varices.\n   - **Comprehensiveness:** High (3 points). It addresses the risk of bleeding and is part of the standard management for portal hypertension.\n\n3. **Losartan Therapy (C):**\n   - **Strength of Evidence:** Low (1 point). Losartan is not typically used for managing esophageal varices.\n   - **Relevance to Clinical Scenario:** Low (1 point). It does not address the varices or portal hypertension.\n   - **Logical Consistency:** Low (1 point). It is not a logical choice for this scenario.\n   - **Comprehensiveness:** Low (1 point). It does not address the key issues in the scenario.\n\n4. **Octreotide Therapy (D):**\n   - **Strength of Evidence:** Moderate (2 points). Octreotide is used in acute variceal bleeding but not for prophylaxis.\n   - **Relevance to Clinical Scenario:** Moderate (2 points). It is relevant in acute settings but not for this scenario.\n   - **Logical Consistency:** Moderate (2 points). It is logical for acute management but not prophylaxis.\n   - **Comprehensiveness:** Moderate (2 points). It addresses acute bleeding but not prophylaxis.\n\n5. **Isosorbide Mononitrate Therapy (E):**\n   - **Strength of Evidence:** Moderate (2 points). It can be used in combination with beta-blockers but is not first-line alone.\n   - **Relevance to Clinical Scenario:** Moderate (2 points). It is relevant but not the primary choice.\n   - **Logical Consistency:** Moderate (2 points). It is logical but not the most effective alone.\n   - **Comprehensiveness:** Moderate (2 points). It partially addresses the issue.\n\n6. **Endoscopic Band Ligation (F):**\n   - **Strength of Evidence:** High (3 points). It is a first-line treatment for preventing variceal bleeding.\n   - **Relevance to Clinical Scenario:** High (3 points). Directly addresses the varices.\n   - **Logical Consistency:** High (3 points). It is consistent with current guidelines.\n   - **Comprehensiveness:** High (3 points). It effectively addresses the varices.\n\n7. **Transjugular Intrahepatic Portosystemic Shunt (G):**\n   - **Strength of Evidence:** Moderate (2 points). TIPS is used for refractory variceal bleeding or ascites.\n   - **Relevance to Clinical Scenario:** Moderate (2 points). It is not the first-line treatment for initial variceal management.\n   - **Logical Consistency:** Moderate (2 points). It is logical for refractory cases.\n   - **Comprehensiveness:** Moderate (2 points). It addresses portal hypertension but is not first-line.\n\n8. **Metoprolol Therapy (H):**\n   - **Strength of Evidence:** Low (1 point). Metoprolol is not typically used for variceal prop ...

# %%
# print line 20 of the dataframe
df['question'][20], df['options'][20]
# Out:
# ('A 35-year-old female comes to the physician because of a 2-year history of progressive fatigue and joint pain. She has a 1-year history of skin problems and a 4-month history of episodic pallor of her fingers. She reports that the skin of her face, neck, and hands is always dry and itchy; there are also numerous “red spots” on her face. She has become more “clumsy” and often drops objects. She has gastroesophageal reflux disease treated with lansoprazole. She does not smoke. She occasionally drinks a beer or a glass of wine. Her temperature is 36.5°C (97.7°F), blood pressure is 154/98 mm Hg, and pulse is 75/min. Examination shows hardening and thickening of the skin of face, neck, and hands. There are small dilated blood vessels around her mouth and on her oral mucosa. Mouth opening is reduced. Active and passive range of motion of the proximal and distal interphalangeal joints is limited. Cardiopulmonary examination shows no abnormalities. Her creatinine is 1.4 mg/dL. The patient is at increased risk for which of the following complications?',
#  {'A': 'Dental caries',
#   'B': 'Antiphospholipid syndrome',
#   'C': 'Lung cancer',
#   'D': 'Urolithiasis',
#   'E': 'Dactylitis',
#   'F': 'Osteoporosis\n"'})

# %%
mcq_with_rubric_answers = answer_all_questions_mcq_with_rubric(df)

# %%
# check the results
mcq_with_rubric_answers[0:10]
# Out:
# ['{\n    "Strength of Evidence": "3",\n    "Relevance to Clinical Scenario": "3",\n    "Logical Consistency": "3",\n    "Comprehensiveness": "3",\n    "Answer": "The most appropriate next step in the management of this patient\'s esophageal varices, given the presence of red spots indicating a high risk of bleeding, is endoscopic band ligation. This procedure is a widely accepted first-line treatment for the prevention of variceal bleeding in patients with high-risk varices.",\n    "Answer_letter": "F"\n}',
#  '{\n    "Strength of Evidence": "3",\n    "Relevance to Clinical Scenario": "3",\n    "Logical Consistency": "3",\n    "Comprehensiveness": "3",\n    "Answer": "The most likely diagnosis for the nontender skin lesion near the right large toenail in this clinical scenario is \'Cholesterol embolism\'. This is supported by the patient\'s history of acute myocardial infarction and the use of medications like aspirin and atorvastatin, which are associated with atherosclerosis and potential cholesterol emboli. The presence of a nontender lesion aligns with the presentation of cholesterol embolism, which can cause small, painless skin lesions due to emboli lodging in small vessels.",\n    "Answer_letter": "A"\n}',
#  '{\n    "Strength of Evidence": "3",\n    "Relevance to Clinical Scenario": "3",\n    "Logical Consistency": "3",\n    "Comprehensiveness": "3",\n    "Answer": "The results of the study are best explained by \'Effect modification\'. In this scenario, the relationship between smoking and Barrett esophagus is modified by the presence of acid reflux. The study found that among patients with or without acid reflux, smoking did not increase the risk of Barrett esophagus, suggesting that acid reflux modifies the effect of smoking on the development of Barrett esophagus.",\n    "Answer_letter": "B"\n}',
#  '{\n    "Strength of Evidence": "3",\n    "Relevance to Clinical Scenario": "3",\n    "Logical Consistency": "3",\n    "Comprehensiveness": "3",\n    "Answer": "The most appropriate next step in management for this patient with Ehlers-Danlos syndrome, knee pain, and an osteochondral fragment within the knee joint is arthroscopy. Arthroscopy is a minimally invasive surgical procedure that allows for direct visualization and treatment of joint pathology. In this case, it would allow for the removal of the osteochondral fragment, which is likely causing the knee pain and effusion. This approach is supported by clinical guidelines for managing intra-articular loose bodies and is directly relevant to the patient\'s current presentation.",\n    "Answer_letter": "A"\n}',
#  'To address the scenario provided, we need to determine the most appropriate next step in management for the 60-year-old man based on his clinical presentation and history. Given the options provided, we will evaluate each potential action using the rubric provided.\n\n### Evaluation of Options:\n\n1. **Perform prostate biopsy (A):**\n   - **Strength of Evidence:** Low (1 point) - There is no indication of prostate cancer suspicion based on the information provided.\n   - **Relevance to Clinical Scenario:** Low (1 point) - The digital rectal exam shows mild symmetrical enlargement, which is common in benign prostatic hyperplasia (BPH) and not indicative of cancer.\n   - **Logical Consistency:** Low (1 point) - Performing a biopsy without suspicion of cancer is not consistent with standard practice.\n   - **Comprehensiveness:** Low (1 point) - Does not address the patient\'s risk factors or history.\n\n2. **Obtain urine sample for cytology (B):**\n   - **Strength of Evidence:** Moderate (2 points) - Given the family history of bladder carcinoma, this could be considered.\n   - **Relevance to Clinical Scenario:** Moderate (2 points) - Addresses the family history of bladder cancer.\n   - **Logical Consistency:** Moderate (2 points) - It is reasonable to consider bladder cancer screening given the family history.\n   - **Comprehensiveness:** Moderate (2 points) - Partially addresses the family history but not the smoking history.\n\n3. **Recommend colonoscopy (C):**\n   - **Strength of Evidence:** Low (1 point) - The patient had an unremarkable colonoscopy 5 years ago.\n   - **Relevance to Clinical Scenario:** Low (1 point) - Not due for another colonoscopy based on standard screening intervals.\n   - **Logical Consistency:** Low (1 point) - Recommending another colonoscopy is not consistent with guidelines.\n   - **Comprehensiveness:** Low (1 point) - Does not address current risk factors.\n\n4. **Discuss PSA assessment with patient (D):**\n   - **Strength of Evidence:** High (3 points) - PSA screening is a standard discussion for men in this age group.\n   - **Relevance to Clinical Scenario:** High (3 points) - Directly addresses prostate health, which is relevant given the exam findings.\n   - **Logical Consistency:** High (3 points) - Consistent with guidelines for prostate cancer screening.\n   - **Comprehensiveness:** High (3 points) - Addresses prostate health, which is a concern given the exam findings.\n\n5. **Obtain low-dose CT scan of the chest (E):**\n   - **Strength of Evidence:** High (3 points) - Recommended for lung cancer screening in smokers.\n   - **Relevance to Clinical Scenario:** High (3 points) - Directly addresses the patient\'s smoking history.\n   - **Logical Consistency:** High (3 points) - Consistent with guidelines for lung cancer screening in smokers.\n   - **Comprehensiveness:** High (3 points) - Addresses the significant risk factor of smoking.\n\n6. **Administer pneumococcal conjugate vaccination (F):**\n   - **Strength of Evidence:** High (3 points) - Recommended for adults over 65 or with certain risk factors.\n   - **Relevance to Clinical Scenario:** High (3 points) - The patient has never received this vaccination.\n   - **Logical Consistency:** High (3 points) - Consistent with vaccination guidelines.\n   - **Comprehensiveness:** High (3 points) - Addresses the lack of vaccination history.\n\n7. **Perform cystoscopy (G):**\n   - **Strength of Evidence:** Moderate (2 points) - Could be considered given family history of bladder cancer.\n   - **Relevance to Clinical Scenario:** Moderate (2 points) - Addresses family history but is more invasive than urine cytology.\n   - **Logical Consistency:** Moderate (2 points) - Reasonable but not first-line without symptoms.\n   - **Comprehensiveness:** Moderate (2 points) - Partially addresses family history.\n\n8. **Obtain CT urography (H):**\n   - **Strength of Evidence:** Low (1 point) - Not indicated without symptoms.\n   - **Relevance to Clinical S ...
#  '```json\n{\n    "Strength of Evidence": "3",\n    "Relevance to Clinical Scenario": "3",\n    "Logical Consistency": "3",\n    "Comprehensiveness": "3",\n    "Answer": "The most likely pathogen causing the symptoms in this scenario is Enterotoxigenic Escherichia coli (ETEC). This is because ETEC is a common cause of traveler\'s diarrhea, especially in regions like India. The patient\'s symptoms of watery diarrhea, abdominal pain, and onset shortly after eating are consistent with ETEC infection. The absence of fever and the presence of watery stools without blood or mucus further support this diagnosis.",\n    "Answer_letter": "K"\n}\n```',
#  '{\n    "Strength of Evidence": "3",\n    "Relevance to Clinical Scenario": "3",\n    "Logical Consistency": "3",\n    "Comprehensiveness": "3",\n    "Answer": "The most appropriate next step in diagnosis for this patient, given the clinical presentation of multiple gastric and duodenal ulcers, thick gastric folds, and negative H. pylori test, is to measure the fasting serum gastrin level. This is because the symptoms and findings are suggestive of Zollinger-Ellison syndrome, which is characterized by gastrin-secreting tumors (gastrinomas) leading to excessive gastric acid production.",\n    "Answer_letter": "D"\n}',
#  'To address the clinical scenario provided, we need to determine the most appropriate next step in management for a 53-year-old woman presenting with weakness, abdominal pain, and melena, with a history of normal colonoscopy three years ago. The patient is hypotensive and tachycardic, indicating possible hypovolemic shock due to gastrointestinal bleeding. The rectal exam confirms melena, suggesting an upper gastrointestinal source.\n\nGiven these findings, the most appropriate next step in management is to perform an esophagogastroduodenoscopy (EGD) to identify and potentially treat the source of upper gastrointestinal bleeding.\n\nHere is the evaluation based on the rubric:\n\n{\n    "Strength of Evidence": "3",\n    "Relevance to Clinical Scenario": "3",\n    "Logical Consistency": "3",\n    "Comprehensiveness": "3",\n    "Answer": "Esophagogastroduodenoscopy (EGD) is the most appropriate next step in management to identify and potentially treat the source of upper gastrointestinal bleeding, given the patient\'s presentation with melena and hemodynamic instability.",\n    "Answer_letter": "F"\n}',
#  '{\n    "Strength of Evidence": "3",\n    "Relevance to Clinical Scenario": "3",\n    "Logical Consistency": "3",\n    "Comprehensiveness": "3",\n    "Answer": "The most likely cause of this patient\'s anemia is mechanical destruction of erythrocytes due to aortic stenosis. The presence of a late systolic crescendo-decrescendo murmur at the right upper sternal border is characteristic of aortic stenosis, which can lead to mechanical hemolysis. This is supported by the laboratory findings of low haptoglobin and elevated bilirubin, indicating hemolysis. The family history of a bicuspid aortic valve further supports this diagnosis.",\n    "Answer_letter": "E"\n}',
#  '{\n    "Strength of Evidence": "3",\n    "Relevance to Clinical Scenario": "3",\n    "Logical Consistency": "3",\n    "Comprehensiveness": "3",\n    "Answer": "The most likely diagnosis for this patient is esophageal perforation. The patient\'s symptoms of severe epigastric discomfort and left-sided chest pain radiating to the back, along with vomiting, are consistent with esophageal perforation, especially following an esophagogastroduodenoscopy. The presence of crepitus over the chest suggests subcutaneous emphysema, which is a classic sign of esophageal perforation. The patient\'s vital signs, including tachycardia and hypotension, indicate a possible acute complication such as mediastinitis or sepsis, which can occur with esophageal perforation.",\n    "Answer_letter": "C"\n}']

# %%
answer_letters = re.findall(r'"Answer_letter":\s*"(\w)"', mcq_with_rubric_answers[4])

# Print the results
print(answer_letters)
# Out:
# ['E']

# %%
count = 0
for i in range(len(mcq_with_rubric_answers)):
    answer_letters = re.findall(r'"Answer_letter":\s*"(\w)"', mcq_with_rubric_answers[i])
    
    # Check if answer_letters is not empty before accessing [0]
    if answer_letters:
        if answer_letters[0] == df['answer'][i]:
            count += 1
        print(answer_letters[0], df['answer'][i])
    else:
        # Print the entire line that couldn't be captured
        print(f"Couldn't capture the answer letter in line {i}: {mcq_with_rubric_answers[i]}")

print("Total correct answers:", count)
# Out:
# F B
# A C
# B C
# A A
# E D
# K K
# D D
# F F
# E E
# C C
# C C
# F F
# F F
# A A
# C C
# D D
# A F
# E E
# D D
# A A
# Couldn't capture the answer letter in line 20: {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "The patient is at increased risk for renal crisis, a complication associated with systemic sclerosis (scleroderma). The symptoms and findings, such as skin thickening, telangiectasia, and limited joint mobility, are consistent with scleroderma. The elevated blood pressure and creatinine level suggest potential renal involvement, which can lead to scleroderma renal crisis characterized by acute renal failure and severe hypertension.",
#     "Answer_letter": "None"
# }
# C C
# C C
# G C
# A A
# A E
# C C
# B G
# C C
# D D
# D E
# Couldn't capture the answer letter in line 31: {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "The most likely underlying condition for the ulcerated mass in the gallbladder with invasion of the gallbladder wall and lymphatic vessels is gallbladder carcinoma. The patient's history of smoking is a risk factor for gallbladder cancer. The pathological findings of an ulcerated mass with invasion are consistent with a malignant process, and gallbladder carcinoma is known to present with such features.",
#     "Answer_letter": "None"
# }
# B B
# C C
# C C
# D F
# C C
# F D
# A A
# A A
# B B
# A A
# E C
# G G
# B B
# F C
# D D
# F A
# C C
# G G
# C C
# C C
# B B
# D D
# H A
# F B
# C A
# B B
# F A
# B B
# B B
# I I
# F F
# B B
# B B
# G G
# H G
# C D
# E G
# F F
# F C
# B B
# B B
# D D
# B B
# C C
# C D
# C A
# Couldn't capture the answer letter in line 78: {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "The most likely finding in further evaluation of this patient is 'macrocytic anemia due to vitamin B12 deficiency'. The patient's laboratory results show macrocytic anemia (elevated MCV of 112 fL) with normal iron studies (normal ferritin and iron levels), which suggests a non-iron deficiency cause of anemia. Given the history of Crohn's disease, which can affect the terminal ileum where vitamin B12 is absorbed, vitamin B12 deficiency is a plausible cause. The patient's symptoms of fatigue and difficulty concentrating are consistent with anemia, and the pale conjunctivae support this diagnosis. The elevated mean corpuscular hemoglobin (MCH) is also consistent with macrocytic anemia.",
#     "Answer_letter": "None"
# }
# E E
# Couldn't capture the answer letter in line 80: {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "The patient's presentation is most consistent with Peutz-Jeghers syndrome. This condition is characterized by the presence of hamartomatous polyps in the gastrointestinal tract and mucocutaneous pigmentation, such as the hyperpigmented maculae on the lips, buccal mucosa, palms, and soles observed in this patient. Peutz-Jeghers syndrome is associated with an increased risk of various malignancies, including gastrointestinal, pancreatic, and breast cancers.",
#     "Answer_letter": "None"
# }
# C B
# G F
# D E
# D A
# E E
# A D
# F F
# A A
# C C
# G G
# G G
# B E
# E G
# E C
# A A
# Couldn't capture the answer letter in line 96: ```json
# {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "The patient's symptoms and findings are suggestive of Plummer-Vinson syndrome, which is characterized by iron deficiency anemia, esophageal webs, and dysphagia. The conjunctival pallor, spoon-shaped nails (koilonychia), and fatigue are indicative of iron deficiency anemia. The esophagogastroduodenoscopy findings of thin membranes protruding into the esophagus align with esophageal webs. Further evaluation is most likely to show iron deficiency, confirmed by low serum ferritin and low serum iron levels.",
#     "Answer_letter": "None"
# }
# ```
# B B
# E C
# A A
# D D
# A A
# D D
# F A
# Couldn't capture the answer letter in line 104: {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "The virus described in the scenario is most likely a member of the Reoviridae family. Reoviruses are nonenveloped, have a segmented RNA genome, and exhibit genetic reassortment when two strains coinfect a single host cell. This reassortment is a well-documented phenomenon in viruses with segmented genomes, such as those in the Reoviridae family.",
#     "Answer_letter": "None"
# }
# A A
# B B
# D D
# F F
# D D
# F F
# B B
# G G
# B B
# E E
# C C
# A A
# D D
# E E
# D D
# C C
# C C
# C C
# B B
# A A
# E E
# B B
# B C
# D D
# D D
# F F
# F F
# G G
# F B
# Couldn't capture the answer letter in line 134: {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "The left recurrent laryngeal nerve is at greatest risk for injury during the surgical resection of an esophageal mass, especially when the mass is located near the upper esophageal sphincter. This nerve runs in close proximity to the esophagus and can be damaged during procedures involving the esophagus, leading to vocal cord paralysis and hoarseness.",
#     "Answer_letter": "None"
# }
# A A
# C C
# C D
# C C
# A F
# B B
# C C
# D E
# F F
# C F
# C C
# C C
# E E
# A A
# D E
# F F
# G G
# C C
# D E
# E E
# E E
# E E
# C B
# D D
# E E
# E E
# A A
# D D
# B B
# F F
# D D
# E E
# A D
# B B
# C C
# Couldn't capture the answer letter in line 170: {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "The most likely finding in this scenario is elevated serum gastrin levels, indicative of Zollinger-Ellison syndrome (gastrinoma). The patient's symptoms of recurrent duodenal ulcers, heartburn, abdominal pain, and greasy diarrhea, along with a family history suggestive of multiple endocrine neoplasia type 1 (MEN1), point towards a gastrin-secreting tumor. This condition leads to excessive gastric acid production, causing the ulcers and diarrhea.",
#     "Answer_letter": "None"
# }
# D D
# B E
# E E
# C D
# E E
# B C
# A D
# E E
# B B
# C C
# A A
# E E
# C A
# A A
# C B
# B B
# E E
# E A
# Couldn't capture the answer letter in line 189: {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "The most likely cause of this patient's symptoms is mechanical destruction of erythrocytes due to aortic stenosis. The patient's symptoms of fatigue and dark urine, along with the laboratory findings of elevated bilirubin and low haptoglobin, suggest hemolysis. The presence of a heart murmur, specifically a late systolic crescendo-decrescendo murmur at the right upper sternal border, is characteristic of aortic stenosis, which can lead to mechanical hemolysis. The family history of a bicuspid aortic valve further supports this diagnosis.",
#     "Answer_letter": "None"
# }
# D D
# B B
# A A
# B B
# B B
# D D
# D D
# E B
# D A
# E A
# B C
# E D
# B B
# A D
# C C
# D A
# B E
# E B
# D A
# E E
# E D
# B B
# D D
# E E
# D D
# D D
# Couldn't capture the answer letter in line 216: {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "The most likely source of this patient's anemia is mechanical destruction of erythrocytes due to aortic stenosis. The presence of a heart murmur, specifically a crescendo-decrescendo murmur over the upper right sternal border, is characteristic of aortic stenosis. This condition can lead to hemolysis as red blood cells are damaged while passing through the stenotic valve. The patient's symptoms of decreased energy and weakness, along with laboratory findings of anemia, support this diagnosis.",
#     "Answer_letter": "None"
# }
# D D
# D D
# A A
# D D
# A A
# E B
# A B
# A A
# C E
# A D
# C C
# A A
# C C
# B B
# C C
# D D
# E C
# A A
# E B
# D D
# C C
# C B
# E E
# E C
# B B
# B B
# A A
# A A
# C B
# A A
# E E
# B B
# D A
# B B
# E E
# B B
# A A
# D D
# B B
# C C
# A A
# D D
# Couldn't capture the answer letter in line 259: {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "The most likely diagnosis for the lesions seen in endoscopy is radiation-induced gastritis. The patient's history of hepatocellular carcinoma treated with radiotherapy, combined with the endoscopic findings of diffuse edematous hyperemic mucosa and multiple hemorrhagic patches with active oozing, strongly suggests this condition. Radiation therapy can cause damage to the gastric mucosa, leading to inflammation and bleeding, which aligns with the patient's symptoms of hematemesis and melena.",
#     "Answer_letter": "None"
# }
# B D
# D D
# B B
# D D
# C C
# C C
# A A
# A B
# A B
# A C
# B D
# E B
# D D
# E C
# D D
# E E
# B D
# B B
# B B
# D D
# B A
# D D
# D A
# E E
# B B
# C C
# B B
# A A
# C C
# A A
# A C
# E E
# B C
# A A
# C C
# E B
# B B
# C C
# A A
# A A
# D D
# E E
# C C
# E E
# C C
# E E
# Couldn't capture the answer letter in line 306: {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "The most likely cause for this patient's lab findings, given the scenario, is over-ingestion of iron supplements. The patient's serum iron level is 130 μg/dL, which is within the normal range, but the presence of a bleeding ulcer in the proximal duodenum and the negative stool guaiac test for occult blood suggest that the bleeding is not significant enough to cause iron deficiency anemia. The patient's use of dietary supplements 'to cope' could imply excessive intake of iron supplements, leading to normal or elevated serum iron levels despite the ulcer. This aligns with the clinical scenario and the lab findings.",
#     "Answer_letter": "None"
# }
# Couldn't capture the answer letter in line 307: {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "The drug that would most likely cause a similar side effect to that seen in this patient is Methotrexate. Methotrexate is known to cause elevated homocysteine levels and decreased serum folic acid levels due to its mechanism of action as a folate antagonist. This aligns with the patient's laboratory findings of elevated homocysteine and decreased folic acid levels.",
#     "Answer_letter": "None"
# }
# D D
# C C
# B B
# B B
# B B
# E E
# D E
# A A
# E E
# Couldn't capture the answer letter in line 317: {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "The patient is likely deficient in iron. The symptoms and biopsy findings are consistent with celiac disease, which can lead to malabsorption of nutrients, including iron. The frequent diarrhea, fatigue, inability to gain weight, and the description of the stools suggest malabsorption. The blunting of intestinal villi and flat mucosa with intraepithelial lymphocytes are classic findings in celiac disease, which often results in iron deficiency anemia due to malabsorption.",
#     "Answer_letter": "None"
# }
# Couldn't capture the answer letter in line 318: {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "The most likely explanation for the cardiac findings in this patient is mechanical destruction of erythrocytes due to aortic regurgitation. The high-pitched blowing diastolic murmur best heard over the right upper sternal border is characteristic of aortic regurgitation. The head bobbing with each heartbeat (De Musset's sign) and the presence of aortic regurgitation are consistent with aortic valve disease, which can lead to mechanical hemolysis. The patient's anemia, low serum ferritin, and iron levels, along with the elevated total iron-binding capacity, suggest iron deficiency anemia, which can be exacerbated by chronic blood loss or hemolysis. The presence of conjunctival hemorrhages, petechiae, and splenomegaly further supports the diagnosis of hemolytic anemia. The neoplastic growth in the colon could also contribute to chronic blood loss, but the cardiac findings are more directly explained by the mechanical destruction of erythrocytes due to the aortic valve abnormality.",
#     "Answer_letter": "None"
# }
# C C
# D D
# A A
# A A
# C C
# D A
# C C
# E C
# D D
# B B
# D E
# C B
# D C
# A A
# A A
# B B
# B B
# B B
# A A
# D D
# E E
# E E
# E B
# E B
# B B
# D C
# B B
# D D
# C C
# B B
# B D
# A B
# B B
# D A
# B B
# E E
# B B
# Couldn't capture the answer letter in line 356: {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "The clinical presentation and laboratory findings suggest the possibility of primary hyperparathyroidism. The patient has hypercalcemia (calcium 11.2 mg/dL) and hypophosphatemia (phosphorus 2.0 mg/dL), which are indicative of hyperparathyroidism. The family history of peptic ulcer disease and recurrent kidney stones, along with the patient's symptoms of abdominal pain and constipation, further support this diagnosis. Additional evaluation is most likely to reveal an elevated parathyroid hormone (PTH) level, confirming primary hyperparathyroidism.",
#     "Answer_letter": "None"
# }
# E E
# A B
# D B
# Couldn't capture the answer letter in line 360: To address the scenario provided, we need to determine the appropriate screening test for a 50-year-old Caucasian man who is a smoker, based on the United States Preventive Services Task Force (USPSTF) guidelines. The patient has no current complaints, is healthy, and has a negative family history for gastrointestinal disorders.
#
# ### Evaluation of Screening Tests:
#
# 1. **Prostate-specific antigen for prostate cancer (A):**
#    - **Strength of Evidence:** Moderate (2 points) - PSA screening is controversial and not universally recommended for all men without specific risk factors.
#    - **Relevance to Clinical Scenario:** Low (1 point) - The scenario does not mention any symptoms or risk factors for prostate cancer.
#    - **Logical Consistency:** Moderate (2 points) - While PSA is a common screening test, it is not directly relevant to the scenario.
#    - **Comprehensiveness:** Low (1 point) - Does not address the smoking history or age-related recommendations.
#
# 2. **Carcinoembryonic antigen for colorectal cancer (B):**
#    - **Strength of Evidence:** Low (1 point) - CEA is not recommended as a screening tool for colorectal cancer.
#    - **Relevance to Clinical Scenario:** Low (1 point) - Not relevant as a screening test for this patient.
#    - **Logical Consistency:** Low (1 point) - CEA is not used for screening.
#    - **Comprehensiveness:** Low (1 point) - Does not address the scenario.
#
# 3. **Abdominal ultrasonography for abdominal aortic aneurysm (C):**
#    - **Strength of Evidence:** High (3 points) - Recommended for men aged 65-75 who have ever smoked.
#    - **Relevance to Clinical Scenario:** Moderate (2 points) - The patient is younger than the recommended age range.
#    - **Logical Consistency:** Moderate (2 points) - Logical for older smokers, but not directly applicable here.
#    - **Comprehensiveness:** Moderate (2 points) - Addresses smoking history but not age.
#
# 4. **Low-dose computerized tomography for lung cancer (D):**
#    - **Strength of Evidence:** High (3 points) - Recommended for adults aged 50-80 with a significant smoking history.
#    - **Relevance to Clinical Scenario:** High (3 points) - Directly relevant due to the patient's smoking history.
#    - **Logical Consistency:** High (3 points) - Consistent with USPSTF guidelines for smokers.
#    - **Comprehensiveness:** High (3 points) - Fully addresses the patient's age and smoking history.
#
# 5. **Colonoscopy for colorectal cancer (E):**
#    - **Strength of Evidence:** High (3 points) - Recommended starting at age 45 for average-risk individuals.
#    - **Relevance to Clinical Scenario:** High (3 points) - Relevant for the patient's age.
#    - **Logical Consistency:** High (3 points) - Consistent with guidelines for colorectal cancer screening.
#    - **Comprehensiveness:** High (3 points) - Addresses age-related screening recommendations.
#
# ### Conclusion:
#
# Based on the USPSTF guidelines and the patient's profile, the most appropriate screening tests are:
#
# - **Low-dose computerized tomography for lung cancer (D)**
# - **Colonoscopy for colorectal cancer (E)**
#
# Both options are relevant and supported by guidelines for this patient's age and smoking history.
#
# ```json
# {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "Low-dose computerized tomography for lung cancer and Colonoscopy for colorectal cancer are recommended for this patient based on USPSTF guidelines.",
#     "Answer_letter": "D and E"
# }
# ```
# D D
# C C
# A A
# C D
# D D
# D D
# B B
# C C
# E E
# E E
# C E
# A A
# B B
# B B
# D D
# A C
# A A
# B B
# D E
# C C
# B B
# A A
# A D
# C E
# F F
# D D
# C C
# E E
# C C
# B B
# B B
# E E
# A A
# E D
# A A
# A A
# B C
# A A
# B B
# A A
# C C
# Couldn't capture the answer letter in line 402: {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "The patient's symptoms of postprandial bloating and abdominal pain following the ingestion of milk products suggest lactose intolerance. Lactose intolerance is due to a deficiency in lactase, the enzyme that breaks down lactose in the digestive system. The drug that has a mechanism of action similar to the pathophysiology of this patient's condition is lactase enzyme supplements. These supplements provide the enzyme that the patient lacks, aiding in the digestion of lactose and alleviating symptoms.",
#     "Answer_letter": "None"
# }
# D D
# A D
# D D
# E E
# C C
# E E
# A A
# C C
# C C
# Couldn't capture the answer letter in line 412: {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "The patient is likely experiencing Clostridioides difficile infection (CDI), commonly associated with antibiotic use, especially in elderly patients. The presence of watery diarrhea and yellow plaques on sigmoidoscopy are classic signs of pseudomembranous colitis caused by C. difficile. The best choice of treatment for this condition is oral vancomycin or fidaxomicin. Oral vancomycin is often preferred for initial episodes of CDI, especially in severe cases.",
#     "Answer_letter": "None"
# }
# A A
# D D
# C D
# D D
# E C
# B B
# B B
# D D
# B B
# A A
# D D
# A A
# B C
# A A
# B B
# E E
# E C
# B B
# E E
# D D
# C C
# E E
# E E
# A B
# C C
# D D
# A A
# A A
# B B
# B B
# A A
# B A
# D D
# A A
# C A
# Couldn't capture the answer letter in line 448: {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "The patient's condition is most strongly associated with diverticulitis. The presence of multiple colonic mucosal outpouchings (diverticula) noted in the colonoscopy, combined with the symptoms of right lower quadrant pain, fever, and constipation, suggest an episode of diverticulitis. Diverticulitis occurs when these diverticula become inflamed or infected, leading to the symptoms observed in this patient.",
#     "Answer_letter": "None"
# }
# E E
# E E
# Couldn't capture the answer letter in line 451: {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "The best answer is that the mechanical destruction of erythrocytes is due to aortic stenosis, as indicated by the heart murmur and family history of bicuspid aortic valve. This conclusion is supported by the clinical presentation of anemia, laboratory findings of hemolysis, and the absence of autoimmune markers or enzyme defects.",
#     "Answer_letter": "None"
# }
# Couldn't capture the answer letter in line 452: {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "The most likely cause of this patient's condition is related to his history of untreated syphilis, which can lead to syphilitic aortitis. This condition can cause calcification of the aortic root and result in aortic regurgitation, which is consistent with the diastolic decrescendo murmur over the right upper sternal border and the tambour-like quality of S2. The patient's history of a sore on his penis that resolved without treatment suggests a past syphilitic infection, which aligns with the findings of aortic root calcification.",
#     "Answer_letter": "None"
# }
# B D
# C C
# E E
# B B
# E C
# E E
# E C
# B B
# B B
# C B
# B B
# A D
# C C
# D D
# E E
# B B
# D B
# D D
# D A
# B D
# C C
# E E
# B B
# C C
# D A
# E E
# D A
# E E
# D D
# B D
# Couldn't capture the answer letter in line 483: ```json
# {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "The patient's presentation is most strongly associated with Crohn's disease. The symptoms of fatigue, abdominal pain, non-bloody diarrhea, and decreased appetite, along with the colonoscopy findings of perianal inflammation, normal rectum, and transmural inflammation in the transverse colon, are characteristic of Crohn's disease. Crohn's disease is an inflammatory bowel disease that can cause transmural inflammation and can affect any part of the gastrointestinal tract, often leading to perianal disease.",
#     "Answer_letter": "None"
# }
# ```
# Couldn't capture the answer letter in line 484: {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "The jejunum and duodenum can be distinguished by several anatomical and histological features. The jejunum has more prominent plicae circulares (circular folds) compared to the duodenum, which aids in nutrient absorption. The duodenum contains Brunner's glands in the submucosa, which secrete alkaline mucus to neutralize gastric acid, a feature absent in the jejunum. Additionally, the jejunum has a thicker wall and a larger diameter than the duodenum. The presence of Peyer's patches is more common in the ileum, but they can also be found in the jejunum, whereas they are not typically present in the duodenum.",
#     "Answer_letter": "None"
# }
# B B
# A A
# B B
# D D
# D A
# A A
# Couldn't capture the answer letter in line 491: {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "The most likely explanation for this patient's symptoms is hypoglycemia. The laboratory result shows a glucose level of 34 mmol/L, which is critically low and can lead to seizure-like activity, lethargy, and unresponsiveness. The absence of fever, pain, or recent trauma, along with the current antibiotic treatment for an ear infection, suggests that the seizure-like activity is not due to an infectious or inflammatory process. The elevated liver enzymes (AST and ALT) could indicate liver stress or damage, which can be associated with metabolic disturbances like hypoglycemia. The normal thyroid function and electrolyte levels further support that the primary issue is the low glucose level. Immediate correction of hypoglycemia is necessary to prevent further neurological complications.",
#     "Answer_letter": "None"
# }
# E A
# C B
# B A
# B E
# A A
# D D
# Couldn't capture the answer letter in line 498: {
#     "Strength of Evidence": "3",
#     "Relevance to Clinical Scenario": "3",
#     "Logical Consistency": "3",
#     "Comprehensiveness": "3",
#     "Answer": "The most likely cause for the patient's poor treatment response is the continued presence of Helicobacter pylori infection, as indicated by the positive repeat urease breath test. This suggests that the initial treatment regimen was ineffective in eradicating the infection, which is a common cause of gastric ulcers. Factors contributing to treatment failure could include antibiotic resistance, inadequate adherence to the treatment regimen, or insufficient acid suppression.",
#     "Answer_letter": "None"
# }
# A A
# C C
# A B
# Total correct answers: 344
